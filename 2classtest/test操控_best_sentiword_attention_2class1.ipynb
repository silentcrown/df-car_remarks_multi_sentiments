# %%
import pandas as pd
import numpy as np
import torchvision as tv
import jieba
from gensim import models
from gensim.models import Word2Vec
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
import torch
show = ToPILImage() # 可以把Tensor转成Image，方便可视化
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../../../data/df_sen_sub/train.csv')
data
# Out:
#             content_id                                            content  \
# 0     vUXizsqexyZVRdFH           因为森林人即将换代，这套系统没必要装在一款即将换代的车型上，因为肯定会影响价格。
# 1     4QroPd9hNfnCHVt7      四驱价格貌似挺高的，高的可以看齐XC60了，看实车前脸有点违和感。不过大众的车应该不会差。
# 2     QmqJ2AvM5GplaRyz  斯柯达要说质量，似乎比大众要好一点，价格也低一些，用料完全一样。我听说过野帝，但没听说过你说...
# 3     KMT1gFJiU4NWrVDn           这玩意都是给有钱任性又不懂车的土豪用的，这价格换一次我妹夫EP020可以换三锅了
# 4     nVIlGd5yMmc37t1o                            17价格忒高，估计也就是14-15左右。
# 5     TVciHBPL5XmUxMEd  我开始就是荣放2.5  森林人2.5二选一    荣放主要是底盘质感不行   太硬  其次是...
# 6     4lb9TsO5rjqUy1Bu                   唉，这货的价格死硬死硬的，低配版优惠1万据说已经罕有了。
# 7     z98xV7MphZIF4EvO                      价格的话只能说一般般吧，太仓前段时间定的比你便宜！
# 8     hoWrMnGTUvdsK3Dm                                听过，价格太贵，但一直念念不忘
# 9     r1WHgbI0ZKqMdELy                                      恭喜恭喜，这个优惠不错哦！
# 10    JSQUo6kblXYvtc2h                                     优惠幅度不小了，北京优惠八千
# 11    7kCF590PjAYqzEL6                         优惠可以了！购进吧！买了不会后悔的！时间可鉴！
# 12    EXBiRczhIu3paJWb                                        现在 什么价 优惠多少
# 13    nQ0bIZtzj6P1Esgd                                 优惠一万一 送贴膜装甲脚垫 铁西庞大
# 14    JvXIqLT8cGDuPEWe                             我也大连的，最近也考虑入手森林人，优惠太小了
# 15    NXyGEbt0AZ5rHJ3e                                  山东威海全系这才优惠3000，MD
# 16    kN0LghcimajxWwH8                                    下手了，豪导特供，优惠1.6万
# 17    vVoKucJy5pO0jSk2                                 优惠了8000，什么都不送。
# 18    iBFJMqHtTRD5Qo6S                          兄弟2.5豪导特供优惠1.6万可以下手吗？
# 19    G8Yr51elsVaXFUZC                          恭喜，优惠多少，我准备明天去提，2.5特装优惠两万
# 20    10WF8Q53pVfOryvA  什么车款，多少优惠啊？康桥我只能谈到优惠1.5其他还送什么没问，试驾了一次看了两次2.0时尚...
# 21    VrRd1HcoMNAkvhJy                                   优惠1 ，就送行程记录
# 22    1BYpO9FsgkmWLNQu  平常心吧，我本来想买傲虎，优惠不大，钱不够，改提森林人，6月提尊贵优惠1.4w，到了9月做活...
# 23    9EFImNb0ywhHBlcR                                 哈哈，25.48。优惠够给力
# 24    2aNFSuYeZo7B1b9R  兄弟，我也云南的，你的优惠也挺大的，现在哪里来的全系3万啊。。。现傲虎全系无优惠，森林人才八...
# 25    4EK1Nu7X2DTzomRS                  来湖北，我上月订的2.0蓝色时尚，优惠1万3送6次保养，本月底提车
# 26    TWPEyNaI5mFgYupn                            什么都没有，就是现金优惠和给了点小东西
# 27    96A5VQfBgPWUYkul                什么都没有，就是现金优惠和给了点小东西，你最好先问问看有没有车
# 28    JXlEzBcKGpI8stdr                             原来最低也就优惠15000至16000
# 29    P5A3evWb9jUyHMB2                                   我们这里，优惠2000，我呵呵了
# ...                ...                                                ...
# 9917  NtDO9KM2TQJYp8rC                                  风噪大 音响差驾驶什么的，秒杀其他
# 9918  lsMktgZyBDUfbowu               安全大于一切，出远门前一定要检查车子，主要有全车油水，轮胎，刹车系统等。
# 9919  hwzJjbCV26pLscxk  发动机直接就不一样了 FA20是斯巴鲁的招牌发动机 给WRX用要是烧的厉害那帮暴力驾驶的估计...
# 9920  6FMslAfukBpR82Po                            看路况，省道多平均油耗8-9，市区多11-12
# 9921  7X9tyquOCj0aw2Ql  换挡不是根据速度，而是根据你的意图。你想省油并匀速驾驶，就在转速允许的情况档位越高越好。想要...
# 9922  7X9tyquOCj0aw2Ql  换挡不是根据速度，而是根据你的意图。你想省油并匀速驾驶，就在转速允许的情况档位越高越好。想要...
# 9923  QBGuT7YNWVDsXgb8                                  同款配置黑森还要下个月中旬才能提车
# 9924  goheSWvcEPp79Lm6                                        正常，我城里跑油耗11
# 9925  pdjz83AoiWvu1lbh  森林人做工一般，配置还不如8、9万的国产车，这是事实。在老家侄儿子的五菱宏光把我的森林人给甩...
# 9926  pdjz83AoiWvu1lbh  森林人做工一般，配置还不如8、9万的国产车，这是事实。在老家侄儿子的五菱宏光把我的森林人给甩...
# 9927  K9s7OTLiCMm1dvzH             导航已经换成凯立德了，其它的功能也很差，我只是用来听收音机，导航还是手机的好
# 9928  wpHCZYOSrmske3yW                   有没有换过导航啥的，一般新车很少电路故障，行车电脑问题几率大点！
# 9929  I5NyHgsnkWvj84di  感觉稍微有点高了，油耗高低和很多方面有关，比如你个人驾驶习惯，你行驶道路拥堵状况等等，平稳驾...
# 9930  AoZJqK17aOz4UfxX                        选12款之前的。12款后都是fb发动机， 机油消耗大。
# 9931  cQlpvPRdOwUXaVkh                  跟欧蓝德的调校很相似啊，掌握规律后，堵车时跟车，可减少踩刹车的次数
# 9932  QVf8TWXrIPDwEgNU                    哈哈哈，欧兰德也能上来跟森比，那破车你开几年试试，那操控也能比
# 9933  dr1QZyaGWbI2BKxz                           14款2.0，大连，七万多公里了，平均油耗10。
# 9934  hMZEBAwkNz8Du714    森林人2.0开了两年，一直在中石化加油站加92#，没啥问题，杠杠的，夏天开空调油耗8.5左右。
# 9935  hMZEBAwkNz8Du714    森林人2.0开了两年，一直在中石化加油站加92#，没啥问题，杠杠的，夏天开空调油耗8.5左右。
# 9936  d4aM8HCr5VisWlfU        国内轮胎的品牌还是比较多的，看你要准备用什么价位的了，一般来说声音越小的价格也就高些。
# 9937  9oHZT5rXOjauPA7V                                      我的也这样，换刹车片后消失
# 9938  wlSvQOt3Kz2ekbcg                               反正我是不会去了，除非关健部位如变速箱油
# 9939  ELB0ZT5CvK9Fok4H  我感觉你的油耗稍大些，我这里山东，最冷零下18度，最高6度或者0度左右，也是16款2.0的，...
# 9940  vdDQXJEg3wSj84er                                     我的方向盘也是两边缝不一样大
# 9941  hUSkd6ptCbfxMPo8  俺必须的说，15公里以上的上下班单程行程，很少红灯，80左右的速度……对小森是极好的……所以...
# 9942  VywQTI4iLuzd1DZ3  老铁没毛病...双击666！！！是不是这样？我这理解逻辑也挑不出毛病吧！你不矫情你试试？多大...
# 9943  Ufv6VpyNaGnShzlJ           2.0时尚，四川这段时间温度最低-1，基本上下班用，现在均速18，表显油耗9.2
# 9944  S8tmC0gxyBjzvLuN                                相貌不起眼，内饰太平淡，开起来才知道好
# 9945  vpaS3ueRQi2rhAgH  一看就知道山寨的！用的肯定是中控的普通视频输入接口而已，这种无屏的记录仪淘宝也就一两百块的东...
# 9946  5R0ZoOdv8H2MNGgt  楼主还在吗，同在上海，想咨询一下家用首辆车，到底是买森林人还是力狮好？如果森林人，2.0的动...
#
#      subject  sentiment_value sentiment_word
# 0         价格                0             影响
# 1         价格               -1              高
# 2         价格                1              低
# 3         价格               -1           有钱任性
# 4         价格               -1              高
# 5         价格                1             便宜
# 6         价格               -1             死硬
# 7         价格                0             一般
# 8         价格               -1              贵
# 9         价格                1           优惠不错
# 10        价格                1         优惠幅度不小
# 11        价格                1           不会后悔
# 12        价格                0             优惠
# 13        价格                0             优惠
# 14        价格               -1           优惠太小
# 15        价格               -1            才优惠
# 16        价格                0             优惠
# 17        价格                0             优惠
# 18        价格                0             优惠
# 19        价格                0             优惠
# 20        价格                0             优惠
# 21        价格                0             优惠
# 22        价格                0             优惠
# 23        价格                0             优惠
# 24        价格               -1              才
# 25        价格                0             优惠
# 26        价格                0             优惠
# 27        价格                0             优惠
# 28        价格                0             优惠
# 29        价格               -1             呵呵
# ...      ...              ...            ...
# 9917     舒适性               -1            NaN
# 9918     安全性                1            NaN
# 9919      动力               -1            NaN
# 9920      油耗                0            NaN
# 9921      动力                0            NaN
# 9922     安全性                1            NaN
# 9923      配置                0            NaN
# 9924      油耗                0            NaN
# 9925      配置               -1            NaN
# 9926      内饰               -1            NaN
# 9927      配置                0            NaN
# 9928      配置                0            NaN
# 9929      油耗                0            NaN
# 9930      动力                0            NaN
# 9931     安全性                1            NaN
# 9932      操控               -1            NaN
# 9933      油耗                0            NaN
# 9934      油耗                0            NaN
# 9935     舒适性                1            NaN
# 9936      价格               -1            NaN
# 9937     安全性                1            NaN
# 9938      动力                0            NaN
# 9939      油耗               -1            NaN
# 9940      操控               -1            NaN
# 9941      油耗                0            NaN
# 9942      外观                1            NaN
# 9943      油耗                0            NaN
# 9944      内饰               -1            NaN
# 9945      配置               -1            NaN
# 9946      动力                0            NaN
#
# [9947 rows x 5 columns]

# %%
'''
data = pd.read_csv('../../data/df_sen_sub/train.csv')
len(data['content_id'].unique()), len(list(data['content_id']))
content_ids = data['content_id'].unique()
subjs = data['subject'].unique()
df = {}
text, subs, sentis = [], [], []
for i in range(len(content_ids)):
    if i % 100 == 0:print(i)
    dd = data[data['content_id'] == content_ids[i]]
    text.append(dd.loc[dd.index.tolist()[0], 'content'])
    temp_subs, temp_senti = [], []
    for sub in subjs:
        temp_subs.append(sub)
        if len(dd[dd['subject'] == sub]) != 0:
            temp_senti.append(str(int(dd[dd['subject'] == sub]['sentiment_value'])))
        else:
            temp_senti.append('2')
    subs.append(','.join(temp_subs))
    sentis.append(','.join(temp_senti))
df['content'] = text
df['subjects'] = subs
df['sentiments'] = sentis
df = pd.DataFrame(df)
df.to_csv('../../data/df_sen_sub/merge_train.csv', index = False)
#data = pd.read_csv('../../data/df_sen_sub/test_public.csv')
'''
# Out:
# "\ndata = pd.read_csv('../../data/df_sen_sub/train.csv')\nlen(data['content_id'].unique()), len(list(data['content_id']))\ncontent_ids = data['content_id'].unique()\nsubjs = data['subject'].unique()\ndf = {}\ntext, subs, sentis = [], [], []\nfor i in range(len(content_ids)):\n    if i % 100 == 0:print(i)\n    dd = data[data['content_id'] == content_ids[i]]\n    text.append(dd.loc[dd.index.tolist()[0], 'content'])\n    temp_subs, temp_senti = [], []\n    for sub in subjs:\n        temp_subs.append(sub)\n        if len(dd[dd['subject'] == sub]) != 0:\n            temp_senti.append(str(int(dd[dd['subject'] == sub]['sentiment_value'])))\n        else:\n            temp_senti.append('2')\n    subs.append(','.join(temp_subs))\n    sentis.append(','.join(temp_senti))\ndf['content'] = text\ndf['subjects'] = subs\ndf['sentiments'] = sentis\ndf = pd.DataFrame(df)\ndf.to_csv('../../data/df_sen_sub/merge_train.csv', index = False)\n#data = pd.read_csv('../../data/df_sen_sub/test_public.csv')\n"

# %%
data = pd.read_csv('../../../data/df_sen_sub/merge_train.csv')
data = data.fillna('')
subs = list(data['subjects'])
sentiments = list(data['sentiments'])
content = list(data['content'])
test_data = pd.read_csv('../../../data/df_sen_sub/test_public.csv')
test_data = test_data.fillna('')
test_content = list(test_data['content'])
data = pd.read_csv('../../../data/df_sen_sub/train.csv')
data = data.fillna('')
senti_words = list(data['sentiment_word'])

# %%
with open('../../../data/df_sen_sub/add_text.txt','w') as f:
    f.write('\n'.join(list(content) + list(test_content)  + list(subs) + senti_words))
# 迭代器，使用jieba将句子进行分词
stopwords = open('../stopwords.txt', 'r').read().split('\n')
class Sentences(object):# 这个类可以根据实际情况重写，我已经将所有的文章进行分句，并整合到了一个文件里面
    def __init__(self, dirname):
        self.dirname = dirname # 句子所在文件，没句句子占一行
        #jieba.load_userdict("wordBase.txt") # 加载词库

    def __iter__(self):
        #for fname in os.listdir(self.dirname):
        for line in open(self.dirname):
                line = line.replace('\n', '')
                res = []
                for word in list(jieba.cut(line)):
                    if word in stopwords:
                        continue
                    res.append(word)
                yield res#list(jieba.cut(line))

sentences = []
def train_word2vec(folder_path, size=100):
    global sentences
    sentences = Sentences(folder_path) #生成分词后的句子，是一个二维数组

    # size是词向量长度
    # worker是线程数量，建议与物理线程数量一致
    # min_count是指出现次数小于一定程度，就忽略，0表示不忽略
    #model = Word2Vec(sentences, size=size, workers=8, min_count=0)

    # 训练结束就将模型保存起来
    #model.save("../../data/df_sen_sub/add_word2vec_model")

# 生成50维度的词向量模型
train_word2vec("../../../data/df_sen_sub/add_text.txt",100)

# 测试训练好的词向量模型，使用model[keyWord]即可获取keyword这个词的词向量
model = Word2Vec.load("../../../data/df_sen_sub/add_word2vec_model")
sentences = list(sentences)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.943 seconds.
# Prefix dict has been built succesfully.

# %%
len(sentences)
# Out:
# 28890

# %%
from collections import Counter
data = pd.read_csv('../../../data/df_sen_sub/train.csv')
sub_uniq = data['subject'].unique()
data = data[pd.notnull(data['sentiment_word'])]
senti_word_set = {}
sum_ = 0
for key in sub_uniq:
    co = 0
    senti_word_set[key] = {}
    #dd = list(data[data['subject'] == key]['sentiment_word'])
    ddd = data[data['subject'] == key]
    for kk in [-1, 0, 1]:
        dd = list(ddd[ddd['sentiment_value'] == kk]['sentiment_word'])
        ss = []
        for phras in dd:
            words = list(jieba.cut(phras))
            for word in words:
                word = word.replace(' ', '')
                if word == '' or word in stopwords:continue
                ss.append(word)
                co += 1
            counter = Counter(ss)
            sort = sorted(counter.items(), key=lambda item: item[1], reverse = True)
            for mm in counter:
                if mm not in senti_word_set[key]:
                    senti_word_set[key][mm] = kk
                elif senti_word_set[key][mm] == kk:
                    continue
                else:
                    senti_word_set[key][mm] = 0
        sum_ += co
print(sum_)
senti_word_set
# Out:
# 6431
# {'价格': {'高': 0,
#   '有钱': -1,
#   '任性': -1,
#   '死硬': -1,
#   '贵': 0,
#   '优惠': 0,
#   '太小': -1,
#   '套路': -1,
#   '太贵': -1,
#   '不值': -1,
#   '高昂': -1,
#   '下不来': -1,
#   '不会': 0,
#   '便宜': 0,
#   '放弃': -1,
#   '平易近人': -1,
#   '价格': 0,
#   '老贵': -1,
#   '没有': 0,
#   '保证': -1,
#   '好多': -1,
#   '更': -1,
#   '合适': 0,
#   '那点': -1,
#   '贵太多': -1,
#   '挺高': -1,
#   '不菲': -1,
#   '一点': 0,
#   '奇高': -1,
#   '不好': -1,
#   '小贵': 0,
#   '过高': -1,
#   '售价': -1,
#   '明显': -1,
#   '高于': -1,
#   '竞品': -1,
#   '优势': -1,
#   '虚高': -1,
#   '不高': 0,
#   '性价比': 0,
#   '不算': -1,
#   '单价': -1,
#   '没': 0,
#   '降价': -1,
#   '不要': 0,
#   '想': -1,
#   '保值': -1,
#   '率': -1,
#   '大众': -1,
#   '好': 0,
#   '略贵': -1,
#   '保养': -1,
#   '不用': -1,
#   '考虑': -1,
#   '不靠': -1,
#   '谱': -1,
#   '没法': -1,
#   '咬咬牙': -1,
#   '不合算': -1,
#   '影响': 0,
#   '亲民点': 0,
#   '差不多': 0,
#   '差距': 0,
#   '知道': 0,
#   '合理': 0,
#   '就行': 0,
#   '行情': 0,
#   '价': 0,
#   '正常': 0,
#   '几百': 0,
#   '参差不齐': 0,
#   '行': 0,
#   '买': 0,
#   '价差': 0,
#   '很大': 0,
#   '低': 0,
#   '不能': 0,
#   '在意': 0,
#   '还行': 0,
#   '不错': 1,
#   '幅度': 1,
#   '不小': 1,
#   '后悔': 1,
#   '值': 1,
#   '愉快': 1,
#   '不够': 1,
#   '比较': 1,
#   '下降': 1,
#   '很多': 1,
#   '超级': 1,
#   '最好': 1,
#   '操控': 1,
#   '满意': 1,
#   '费用': 1,
#   '相当': 1,
#   '实惠': 1,
#   '再贵': 1,
#   '车': 1,
#   '欧蓝德': 1,
#   '真心': 1,
#   '秒杀': 1,
#   '对手': 1,
#   '力度': 1,
#   '良心': 1,
#   '找不出': 1,
#   '第二辆': 1},
#  '配置': {'没': -1,
#   '实用': 0,
#   '背光': -1,
#   '没有': 0,
#   '山寨': -1,
#   '不值钱': -1,
#   '贵': -1,
#   '比不上': -1,
#   '黑': -1,
#   '垃圾': -1,
#   '差': -1,
#   '卡死': -1,
#   '黑屏': -1,
#   '惨不忍睹': -1,
#   '鸡肋': -1,
#   '坑': -1,
#   '结实': -1,
#   '国内': -1,
#   '减配': -1,
#   '全景': -1,
#   '天窗': -1,
#   '可惜': -1,
#   '不行': -1,
#   '看不上眼': -1,
#   '换个': -1,
#   '正常': -1,
#   '点': -1,
#   '喜欢': 0,
#   '不高': -1,
#   '缺失': -1,
#   '遗憾': -1,
#   '低': -1,
#   '后悔': 0,
#   '不能': -1,
#   '忍': -1,
#   '咋样': -1,
#   '不太': 0,
#   '重视': -1,
#   '不选': -1,
#   '挫': -1,
#   '改款': -1,
#   '电动': -1,
#   '尾门': -1,
#   '太慢': -1,
#   '没落': -1,
#   '锁': -1,
#   '不久': -1,
#   '必要': -1,
#   '声音': -1,
#   '手机': 0,
#   '导航': 0,
#   '掉': -1,
#   '链子': -1,
#   '车载': -1,
#   '带到': -1,
#   '沟里': -1,
#   '硬伤': -1,
#   '差点': -1,
#   '优势': -1,
#   '方便': 0,
#   '太': -1,
#   '太扯': -1,
#   '值得': 0,
#   '不值': -1,
#   '配置': 0,
#   '简陋': -1,
#   '差一点': -1,
#   '很差': -1,
#   '简配': -1,
#   '厉害': -1,
#   '主': -1,
#   '坑爹': -1,
#   '吐槽': -1,
#   '有点': 0,
#   '抖': -1,
#   '丑到': -1,
#   '无力': -1,
#   '机舱': -1,
#   '里': -1,
#   '走': -1,
#   '管子': -1,
#   '不好': -1,
#   '断轴': -1,
#   '中控': -1,
#   '比较': 0,
#   '音质': -1,
#   '心里': -1,
#   '凉凉的': -1,
#   '早日': -1,
#   '完蛋': -1,
#   '不让': -1,
#   '省心': -1,
#   '区别': -1,
#   '连线': 0,
#   '简单': 0,
#   '后窗': 0,
#   '无所谓': 0,
#   '省钱': 0,
#   '不少': 0,
#   '不带': 0,
#   '是否': 0,
#   '好': 1,
#   'OK': 1,
#   '不错': 1,
#   '值': 1,
#   '一点': 1,
#   '问题': 1,
#   '高': 1,
#   '出色': 1,
#   '顶级': 1,
#   '超前': 1,
#   '买': 1,
#   '机械性能': 1,
#   '80': 1,
#   '分': 1,
#   '均衡': 1,
#   '提升': 1,
#   '厚道': 1,
#   '不差': 1,
#   '全': 1,
#   '真高': 1,
#   '满意': 1,
#   '非常': 1,
#   '合理': 1,
#   '蛮': 1,
#   '强太多': 1,
#   '合适': 1,
#   '胜出': 1,
#   '丰富': 1,
#   '够': 1,
#   '秒杀': 1,
#   '真心': 1,
#   '机械': 1,
#   '手刹': 1,
#   '四驱': 1,
#   '安全': 1,
#   '米其林': 1,
#   '3ST': 1,
#   '安静': 1,
#   '舒适': 1,
#   '坦克': 1,
#   '欧蓝德': 1,
#   '肯定': 1,
#   '压倒性': 1,
#   '说': 1,
#   '更好': 1,
#   '已成': 1,
#   '绝唱': 1,
#   '好用': 1,
#   '皮实': 1,
#   '整车': 1,
#   '扎实': 1,
#   '视野': 1,
#   '性好': 1,
#   '开着': 1,
#   '方面': 1,
#   '舒服': 1,
#   '优点': 1,
#   '缺点': 1,
#   '几乎': 1,
#   '零': 1,
#   '期待': 1,
#   'SGP': 1,
#   '新森': 1,
#   '影响': 1,
#   '新款': 1,
#   '厚重': 1,
#   '大气': 1,
#   '良心': 1},
#  '操控': {'垃圾': -1,
#   '那么回事': -1,
#   '渗油': -1,
#   '无法': 0,
#   '差': -1,
#   '开': 0,
#   '起来': -1,
#   '实在': -1,
#   '…': -1,
#   '.': -1,
#   '多余': -1,
#   '比不上': -1,
#   '颠簸': -1,
#   '完败': -1,
#   '没': 0,
#   '好': 0,
#   '承受': -1,
#   '不起': -1,
#   '不好': -1,
#   '静音': -1,
#   '抖': -1,
#   '响': -1,
#   '异响': -1,
#   '差劲': -1,
#   '刹车盘': -1,
#   '刺': -1,
#   '拉拉': -1,
#   '掉': -1,
#   '漆': -1,
#   '偏': -1,
#   '嘎嘎响': -1,
#   '脱皮': -1,
#   '底盘': 0,
#   '漏油': -1,
#   '走烂路': -1,
#   '颠': -1,
#   '磨得': -1,
#   '发亮': -1,
#   '解': -1,
#   '太': 0,
#   '味道': -1,
#   '真': -1,
#   '不小': -1,
#   '廉价': -1,
#   '欠缺': -1,
#   '废': -1,
#   '刹车': -1,
#   '通病': -1,
#   '刹': -1,
#   '不住': -1,
#   '不佳': -1,
#   '重': -1,
#   '一点': 0,
#   '很多': 0,
#   '方向': -1,
#   '飘': -1,
#   '方向盘': 0,
#   '总是': -1,
#   '不断': -1,
#   '修正': -1,
#   '车身': -1,
#   '反应': -1,
#   '迟钝': -1,
#   '软': -1,
#   '间隙': -1,
#   '低': 0,
#   '有点': 0,
#   '需要': -1,
#   '一直': -1,
#   '微调': -1,
#   '紧凑': 0,
#   '设计': -1,
#   '简练': -1,
#   '高度': -1,
#   '180mm': -1,
#   '太高': -1,
#   '过坑': -1,
#   '瞬间': -1,
#   '轿车': -1,
#   '晃动': -1,
#   '飞': -1,
#   '叉叉': -1,
#   '摆动': -1,
#   '手感': 0,
#   '危险': -1,
#   '平衡': 0,
#   '换': 0,
#   '规格': 0,
#   '没敢': 0,
#   '玩': 0,
#   '中等': 0,
#   '偏硬': 0,
#   '更': 0,
#   '硬': 0,
#   '换代': 0,
#   '慢': 0,
#   '太稳': 0,
#   '重新': 0,
#   '松散': 0,
#   '告诉': 0,
#   '抖动': 0,
#   '更高': 0,
#   '舒服': 0,
#   '调节': 0,
#   '没什么': 0,
#   '影响': 0,
#   '没有磨损': 0,
#   '不错': 0,
#   '兼顾': 0,
#   '东西': 0,
#   '最高': 0,
#   '变化': 0,
#   '烂': 0,
#   '无所谓': 0,
#   '高': 0,
#   '控制不了': 0,
#   '加热': 0,
#   '问题': 0,
#   '差不多': 0,
#   '一流': 1,
#   '追求': 1,
#   '良好': 1,
#   '第一': 1,
#   '灵活': 1,
#   '完胜': 1,
#   '好用': 1,
#   '挺棒': 1,
#   '专业': 1,
#   '漂移': 1,
#   '好感': 1,
#   '优势': 1,
#   '喜欢': 1,
#   '符合': 1,
#   '95': 1,
#   '分': 1,
#   '牛': 1,
#   '逼': 1,
#   '要求': 1,
#   '一致': 1,
#   '升级': 1,
#   '值得': 1,
#   '不飘': 1,
#   '更好': 1,
#   '满意': 1,
#   '厉害': 1,
#   '灵巧': 1,
#   '强': 1,
#   '韧性': 1,
#   '很稳': 1,
#   '很准': 1,
#   '好点': 1,
#   '操控': 1,
#   '感': 1,
#   '安全': 1,
#   '优点': 1,
#   '轻松': 1,
#   '忍住': 1,
#   '没改': 1,
#   '舒适感': 1,
#   '真心': 1,
#   '犹如': 1,
#   '宝马': 1,
#   '比较': 1,
#   '优': 1,
#   '确实': 1,
#   '很棒': 1,
#   '自信': 1,
#   '操控性': 1,
#   '相当': 1,
#   '一个': 1,
#   '档次': 1,
#   '看点': 1,
#   '费劲': 1,
#   '没得说': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '提高': 1,
#   '性能': 1,
#   '说': 1,
#   '坐姿': 1,
#   '驾驶': 1,
#   '质感': 1,
#   '蛮': 1,
#   '给力': 1,
#   '安心': 1,
#   '质量': 1,
#   '完美': 1,
#   '肯定': 1,
#   '随性': 1,
#   '稳': 1,
#   '破百': 1,
#   '胜出': 1,
#   '最好': 1,
#   '无敌': 1,
#   '闻名': 1,
#   '可靠': 1,
#   '超过': 1,
#   '非常': 1,
#   '略胜一筹': 1,
#   '距离': 1,
#   '短': 1,
#   '灵': 1,
#   '轻': 1,
#   '操纵': 1,
#   '好开': 1,
#   '比新森强': 1,
#   '没见': 1,
#   '跑': 1,
#   '14': 1,
#   '万': 1,
#   '机器': 1,
#   '基本': 1,
#   '着迷': 1,
#   '纠结': 1,
#   '后悔': 1,
#   '解释': 1,
#   '挺稳': 1},
#  '舒适性': {'坑': -1,
#   '异响': -1,
#   '噪音': 0,
#   '颠': -1,
#   '问题': 0,
#   '打不开': -1,
#   '乱响': -1,
#   '卡顿': -1,
#   '质量': -1,
#   '很差': -1,
#   '腰疼': -1,
#   '抖': -1,
#   '舒服': 0,
#   '气门': -1,
#   '声音': 0,
#   '震': -1,
#   '响': -1,
#   '隔音': -1,
#   '不好': -1,
#   '忽悠': -1,
#   '容易': -1,
#   '晕车': -1,
#   '就别': -1,
#   '想': -1,
#   '开着': -1,
#   '累': -1,
#   '唯一': -1,
#   '不足': -1,
#   '风噪大': -1,
#   '差多': -1,
#   '很大': -1,
#   '舒适': 0,
#   '颠簸': -1,
#   '有点': 0,
#   '影响': -1,
#   '味': -1,
#   '较大': -1,
#   '偏': -1,
#   '不行': -1,
#   '较差': -1,
#   '受不了': -1,
#   '特别': -1,
#   '空调': 0,
#   '咋样': -1,
#   '烦透了': -1,
#   '耳朵': -1,
#   '音响': -1,
#   '太': 0,
#   '差': -1,
#   '变': 0,
#   '滴水': 0,
#   '现象': -1,
#   '确实': -1,
#   '不会': -1,
#   '制冷': 0,
#   '速度': -1,
#   '快': 0,
#   '开': 0,
#   '没劲': -1,
#   '差一点': -1,
#   '依旧': -1,
#   '抖抖': -1,
#   '不少': -1,
#   '难受': -1,
#   '支持': -1,
#   '发出声音': -1,
#   '很烦': -1,
#   '风噪': -1,
#   '最大': -1,
#   '比较': -1,
#   '俩': -1,
#   '车': -1,
#   '不算': 0,
#   '太好': -1,
#   '原胎': -1,
#   '严实': -1,
#   '出': -1,
#   '偏低': -1,
#   '硬': -1,
#   '毛病': -1,
#   '滋滋': -1,
#   '声': -1,
#   '土腥味': -1,
#   '抖动': -1,
#   '摩擦音': -1,
#   '气味': -1,
#   '呛': -1,
#   '格叽格': -1,
#   '叽响': -1,
#   '座椅': 0,
#   '臭': -1,
#   '视野': 0,
#   '森': -1,
#   '金属': -1,
#   '撞击': -1,
#   '响声': -1,
#   '敲击': -1,
#   '真心': -1,
#   '点': 0,
#   '发动机': -1,
#   '效果': 0,
#   '内部': -1,
#   '味道': -1,
#   '胎噪件': -1,
#   '15': -1,
#   '万': -1,
#   '听': -1,
#   '心烦': -1,
#   '后排': -1,
#   '太硬': -1,
#   '颈椎': -1,
#   '有点累': -1,
#   'X1': -1,
#   '可怜': -1,
#   '更': -1,
#   '吵': -1,
#   '扯淡': -1,
#   '静音': 0,
#   '原厂': 0,
#   '冻得': 0,
#   '正常': 0,
#   '以前': 0,
#   '小点': 0,
#   '保养': 0,
#   '忽略不计': 0,
#   '忽略': 0,
#   '掩盖': 0,
#   '有所': 0,
#   '下降': 0,
#   '冷': 0,
#   '不给力': 0,
#   '冰箱': 0,
#   '变化': 0,
#   '没': 0,
#   '舒适性': 0,
#   '还行': 0,
#   '不介意': 0,
#   '好': 1,
#   '牛': 1,
#   '逼': 1,
#   '空间': 1,
#   '看中': 1,
#   '记忆': 1,
#   '提升': 1,
#   '强': 1,
#   '感觉': 1,
#   '不错': 1,
#   '恒温': 1,
#   '满意': 1,
#   '分区': 1,
#   '减少': 1,
#   '提高': 1,
#   '很多': 1,
#   '低': 1,
#   '好听': 1,
#   '好用': 1,
#   '好点': 1,
#   '蛮': 1,
#   '给力': 1,
#   '没有': 1,
#   '高': 1,
#   '厉害': 1,
#   '非常': 1,
#   '风力': 1,
#   '强劲': 1,
#   '坐姿': 1,
#   '视线': 1,
#   '更好': 1,
#   '说': 1,
#   '性好': 1,
#   '超级': 1,
#   '调': 1,
#   '秒杀': 1,
#   'SUV': 1,
#   '乘客': 1,
#   '安静': 1},
#  '油耗': {'省油': 0,
#   '略': -1,
#   '高': 0,
#   '公平': -1,
#   '全': -1,
#   '行业': -1,
#   '造假': -1,
#   '真': -1,
#   '喜欢': -1,
#   '费油': 0,
#   '偏': -1,
#   '完败': -1,
#   '升高': -1,
#   '上升': -1,
#   '增加': 0,
#   '油耗': 0,
#   '会': -1,
#   '顶不住': -1,
#   '太高': -1,
#   '哗哗': -1,
#   '以前': -1,
#   '可能': -1,
#   '低': 0,
#   '点': -1,
#   '高点': 0,
#   '颇': -1,
#   '很多': -1,
#   '特大': -1,
#   '贼': -1,
#   '不好': -1,
#   '蹭': -1,
#   '上涨': -1,
#   '性价比': -1,
#   '控制': -1,
#   '一点': -1,
#   '1.8': -1,
#   'T': -1,
#   '不低': -1,
#   '确实': 0,
#   '爱': -1,
#   '滴': -1,
#   '不敢恭维': -1,
#   '不着': -1,
#   '调': -1,
#   '不见得': -1,
#   '省': 0,
#   '没': 0,
#   '感觉': 0,
#   '差不多': 0,
#   '市区': 0,
#   '左右': 0,
#   '正常': 0,
#   '必要': 0,
#   '做': 0,
#   '区别': 0,
#   '没说的': 0,
#   '关心': 0,
#   '稍微': 0,
#   '只能': 0,
#   '说': 0,
#   '行': 1,
#   '满意': 1,
#   '知足': 1,
#   '不高': 1,
#   '好': 1,
#   '毛病': 1,
#   '没有': 1,
#   '现象': 1,
#   '平顺': 1,
#   '自然': 1,
#   '给力': 1,
#   '额外': 1,
#   '惊喜': 1,
#   '问题': 1,
#   '不错': 1,
#   '下降': 1,
#   '不会': 1,
#   '一个': 1,
#   '稳定': 1,
#   '变化': 1,
#   '废油': 1,
#   '效果': 1,
#   '相当': 1,
#   '棒': 1,
#   '非常': 1,
#   '耐用': 1,
#   '值得': 1,
#   '拥有': 1,
#   '胜出': 1,
#   '够': 1,
#   '牛': 1,
#   '2.0': 1,
#   '森': 1,
#   '真心': 1,
#   '低油耗': 1,
#   '5.9': 1,
#   '驾驶': 1,
#   '体验': 1,
#   '超级': 1,
#   '不少': 1,
#   '水平': 1,
#   '已经': 1,
#   '挺': 1,
#   '一定': 1},
#  '动力': {'反应': 0,
#   '慢': -1,
#   '熄火': -1,
#   '肉': 0,
#   '不佳': -1,
#   '烧': 0,
#   '机油': 0,
#   '郁闷': -1,
#   '坑': -1,
#   '爆震': -1,
#   '怕': 0,
#   '失望': -1,
#   '没': 0,
#   '太吵': -1,
#   '担心': 0,
#   '通病': -1,
#   '偶尔': -1,
#   '顿挫': -1,
#   '有点': 0,
#   '受不了': -1,
#   '不够': 0,
#   '异响': -1,
#   '问题': 0,
#   '差点': -1,
#   '意思': -1,
#   '质量': -1,
#   '不行': -1,
#   '一个': -1,
#   '缸体': -1,
#   '工作': -1,
#   '严重': -1,
#   '抖动': -1,
#   '不好': -1,
#   '差': 0,
#   '车重': -1,
#   '不选': -1,
#   '代价': -1,
#   '偏弱': -1,
#   '过时': -1,
#   '轻微': -1,
#   '渗油': -1,
#   '完善': -1,
#   '变弱': -1,
#   '不了': -1,
#   '下降': 0,
#   '一点': 0,
#   '一点点': 0,
#   '鸡肋': 0,
#   '故障': -1,
#   '弱': -1,
#   '没有': 0,
#   '以前': 0,
#   '灵敏': 0,
#   '温度': 0,
#   '高': 0,
#   '漏油': -1,
#   '设计': -1,
#   '缺陷': -1,
#   '消耗': -1,
#   '生锈': -1,
#   '涉水': -1,
#   '锁死': -1,
#   '查不出': -1,
#   '哗啦声': -1,
#   '败笔': -1,
#   '转速': -1,
#   '低': 0,
#   '负担': -1,
#   '轰': -1,
#   '轰响': -1,
#   '飙车': -1,
#   '差劲': -1,
#   '牛车': -1,
#   '变闷': -1,
#   '动力': 0,
#   '降低': -1,
#   '压力': -1,
#   '重新': -1,
#   '打胶': -1,
#   '加速': 0,
#   '缓慢': -1,
#   '太弱': -1,
#   '跟不上': -1,
#   '冒烟': -1,
#   '点': 0,
#   '缝隙': -1,
#   '里': -1,
#   '油泥': -1,
#   '搞': -1,
#   '好': 0,
#   '到哪去': -1,
#   '明显': 0,
#   '发动机': 0,
#   '噪声': -1,
#   '变速箱': -1,
#   '存在': -1,
#   '不足': 0,
#   '噪音': 0,
#   '没力': -1,
#   '异味': -1,
#   '一直': -1,
#   '弊病': -1,
#   '段': -1,
#   '别提': -1,
#   '急': -1,
#   '嘶哑': -1,
#   '减少': -1,
#   '逊色': -1,
#   '降': -1,
#   '之前': -1,
#   '硬伤': -1,
#   '很差': -1,
#   '捉急': -1,
#   '差些': -1,
#   '太': 0,
#   '太行': -1,
#   '风险': -1,
#   '很大': -1,
#   '1.6': -1,
#   'T': -1,
#   '四缸': -1,
#   '四驱': 0,
#   '超个': -1,
#   '车': -1,
#   '感觉': 0,
#   '费劲': -1,
#   '擅长': -1,
#   '不好受': -1,
#   '老坏': -1,
#   '肯定': -1,
#   '指望': -1,
#   '偏磨': -1,
#   '没什么': -1,
#   '亮点': -1,
#   '不会': 0,
#   '很快': -1,
#   '连速腾': -1,
#   '起步': -1,
#   '赶不上': -1,
#   '爬坡': -1,
#   '爬': -1,
#   '上去': -1,
#   '大众': -1,
#   '调教': -1,
#   '维修': -1,
#   '起来': -1,
#   '麻烦': -1,
#   '高性能': -1,
#   '烧漏': -1,
#   '落后': -1,
#   '真的': 0,
#   '实在': -1,
#   '太老': -1,
#   '远': -1,
#   '牛': 0,
#   'b': -1,
#   '不到': -1,
#   '心理': -1,
#   '没底': -1,
#   '垃圾': -1,
#   '运气': 0,
#   '纠结': 0,
#   '好像': 0,
#   '够用': 0,
#   '不烧': 0,
#   '驾驶': 0,
#   '足够': 0,
#   '一般般': 0,
#   '换油': 0,
#   '偏': 0,
#   '伤': 0,
#   '蓄电池': 0,
#   '重心': 0,
#   '避免': 0,
#   '没关系': 0,
#   '难点': 0,
#   '不敢': 0,
#   '通红': 0,
#   '都行': 0,
#   '爆缸': 0,
#   '正常': 0,
#   '声音': 0,
#   '变小': 0,
#   '不说': 0,
#   '没觉': 0,
#   '没事': 0,
#   '影响': 0,
#   '散热': 0,
#   '不解': 0,
#   '忽略': 0,
#   '行': 0,
#   '区别': 0,
#   '差不多': 0,
#   '有所': 0,
#   '护板': 0,
#   '破碎': 0,
#   '做到': 0,
#   '最好': 0,
#   '布局': 0,
#   '限制': 0,
#   '觉得': 0,
#   '适当': 0,
#   '保养': 0,
#   '低沉': 0,
#   '疯狂': 0,
#   '没法': 0,
#   '磨损': 0,
#   '差别': 0,
#   '提速': 0,
#   '水平': 0,
#   '对置': 0,
#   '横向': 0,
#   '占用': 0,
#   '空间': 0,
#   '充足': 1,
#   '舒服': 1,
#   '很少': 1,
#   '耐用': 1,
#   '少': 1,
#   '足': 1,
#   '超车': 1,
#   '满意': 1,
#   '轻松': 1,
#   '不错': 1,
#   '用不完': 1,
#   '劲': 1,
#   '给力': 1,
#   '非常': 1,
#   '够': 1,
#   '杠杠': 1,
#   '开着': 1,
#   '爽': 1,
#   '很多': 1,
#   '完全': 1,
#   '不能': 1,
#   '比拟': 1,
#   '不差': 1,
#   '快': 1,
#   '改观': 1,
#   '不少': 1,
#   '好点': 1,
#   '95': 1,
#   '分': 1,
#   '排量': 1,
#   '提高': 1,
#   '升级': 1,
#   '提升': 1,
#   '强': 1,
#   '全时': 1,
#   '加强': 1,
#   '敏捷': 1,
#   '随叫随到': 1,
#   '好太多': 1,
#   '高原': 1,
#   '小霸王': 1,
#   '信心': 1,
#   '满满': 1,
#   '情况': 1,
#   '很爽': 1,
#   '损耗': 1,
#   '省心': 1,
#   '漏': 1,
#   '均衡': 1,
#   '轻盈': 1,
#   '舒适': 1,
#   '王': 1,
#   '优': 1,
#   '更好': 1,
#   '堪比': 1,
#   '跑车': 1,
#   '相当': 1,
#   '轻轻松松': 1,
#   '优势': 1,
#   '干净': 1,
#   '甩': 1,
#   'n': 1,
#   '条街': 1,
#   '专家': 1,
#   '已经': 1,
#   '猛': 1,
#   '拔尖': 1,
#   '追不上': 1,
#   '喜欢': 1,
#   '强些': 1,
#   '强劲': 1,
#   '更足': 1,
#   '性能': 1,
#   '效果': 1,
#   '质感': 1,
#   '很小': 1,
#   '好车': 1,
#   '太好了': 1,
#   '车挺': 1,
#   '破百': 1,
#   '秒杀': 1,
#   '胜出': 1,
#   '无敌': 1,
#   '出色': 1,
#   '可靠': 1,
#   '没得说': 1,
#   '超过': 1,
#   '更高': 1,
#   '稳定': 1,
#   '新': 1,
#   '坦克': 1,
#   '欧蓝德': 1,
#   '开启': 1,
#   '汽车': 1,
#   '新篇章': 1,
#   '轻': 1,
#   '强多': 1,
#   '响应': 1,
#   '旅行': 1,
#   '更强': 1,
#   '老牛': 1,
#   '逼': 1,
#   '最大': 1,
#   '卖点': 1,
#   '原来': 1,
#   '稳': 1,
#   '没见': 1,
#   '跑': 1,
#   '14': 1,
#   '万': 1,
#   '机器': 1,
#   '直列': 1,
#   '诱惑': 1,
#   '中控台': 1,
#   '确实': 1,
#   '着迷': 1,
#   '扯淡': 1,
#   '后悔': 1,
#   '太给力': 1,
#   '算': 1,
#   '输': 1},
#  '内饰': {'普通': 0,
#   '松垮': -1,
#   '旧': -1,
#   '差': -1,
#   '改改': 0,
#   '一点点': -1,
#   '细致': -1,
#   '挫': -1,
#   '破破烂烂': -1,
#   '有点': -1,
#   '糙': -1,
#   '影响': -1,
#   '驾驶': -1,
#   '全': -1,
#   '塑料': -1,
#   '简陋': -1,
#   '改': -1,
#   '不够': -1,
#   '完败': -1,
#   '太': 0,
#   '水': -1,
#   '过时': -1,
#   '出毛病': -1,
#   '脱皮': -1,
#   '粗糙': -1,
#   '现款': -1,
#   '一个': 0,
#   '档次': 0,
#   '内饰': 0,
#   '老气': -1,
#   '低档': -1,
#   '伤感情': -1,
#   '异味': -1,
#   '没用': -1,
#   '不满': -1,
#   '+': -1,
#   'E': -1,
#   'E11': -1,
#   ':': -1,
#   'E742': -1,
#   '缺点': -1,
#   '硬伤': -1,
#   '差一点': -1,
#   '令人发指': -1,
#   '粗': -1,
#   '不能': -1,
#   '接受': -1,
#   '整': -1,
#   '渣': -1,
#   '没戏': -1,
#   '难受': -1,
#   '单调': -1,
#   '豪华': 0,
#   '硬': -1,
#   '凸': -1,
#   '太过': -1,
#   '简单': 0,
#   '粗糟': -1,
#   '吐': -1,
#   '寒酸': -1,
#   '十万块': -1,
#   '国产车': -1,
#   '扯淡': -1,
#   '吐槽': -1,
#   '掉': -1,
#   '没得': -1,
#   '不敢恭维': -1,
#   '惨不忍睹': -1,
#   '非常': -1,
#   '落后': -1,
#   '一股': -1,
#   '丰田': -1,
#   '味': -1,
#   '后排': -1,
#   '座椅': -1,
#   '格叽格': -1,
#   '叽响': -1,
#   '臭味': -1,
#   '廉价': -1,
#   '感': -1,
#   'L0W': -1,
#   '磕碜': -1,
#   '点': -1,
#   '较差': -1,
#   '感觉': -1,
#   '多丑': -1,
#   '科技': 0,
#   '一如既往': -1,
#   '做工': 0,
#   '设计': 0,
#   '土土': -1,
#   '居然': -1,
#   '舒坦': -1,
#   '还好': 0,
#   '感冒': 0,
#   '面包车': 0,
#   '60': 0,
#   '分': 0,
#   '大致相同': 0,
#   '用处': 0,
#   '不提': 0,
#   '心知肚明': 0,
#   '要求': 0,
#   '不高': 0,
#   '特别': 0,
#   '舒服': 0,
#   '贼': 0,
#   '嚣张': 0,
#   '齐全': 0,
#   '就行': 0,
#   '不在乎': 0,
#   '不错': 1,
#   '好': 1,
#   '坐': 1,
#   '进去': 1,
#   '放松': 1,
#   '保值': 1,
#   '耐用': 1,
#   '喜欢': 1,
#   '认可度': 1,
#   '高': 1,
#   '皮实': 1,
#   '提升': 1,
#   '好看': 1,
#   '符合': 1,
#   '一致': 1,
#   '车': 1,
#   '手感': 1,
#   '爆炸': 1,
#   '不逊于': 1,
#   '大改': 1,
#   '强': 1,
#   '没': 1,
#   '说': 1,
#   '品质': 1,
#   '记忆': 1,
#   '绝对值': 1,
#   '感强': 1,
#   '中上游': 1,
#   '绝对': 1,
#   '口味': 1,
#   '保持': 1,
#   '用料': 1,
#   '简洁': 1,
#   '干练': 1,
#   '炫酷': 1,
#   '高出': 1,
#   '带': 1,
#   '喜感': 1,
#   '好点': 1,
#   '更好': 1,
#   '不少': 1,
#   '漂亮': 1,
#   '细': 1,
#   '骚': 1,
#   '很多': 1,
#   '高大': 1,
#   '秒杀': 1,
#   '胜出': 1,
#   '帅': 1,
#   '新': 1,
#   '简约': 1,
#   '比较': 1,
#   '真的': 1,
#   '感高': 1,
#   '森林': 1,
#   '人强': 1,
#   '偏硬': 1,
#   '造型': 1,
#   '吊打': 1},
#  '安全性': {'软': -1,
#   '强': 0,
#   '差劲': -1,
#   '耐磨': -1,
#   '刹': -1,
#   '不住': -1,
#   '少': -1,
#   '气囊': -1,
#   '心寒': -1,
#   '刹车': 0,
#   '行程': -1,
#   '距离': -1,
#   '长': -1,
#   '不给力': -1,
#   '问题': 0,
#   '醉': -1,
#   '恼人': -1,
#   '能比': -1,
#   '不行': -1,
#   '急刹车': -1,
#   '差点': -1,
#   '追尾': -1,
#   '无奈': -1,
#   '急': 0,
#   '加速': 0,
#   '耐用': 1,
#   '不错': 1,
#   '要求': 1,
#   '一致': 1,
#   '安全': 1,
#   '第一': 1,
#   '高': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '好': 1,
#   '超好': 1,
#   '适合': 1,
#   '效果': 1,
#   '皮实': 1,
#   '更': 1,
#   '扎实': 1,
#   '喜欢': 1,
#   '机械': 1,
#   '手刹': 1,
#   '卤素灯': 1,
#   '明显': 1,
#   '穿透力': 1,
#   '更强': 1,
#   '安全感': 1,
#   '极高': 1,
#   '硬': 1,
#   '脚感': 1,
#   '非常': 1,
#   '细腻': 1,
#   '微操': 1,
#   '完': 1,
#   '线性': 1,
#   '踩': 1,
#   '随有': 1,
#   '挺': 1,
#   '避震': 1,
#   '觉得': 1,
#   '够': 1,
#   '算': 1,
#   '输': 1},
#  '空间': {'硬伤': -1,
#   '真': -1,
#   '喜欢': 0,
#   '排挤': -1,
#   '不行': -1,
#   '钻进去': -1,
#   '奢望': -1,
#   '真的': -1,
#   '空间': 0,
#   '不敢恭维': -1,
#   '后排': -1,
#   '点': -1,
#   '舒服': 0,
#   '满意': 0,
#   '一点': -1,
#   '·': -1,
#   '没有': -1,
#   '没': 0,
#   '宽敞': 0,
#   '差': -1,
#   '有点': 0,
#   '显小': -1,
#   '异响': -1,
#   '太小': -1,
#   '完败': -1,
#   '抓狂': -1,
#   '轴距': 0,
#   '严重': -1,
#   '不符': -1,
#   '不在意': 0,
#   '感冒': 0,
#   '差别': 0,
#   '不差': 0,
#   '横向': 0,
#   '比森好': 0,
#   '纵向': 0,
#   '森': 0,
#   '较大': 0,
#   '好些': 1,
#   '满足': 1,
#   '不错': 1,
#   '坐': 1,
#   '进去': 1,
#   '放松': 1,
#   '出色': 1,
#   '杀手锏': 1,
#   '车体': 1,
#   '高': 1,
#   '均衡': 1,
#   '差不多': 1,
#   '好': 1,
#   '实用': 1,
#   '方面': 1,
#   '保障': 1,
#   '动力': 1,
#   '非常': 1,
#   '够用': 1,
#   '不小': 1,
#   '容量': 1,
#   '宽大': 1,
#   '舒适': 1,
#   '特大': 1,
#   '变': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '相当': 1,
#   '优势': 1,
#   '挺大': 1,
#   '更': 1,
#   '方便': 1,
#   '杠杠': 1,
#   '挺': 1,
#   '行': 1,
#   '很漂亮': 1,
#   '加长': 1,
#   '森林': 1,
#   '高点': 1,
#   '胜出': 1,
#   '很多': 1,
#   '理想': 1,
#   '后备箱': 1,
#   '更大': 1,
#   '说': 1,
#   '/': 1,
#   '后座': 1,
#   '宽': 1,
#   '坐姿': 1,
#   '好点': 1,
#   '太': 1,
#   '诱惑': 1,
#   '中控台': 1,
#   '车': 1,
#   '蛮大': 1,
#   '更好': 1},
#  '外观': {'差点': -1,
#   '硬': -1,
#   '变色': -1,
#   '丑': -1,
#   '薄': -1,
#   '好看': 0,
#   '屁股': -1,
#   '喜欢': 0,
#   '颜值': 0,
#   '差': -1,
#   '难看': -1,
#   '中庸': -1,
#   '接受度': -1,
#   '不高': -1,
#   '老气': -1,
#   '挫': -1,
#   '取消': -1,
#   '掰': -1,
#   '不动': -1,
#   '纠结': 0,
#   '硬伤': -1,
#   '很多': -1,
#   '倾斜': -1,
#   '里外': -1,
#   '摇晃': -1,
#   '平庸': -1,
#   '越丑': -1,
#   '符合': -1,
#   '协调': 0,
#   '真': 0,
#   '好': 0,
#   '外观': 0,
#   '没有': -1,
#   '丝毫': -1,
#   '质感': -1,
#   '奇丑无比': -1,
#   '太小': -1,
#   '气': -1,
#   '太丑': -1,
#   '挫样': -1,
#   '接受': -1,
#   '不了': -1,
#   '廉价': -1,
#   '软': -1,
#   '不敢恭维': -1,
#   '有点': -1,
#   '土': -1,
#   '现款': -1,
#   '无力': -1,
#   '吐槽': -1,
#   '觉得': 0,
#   '19': -1,
#   '款': -1,
#   '老款': -1,
#   '新潮': -1,
#   '拼凑': -1,
#   '杀马特': -1,
#   '尾灯': -1,
#   '好丑': -1,
#   '史上': -1,
#   '车漆': -1,
#   '平淡无奇': -1,
#   '无比': -1,
#   '毁': -1,
#   '日系车': -1,
#   '漆软': -1,
#   '真软': -1,
#   '前脸': 0,
#   '无爱': -1,
#   '镀铬': -1,
#   '太': -1,
#   '尴尬': -1,
#   '漆面': -1,
#   '太薄': -1,
#   '不像': -1,
#   '换代': -1,
#   '应有': -1,
#   '水平': -1,
#   '多丑': -1,
#   '不怎么': -1,
#   '中网': -1,
#   '低级': -1,
#   '下限': -1,
#   '在意': 0,
#   '普通': 0,
#   '凶狠': 0,
#   '前': 0,
#   '脸': 0,
#   '高配': 0,
#   '不在意': 0,
#   '无所谓': 0,
#   '性价比': 1,
#   '逼格': 1,
#   '高': 1,
#   '特别': 1,
#   '迷恋': 1,
#   '认可度': 1,
#   '尊贵': 1,
#   '挺': 1,
#   '炫': 1,
#   '要求': 1,
#   '一致': 1,
#   '时尚': 1,
#   '大改': 1,
#   '大气': 1,
#   '生猛': 1,
#   '作用': 1,
#   '降低': 1,
#   '高度': 1,
#   '口味': 1,
#   '看中': 1,
#   '不错': 1,
#   '视野': 1,
#   '底盘': 1,
#   '厉害': 1,
#   '漂亮': 1,
#   '合眼': 1,
#   '缘': 1,
#   '外形': 1,
#   '一个': 1,
#   '档次': 1,
#   '隐隐': 1,
#   '豪华车': 1,
#   '感觉': 1,
#   '真心': 1,
#   '赞': 1,
#   '车': 1,
#   '一次': 1,
#   '没修过': 1,
#   '秀气': 1,
#   '秒杀': 1,
#   '厚': 1,
#   '强化': 1,
#   '硬朗': 1,
#   '确实': 1,
#   '点': 1,
#   '颜色': 1,
#   '光线': 1,
#   '看着': 1,
#   '舒服': 1,
#   '耐看': 1,
#   '中规中矩': 1,
#   '至少': 1,
#   '新款': 1,
#   '低调': 1,
#   '这种': 1,
#   '设计': 1,
#   '精致': 1,
#   '更好': 1,
#   '森': 1,
#   '保持': 1,
#   '偏硬': 1,
#   '造型': 1,
#   '吊打': 1,
#   '面子': 1,
#   '个人': 1,
#   '比较': 1,
#   '帅气': 1,
#   '社会': 1,
#   '前网': 1,
#   '辨识': 1,
#   '度': 1,
#   '厚重': 1,
#   '真的': 1}}

# %%
x_vecs = []
x_test_vecs = []  
ind = 0
word2ind = {}
pretrained = []
senti_sen = []
senti_test_sen = []
for i in range(len(test_content) + len(content)):
    if i < len(content):
        temp = []
        t_s = []
        for j in range(len(sentences[i])):
            if sentences[i][j] not in word2ind:
                pretrained.append(model[sentences[i][j]])
                word2ind[sentences[i][j]] = ind
                ind += 1
            t_s.append(sentences[i][j])
            temp.append(model[sentences[i][j]])
        while len(temp) < 50:
            temp.append([0.0] * 100)
        if len(temp) > 50:
            temp = temp[:50]
        x_vecs.append(temp)
        senti_sen.append(t_s[:50])
    else:
        temp = []
        t_s = []
        for j in range(len(sentences[i])):
            if sentences[i][j] not in word2ind:
                pretrained.append(model[sentences[i][j]])
                word2ind[sentences[i][j]] = ind
                ind += 1
            t_s.append(sentences[i][j])
            temp.append(model[sentences[i][j]])
        while len(temp) < 50:
            temp.append([0.0] * 100)
        if len(temp) > 50:
            temp = temp[:50]
        x_test_vecs.append(temp)
        senti_test_sen.append(t_s[:50])     
x_vecs = np.array(x_vecs)
x_test_vecs = np.array(x_test_vecs)
print(x_vecs.shape, x_test_vecs.shape)
# Out:
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:18: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:30: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# (8290, 50, 100) (2364, 50, 100)

# %%
x_sent_vecs = {}
x_test_sent_vecs = {}
for key in senti_word_set:
    x_sent_vecs[key] = []
    x_test_sent_vecs[key] = []
    for i in range(len(content) + len(test_content)):
        if i < len(content):
            t_sent = []
            for j in range(len(sentences[i])):
                if sentences[i][j] in senti_word_set[key]:
                    t_sent.append(senti_word_set[key][sentences[i][j]])
                else:
                    t_sent.append(0) 
            while len(t_sent) < 50:
                t_sent.append(0)
            if len(t_sent) > 50:
                t_sent = t_sent[:50]
            x_sent_vecs[key].append(t_sent)
        else:
            t_sent = []
            for j in range(len(sentences[i])):
                if sentences[i][j] in senti_word_set[key]:
                    t_sent.append(senti_word_set[key][sentences[i][j]])
                else:
                    t_sent.append(0) 
            while len(t_sent) < 50:
                t_sent.append(0)
            if len(t_sent) > 50:
                t_sent = t_sent[:50]
            x_test_sent_vecs[key].append(t_sent)

# %%
#va, content_vecs, y
pretrained.append([0.0] * 100)
word2ind['null'] = 17387
ind2word = {}
for key in word2ind:
    ind2word[word2ind[key]] = key
map_ = ['-1', '0', '1', '2']
sub_set = {}
for i in range(len(subs)):
    subjs = subs[i].split(',')
    sentis = sentiments[i].split(',')
    for j in range(len(subjs)):
        if subjs[j] not in sub_set:
            sub_set[subjs[j]] = []
        if sentis[j] == '2':
            sub_set[subjs[j]].append(0)
        else:
            sub_set[subjs[j]].append(1)
        #sub_set[subjs[j]].append(map_.index(sentis[j]))

# %%
pretrained = np.array(pretrained)
han_x = []
for i in range(len(senti_sen)):
    temp = []
    for j in range(len(senti_sen[i])):
        temp.append(word2ind[senti_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x.append(temp)
han_x = np.array(han_x)

han_x_test = []
for i in range(len(senti_test_sen)):
    temp = []
    for j in range(len(senti_test_sen[i])):
        temp.append(word2ind[senti_test_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x_test.append(temp)
han_x = np.array(han_x)
han_x_test = np.array(han_x_test)

# %%
'''
class Net(nn.Module):
    def __init__(self, pretrained, vocab_size):
        super(Net, self).__init__()
        self.bilstm = nn.LSTM(input_size = 100, hidden_size = 100, bidirectional = True) 
        #self.fc1   = nn.Linear(3750, 50) 
        #self.fc2   = nn.Linear(200, 50)
        #self.fc3   = nn.Linear(200, 50)
        #self.fc4   = nn.Linear(100, 3)
        self.fctest   = nn.Linear(200, 3)
        self.embeddings = nn.Embedding(vocab_size, 100)
        pretrained_weight = np.array(pretrained)
        self.embeddings.weight.data.copy_(torch.from_numpy(pretrained_weight))
        
    def forward(self, x, aspects): 
        x = self.embeddings(x)#batch,50,100
        #va = self.embeddings(aspects[0])
        #t_va = va.unsqueeze(0).expand(x.shape[0], x.shape[1], 100)
        output, (hn, cn) =  self.bilstm(x.float())#batch,50,200
        H, hN = output, output[:,-1,:]
        #con = torch.cat((t_va, H), 2)
        #t1 = F.max_pool2d(F.relu(con), (1, 4))
        #con = t1.view(x.size()[0], -1)
        #con = F.relu(self.fc1(con))
        #alpha = con.unsqueeze(1)
        #rr = torch.matmul(alpha,H).squeeze(1)
        #yy = torch.cat((F.relu(self.fc2(rr)), F.relu(self.fc3(hN))), 1)
        #x = self.fc4(yy)
        x  = self.fctest(hN)
        return x
    

net = Net(pretrained, len(pretrained))
print(net)
from torch import optim
criterion = nn.CrossEntropyLoss() # 交叉熵损失函数
optimizer = optim.SGD(net.parameters(), lr=0.005, momentum=0.9)
'''
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self, pretrained, vocab_size):
        super(Net, self).__init__()
        #self.rnn1 = nn.RNN(100, 100) 
        self.bilstm = nn.LSTM(input_size = 100, hidden_size = 100, bidirectional = True)
        #self.fc1   = nn.Linear(1250, 120) 
        self.fch = nn.Linear(200, 100)
        self.fcv = nn.Linear(200, 100)
        self.fcw = nn.Linear(200, 1)
        self.fcwp = nn.Linear(200,50)
        self.fcwh = nn.Linear(200,50)
        self.fcwsen = nn.Linear(200, 50)
        self.fc1   = nn.Linear(3750, 120) 
        self.fc2   = nn.Linear(120, 50)
        self.fc3   = nn.Linear(50, 2)
        self.embeddings = nn.Embedding(vocab_size, 100)
        pretrained_weight = np.array(pretrained)
        self.embeddings.weight.data.copy_(torch.from_numpy(pretrained_weight))
        
    def forward(self, mode, x, x_sent, aspects): 
        x = self.embeddings(x) #[4,50,100]
        bn = nn.BatchNorm1d(50)
        x = bn(x)
        batch_size = x.shape[0]
        N = x.shape[1]
        output, (hn, cn) =  self.bilstm(x.float())  #[4,50,200]
        hN = output[:,-1,:]
        va = self.embeddings(aspects[0]) #[1, 100]
        t_va = torch.matmul(torch.ones((x.shape[0],50, 1)), va)#[4, 50, 100]
        x_sent = x_sent.float()
        #[4, 50] *? = [4, 50, 100]
        sent_va = torch.mul(torch.matmul(x_sent.reshape((x.shape[0], 50, 1)), torch.ones((x.shape[0],1, 100))), t_va)  #[4, 50, 100]
        t_va = torch.cat((sent_va, t_va),  2)
        t_va = t_va.reshape((-1, 200)) #[4*50, 100]
        x = output.reshape((-1, 200)) #[4*50, 200]
        x = torch.tanh(torch.cat((self.fch(x), self.fcv(t_va)), 1))
        M = x.reshape((batch_size, N, -1)) #[4, 50, 200]
        alpha = F.softmax(self.fcw(M)).reshape((batch_size, 1, -1))#[4,50]
        rr = torch.matmul(alpha, output).reshape((batch_size, -1)) #[4, 200]
        x_sent = x_sent.reshape((batch_size, 1, -1))
        ss = torch.matmul(x_sent.float(), output).reshape((batch_size, -1))
        final = torch.tanh(self.fcwh(hN) + self.fcwp(rr) + self.fcwsen(ss))
        x = self.fc3(final)   
        return x, alpha
net = Net(pretrained, len(pretrained))    
from torch import optim
criterion = nn.CrossEntropyLoss() # 交叉熵损失函数
optimizer = optim.Adagrad(net.parameters(), lr=0.01)#, momentum=0.9)

# %%
import torch.nn as nn
import torch.nn.functional as F
result_set1 = {}
for key in sub_set:
    if key != '操控':
        continue
    print(key)
    res = []
    with torch.no_grad():
        correct, total = 0, 0
        testset = [(han_x_test[i],np.array(x_test_sent_vecs[key][i])) for i in range(len(han_x_test))]
        testloader = torch.utils.data.DataLoader(
                            testset, 
                            batch_size=4,
                            shuffle=False, 
                            num_workers=2)
        for data in testloader:
            # 梯度清零
            optimizer.zero_grad()
            # forward + backward 
            (inputs, sentis) = data
            va = [[word2ind[key]]]
            va = torch.from_numpy(np.array(va))
            net = torch.load('./../2-mlclasstrain/net' + key + '.pkl')
            outputs,alpha = net('test', inputs, sentis, va)
            _, predicted = torch.max(outputs, 1)
            res = res + [int(predicted[i]) for i in range(len(predicted))]
    real_text = []
    for i in range(len(han_x_test)):
        temp = []
        for j in range(len(han_x_test[i])):
            temp.append(ind2word[han_x_test[i][j]])
        real_text.append(''.join(temp))
    
    for zz in range(len(res)):
        if res[zz] == 0:
            set_ = ['操控']
            for k in set_:
                if k in real_text[zz]:
                    res[zz] = 1
                    break
    result_set1[key] = res
# Out:
# 操控
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:80: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.

# %%
for i in range(len(real_text)):
    if result_set1['操控'][i] == 1:
        print(real_text[i])
# Out:
# 从技术上比亚迪电动四驱真正意义全时四驱nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 一个朋友玩越野一直待见城市SUV四驱性能一次一辆森林跟着一起出去活动一次现在变成森林免费托nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 价位全时四驱斯巴鲁nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 这是驾驶模式i默认经济模式S运动超车模式多功能方向盘右手边位置设置nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 稳定可靠玩漂移nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 途观加95油耗比小森高点保养差不多后期维修比小森便宜点没事故基本问题不大小森是全时四驱31以内唯一全时适时区别途观做工更扎实北方小森优势不论什么路面雨雪天气安全系数高出很多操控没说途观更舒适方面考虑小森没
# 途观加95油耗比小森高点保养差不多后期维修比小森便宜点没事故基本问题不大小森是全时四驱32以内唯一全时适时区别途观做工更扎实北方小森优势不论什么路面雨雪天气安全系数高出很多操控没说途观更舒适方面考虑小森没
# 一台老x12.0进口操控动力挺不错新x1减配挺严重4s店说nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 还好现在异响底盘上方底盘下方不爽nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 当年纠结问题论坛老司机说买森林不会买CRV两个车森林驾驶视野宽阔操控好原因说知道没必要考虑斯巴鲁内饰差点意思CRV刚好相反综上上周提了18款森林手打多字客气nullnullnullnullnullnullnullnull
# 每种轮胎各有千秋注重方面固特异静音舒适耐用干湿地操控性能蛮不错nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 其实原厂胎真的不错排水性一流省油现在用倍耐力P7胎噪大油耗防爆胎有点不爽.nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 觉着不错森林第四辆车内饰看着外不错试驾类别车后决定操控…懂nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 操控森好些翼虎好些斯巴鲁太少翼虎经常开都说森操控好想知道多大区别nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 商务车四驱不行走烂路底盘不行油耗SUV高不低实在感冒MPVnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 02年老奥迪a62.4排量v6发动机高速6.5森林高速平均个油市区12负责人说四驱suv肯定两驱轿车费油觉得全时四驱比分时四驱费油森林油耗略高接受喜欢nullnullnullnullnullnullnullnullnullnullnullnullnull
# 的确如此森林简单粗暴操控不错舒适性相对现在无法形容……nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 家里进口老指2.4森林2.5表示两款各有味道国产新指4s看过自由侠plus感觉2.5th或许会好新指公路操控内部空间绝对会森林nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# q5坐没开过比较下来Q5牌子响亮好多真比不上森林空间森林人小后排中间拱高根本没法坐人避震森林路感太强烈操控性不敢说没开nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 开森林开同事傲虎这俩车取向完全森林人偏运动运动型操控性好于傲虎内饰做工隔音差于傲虎适合外出比较比较offroad情况傲虎偏家居舒适性稳定性好于森林适合主要城市偶尔offroad情况具体选车楼主到底条件建议直接
# 没开过荣放级别排量动力刹车不会有太大差异底盘滤震说森林人好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 大梁车底盘强度耐操度真心可笑拉力赛车量产车10年20万公里无大修nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 进口车防止运输过程中发动机裸露盐分腐蚀会碰蜡进行隔离nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 两个体验正确确实车子开熟悉回正慢适应初段窜感觉消失反倒觉得起步加速慢噪音接受森林使用年限长后底盘噪音还会进一步增大nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林同价位SUV中不输同级对手上面几个车比方面自取其辱操控可能普拉多好点外方面随便一台秒杀森林一分钱一分货nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘拉拉到头角度往上顶调座椅nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 这能看出底盘吊起来看nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 觉得手上最好耳机铁三角im02不算木耳小森隔音不算太好音响听个响毕竟买操控nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 车况没说底盘悬挂原版全车喷漆nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 昨天试驾探界者操控不错悬架运动偏硬1.5t新车价格新款二手森林便宜情怀nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 一个越野车一个城市SUV越野性能同一个起跑线没法H92.0T动力森林2.0T相信森林2.0T肯定H9窜快车重摆在nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 全险礼品确实能要不少杠护板底盘装甲侧踏脚垫觉得没有喜欢换成价格优惠同意nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 感觉超一百二路上特殊情况控制不了轻轻一动方向盘飞nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 内饰傲虎森林强些操控没太大区别森林车身短些城里穿梭森林人比傲虎灵活舒适性傲虎后排比森林舒服很多性森林人比傲虎强些（间隙森林220mm傲虎213mm）轴距长影响性nullnullnullnullnullnullnullnullnullnullnullnull
# 傲虎好适合旅行出去玩舒适度油耗后期使用成本低正常保养费用不到六百块钱傲虎轿车舒适度越野车底盘nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 开sg9森不能说瞎话bmw不说操控真是爆森系没开过开笨重x5高速变道立交桥匝道感觉同等时速驾驶信心安全感完爆老森系比x5重心更低只会更强可能老森换套sti减震绞牙会拼nullnullnullnullnullnull
# rav42019款合资车安全性进口森林人好全时四驱不了森林明年两个车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 12款森林现在越开越喜欢特别操控感平时需正常保养即可nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# SGP底盘吸引我要买2018款犹豫想沃尔沃XC60安全著称nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 原因价格油耗奥迪a6现在一款全时nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林主打操控……说森林操控cx5好醉……两车特别喜欢森林劝买cx5nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 光有2.0排量确实欠考虑走量反对选择一辆空有操控没有动力车只能算半残nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 要求配置高排量操控感好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 其实现代车型安全性能远没有看到几颗星差异整体安全性能趋势统一nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 操控不好圈速成绩跑nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘皮子细腻xt粗糙国产车真皮方向盘完全颗粒中控台nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 性能车得XT换代明年初亮相买估计最早明年夏天nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 23.38送膜终免机油底盘装甲一键启动nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 要换肯定想换保留导航方向盘功能主机知道型号nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 主机导航方向盘控制不破线直插安装nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 觉得值看看现在市场哪家车企是标配全时四驱nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 高度整合是果全对称中差前叉水平布置对称垂直布置影响最后变速箱内部解决nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 备胎排气管低特别备胎说提臀一点不为过看过知道欧蓝德底盘最低发动机护板nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 真像说斯巴鲁现在价格水平对置发动机全时四驱成本不会太低买绝对不会在意内饰nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 国外有个视频开关espxmode四种组合效果其实xmode不会增加动力带锁多片离合器直接进入工作真缺动力要关esp……nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 经常走烂路何必装东西小森底盘高装渗漏漏油难发现城市中没必要nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 有抖红绿灯时挂N档会间歇抖没毛病去年月底提车现在万多km后来看帖说抖发动机特性习惯好在我看来操控起来真不算事nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 增加车重油耗增加原来想加厚不锈钢板考虑没梁加装甲没意义没大梁硬伤不敢豁车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 不会cx5操控好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 保时捷水平对置发动机额外加强操控降低共振作用nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 水平对置发动机全时四驱整车进口三十万落地找nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 经常森林人强非常正常硬派越野森林比比操控好不好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# rav4越野能力从来森林碾压别用厂家宣传名词秀下限越野车好不好差速器配置电子限滑rav4操控不行越野不行一台耐用丰田代步车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 14款车主车操控性好视野开阔后视镜视野同样开阔四驱雨雪打滑油耗不高140迈内加速快不好地方内饰寒酸隔音差减速带颠厉害……nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 好车性能车才烧机油nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 买之前没试驾……刹车油门挨一起赛车性能车做趾普通车必须高度差保证安全适应好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 东西成本高新款没有算是偷工减料森本来主打操控平衡卖点省掉确实应该看看淘宝老森新森够避震价格差很多nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 应该要换轿车重心低操控好喜欢低一点开车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 纠结上次开一下朋友汉兰达隔音避震确实森林人好车太大晃晃悠悠太笨喜欢喜欢森林操控SUV开久想开轿车担心轿车坐姿nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 一车一况没有事故没有水泡原厂玻璃大部分原车漆发动机底盘一滴漏精品二手车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 装一根祖国货前顶街道使用偶尔激烈驾驶没下过赛道没觉得会提升日常驾驶操控性反倒沟沟坎坎颠后来拆nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 迷上公路操控越野兼顾安全性空间nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 马自达不错四驱弱些后排空间小点nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 斯巴鲁品控未必华晨好买斯巴鲁是因为操控义无反顾纠结买最后后悔nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 没开x5开过宝马宝马操控言过其实nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 请楼主宝马系论坛看看买大叫后悔动力足颜值好***操控爽保值高简直无敌啊哈nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林驾驶乐趣带你去更地方安全性品牌力不足三系操控性好品牌力强***高suv更实用坐五个森林更舒服途观神车…神车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 不说光说安全操控加上森林整车进口奇峻合资品质没法楼主想想nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林四驱结构2006年没什么变化今天好使2011指南用杰科特cvt奇骏电控烂发动机套三菱底盘拼装车觉得nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 优惠价格24.98万元具体贴膜脚垫底盘装甲具体现金优惠私信nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 空间没有要求果断选择xv车小操控好好停车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 哈哈哈开过之后慢慢发觉原来操控真的不同车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 性能NX200根森林没法雷克萨斯侧重点性能舒适豪华内饰做工用料森林应该完败机械性能NX200对手nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 胎宽变宽方向会蹭轮內机件ET值向外移方法加垫片转距底盘部件改动打破原车平衡破平衡寻找新平衡nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 讲城市要四驱没卵用有感城市驾驶更好安全操控全时四驱必要高端桥车顶配都四驱版本原因建议了解nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 途观L试驾内饰豪华感比森强后排空间比森多出四指两点满意放弃一是天窗顶棚一层薄纱试驾正好烈日当头感觉晒遮光性一点不好二是全系标配韩泰轮胎大众标榜高安全车身不配双好鞋通常注意不到nullnullnullnullnull
# 森林操控肯定比昂科威强四驱能力强很多内饰隔音比不上昂科威nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 起步扶方向盘3000转起步跑偏先检查胎压轮定位nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 单纯比较动力底盘机械性能选森林2.0XT应该GLC差不用比较森完败nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 具备基本四驱知识全时四驱适时四驱两个不同概念本质不同nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 少探讨没注意底盘件定现在赛车级全铝水箱也定!nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 神丁聊改车买改件精品提升操控操控提升动力nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 一个买菜车烧机油到处响座椅两年半开裂知道何来性能发动机七万公里声音拖拉机性能nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 挂东东底盘nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 发动踩刹车挂档松手刹松刹车车走驻车时踩刹车至车停挂P档拉手刹注意加速刹车过猛没什么几天做到人车合一nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘设置里找nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 斯巴鲁车操控制非常好加速推背感省油nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 可迪亚克试驾操控内饰森林新款特别加鹰眼价格高不低nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林性能好车好看省钱适合初创业者nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 机械性能操控性安全性没办法吐槽只能吐槽内饰说老实话13款之后内饰不差nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 一直忘记写方向盘抖动解决属于动平衡问题轮胎调换一下好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 不用说价位森林超级维特拉是全时四驱欧蓝德四驱强欧蓝德顶配一个类似于加前锁nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 三声滴滴滴不见开门:反复后面升降按钮并用手带力往上拉十有八九开不开多半洗车工动方向盘左下边后门按钮一下即可nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 我前几年换米其林3st安静安静森林适合路感操控变差路不平抢方向盘最好还换横滨倍耐力p7nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 够折腾空要出风口要换大约1000不到想左右车门两侧出风口看着突兀再换两个大约700左右方向盘按键要换大约900不到会安装加上这台导航拆车件需要3400方向盘按键线路需要破线查线路掂量折腾nullnullnullnullnullnullnull
# 液压助力随动冲突方向盘角度传感器信号就行了nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 抬高底盘换成mt胎nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 护板底盘装甲应该喷车底一层类似沥青东西nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# XV新底盘方面优于森林动力空间市里开开xv喜欢出去跑森林人要好很多nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 觉得楼主先好好整理思路喷cussco一个第三方配件商根本森林原有设计生产东西说白了提供一个选择真满意原设计所谓刚性操控驾驶感受加装（不能称得上改善说）逻辑出厂应该韩寒台车生产满意nullnullnullnullnull
# 客观说总体不错内饰提升不少前脸喜欢前脸倒2018款好看估计操控新款好说实话——现在森林操控不错nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 之前选车感觉日系SUV全时四驱加上辅助件齐全排量1.3—1.5之间森林便宜2.0排量森林价格差不多略高这有级别比较看出性价比关系操控没有森林人好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 安索之前用过两次价格贵性能差深踩油门时要老命嘶吼nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 这款车形容一下10万元档次内饰隔音20万元档次外观50万档次操控nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 需要操控好点价格便宜烂路走即可.120转弯nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘套尤其抵触样子难看土得掉渣手感差握感太粗不利于操控安全nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 先了解一下两车性能发动机比较比较应该知道选车森林全时四驱2.02.5水平对置发动机功力强大nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 其实没必要花钱搞喇叭原车不好是因为配导航不好发烧友儿子原车cd回换上去发现5000大洋花得没必要nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 486性能车油耗近来3000公里没什么急事加速急油耗低一点nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 感觉方向盘不正四轮定位调整nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘明显右边左边nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 感觉平时基本打死方向盘最后回一点点nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 你好感觉开冷空调时没有这种情况今天第一次开热空调发现方向盘抖厉害怠速时明显感觉nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 先方向盘气囊拆下来一颗镙丝拧下来nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# XT底盘加强件没必要更换增加自重nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 简单问题试驾一下玩方向盘比玩键盘更谱nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 他俩公路性能直接被森秒杀城市SUV越野副业森是越野里公路性能最好公路性能好SUV里越野牛nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 似乎车车架子发动机四驱系统以外剩下部分乏善可陈nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 太缓慢减速带车身起伏太右前底盘就会异响快速减速带烂路不会响nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 真不好形容阻尼感是减速带底盘感觉很整没有多余跳动不会那种坐轿子感觉nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 保养贵操控不错suv里试驾空间没有汉兰达没有气派大气斯巴鲁低调车装逼勿选优势四驱安全一点nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 气囊安装方式安装位置固定不牢万一出意外气囊会方向盘脱出伤人风险nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# Q5底盘低冰辙地伤不起nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 没明白想知道全时四驱起到作用nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 楼主不能光想着调座椅调整方向盘方向盘往外拉腿弯曲角度踩刹车不会累需要伸手够些方向盘nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 我换变速箱油试过底盘震动晃动很大ESP一关好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林刹车软是越野湿滑路面一种调教硬做nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 车友分享两句倒车影像框是斜调调好觉得斜底盘觉得比途观整可能是因为隔音太差觉得没有途观底盘紧实nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 安全性日本车比安全别比轿车底盘大梁底盘安全太不自量力nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 经常暴力驾驶油怕受不了欧洲性能车机油普遍非常稠nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 高速稳定操控没事先试试160朝上弯道或事穿梭估计试完没机会发照片得瑟新闻估计出现nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 很多说特别操控几乎完美动力配上T简直神车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 开过没开几年方向盘能转半圈nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 不能秒H5秒杀城市SUVH5越野性能BJ40不行nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 深有同感看好纯进口车品质全时四驱主动安全系统决定买小森nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘跟着发动机走nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 碰到屏幕摄像头开关会启动后视功能几次方向盘左边source按键好像开启不太确定nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 动力100公里好加速线性100提速稍慢点够用城里开灵活异响暂没有行驶稳定性好特别开弯道稳当.nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 打死方向正位快速晃动方向盘响声晃动很小幅度左右10度响声知道是不是问题不好意识长时间时间回复谢谢回帖nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 奔全时四驱买车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 15款小屏设置方向盘右16款位置改为方向盘加热键小屏设置键移中控台nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 问过一位专业车手说日常公路开两车没太大区别极限操控森林人强nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林空间视野天窗四驱后排cx5不了纯进口品质美国最好品质紧凑SUV森林几乎年年上榜nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林太软刹车泵装防火墙加装刹车顶效果好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 感觉森林四驱驾驶视野操控crv好基本crv更好特别看中上述因素考虑实用crv好些nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 现在基本确定suv出去野轿车底盘太低野起来nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 没有钥匙芯片车子无法发动防盗锁会锁死方向盘吊车这种全进口车发动机锁比较难破盗窃收益成本成正比nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 没U盘蓝牙倒车影像方向盘控制不行nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# V6情节尽早下手以后会越来越少汉兰达空间这车空间利用真的绝住老小区需要抢车位曾经见过有个空车位汉兰达听不进去CRV进去媳妇停车技术练nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 亲戚家crv不错内饰森林人强视野森痛快底盘森高nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 话题好比一个月50000元够花泰森不够大众就够开法拉利觉得森林动力不足开五菱宏光说动力操控不错nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 按说没必要森林安全性能极好整车防撞梁结实油耗低成心省钱活细开油耗可低.OL以下nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 开不够颠簸路遇到太少那种城市里卡车压到处坑洼路面真的不敢开快叽里嘎啦声音底盘传来震动松散同样途观开过没样子nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 外行纸面听说东西干这行天天知道要换台车开开日系车快速过检速带知道底盘松散（包括森林在内）我开车实在太整体驾驶质感日系德系差唯好点所谓稳定性nullnullnullnullnullnullnullnullnullnullnull
# 我开10多年车一直知道操控开过五菱之光昌河铃木利亚纳1.4手动森林2.5自动精英nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 感受操控充分测试实际数据支撑安全性忽略nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘锁有用脚垫原车贴膜广州顶住不贴确实厉害贴膜防倾杆原车车本来颠再换个更粗nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 楼主昨天车遇到情况09XT方向盘下方出白烟白色无味跳立即熄火没检查出问题微信有事想确认一下加13582336635nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 了解下马牌LX2SUVMPV定位专用胎整体稍微硬些胶软挺耐老化适应轻微非铺装路面朋友介绍感觉好比米胖子便宜不少更主要轿车专用胎娇气泥地雪地抓地力稍微好些噪音不能轿车胎比没大区别不像倍耐力
# 车底盘发动机确实挺LOWnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 东西最好原厂塑料没有异响保护买铝合金那种随型不要平发动机变速箱桥一共七八百找修理铺安装nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 哥们方向盘控制匹配成功nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 根本斯巴鲁方向盘nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 北美2.5没有垃圾方向盘助力nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 动力搭配对四驱性能关键nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 说挺中肯森林朋友好多黑森林说宝马操控好哈哈哈赞认证回复这条信息左边头像头像下方有个认证森林字眼点一下认证会上传行驶证申请认证中心nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 偶大哥xv四驱森林可能外观糊弄脑子里一直xv城市跨界suvxv没有脱困能力一直知道森林四驱能力森林脱困能力名声太响级别没车敢叫板只顾研究森林nullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 意思很多神话森林操控性nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 空间视野操控四驱可靠性沃尔沃森林确实一个档次nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 之前打算订凯美瑞混动店里交了意向金森林视野操控世界第一eyesight执念现在退意向金纠结选现款森林新款新款2.0配备es现款2.5发动机马上绝版nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 属于底盘加强件好像没nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 重心底水平对置全时四驱开过知道车唯一缺点日后维护成本高后来想想买台奥迪他弟维修便宜nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘自动回位应该前轮束角倾角一定关系nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 途观森林越野性能好点今年听到最大笑话nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 确实松垮感去年底添小车c3xr 价格不到森林一半底盘整体性高速沉稳感真森林人强日系车共同基因底盘不够整车子轻飘nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 安卓手机先下载亿连手机助手手套箱数据线手机手机打开助手车上方向盘source选择手机nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 拉杆主要起到一个底盘加强作用为主操控之前改装防倾杆横拉杆对后加小拉杆作用感觉明显之前没改装单独加拉杆感觉明显nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 斯巴鲁操控确实不错十一开着斯巴鲁游玩走起来nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林省心省油出毛病途观新车烧机油冠道没开过评论森林隔音不好异响操控那么回事普通人极限nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘右侧定速巡航按键下边左S右I模式超车切换运动模式时会响一声转速会提升默认I经济模式nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 意思森林操控比昂科威好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 看看超维底盘知道差距不小nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 肯定开省油上坡前有意识加速冲破坡中松油下坡完全松油定速巡航做不到nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 底盘易损件建议换新车子好好整一下会新好开看看保养手册看看原车主一直保养nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 受教一款底盘兼顾韧性整路感灵活舒适好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 没用底盘喷不锈铸铁件喷锈nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 去告斯巴鲁虚假广告每个车后面贴全时四驱告倒信说家分时四驱nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 非铺装路越野最轻代价刮底盘前保险杠有点磕碰刮掉点油漆轮胎扎是非铺装路面难以避免要爽代价nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 买车时试驾很多SUV森林驾驶感坐姿轿车底盘SUV里面算最高神奇nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 底盘胶套换掉看看球头换全车减震加弹簧胶套球头完美解决恢复如初nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 考虑入斯巴鲁主要考虑省油操控好跑烂路耐操不太看重舒适性噪音问题……森林应该不会BRZ更令人困扰nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 第一个图是四驱四轮状态绿色轮子转动左手正握方向盘左手中指抠一下方向盘拉杆会变化nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# glc操控gla没法森林nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 厉害厉害可能家用为主自驾肯定会经常自驾游看到SGP平台刚性操控性增加咱买2.5STI2.5T感觉现款操作动力应该还过得去nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 肯定选GT三俗话说坐奔驰开宝马买菜车操控性肯定GTnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 傲虎舒适性更好森林性操控更好更看重哪一点试驾坐进去感受一下选择nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 这车容易发现问题异响这是一部内饰做差车动手不算大事nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 可靠性较大离地间隙较轻车重比较好操控较强越野能力nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 奇骏纯工具代步车森林买来享受操控乐趣两个车满足越野需求nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# GT伟大旅行缩写动力操控长途旅行方面吊打森林非要找缺点森林人短些刨泥坑好点傲虎还行紧凑型suv森林道奇酷威nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 视频底盘没卡住公分间隙烧轮胎减震冲击少不了nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 前轮悬空前后轮间底盘位置已经托底没有支撑点车头不会翘起来nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 经常使用N档应用自启动车熄火后放N档脚离开刹车踏板应用自启动车停放N档脚离开刹车踏板红绿灯时脚非常难受不能踩重重了熄火不能轻轻车可能动刹车片可能发出声音nullnullnullnullnullnullnullnullnull
# 方向重两个前减震上部顶胶换试试年限车前减震顶胶里压力轴承估计不会太好会影响方向回正力度nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 同样感受真真不知道换操控不行质量放心贼费油nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 车空间比较完整人扣安全带应该没多大事希望一直保持安全水准会一直追随nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 噪音觉得我开三年没觉得后悔操控好加速稳街车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 便宜日本车才不说雷车层次国产冠道包括底盘平整度隔音钱没到nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 奇骏太软坐在沙发里面开车途观方向盘太硬典型大众范油门刹车硬nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林轴距短2.6米这才所谓操控好主要原因nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 大多数性能较强车发动机压榨更狠出问题nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 低配2.0轮胎前脸没有尾翼方向盘没有换挡拨片排挡杆里外样子区别很大应该可能搞错nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 一个人开森林全家使用后排经常坐人途观森林路面反馈太积极一个人开爽后面坐车舒服途观稳底盘懒没太大特色适合家用刚换代nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 喜欢机械手刹 好底盘好发动机够nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 根本问题方向盘歪nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# AT胎公里操控会好很多nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 调下距离方向盘左下方正常应该档调到档试试下调远近距离看不太清nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 方向盘左一堆按键一个开关随动转向功能nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 有点抓地力肯定提高动力损耗觉得得不偿失需求nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 欧蓝德不配超选四驱超选四驱偏向结构诠释欧蓝德四驱架构三菱evolution接近电控底层构建相同nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 高强度铁皮抗拉伸好质量轻重点造假……只能找到借口...nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 07款认为经典一代无框门momo方向盘现在13万公里车况一级棒朋友说开起来万公里车nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 说抖方向盘方向盘抖看看轮胎nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 奥迪方向盘方向感nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 森林进口车船运过来车做一次底盘装甲销售说nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 恭喜恭喜森林接缝处尤其尾部能购忍受装配工艺主流国产车略差爱水平对置发动机全时四驱系统森林2.02.5发动机账面数据不怎么样开起来行nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 主要森性能取向用途感觉更适合原来尾灯风格其实学习一下路虎平直线条好绝对好看设计师不好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 北方一个城市辽宁内蒙比较近冬天有雪选择全时四驱心安nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 底盘升起来看看是不是传动轴nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 用久会调听说简单底盘下面拧nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 为啥性能好车便宜日本南美欧洲国家销售量惨淡请问这是饥饿营销一种懂车教授牛逼车神nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 楼主你好所谓嗒嗒声是因为水箱风扇工作这时候发动机温度高节温器采集温度数据需要风扇继续工作采纳nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 钥匙口on位置按双闪键下方屏幕操控键往里功能叫做svm说明书nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 定速巡航车速60公里先一下长条按键一下SET键启动定速巡航定速巡航过程中踩油门刹车解除nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 公路操控马自达略胜半筹差别烂路上森林人胜全面nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 销售缺乏知识说全时四驱干什么说水平对置发动机好nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 应该没事底盘加轮胎震动消化nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# bba关长城吊事长城全系全时四驱长城wey38吐槽极限低不行直线慢弯道亡心理平衡干跑斯巴鲁论坛充英雄nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 有时候觉得内饰松散nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 前阵子刚检测完全时四驱滚筒没事车子直接窜过去年检原地测尾气一定告诉工作人员这车全时四驱nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 忘连续12届达喀尔拉力赛山猫可不是大梁底盘今天路虎JEEP部分车型仿造山猫底盘个人喜欢山猫H5山猫爬山nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 说事儿买斯巴鲁不会在乎重要全时四驱nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 产物Q5底盘规格布局森林人强一星半点傲虎方面没有资格挑战Q5老款三十多万买Q5估计想不要想nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 雪地里方向盘打死加油确实抖后轮抖前当雪咋办nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull
# 12款2.5xs 4at目前行驶10万公里 车机油消耗点能拉货自驾上下班通勤驾驶感觉好操控不错 感觉值nullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnullnull

# %%
from collections import Counter
Counter(result_set1['操控'])
# Out:
# Counter({0: 2109, 1: 255})
