# %%
import pandas as pd
import numpy as np
import torchvision as tv
import jieba
from gensim import models
from gensim.models import Word2Vec
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
import torch
show = ToPILImage() # 可以把Tensor转成Image，方便可视化
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../../../../data/df_sen_sub/train.csv')
data
# Out:
#             content_id                                            content  \
# 0     vUXizsqexyZVRdFH           因为森林人即将换代，这套系统没必要装在一款即将换代的车型上，因为肯定会影响价格。
# 1     4QroPd9hNfnCHVt7      四驱价格貌似挺高的，高的可以看齐XC60了，看实车前脸有点违和感。不过大众的车应该不会差。
# 2     QmqJ2AvM5GplaRyz  斯柯达要说质量，似乎比大众要好一点，价格也低一些，用料完全一样。我听说过野帝，但没听说过你说...
# 3     KMT1gFJiU4NWrVDn           这玩意都是给有钱任性又不懂车的土豪用的，这价格换一次我妹夫EP020可以换三锅了
# 4     nVIlGd5yMmc37t1o                            17价格忒高，估计也就是14-15左右。
# 5     TVciHBPL5XmUxMEd  我开始就是荣放2.5  森林人2.5二选一    荣放主要是底盘质感不行   太硬  其次是...
# 6     4lb9TsO5rjqUy1Bu                   唉，这货的价格死硬死硬的，低配版优惠1万据说已经罕有了。
# 7     z98xV7MphZIF4EvO                      价格的话只能说一般般吧，太仓前段时间定的比你便宜！
# 8     hoWrMnGTUvdsK3Dm                                听过，价格太贵，但一直念念不忘
# 9     r1WHgbI0ZKqMdELy                                      恭喜恭喜，这个优惠不错哦！
# 10    JSQUo6kblXYvtc2h                                     优惠幅度不小了，北京优惠八千
# 11    7kCF590PjAYqzEL6                         优惠可以了！购进吧！买了不会后悔的！时间可鉴！
# 12    EXBiRczhIu3paJWb                                        现在 什么价 优惠多少
# 13    nQ0bIZtzj6P1Esgd                                 优惠一万一 送贴膜装甲脚垫 铁西庞大
# 14    JvXIqLT8cGDuPEWe                             我也大连的，最近也考虑入手森林人，优惠太小了
# 15    NXyGEbt0AZ5rHJ3e                                  山东威海全系这才优惠3000，MD
# 16    kN0LghcimajxWwH8                                    下手了，豪导特供，优惠1.6万
# 17    vVoKucJy5pO0jSk2                                 优惠了8000，什么都不送。
# 18    iBFJMqHtTRD5Qo6S                          兄弟2.5豪导特供优惠1.6万可以下手吗？
# 19    G8Yr51elsVaXFUZC                          恭喜，优惠多少，我准备明天去提，2.5特装优惠两万
# 20    10WF8Q53pVfOryvA  什么车款，多少优惠啊？康桥我只能谈到优惠1.5其他还送什么没问，试驾了一次看了两次2.0时尚...
# 21    VrRd1HcoMNAkvhJy                                   优惠1 ，就送行程记录
# 22    1BYpO9FsgkmWLNQu  平常心吧，我本来想买傲虎，优惠不大，钱不够，改提森林人，6月提尊贵优惠1.4w，到了9月做活...
# 23    9EFImNb0ywhHBlcR                                 哈哈，25.48。优惠够给力
# 24    2aNFSuYeZo7B1b9R  兄弟，我也云南的，你的优惠也挺大的，现在哪里来的全系3万啊。。。现傲虎全系无优惠，森林人才八...
# 25    4EK1Nu7X2DTzomRS                  来湖北，我上月订的2.0蓝色时尚，优惠1万3送6次保养，本月底提车
# 26    TWPEyNaI5mFgYupn                            什么都没有，就是现金优惠和给了点小东西
# 27    96A5VQfBgPWUYkul                什么都没有，就是现金优惠和给了点小东西，你最好先问问看有没有车
# 28    JXlEzBcKGpI8stdr                             原来最低也就优惠15000至16000
# 29    P5A3evWb9jUyHMB2                                   我们这里，优惠2000，我呵呵了
# ...                ...                                                ...
# 9917  NtDO9KM2TQJYp8rC                                  风噪大 音响差驾驶什么的，秒杀其他
# 9918  lsMktgZyBDUfbowu               安全大于一切，出远门前一定要检查车子，主要有全车油水，轮胎，刹车系统等。
# 9919  hwzJjbCV26pLscxk  发动机直接就不一样了 FA20是斯巴鲁的招牌发动机 给WRX用要是烧的厉害那帮暴力驾驶的估计...
# 9920  6FMslAfukBpR82Po                            看路况，省道多平均油耗8-9，市区多11-12
# 9921  7X9tyquOCj0aw2Ql  换挡不是根据速度，而是根据你的意图。你想省油并匀速驾驶，就在转速允许的情况档位越高越好。想要...
# 9922  7X9tyquOCj0aw2Ql  换挡不是根据速度，而是根据你的意图。你想省油并匀速驾驶，就在转速允许的情况档位越高越好。想要...
# 9923  QBGuT7YNWVDsXgb8                                  同款配置黑森还要下个月中旬才能提车
# 9924  goheSWvcEPp79Lm6                                        正常，我城里跑油耗11
# 9925  pdjz83AoiWvu1lbh  森林人做工一般，配置还不如8、9万的国产车，这是事实。在老家侄儿子的五菱宏光把我的森林人给甩...
# 9926  pdjz83AoiWvu1lbh  森林人做工一般，配置还不如8、9万的国产车，这是事实。在老家侄儿子的五菱宏光把我的森林人给甩...
# 9927  K9s7OTLiCMm1dvzH             导航已经换成凯立德了，其它的功能也很差，我只是用来听收音机，导航还是手机的好
# 9928  wpHCZYOSrmske3yW                   有没有换过导航啥的，一般新车很少电路故障，行车电脑问题几率大点！
# 9929  I5NyHgsnkWvj84di  感觉稍微有点高了，油耗高低和很多方面有关，比如你个人驾驶习惯，你行驶道路拥堵状况等等，平稳驾...
# 9930  AoZJqK17aOz4UfxX                        选12款之前的。12款后都是fb发动机， 机油消耗大。
# 9931  cQlpvPRdOwUXaVkh                  跟欧蓝德的调校很相似啊，掌握规律后，堵车时跟车，可减少踩刹车的次数
# 9932  QVf8TWXrIPDwEgNU                    哈哈哈，欧兰德也能上来跟森比，那破车你开几年试试，那操控也能比
# 9933  dr1QZyaGWbI2BKxz                           14款2.0，大连，七万多公里了，平均油耗10。
# 9934  hMZEBAwkNz8Du714    森林人2.0开了两年，一直在中石化加油站加92#，没啥问题，杠杠的，夏天开空调油耗8.5左右。
# 9935  hMZEBAwkNz8Du714    森林人2.0开了两年，一直在中石化加油站加92#，没啥问题，杠杠的，夏天开空调油耗8.5左右。
# 9936  d4aM8HCr5VisWlfU        国内轮胎的品牌还是比较多的，看你要准备用什么价位的了，一般来说声音越小的价格也就高些。
# 9937  9oHZT5rXOjauPA7V                                      我的也这样，换刹车片后消失
# 9938  wlSvQOt3Kz2ekbcg                               反正我是不会去了，除非关健部位如变速箱油
# 9939  ELB0ZT5CvK9Fok4H  我感觉你的油耗稍大些，我这里山东，最冷零下18度，最高6度或者0度左右，也是16款2.0的，...
# 9940  vdDQXJEg3wSj84er                                     我的方向盘也是两边缝不一样大
# 9941  hUSkd6ptCbfxMPo8  俺必须的说，15公里以上的上下班单程行程，很少红灯，80左右的速度……对小森是极好的……所以...
# 9942  VywQTI4iLuzd1DZ3  老铁没毛病...双击666！！！是不是这样？我这理解逻辑也挑不出毛病吧！你不矫情你试试？多大...
# 9943  Ufv6VpyNaGnShzlJ           2.0时尚，四川这段时间温度最低-1，基本上下班用，现在均速18，表显油耗9.2
# 9944  S8tmC0gxyBjzvLuN                                相貌不起眼，内饰太平淡，开起来才知道好
# 9945  vpaS3ueRQi2rhAgH  一看就知道山寨的！用的肯定是中控的普通视频输入接口而已，这种无屏的记录仪淘宝也就一两百块的东...
# 9946  5R0ZoOdv8H2MNGgt  楼主还在吗，同在上海，想咨询一下家用首辆车，到底是买森林人还是力狮好？如果森林人，2.0的动...
#
#      subject  sentiment_value sentiment_word
# 0         价格                0             影响
# 1         价格               -1              高
# 2         价格                1              低
# 3         价格               -1           有钱任性
# 4         价格               -1              高
# 5         价格                1             便宜
# 6         价格               -1             死硬
# 7         价格                0             一般
# 8         价格               -1              贵
# 9         价格                1           优惠不错
# 10        价格                1         优惠幅度不小
# 11        价格                1           不会后悔
# 12        价格                0             优惠
# 13        价格                0             优惠
# 14        价格               -1           优惠太小
# 15        价格               -1            才优惠
# 16        价格                0             优惠
# 17        价格                0             优惠
# 18        价格                0             优惠
# 19        价格                0             优惠
# 20        价格                0             优惠
# 21        价格                0             优惠
# 22        价格                0             优惠
# 23        价格                0             优惠
# 24        价格               -1              才
# 25        价格                0             优惠
# 26        价格                0             优惠
# 27        价格                0             优惠
# 28        价格                0             优惠
# 29        价格               -1             呵呵
# ...      ...              ...            ...
# 9917     舒适性               -1            NaN
# 9918     安全性                1            NaN
# 9919      动力               -1            NaN
# 9920      油耗                0            NaN
# 9921      动力                0            NaN
# 9922     安全性                1            NaN
# 9923      配置                0            NaN
# 9924      油耗                0            NaN
# 9925      配置               -1            NaN
# 9926      内饰               -1            NaN
# 9927      配置                0            NaN
# 9928      配置                0            NaN
# 9929      油耗                0            NaN
# 9930      动力                0            NaN
# 9931     安全性                1            NaN
# 9932      操控               -1            NaN
# 9933      油耗                0            NaN
# 9934      油耗                0            NaN
# 9935     舒适性                1            NaN
# 9936      价格               -1            NaN
# 9937     安全性                1            NaN
# 9938      动力                0            NaN
# 9939      油耗               -1            NaN
# 9940      操控               -1            NaN
# 9941      油耗                0            NaN
# 9942      外观                1            NaN
# 9943      油耗                0            NaN
# 9944      内饰               -1            NaN
# 9945      配置               -1            NaN
# 9946      动力                0            NaN
#
# [9947 rows x 5 columns]

# %%
'''
data = pd.read_csv('../../data/df_sen_sub/train.csv')
len(data['content_id'].unique()), len(list(data['content_id']))
content_ids = data['content_id'].unique()
subjs = data['subject'].unique()
df = {}
text, subs, sentis = [], [], []
for i in range(len(content_ids)):
    if i % 100 == 0:print(i)
    dd = data[data['content_id'] == content_ids[i]]
    text.append(dd.loc[dd.index.tolist()[0], 'content'])
    temp_subs, temp_senti = [], []
    for sub in subjs:
        temp_subs.append(sub)
        if len(dd[dd['subject'] == sub]) != 0:
            temp_senti.append(str(int(dd[dd['subject'] == sub]['sentiment_value'])))
        else:
            temp_senti.append('2')
    subs.append(','.join(temp_subs))
    sentis.append(','.join(temp_senti))
df['content'] = text
df['subjects'] = subs
df['sentiments'] = sentis
df = pd.DataFrame(df)
df.to_csv('../../data/df_sen_sub/merge_train.csv', index = False)
#data = pd.read_csv('../../data/df_sen_sub/test_public.csv')
'''
# Out:
# "\ndata = pd.read_csv('../../data/df_sen_sub/train.csv')\nlen(data['content_id'].unique()), len(list(data['content_id']))\ncontent_ids = data['content_id'].unique()\nsubjs = data['subject'].unique()\ndf = {}\ntext, subs, sentis = [], [], []\nfor i in range(len(content_ids)):\n    if i % 100 == 0:print(i)\n    dd = data[data['content_id'] == content_ids[i]]\n    text.append(dd.loc[dd.index.tolist()[0], 'content'])\n    temp_subs, temp_senti = [], []\n    for sub in subjs:\n        temp_subs.append(sub)\n        if len(dd[dd['subject'] == sub]) != 0:\n            temp_senti.append(str(int(dd[dd['subject'] == sub]['sentiment_value'])))\n        else:\n            temp_senti.append('2')\n    subs.append(','.join(temp_subs))\n    sentis.append(','.join(temp_senti))\ndf['content'] = text\ndf['subjects'] = subs\ndf['sentiments'] = sentis\ndf = pd.DataFrame(df)\ndf.to_csv('../../data/df_sen_sub/merge_train.csv', index = False)\n#data = pd.read_csv('../../data/df_sen_sub/test_public.csv')\n"

# %%
data = pd.read_csv('../../../../data/df_sen_sub/merge_train.csv')
data = data.fillna('')
subs = list(data['subjects'])
sentiments = list(data['sentiments'])
content = list(data['content'])
test_data = pd.read_csv('../../../../data/df_sen_sub/test_public.csv')
test_data = test_data.fillna('')
test_content = list(test_data['content'])
data = pd.read_csv('../../../../data/df_sen_sub/train.csv')
data = data.fillna('')
senti_words = list(data['sentiment_word'])

# %%
with open('../../../../data/df_sen_sub/add_text.txt','w') as f:
    f.write('\n'.join(list(content) + list(test_content)  + list(subs) + senti_words))
# 迭代器，使用jieba将句子进行分词
stopwords = open('../../stopwords.txt', 'r').read().split('\n')
class Sentences(object):# 这个类可以根据实际情况重写，我已经将所有的文章进行分句，并整合到了一个文件里面
    def __init__(self, dirname):
        self.dirname = dirname # 句子所在文件，没句句子占一行
        #jieba.load_userdict("wordBase.txt") # 加载词库

    def __iter__(self):
        #for fname in os.listdir(self.dirname):
        for line in open(self.dirname):
                line = line.replace('\n', '')
                res = []
                for word in list(jieba.cut(line)):
                    if word in stopwords:
                        continue
                    res.append(word)
                yield res#list(jieba.cut(line))

sentences = []
def train_word2vec(folder_path, size=100):
    global sentences
    sentences = Sentences(folder_path) #生成分词后的句子，是一个二维数组

    # size是词向量长度
    # worker是线程数量，建议与物理线程数量一致
    # min_count是指出现次数小于一定程度，就忽略，0表示不忽略
    #model = Word2Vec(sentences, size=size, workers=8, min_count=0)

    # 训练结束就将模型保存起来
    #model.save("../../data/df_sen_sub/add_word2vec_model")

# 生成50维度的词向量模型
train_word2vec("../../../../data/df_sen_sub/add_text.txt",100)

# 测试训练好的词向量模型，使用model[keyWord]即可获取keyword这个词的词向量
model = Word2Vec.load("../../../../data/df_sen_sub/add_word2vec_model")
sentences = list(sentences)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.951 seconds.
# Prefix dict has been built succesfully.

# %%
len(sentences)
# Out:
# 28890

# %%
from collections import Counter
data = pd.read_csv('../../../../data/df_sen_sub/train.csv')
sub_uniq = data['subject'].unique()
data = data[pd.notnull(data['sentiment_word'])]
senti_word_set = {}
sum_ = 0
for key in sub_uniq:
    co = 0
    senti_word_set[key] = {}
    #dd = list(data[data['subject'] == key]['sentiment_word'])
    ddd = data[data['subject'] == key]
    for kk in [-1, 0, 1]:
        dd = list(ddd[ddd['sentiment_value'] == kk]['sentiment_word'])
        ss = []
        for phras in dd:
            words = list(jieba.cut(phras))
            for word in words:
                word = word.replace(' ', '')
                if word == '' or word in stopwords:continue
                ss.append(word)
                co += 1
            counter = Counter(ss)
            sort = sorted(counter.items(), key=lambda item: item[1], reverse = True)
            for mm in counter:
                if mm not in senti_word_set[key]:
                    senti_word_set[key][mm] = kk
                elif senti_word_set[key][mm] == kk:
                    continue
                else:
                    senti_word_set[key][mm] = 0
        sum_ += co
print(sum_)
senti_word_set
# Out:
# 6431
# {'价格': {'高': 0,
#   '有钱': -1,
#   '任性': -1,
#   '死硬': -1,
#   '贵': 0,
#   '优惠': 0,
#   '太小': -1,
#   '套路': -1,
#   '太贵': -1,
#   '不值': -1,
#   '高昂': -1,
#   '下不来': -1,
#   '不会': 0,
#   '便宜': 0,
#   '放弃': -1,
#   '平易近人': -1,
#   '价格': 0,
#   '老贵': -1,
#   '没有': 0,
#   '保证': -1,
#   '好多': -1,
#   '更': -1,
#   '合适': 0,
#   '那点': -1,
#   '贵太多': -1,
#   '挺高': -1,
#   '不菲': -1,
#   '一点': 0,
#   '奇高': -1,
#   '不好': -1,
#   '小贵': 0,
#   '过高': -1,
#   '售价': -1,
#   '明显': -1,
#   '高于': -1,
#   '竞品': -1,
#   '优势': -1,
#   '虚高': -1,
#   '不高': 0,
#   '性价比': 0,
#   '不算': -1,
#   '单价': -1,
#   '没': 0,
#   '降价': -1,
#   '不要': 0,
#   '想': -1,
#   '保值': -1,
#   '率': -1,
#   '大众': -1,
#   '好': 0,
#   '略贵': -1,
#   '保养': -1,
#   '不用': -1,
#   '考虑': -1,
#   '不靠': -1,
#   '谱': -1,
#   '没法': -1,
#   '咬咬牙': -1,
#   '不合算': -1,
#   '影响': 0,
#   '亲民点': 0,
#   '差不多': 0,
#   '差距': 0,
#   '知道': 0,
#   '合理': 0,
#   '就行': 0,
#   '行情': 0,
#   '价': 0,
#   '正常': 0,
#   '几百': 0,
#   '参差不齐': 0,
#   '行': 0,
#   '买': 0,
#   '价差': 0,
#   '很大': 0,
#   '低': 0,
#   '不能': 0,
#   '在意': 0,
#   '还行': 0,
#   '不错': 1,
#   '幅度': 1,
#   '不小': 1,
#   '后悔': 1,
#   '值': 1,
#   '愉快': 1,
#   '不够': 1,
#   '比较': 1,
#   '下降': 1,
#   '很多': 1,
#   '超级': 1,
#   '最好': 1,
#   '操控': 1,
#   '满意': 1,
#   '费用': 1,
#   '相当': 1,
#   '实惠': 1,
#   '再贵': 1,
#   '车': 1,
#   '欧蓝德': 1,
#   '真心': 1,
#   '秒杀': 1,
#   '对手': 1,
#   '力度': 1,
#   '良心': 1,
#   '找不出': 1,
#   '第二辆': 1},
#  '配置': {'没': -1,
#   '实用': 0,
#   '背光': -1,
#   '没有': 0,
#   '山寨': -1,
#   '不值钱': -1,
#   '贵': -1,
#   '比不上': -1,
#   '黑': -1,
#   '垃圾': -1,
#   '差': -1,
#   '卡死': -1,
#   '黑屏': -1,
#   '惨不忍睹': -1,
#   '鸡肋': -1,
#   '坑': -1,
#   '结实': -1,
#   '国内': -1,
#   '减配': -1,
#   '全景': -1,
#   '天窗': -1,
#   '可惜': -1,
#   '不行': -1,
#   '看不上眼': -1,
#   '换个': -1,
#   '正常': -1,
#   '点': -1,
#   '喜欢': 0,
#   '不高': -1,
#   '缺失': -1,
#   '遗憾': -1,
#   '低': -1,
#   '后悔': 0,
#   '不能': -1,
#   '忍': -1,
#   '咋样': -1,
#   '不太': 0,
#   '重视': -1,
#   '不选': -1,
#   '挫': -1,
#   '改款': -1,
#   '电动': -1,
#   '尾门': -1,
#   '太慢': -1,
#   '没落': -1,
#   '锁': -1,
#   '不久': -1,
#   '必要': -1,
#   '声音': -1,
#   '手机': 0,
#   '导航': 0,
#   '掉': -1,
#   '链子': -1,
#   '车载': -1,
#   '带到': -1,
#   '沟里': -1,
#   '硬伤': -1,
#   '差点': -1,
#   '优势': -1,
#   '方便': 0,
#   '太': -1,
#   '太扯': -1,
#   '值得': 0,
#   '不值': -1,
#   '配置': 0,
#   '简陋': -1,
#   '差一点': -1,
#   '很差': -1,
#   '简配': -1,
#   '厉害': -1,
#   '主': -1,
#   '坑爹': -1,
#   '吐槽': -1,
#   '有点': 0,
#   '抖': -1,
#   '丑到': -1,
#   '无力': -1,
#   '机舱': -1,
#   '里': -1,
#   '走': -1,
#   '管子': -1,
#   '不好': -1,
#   '断轴': -1,
#   '中控': -1,
#   '比较': 0,
#   '音质': -1,
#   '心里': -1,
#   '凉凉的': -1,
#   '早日': -1,
#   '完蛋': -1,
#   '不让': -1,
#   '省心': -1,
#   '区别': -1,
#   '连线': 0,
#   '简单': 0,
#   '后窗': 0,
#   '无所谓': 0,
#   '省钱': 0,
#   '不少': 0,
#   '不带': 0,
#   '是否': 0,
#   '好': 1,
#   'OK': 1,
#   '不错': 1,
#   '值': 1,
#   '一点': 1,
#   '问题': 1,
#   '高': 1,
#   '出色': 1,
#   '顶级': 1,
#   '超前': 1,
#   '买': 1,
#   '机械性能': 1,
#   '80': 1,
#   '分': 1,
#   '均衡': 1,
#   '提升': 1,
#   '厚道': 1,
#   '不差': 1,
#   '全': 1,
#   '真高': 1,
#   '满意': 1,
#   '非常': 1,
#   '合理': 1,
#   '蛮': 1,
#   '强太多': 1,
#   '合适': 1,
#   '胜出': 1,
#   '丰富': 1,
#   '够': 1,
#   '秒杀': 1,
#   '真心': 1,
#   '机械': 1,
#   '手刹': 1,
#   '四驱': 1,
#   '安全': 1,
#   '米其林': 1,
#   '3ST': 1,
#   '安静': 1,
#   '舒适': 1,
#   '坦克': 1,
#   '欧蓝德': 1,
#   '肯定': 1,
#   '压倒性': 1,
#   '说': 1,
#   '更好': 1,
#   '已成': 1,
#   '绝唱': 1,
#   '好用': 1,
#   '皮实': 1,
#   '整车': 1,
#   '扎实': 1,
#   '视野': 1,
#   '性好': 1,
#   '开着': 1,
#   '方面': 1,
#   '舒服': 1,
#   '优点': 1,
#   '缺点': 1,
#   '几乎': 1,
#   '零': 1,
#   '期待': 1,
#   'SGP': 1,
#   '新森': 1,
#   '影响': 1,
#   '新款': 1,
#   '厚重': 1,
#   '大气': 1,
#   '良心': 1},
#  '操控': {'垃圾': -1,
#   '那么回事': -1,
#   '渗油': -1,
#   '无法': 0,
#   '差': -1,
#   '开': 0,
#   '起来': -1,
#   '实在': -1,
#   '…': -1,
#   '.': -1,
#   '多余': -1,
#   '比不上': -1,
#   '颠簸': -1,
#   '完败': -1,
#   '没': 0,
#   '好': 0,
#   '承受': -1,
#   '不起': -1,
#   '不好': -1,
#   '静音': -1,
#   '抖': -1,
#   '响': -1,
#   '异响': -1,
#   '差劲': -1,
#   '刹车盘': -1,
#   '刺': -1,
#   '拉拉': -1,
#   '掉': -1,
#   '漆': -1,
#   '偏': -1,
#   '嘎嘎响': -1,
#   '脱皮': -1,
#   '底盘': 0,
#   '漏油': -1,
#   '走烂路': -1,
#   '颠': -1,
#   '磨得': -1,
#   '发亮': -1,
#   '解': -1,
#   '太': 0,
#   '味道': -1,
#   '真': -1,
#   '不小': -1,
#   '廉价': -1,
#   '欠缺': -1,
#   '废': -1,
#   '刹车': -1,
#   '通病': -1,
#   '刹': -1,
#   '不住': -1,
#   '不佳': -1,
#   '重': -1,
#   '一点': 0,
#   '很多': 0,
#   '方向': -1,
#   '飘': -1,
#   '方向盘': 0,
#   '总是': -1,
#   '不断': -1,
#   '修正': -1,
#   '车身': -1,
#   '反应': -1,
#   '迟钝': -1,
#   '软': -1,
#   '间隙': -1,
#   '低': 0,
#   '有点': 0,
#   '需要': -1,
#   '一直': -1,
#   '微调': -1,
#   '紧凑': 0,
#   '设计': -1,
#   '简练': -1,
#   '高度': -1,
#   '180mm': -1,
#   '太高': -1,
#   '过坑': -1,
#   '瞬间': -1,
#   '轿车': -1,
#   '晃动': -1,
#   '飞': -1,
#   '叉叉': -1,
#   '摆动': -1,
#   '手感': 0,
#   '危险': -1,
#   '平衡': 0,
#   '换': 0,
#   '规格': 0,
#   '没敢': 0,
#   '玩': 0,
#   '中等': 0,
#   '偏硬': 0,
#   '更': 0,
#   '硬': 0,
#   '换代': 0,
#   '慢': 0,
#   '太稳': 0,
#   '重新': 0,
#   '松散': 0,
#   '告诉': 0,
#   '抖动': 0,
#   '更高': 0,
#   '舒服': 0,
#   '调节': 0,
#   '没什么': 0,
#   '影响': 0,
#   '没有磨损': 0,
#   '不错': 0,
#   '兼顾': 0,
#   '东西': 0,
#   '最高': 0,
#   '变化': 0,
#   '烂': 0,
#   '无所谓': 0,
#   '高': 0,
#   '控制不了': 0,
#   '加热': 0,
#   '问题': 0,
#   '差不多': 0,
#   '一流': 1,
#   '追求': 1,
#   '良好': 1,
#   '第一': 1,
#   '灵活': 1,
#   '完胜': 1,
#   '好用': 1,
#   '挺棒': 1,
#   '专业': 1,
#   '漂移': 1,
#   '好感': 1,
#   '优势': 1,
#   '喜欢': 1,
#   '符合': 1,
#   '95': 1,
#   '分': 1,
#   '牛': 1,
#   '逼': 1,
#   '要求': 1,
#   '一致': 1,
#   '升级': 1,
#   '值得': 1,
#   '不飘': 1,
#   '更好': 1,
#   '满意': 1,
#   '厉害': 1,
#   '灵巧': 1,
#   '强': 1,
#   '韧性': 1,
#   '很稳': 1,
#   '很准': 1,
#   '好点': 1,
#   '操控': 1,
#   '感': 1,
#   '安全': 1,
#   '优点': 1,
#   '轻松': 1,
#   '忍住': 1,
#   '没改': 1,
#   '舒适感': 1,
#   '真心': 1,
#   '犹如': 1,
#   '宝马': 1,
#   '比较': 1,
#   '优': 1,
#   '确实': 1,
#   '很棒': 1,
#   '自信': 1,
#   '操控性': 1,
#   '相当': 1,
#   '一个': 1,
#   '档次': 1,
#   '看点': 1,
#   '费劲': 1,
#   '没得说': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '提高': 1,
#   '性能': 1,
#   '说': 1,
#   '坐姿': 1,
#   '驾驶': 1,
#   '质感': 1,
#   '蛮': 1,
#   '给力': 1,
#   '安心': 1,
#   '质量': 1,
#   '完美': 1,
#   '肯定': 1,
#   '随性': 1,
#   '稳': 1,
#   '破百': 1,
#   '胜出': 1,
#   '最好': 1,
#   '无敌': 1,
#   '闻名': 1,
#   '可靠': 1,
#   '超过': 1,
#   '非常': 1,
#   '略胜一筹': 1,
#   '距离': 1,
#   '短': 1,
#   '灵': 1,
#   '轻': 1,
#   '操纵': 1,
#   '好开': 1,
#   '比新森强': 1,
#   '没见': 1,
#   '跑': 1,
#   '14': 1,
#   '万': 1,
#   '机器': 1,
#   '基本': 1,
#   '着迷': 1,
#   '纠结': 1,
#   '后悔': 1,
#   '解释': 1,
#   '挺稳': 1},
#  '舒适性': {'坑': -1,
#   '异响': -1,
#   '噪音': 0,
#   '颠': -1,
#   '问题': 0,
#   '打不开': -1,
#   '乱响': -1,
#   '卡顿': -1,
#   '质量': -1,
#   '很差': -1,
#   '腰疼': -1,
#   '抖': -1,
#   '舒服': 0,
#   '气门': -1,
#   '声音': 0,
#   '震': -1,
#   '响': -1,
#   '隔音': -1,
#   '不好': -1,
#   '忽悠': -1,
#   '容易': -1,
#   '晕车': -1,
#   '就别': -1,
#   '想': -1,
#   '开着': -1,
#   '累': -1,
#   '唯一': -1,
#   '不足': -1,
#   '风噪大': -1,
#   '差多': -1,
#   '很大': -1,
#   '舒适': 0,
#   '颠簸': -1,
#   '有点': 0,
#   '影响': -1,
#   '味': -1,
#   '较大': -1,
#   '偏': -1,
#   '不行': -1,
#   '较差': -1,
#   '受不了': -1,
#   '特别': -1,
#   '空调': 0,
#   '咋样': -1,
#   '烦透了': -1,
#   '耳朵': -1,
#   '音响': -1,
#   '太': 0,
#   '差': -1,
#   '变': 0,
#   '滴水': 0,
#   '现象': -1,
#   '确实': -1,
#   '不会': -1,
#   '制冷': 0,
#   '速度': -1,
#   '快': 0,
#   '开': 0,
#   '没劲': -1,
#   '差一点': -1,
#   '依旧': -1,
#   '抖抖': -1,
#   '不少': -1,
#   '难受': -1,
#   '支持': -1,
#   '发出声音': -1,
#   '很烦': -1,
#   '风噪': -1,
#   '最大': -1,
#   '比较': -1,
#   '俩': -1,
#   '车': -1,
#   '不算': 0,
#   '太好': -1,
#   '原胎': -1,
#   '严实': -1,
#   '出': -1,
#   '偏低': -1,
#   '硬': -1,
#   '毛病': -1,
#   '滋滋': -1,
#   '声': -1,
#   '土腥味': -1,
#   '抖动': -1,
#   '摩擦音': -1,
#   '气味': -1,
#   '呛': -1,
#   '格叽格': -1,
#   '叽响': -1,
#   '座椅': 0,
#   '臭': -1,
#   '视野': 0,
#   '森': -1,
#   '金属': -1,
#   '撞击': -1,
#   '响声': -1,
#   '敲击': -1,
#   '真心': -1,
#   '点': 0,
#   '发动机': -1,
#   '效果': 0,
#   '内部': -1,
#   '味道': -1,
#   '胎噪件': -1,
#   '15': -1,
#   '万': -1,
#   '听': -1,
#   '心烦': -1,
#   '后排': -1,
#   '太硬': -1,
#   '颈椎': -1,
#   '有点累': -1,
#   'X1': -1,
#   '可怜': -1,
#   '更': -1,
#   '吵': -1,
#   '扯淡': -1,
#   '静音': 0,
#   '原厂': 0,
#   '冻得': 0,
#   '正常': 0,
#   '以前': 0,
#   '小点': 0,
#   '保养': 0,
#   '忽略不计': 0,
#   '忽略': 0,
#   '掩盖': 0,
#   '有所': 0,
#   '下降': 0,
#   '冷': 0,
#   '不给力': 0,
#   '冰箱': 0,
#   '变化': 0,
#   '没': 0,
#   '舒适性': 0,
#   '还行': 0,
#   '不介意': 0,
#   '好': 1,
#   '牛': 1,
#   '逼': 1,
#   '空间': 1,
#   '看中': 1,
#   '记忆': 1,
#   '提升': 1,
#   '强': 1,
#   '感觉': 1,
#   '不错': 1,
#   '恒温': 1,
#   '满意': 1,
#   '分区': 1,
#   '减少': 1,
#   '提高': 1,
#   '很多': 1,
#   '低': 1,
#   '好听': 1,
#   '好用': 1,
#   '好点': 1,
#   '蛮': 1,
#   '给力': 1,
#   '没有': 1,
#   '高': 1,
#   '厉害': 1,
#   '非常': 1,
#   '风力': 1,
#   '强劲': 1,
#   '坐姿': 1,
#   '视线': 1,
#   '更好': 1,
#   '说': 1,
#   '性好': 1,
#   '超级': 1,
#   '调': 1,
#   '秒杀': 1,
#   'SUV': 1,
#   '乘客': 1,
#   '安静': 1},
#  '油耗': {'省油': 0,
#   '略': -1,
#   '高': 0,
#   '公平': -1,
#   '全': -1,
#   '行业': -1,
#   '造假': -1,
#   '真': -1,
#   '喜欢': -1,
#   '费油': 0,
#   '偏': -1,
#   '完败': -1,
#   '升高': -1,
#   '上升': -1,
#   '增加': 0,
#   '油耗': 0,
#   '会': -1,
#   '顶不住': -1,
#   '太高': -1,
#   '哗哗': -1,
#   '以前': -1,
#   '可能': -1,
#   '低': 0,
#   '点': -1,
#   '高点': 0,
#   '颇': -1,
#   '很多': -1,
#   '特大': -1,
#   '贼': -1,
#   '不好': -1,
#   '蹭': -1,
#   '上涨': -1,
#   '性价比': -1,
#   '控制': -1,
#   '一点': -1,
#   '1.8': -1,
#   'T': -1,
#   '不低': -1,
#   '确实': 0,
#   '爱': -1,
#   '滴': -1,
#   '不敢恭维': -1,
#   '不着': -1,
#   '调': -1,
#   '不见得': -1,
#   '省': 0,
#   '没': 0,
#   '感觉': 0,
#   '差不多': 0,
#   '市区': 0,
#   '左右': 0,
#   '正常': 0,
#   '必要': 0,
#   '做': 0,
#   '区别': 0,
#   '没说的': 0,
#   '关心': 0,
#   '稍微': 0,
#   '只能': 0,
#   '说': 0,
#   '行': 1,
#   '满意': 1,
#   '知足': 1,
#   '不高': 1,
#   '好': 1,
#   '毛病': 1,
#   '没有': 1,
#   '现象': 1,
#   '平顺': 1,
#   '自然': 1,
#   '给力': 1,
#   '额外': 1,
#   '惊喜': 1,
#   '问题': 1,
#   '不错': 1,
#   '下降': 1,
#   '不会': 1,
#   '一个': 1,
#   '稳定': 1,
#   '变化': 1,
#   '废油': 1,
#   '效果': 1,
#   '相当': 1,
#   '棒': 1,
#   '非常': 1,
#   '耐用': 1,
#   '值得': 1,
#   '拥有': 1,
#   '胜出': 1,
#   '够': 1,
#   '牛': 1,
#   '2.0': 1,
#   '森': 1,
#   '真心': 1,
#   '低油耗': 1,
#   '5.9': 1,
#   '驾驶': 1,
#   '体验': 1,
#   '超级': 1,
#   '不少': 1,
#   '水平': 1,
#   '已经': 1,
#   '挺': 1,
#   '一定': 1},
#  '动力': {'反应': 0,
#   '慢': -1,
#   '熄火': -1,
#   '肉': 0,
#   '不佳': -1,
#   '烧': 0,
#   '机油': 0,
#   '郁闷': -1,
#   '坑': -1,
#   '爆震': -1,
#   '怕': 0,
#   '失望': -1,
#   '没': 0,
#   '太吵': -1,
#   '担心': 0,
#   '通病': -1,
#   '偶尔': -1,
#   '顿挫': -1,
#   '有点': 0,
#   '受不了': -1,
#   '不够': 0,
#   '异响': -1,
#   '问题': 0,
#   '差点': -1,
#   '意思': -1,
#   '质量': -1,
#   '不行': -1,
#   '一个': -1,
#   '缸体': -1,
#   '工作': -1,
#   '严重': -1,
#   '抖动': -1,
#   '不好': -1,
#   '差': 0,
#   '车重': -1,
#   '不选': -1,
#   '代价': -1,
#   '偏弱': -1,
#   '过时': -1,
#   '轻微': -1,
#   '渗油': -1,
#   '完善': -1,
#   '变弱': -1,
#   '不了': -1,
#   '下降': 0,
#   '一点': 0,
#   '一点点': 0,
#   '鸡肋': 0,
#   '故障': -1,
#   '弱': -1,
#   '没有': 0,
#   '以前': 0,
#   '灵敏': 0,
#   '温度': 0,
#   '高': 0,
#   '漏油': -1,
#   '设计': -1,
#   '缺陷': -1,
#   '消耗': -1,
#   '生锈': -1,
#   '涉水': -1,
#   '锁死': -1,
#   '查不出': -1,
#   '哗啦声': -1,
#   '败笔': -1,
#   '转速': -1,
#   '低': 0,
#   '负担': -1,
#   '轰': -1,
#   '轰响': -1,
#   '飙车': -1,
#   '差劲': -1,
#   '牛车': -1,
#   '变闷': -1,
#   '动力': 0,
#   '降低': -1,
#   '压力': -1,
#   '重新': -1,
#   '打胶': -1,
#   '加速': 0,
#   '缓慢': -1,
#   '太弱': -1,
#   '跟不上': -1,
#   '冒烟': -1,
#   '点': 0,
#   '缝隙': -1,
#   '里': -1,
#   '油泥': -1,
#   '搞': -1,
#   '好': 0,
#   '到哪去': -1,
#   '明显': 0,
#   '发动机': 0,
#   '噪声': -1,
#   '变速箱': -1,
#   '存在': -1,
#   '不足': 0,
#   '噪音': 0,
#   '没力': -1,
#   '异味': -1,
#   '一直': -1,
#   '弊病': -1,
#   '段': -1,
#   '别提': -1,
#   '急': -1,
#   '嘶哑': -1,
#   '减少': -1,
#   '逊色': -1,
#   '降': -1,
#   '之前': -1,
#   '硬伤': -1,
#   '很差': -1,
#   '捉急': -1,
#   '差些': -1,
#   '太': 0,
#   '太行': -1,
#   '风险': -1,
#   '很大': -1,
#   '1.6': -1,
#   'T': -1,
#   '四缸': -1,
#   '四驱': 0,
#   '超个': -1,
#   '车': -1,
#   '感觉': 0,
#   '费劲': -1,
#   '擅长': -1,
#   '不好受': -1,
#   '老坏': -1,
#   '肯定': -1,
#   '指望': -1,
#   '偏磨': -1,
#   '没什么': -1,
#   '亮点': -1,
#   '不会': 0,
#   '很快': -1,
#   '连速腾': -1,
#   '起步': -1,
#   '赶不上': -1,
#   '爬坡': -1,
#   '爬': -1,
#   '上去': -1,
#   '大众': -1,
#   '调教': -1,
#   '维修': -1,
#   '起来': -1,
#   '麻烦': -1,
#   '高性能': -1,
#   '烧漏': -1,
#   '落后': -1,
#   '真的': 0,
#   '实在': -1,
#   '太老': -1,
#   '远': -1,
#   '牛': 0,
#   'b': -1,
#   '不到': -1,
#   '心理': -1,
#   '没底': -1,
#   '垃圾': -1,
#   '运气': 0,
#   '纠结': 0,
#   '好像': 0,
#   '够用': 0,
#   '不烧': 0,
#   '驾驶': 0,
#   '足够': 0,
#   '一般般': 0,
#   '换油': 0,
#   '偏': 0,
#   '伤': 0,
#   '蓄电池': 0,
#   '重心': 0,
#   '避免': 0,
#   '没关系': 0,
#   '难点': 0,
#   '不敢': 0,
#   '通红': 0,
#   '都行': 0,
#   '爆缸': 0,
#   '正常': 0,
#   '声音': 0,
#   '变小': 0,
#   '不说': 0,
#   '没觉': 0,
#   '没事': 0,
#   '影响': 0,
#   '散热': 0,
#   '不解': 0,
#   '忽略': 0,
#   '行': 0,
#   '区别': 0,
#   '差不多': 0,
#   '有所': 0,
#   '护板': 0,
#   '破碎': 0,
#   '做到': 0,
#   '最好': 0,
#   '布局': 0,
#   '限制': 0,
#   '觉得': 0,
#   '适当': 0,
#   '保养': 0,
#   '低沉': 0,
#   '疯狂': 0,
#   '没法': 0,
#   '磨损': 0,
#   '差别': 0,
#   '提速': 0,
#   '水平': 0,
#   '对置': 0,
#   '横向': 0,
#   '占用': 0,
#   '空间': 0,
#   '充足': 1,
#   '舒服': 1,
#   '很少': 1,
#   '耐用': 1,
#   '少': 1,
#   '足': 1,
#   '超车': 1,
#   '满意': 1,
#   '轻松': 1,
#   '不错': 1,
#   '用不完': 1,
#   '劲': 1,
#   '给力': 1,
#   '非常': 1,
#   '够': 1,
#   '杠杠': 1,
#   '开着': 1,
#   '爽': 1,
#   '很多': 1,
#   '完全': 1,
#   '不能': 1,
#   '比拟': 1,
#   '不差': 1,
#   '快': 1,
#   '改观': 1,
#   '不少': 1,
#   '好点': 1,
#   '95': 1,
#   '分': 1,
#   '排量': 1,
#   '提高': 1,
#   '升级': 1,
#   '提升': 1,
#   '强': 1,
#   '全时': 1,
#   '加强': 1,
#   '敏捷': 1,
#   '随叫随到': 1,
#   '好太多': 1,
#   '高原': 1,
#   '小霸王': 1,
#   '信心': 1,
#   '满满': 1,
#   '情况': 1,
#   '很爽': 1,
#   '损耗': 1,
#   '省心': 1,
#   '漏': 1,
#   '均衡': 1,
#   '轻盈': 1,
#   '舒适': 1,
#   '王': 1,
#   '优': 1,
#   '更好': 1,
#   '堪比': 1,
#   '跑车': 1,
#   '相当': 1,
#   '轻轻松松': 1,
#   '优势': 1,
#   '干净': 1,
#   '甩': 1,
#   'n': 1,
#   '条街': 1,
#   '专家': 1,
#   '已经': 1,
#   '猛': 1,
#   '拔尖': 1,
#   '追不上': 1,
#   '喜欢': 1,
#   '强些': 1,
#   '强劲': 1,
#   '更足': 1,
#   '性能': 1,
#   '效果': 1,
#   '质感': 1,
#   '很小': 1,
#   '好车': 1,
#   '太好了': 1,
#   '车挺': 1,
#   '破百': 1,
#   '秒杀': 1,
#   '胜出': 1,
#   '无敌': 1,
#   '出色': 1,
#   '可靠': 1,
#   '没得说': 1,
#   '超过': 1,
#   '更高': 1,
#   '稳定': 1,
#   '新': 1,
#   '坦克': 1,
#   '欧蓝德': 1,
#   '开启': 1,
#   '汽车': 1,
#   '新篇章': 1,
#   '轻': 1,
#   '强多': 1,
#   '响应': 1,
#   '旅行': 1,
#   '更强': 1,
#   '老牛': 1,
#   '逼': 1,
#   '最大': 1,
#   '卖点': 1,
#   '原来': 1,
#   '稳': 1,
#   '没见': 1,
#   '跑': 1,
#   '14': 1,
#   '万': 1,
#   '机器': 1,
#   '直列': 1,
#   '诱惑': 1,
#   '中控台': 1,
#   '确实': 1,
#   '着迷': 1,
#   '扯淡': 1,
#   '后悔': 1,
#   '太给力': 1,
#   '算': 1,
#   '输': 1},
#  '内饰': {'普通': 0,
#   '松垮': -1,
#   '旧': -1,
#   '差': -1,
#   '改改': 0,
#   '一点点': -1,
#   '细致': -1,
#   '挫': -1,
#   '破破烂烂': -1,
#   '有点': -1,
#   '糙': -1,
#   '影响': -1,
#   '驾驶': -1,
#   '全': -1,
#   '塑料': -1,
#   '简陋': -1,
#   '改': -1,
#   '不够': -1,
#   '完败': -1,
#   '太': 0,
#   '水': -1,
#   '过时': -1,
#   '出毛病': -1,
#   '脱皮': -1,
#   '粗糙': -1,
#   '现款': -1,
#   '一个': 0,
#   '档次': 0,
#   '内饰': 0,
#   '老气': -1,
#   '低档': -1,
#   '伤感情': -1,
#   '异味': -1,
#   '没用': -1,
#   '不满': -1,
#   '+': -1,
#   'E': -1,
#   'E11': -1,
#   ':': -1,
#   'E742': -1,
#   '缺点': -1,
#   '硬伤': -1,
#   '差一点': -1,
#   '令人发指': -1,
#   '粗': -1,
#   '不能': -1,
#   '接受': -1,
#   '整': -1,
#   '渣': -1,
#   '没戏': -1,
#   '难受': -1,
#   '单调': -1,
#   '豪华': 0,
#   '硬': -1,
#   '凸': -1,
#   '太过': -1,
#   '简单': 0,
#   '粗糟': -1,
#   '吐': -1,
#   '寒酸': -1,
#   '十万块': -1,
#   '国产车': -1,
#   '扯淡': -1,
#   '吐槽': -1,
#   '掉': -1,
#   '没得': -1,
#   '不敢恭维': -1,
#   '惨不忍睹': -1,
#   '非常': -1,
#   '落后': -1,
#   '一股': -1,
#   '丰田': -1,
#   '味': -1,
#   '后排': -1,
#   '座椅': -1,
#   '格叽格': -1,
#   '叽响': -1,
#   '臭味': -1,
#   '廉价': -1,
#   '感': -1,
#   'L0W': -1,
#   '磕碜': -1,
#   '点': -1,
#   '较差': -1,
#   '感觉': -1,
#   '多丑': -1,
#   '科技': 0,
#   '一如既往': -1,
#   '做工': 0,
#   '设计': 0,
#   '土土': -1,
#   '居然': -1,
#   '舒坦': -1,
#   '还好': 0,
#   '感冒': 0,
#   '面包车': 0,
#   '60': 0,
#   '分': 0,
#   '大致相同': 0,
#   '用处': 0,
#   '不提': 0,
#   '心知肚明': 0,
#   '要求': 0,
#   '不高': 0,
#   '特别': 0,
#   '舒服': 0,
#   '贼': 0,
#   '嚣张': 0,
#   '齐全': 0,
#   '就行': 0,
#   '不在乎': 0,
#   '不错': 1,
#   '好': 1,
#   '坐': 1,
#   '进去': 1,
#   '放松': 1,
#   '保值': 1,
#   '耐用': 1,
#   '喜欢': 1,
#   '认可度': 1,
#   '高': 1,
#   '皮实': 1,
#   '提升': 1,
#   '好看': 1,
#   '符合': 1,
#   '一致': 1,
#   '车': 1,
#   '手感': 1,
#   '爆炸': 1,
#   '不逊于': 1,
#   '大改': 1,
#   '强': 1,
#   '没': 1,
#   '说': 1,
#   '品质': 1,
#   '记忆': 1,
#   '绝对值': 1,
#   '感强': 1,
#   '中上游': 1,
#   '绝对': 1,
#   '口味': 1,
#   '保持': 1,
#   '用料': 1,
#   '简洁': 1,
#   '干练': 1,
#   '炫酷': 1,
#   '高出': 1,
#   '带': 1,
#   '喜感': 1,
#   '好点': 1,
#   '更好': 1,
#   '不少': 1,
#   '漂亮': 1,
#   '细': 1,
#   '骚': 1,
#   '很多': 1,
#   '高大': 1,
#   '秒杀': 1,
#   '胜出': 1,
#   '帅': 1,
#   '新': 1,
#   '简约': 1,
#   '比较': 1,
#   '真的': 1,
#   '感高': 1,
#   '森林': 1,
#   '人强': 1,
#   '偏硬': 1,
#   '造型': 1,
#   '吊打': 1},
#  '安全性': {'软': -1,
#   '强': 0,
#   '差劲': -1,
#   '耐磨': -1,
#   '刹': -1,
#   '不住': -1,
#   '少': -1,
#   '气囊': -1,
#   '心寒': -1,
#   '刹车': 0,
#   '行程': -1,
#   '距离': -1,
#   '长': -1,
#   '不给力': -1,
#   '问题': 0,
#   '醉': -1,
#   '恼人': -1,
#   '能比': -1,
#   '不行': -1,
#   '急刹车': -1,
#   '差点': -1,
#   '追尾': -1,
#   '无奈': -1,
#   '急': 0,
#   '加速': 0,
#   '耐用': 1,
#   '不错': 1,
#   '要求': 1,
#   '一致': 1,
#   '安全': 1,
#   '第一': 1,
#   '高': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '好': 1,
#   '超好': 1,
#   '适合': 1,
#   '效果': 1,
#   '皮实': 1,
#   '更': 1,
#   '扎实': 1,
#   '喜欢': 1,
#   '机械': 1,
#   '手刹': 1,
#   '卤素灯': 1,
#   '明显': 1,
#   '穿透力': 1,
#   '更强': 1,
#   '安全感': 1,
#   '极高': 1,
#   '硬': 1,
#   '脚感': 1,
#   '非常': 1,
#   '细腻': 1,
#   '微操': 1,
#   '完': 1,
#   '线性': 1,
#   '踩': 1,
#   '随有': 1,
#   '挺': 1,
#   '避震': 1,
#   '觉得': 1,
#   '够': 1,
#   '算': 1,
#   '输': 1},
#  '空间': {'硬伤': -1,
#   '真': -1,
#   '喜欢': 0,
#   '排挤': -1,
#   '不行': -1,
#   '钻进去': -1,
#   '奢望': -1,
#   '真的': -1,
#   '空间': 0,
#   '不敢恭维': -1,
#   '后排': -1,
#   '点': -1,
#   '舒服': 0,
#   '满意': 0,
#   '一点': -1,
#   '·': -1,
#   '没有': -1,
#   '没': 0,
#   '宽敞': 0,
#   '差': -1,
#   '有点': 0,
#   '显小': -1,
#   '异响': -1,
#   '太小': -1,
#   '完败': -1,
#   '抓狂': -1,
#   '轴距': 0,
#   '严重': -1,
#   '不符': -1,
#   '不在意': 0,
#   '感冒': 0,
#   '差别': 0,
#   '不差': 0,
#   '横向': 0,
#   '比森好': 0,
#   '纵向': 0,
#   '森': 0,
#   '较大': 0,
#   '好些': 1,
#   '满足': 1,
#   '不错': 1,
#   '坐': 1,
#   '进去': 1,
#   '放松': 1,
#   '出色': 1,
#   '杀手锏': 1,
#   '车体': 1,
#   '高': 1,
#   '均衡': 1,
#   '差不多': 1,
#   '好': 1,
#   '实用': 1,
#   '方面': 1,
#   '保障': 1,
#   '动力': 1,
#   '非常': 1,
#   '够用': 1,
#   '不小': 1,
#   '容量': 1,
#   '宽大': 1,
#   '舒适': 1,
#   '特大': 1,
#   '变': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '相当': 1,
#   '优势': 1,
#   '挺大': 1,
#   '更': 1,
#   '方便': 1,
#   '杠杠': 1,
#   '挺': 1,
#   '行': 1,
#   '很漂亮': 1,
#   '加长': 1,
#   '森林': 1,
#   '高点': 1,
#   '胜出': 1,
#   '很多': 1,
#   '理想': 1,
#   '后备箱': 1,
#   '更大': 1,
#   '说': 1,
#   '/': 1,
#   '后座': 1,
#   '宽': 1,
#   '坐姿': 1,
#   '好点': 1,
#   '太': 1,
#   '诱惑': 1,
#   '中控台': 1,
#   '车': 1,
#   '蛮大': 1,
#   '更好': 1},
#  '外观': {'差点': -1,
#   '硬': -1,
#   '变色': -1,
#   '丑': -1,
#   '薄': -1,
#   '好看': 0,
#   '屁股': -1,
#   '喜欢': 0,
#   '颜值': 0,
#   '差': -1,
#   '难看': -1,
#   '中庸': -1,
#   '接受度': -1,
#   '不高': -1,
#   '老气': -1,
#   '挫': -1,
#   '取消': -1,
#   '掰': -1,
#   '不动': -1,
#   '纠结': 0,
#   '硬伤': -1,
#   '很多': -1,
#   '倾斜': -1,
#   '里外': -1,
#   '摇晃': -1,
#   '平庸': -1,
#   '越丑': -1,
#   '符合': -1,
#   '协调': 0,
#   '真': 0,
#   '好': 0,
#   '外观': 0,
#   '没有': -1,
#   '丝毫': -1,
#   '质感': -1,
#   '奇丑无比': -1,
#   '太小': -1,
#   '气': -1,
#   '太丑': -1,
#   '挫样': -1,
#   '接受': -1,
#   '不了': -1,
#   '廉价': -1,
#   '软': -1,
#   '不敢恭维': -1,
#   '有点': -1,
#   '土': -1,
#   '现款': -1,
#   '无力': -1,
#   '吐槽': -1,
#   '觉得': 0,
#   '19': -1,
#   '款': -1,
#   '老款': -1,
#   '新潮': -1,
#   '拼凑': -1,
#   '杀马特': -1,
#   '尾灯': -1,
#   '好丑': -1,
#   '史上': -1,
#   '车漆': -1,
#   '平淡无奇': -1,
#   '无比': -1,
#   '毁': -1,
#   '日系车': -1,
#   '漆软': -1,
#   '真软': -1,
#   '前脸': 0,
#   '无爱': -1,
#   '镀铬': -1,
#   '太': -1,
#   '尴尬': -1,
#   '漆面': -1,
#   '太薄': -1,
#   '不像': -1,
#   '换代': -1,
#   '应有': -1,
#   '水平': -1,
#   '多丑': -1,
#   '不怎么': -1,
#   '中网': -1,
#   '低级': -1,
#   '下限': -1,
#   '在意': 0,
#   '普通': 0,
#   '凶狠': 0,
#   '前': 0,
#   '脸': 0,
#   '高配': 0,
#   '不在意': 0,
#   '无所谓': 0,
#   '性价比': 1,
#   '逼格': 1,
#   '高': 1,
#   '特别': 1,
#   '迷恋': 1,
#   '认可度': 1,
#   '尊贵': 1,
#   '挺': 1,
#   '炫': 1,
#   '要求': 1,
#   '一致': 1,
#   '时尚': 1,
#   '大改': 1,
#   '大气': 1,
#   '生猛': 1,
#   '作用': 1,
#   '降低': 1,
#   '高度': 1,
#   '口味': 1,
#   '看中': 1,
#   '不错': 1,
#   '视野': 1,
#   '底盘': 1,
#   '厉害': 1,
#   '漂亮': 1,
#   '合眼': 1,
#   '缘': 1,
#   '外形': 1,
#   '一个': 1,
#   '档次': 1,
#   '隐隐': 1,
#   '豪华车': 1,
#   '感觉': 1,
#   '真心': 1,
#   '赞': 1,
#   '车': 1,
#   '一次': 1,
#   '没修过': 1,
#   '秀气': 1,
#   '秒杀': 1,
#   '厚': 1,
#   '强化': 1,
#   '硬朗': 1,
#   '确实': 1,
#   '点': 1,
#   '颜色': 1,
#   '光线': 1,
#   '看着': 1,
#   '舒服': 1,
#   '耐看': 1,
#   '中规中矩': 1,
#   '至少': 1,
#   '新款': 1,
#   '低调': 1,
#   '这种': 1,
#   '设计': 1,
#   '精致': 1,
#   '更好': 1,
#   '森': 1,
#   '保持': 1,
#   '偏硬': 1,
#   '造型': 1,
#   '吊打': 1,
#   '面子': 1,
#   '个人': 1,
#   '比较': 1,
#   '帅气': 1,
#   '社会': 1,
#   '前网': 1,
#   '辨识': 1,
#   '度': 1,
#   '厚重': 1,
#   '真的': 1}}

# %%
x_vecs = []
x_test_vecs = []  
ind = 0
word2ind = {}
pretrained = []
senti_sen = []
senti_test_sen = []
for i in range(len(test_content) + len(content)):
    if i < len(content):
        temp = []
        t_s = []
        for j in range(len(sentences[i])):
            if sentences[i][j] not in word2ind:
                pretrained.append(model[sentences[i][j]])
                word2ind[sentences[i][j]] = ind
                ind += 1
            t_s.append(sentences[i][j])
            temp.append(model[sentences[i][j]])
        while len(temp) < 50:
            temp.append([0.0] * 100)
        if len(temp) > 50:
            temp = temp[:50]
        x_vecs.append(temp)
        senti_sen.append(t_s[:50])
    else:
        temp = []
        t_s = []
        for j in range(len(sentences[i])):
            if sentences[i][j] not in word2ind:
                pretrained.append(model[sentences[i][j]])
                word2ind[sentences[i][j]] = ind
                ind += 1
            t_s.append(sentences[i][j])
            temp.append(model[sentences[i][j]])
        while len(temp) < 50:
            temp.append([0.0] * 100)
        if len(temp) > 50:
            temp = temp[:50]
        x_test_vecs.append(temp)
        senti_test_sen.append(t_s[:50])     
x_vecs = np.array(x_vecs)
x_test_vecs = np.array(x_test_vecs)
print(x_vecs.shape, x_test_vecs.shape)
# Out:
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:18: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:30: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# (8290, 50, 100) (2364, 50, 100)

# %%
x_sent_vecs = {}
x_test_sent_vecs = {}
for key in senti_word_set:
    x_sent_vecs[key] = []
    x_test_sent_vecs[key] = []
    for i in range(len(content) + len(test_content)):
        if i < len(content):
            t_sent = []
            for j in range(len(sentences[i])):
                if sentences[i][j] in senti_word_set[key]:
                    t_sent.append(senti_word_set[key][sentences[i][j]])
                else:
                    t_sent.append(0) 
            while len(t_sent) < 50:
                t_sent.append(0)
            if len(t_sent) > 50:
                t_sent = t_sent[:50]
            x_sent_vecs[key].append(t_sent)
        else:
            t_sent = []
            for j in range(len(sentences[i])):
                if sentences[i][j] in senti_word_set[key]:
                    t_sent.append(senti_word_set[key][sentences[i][j]])
                else:
                    t_sent.append(0) 
            while len(t_sent) < 50:
                t_sent.append(0)
            if len(t_sent) > 50:
                t_sent = t_sent[:50]
            x_test_sent_vecs[key].append(t_sent)

# %%
#va, content_vecs, y
pretrained.append([0.0] * 100)
word2ind['null'] = 17387
ind2word = {}
for key in word2ind:
    ind2word[word2ind[key]] = key
map_ = ['-1', '0', '1', '2']
sub_set = {}
for i in range(len(subs)):
    subjs = subs[i].split(',')
    sentis = sentiments[i].split(',')
    for j in range(len(subjs)):
        if subjs[j] not in sub_set:
            sub_set[subjs[j]] = []
        if sentis[j] == '2':
            sub_set[subjs[j]].append(0)
        else:
            sub_set[subjs[j]].append(1)
        #sub_set[subjs[j]].append(map_.index(sentis[j]))

# %%
pretrained = np.array(pretrained)
han_x = []
for i in range(len(senti_sen)):
    temp = []
    for j in range(len(senti_sen[i])):
        temp.append(word2ind[senti_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x.append(temp)
han_x = np.array(han_x)

han_x_test = []
for i in range(len(senti_test_sen)):
    temp = []
    for j in range(len(senti_test_sen[i])):
        temp.append(word2ind[senti_test_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x_test.append(temp)
han_x = np.array(han_x)
han_x_test = np.array(han_x_test)

# %%
'''
class Net(nn.Module):
    def __init__(self, pretrained, vocab_size):
        super(Net, self).__init__()
        self.bilstm = nn.LSTM(input_size = 100, hidden_size = 100, bidirectional = True) 
        #self.fc1   = nn.Linear(3750, 50) 
        #self.fc2   = nn.Linear(200, 50)
        #self.fc3   = nn.Linear(200, 50)
        #self.fc4   = nn.Linear(100, 3)
        self.fctest   = nn.Linear(200, 3)
        self.embeddings = nn.Embedding(vocab_size, 100)
        pretrained_weight = np.array(pretrained)
        self.embeddings.weight.data.copy_(torch.from_numpy(pretrained_weight))
        
    def forward(self, x, aspects): 
        x = self.embeddings(x)#batch,50,100
        #va = self.embeddings(aspects[0])
        #t_va = va.unsqueeze(0).expand(x.shape[0], x.shape[1], 100)
        output, (hn, cn) =  self.bilstm(x.float())#batch,50,200
        H, hN = output, output[:,-1,:]
        #con = torch.cat((t_va, H), 2)
        #t1 = F.max_pool2d(F.relu(con), (1, 4))
        #con = t1.view(x.size()[0], -1)
        #con = F.relu(self.fc1(con))
        #alpha = con.unsqueeze(1)
        #rr = torch.matmul(alpha,H).squeeze(1)
        #yy = torch.cat((F.relu(self.fc2(rr)), F.relu(self.fc3(hN))), 1)
        #x = self.fc4(yy)
        x  = self.fctest(hN)
        return x
    

net = Net(pretrained, len(pretrained))
print(net)
from torch import optim
criterion = nn.CrossEntropyLoss() # 交叉熵损失函数
optimizer = optim.SGD(net.parameters(), lr=0.005, momentum=0.9)
'''
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self, pretrained, vocab_size):
        super(Net, self).__init__()
        #self.rnn1 = nn.RNN(100, 100) 
        self.bilstm = nn.LSTM(input_size = 100, hidden_size = 100, bidirectional = True)
        #self.fc1   = nn.Linear(1250, 120) 
        self.fch = nn.Linear(200, 100)
        self.fcv = nn.Linear(200, 100)
        self.fcw = nn.Linear(200, 1)
        self.fcwp = nn.Linear(200,50)
        self.fcwh = nn.Linear(200,50)
        self.fcwsen = nn.Linear(200, 50)
        self.fc1   = nn.Linear(3750, 120) 
        self.fc2   = nn.Linear(120, 50)
        self.fc3   = nn.Linear(50, 2)
        self.embeddings = nn.Embedding(vocab_size, 100)
        pretrained_weight = np.array(pretrained)
        self.embeddings.weight.data.copy_(torch.from_numpy(pretrained_weight))
        
    def forward(self, mode, x, x_sent, aspects): 
        x = self.embeddings(x) #[4,50,100]
        bn = nn.BatchNorm1d(50)
        x = bn(x)
        batch_size = x.shape[0]
        N = x.shape[1]
        output, (hn, cn) =  self.bilstm(x.float())  #[4,50,200]
        hN = output[:,-1,:]
        va = self.embeddings(aspects[0]) #[1, 100]
        t_va = torch.matmul(torch.ones((x.shape[0],50, 1)), va)#[4, 50, 100]
        x_sent = x_sent.float()
        #[4, 50] *? = [4, 50, 100]
        sent_va = torch.mul(torch.matmul(x_sent.reshape((x.shape[0], 50, 1)), torch.ones((x.shape[0],1, 100))), t_va)  #[4, 50, 100]
        t_va = torch.cat((sent_va, t_va),  2)
        t_va = t_va.reshape((-1, 200)) #[4*50, 100]
        x = output.reshape((-1, 200)) #[4*50, 200]
        x = torch.tanh(torch.cat((self.fch(x), self.fcv(t_va)), 1))
        M = x.reshape((batch_size, N, -1)) #[4, 50, 200]
        alpha = F.softmax(self.fcw(M)).reshape((batch_size, 1, -1))#[4,50]
        rr = torch.matmul(alpha, output).reshape((batch_size, -1)) #[4, 200]
        x_sent = x_sent.reshape((batch_size, 1, -1))
        ss = torch.matmul(x_sent.float(), output).reshape((batch_size, -1))
        final = torch.tanh(self.fcwh(hN) + self.fcwp(rr) + self.fcwsen(ss))
        x = self.fc3(final)   
        return x, alpha
net = Net(pretrained, len(pretrained))    
from torch import optim
criterion = nn.CrossEntropyLoss() # 交叉熵损失函数
optimizer = optim.Adagrad(net.parameters(), lr=0.01)#, momentum=0.9)

# %%
import torch.nn as nn
import torch.nn.functional as F
result_set1 = {}
for key in sub_set:
    print(key)
    res = []
    with torch.no_grad():
        correct, total = 0, 0
        testset = [(han_x_test[i],np.array(x_test_sent_vecs[key][i])) for i in range(len(han_x_test))]
        testloader = torch.utils.data.DataLoader(
                            testset, 
                            batch_size=4,
                            shuffle=False, 
                            num_workers=2)
        for data in testloader:
            # 梯度清零
            optimizer.zero_grad()
            # forward + backward 
            (inputs, sentis) = data
            va = [[word2ind[key]]]
            va = torch.from_numpy(np.array(va))
            net = torch.load('./../../2-mlclasstrain/net' + key + '.pkl')
            outputs,alpha = net('test', inputs, sentis, va)
            _, predicted = torch.max(outputs, 1)
            res = res + [int(predicted[i]) for i in range(len(predicted))]
    real_text = []
    for i in range(len(han_x_test)):
        temp = []
        for j in range(len(han_x_test[i])):
            temp.append(ind2word[han_x_test[i][j]])
        real_text.append(''.join(temp))
    for zz in range(len(res)):
        if res[zz] == 0:
            set_ = ['外观']
            for k in set_:
                if k in real_text[zz]:
                    res[zz] = 1
                    break
    result_set1[key] = res
# Out:
# 价格
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:80: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 配置
# 操控
# 舒适性
# 油耗
# 动力
# 内饰
# 安全性
# 空间
# 外观

# %%
len(result_set1['价格'])
# Out:
# 2364

# %%
test_data = pd.read_csv('../../../../data/df_sen_sub/test_public.csv')

# %%
result_set = {}
for key in result_set1:
    result_set[key] = []
    for i in range(len(test_data)):
        if result_set1[key][i] == 1:
            result_set[key].append(str(test_data.loc[i, 'content_id']))

# %%
result = pd.read_csv('../copy_final_result++.csv')
see = pd.read_csv('../copy_see_final_result++.csv')

# %%
new_result = {}
content_ids = []
subjects = []
sentiment_values = []
sentiment_words = []

# %%
last = None
count = 0
for i in range(len(result)):
    sub = str(result.loc[i, 'subject'])
    if str(result.loc[i, 'content_id']) in result_set[sub]:
        content_ids.append(result.loc[i, 'content_id'])
        subjects.append(result.loc[i, 'subject'])
        sentiment_values.append(result.loc[i, 'sentiment_value'])
        sentiment_words.append("")
    if last != None and last not in set(content_ids):
        count += 1
        print(see.loc[i - 1])
        content_ids.append(last)
        subjects.append('动力')
        sentiment_values.append(0)
        sentiment_words.append("")        
    last = str(result.loc[i, 'content_id'])
if last != None and last not in set(content_ids):
    content_ids.append(last)
    subjects.append('动力')
    sentiment_values.append(0)
    sentiment_words.append("")    
print(count)
# Out:
# content_id                        pwd8MnrthDqLZafe
# subject                                         价格
# sentiment_value                                  0
# sentiment_word                                 NaN
# content            如果实在想买就等车展期间，优惠2万，我24.98万入的2.5豪
# Name: 4, dtype: object
# content_id         U5RMQtopwFzDVxHm
# subject                          价格
# sentiment_value                   0
# sentiment_word                  NaN
# content                27.5 相比较优惠的少
# Name: 6, dtype: object
# content_id                 icMQmPJA9Sv0KGTw
# subject                                 舒适性
# sentiment_value                           0
# sentiment_word                          NaN
# content            传感器是在轮毂里面的，连着气门嘴的，跟轮胎没关系
# Name: 15, dtype: object
# content_id                                          VQkjM1657sIroCf3
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            60肯定是不行的。 原车轮胎的直径=215*0.65*2 15*25.4（一英寸=25.4毫...
# Name: 16, dtype: object
# content_id         1rGSYnOx9Fb2ULQX
# subject                          配置
# sentiment_value                   0
# sentiment_word                  NaN
# content             那你们换的什么中控呀？
# Name: 17, dtype: object
# content_id         SgNFp8ixQX1HA64y
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content               都这样，提高油号有所减轻。
# Name: 18, dtype: object
# content_id         sO6Ac1mThYBKyl4M
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content             你的真费油，我在北京开才9.2
# Name: 19, dtype: object
# content_id                     Er3x8Ks6mpQqeZO0
# subject                                      油耗
# sentiment_value                               0
# sentiment_word                              NaN
# content            根据实际经验和车友反映，60-80速度区间相对比较省油。
# Name: 25, dtype: object
# content_id                                          f5UhrHg6Zztl7VWj
# subject                                                          舒适性
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            换轮胎应当根据个人用车情况选择，里程少的应偏重舒适性，里程多的偏重轮胎的耐磨指标。舒适性好的...
# Name: 26, dtype: object
# content_id                  E9SZbnzR2XW0QiLs
# subject                                   动力
# sentiment_value                            0
# sentiment_word                           NaN
# content            真皮座椅真的不用加套。我的用了5年了，还是很好的。
# Name: 33, dtype: object
# content_id             DXhAOZEsTBVWaSRH
# subject                              动力
# sentiment_value                       0
# sentiment_word                      NaN
# content            换汤不换药，没感觉。安全设备肯定会阉割的
# Name: 34, dtype: object
# content_id                                          6p8glZ2iewsInqK4
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            毫无根据的说法，森林人哪溥如纸的铁皮我也是醉了，虽然说铁皮厚和安全不划等号，但森林人哪个也太...
# Name: 35, dtype: object
# content_id                          bVeAzdpgX7tFDlPI
# subject                                           动力
# sentiment_value                                    0
# sentiment_word                                   NaN
# content            途观l的100至0刹车确实好，真扎实，比森林人强挺多。其它更喜欢森
# Name: 38, dtype: object
# content_id                  lQ0N8fd4On7TzcsD
# subject                                   动力
# sentiment_value                            0
# sentiment_word                           NaN
# content            刹车油不贵 一年半就可以换了 我习惯提前点周期换油
# Name: 39, dtype: object
# content_id           23EJ8RwY9PcotslQ
# subject                            动力
# sentiment_value                     0
# sentiment_word                    NaN
# content            2.0 13款 7万开始烧机油
# Name: 52, dtype: object
# content_id                                    n2Fm18vbEDIa53ys
# subject                                                     动力
# sentiment_value                                              0
# sentiment_word                                             NaN
# content            CVT变速箱怎么配手动呀？实在要，有拨片给你玩的。至于质量问题，说不请的，看人品了……
# Name: 61, dtype: object
# content_id                                   Mq4oVg68SWFBz9i5
# subject                                                    动力
# sentiment_value                                             0
# sentiment_word                                            NaN
# content            不用热车，刚开始别急加速就行。不要超过1500转？那就还原地热车吧，别去马路当路障。
# Name: 62, dtype: object
# content_id              7hHUfbrVKp1aAFmN
# subject                               动力
# sentiment_value                        0
# sentiment_word                       NaN
# content            额 20的森就是没故障码也是加速无力。。。
# Name: 63, dtype: object
# content_id                                          qvD82LNTpMdsAXIe
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            有一定速度后再踩到2000转是很平稳很舒服，我是等红灯起步的时候，从静止开始脚一重就瞬间两千...
# Name: 64, dtype: object
# content_id                                          KaM0rQpCE7yLYgH2
# subject                                                           空间
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            后备箱异响可能是折页也有可能是门扇和车体密封胶条间摩擦挤压，我之前是费很大劲找，甚至调了锁扣...
# Name: 66, dtype: object
# content_id                           g1qaKmR09LUXcp8B
# subject                                            外观
# sentiment_value                                     1
# sentiment_word                                    NaN
# content            个人喜欢银色，耐看，典雅。颜色还是要坚持第一印象吧楼主，跟着感觉走。
# Name: 67, dtype: object
# content_id                OKVCfRJ8X9BwxaTv
# subject                                 动力
# sentiment_value                          0
# sentiment_word                         NaN
# content            同意，机械手刹看着不高大上，但是就是好用
# Name: 68, dtype: object
# content_id                            tcPLeKdDrkYG1394
# subject                                             价格
# sentiment_value                                      0
# sentiment_word                                     NaN
# content            欧蓝德超值，森林人基本没啥性价比，买森的基本就是喜欢你就不考虑性价比。
# Name: 69, dtype: object
# content_id                    siYq5vrJBQzkuZPy
# subject                                     外观
# sentiment_value                              0
# sentiment_word                             NaN
# content            车身结构强度较差异响此起彼伏，当它不存在吧。迟早还会响
# Name: 70, dtype: object
# content_id         aLs9AwhZ85vgiRbx
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content                 防爆胎又硬又重，好用吗
# Name: 71, dtype: object
# content_id         UneE7iqV6mW5HlgP
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content              长途7个 市区8~9个
# Name: 72, dtype: object
# content_id         8P6E32xNmKAebnOs
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content            比我低，我跑市区在11.6左右。
# Name: 73, dtype: object
# content_id                          j2vcEXIrmkH9qs1J
# subject                                           动力
# sentiment_value                                    0
# sentiment_word                                   NaN
# content            那要是还想有一点越野能力呢？虽然森林人能玩的也是轻度越野。
# Name: 74, dtype: object
# content_id         CshiU6A13rR9dbPS
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content               日系车漆薄 这都是老问题了
# Name: 75, dtype: object
# content_id                            6JZHOqne2YW01FVz
# subject                                             动力
# sentiment_value                                      0
# sentiment_word                                     NaN
# content            我也13，也有很多小裂纹~老化了，目前跑了67000~准备再跑一万就换
# Name: 76, dtype: object
# content_id         kFo7T8n6wXICfc3d
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content            原厂轮毂能上235的胎吗？
# Name: 77, dtype: object
# content_id                     4nAlYpJof87Nj1F3
# subject                                      动力
# sentiment_value                               0
# sentiment_word                              NaN
# content            我换的是米其林揽途235/50/18，1000一条
# Name: 78, dtype: object
# content_id         RF9YTAlbQU5CagdN
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content              运动款前脸更好看！个人认为!
# Name: 80, dtype: object
# content_id             DYhuU8SPpywX2eN9
# subject                              动力
# sentiment_value                       0
# sentiment_word                      NaN
# content            高速8.8左右，城市9.2，用的雪地胎。
# Name: 81, dtype: object
# content_id         hcWAJdmC9avz7MU1
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content             稳定 可靠 还能玩漂移
# Name: 83, dtype: object
# content_id                         9Jt0O5d3s6wz1lkf
# subject                                          动力
# sentiment_value                                   0
# sentiment_word                                  NaN
# content            腰不好还是别开车了，森林人坐着不舒服，这个级别就没有适合你的车了
# Name: 84, dtype: object
# content_id                                          06vPIQBqVNe2dl3f
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            途观加95油耗比小森高点，保养差不多，后期维修比小森便宜点，没事故基本问题都不大，小森是全时...
# Name: 87, dtype: object
# content_id                                          ARIng69ZHsY7DCN1
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            下雪真心没用，就是好起步，不费力，转向该滑的滑。好处行车中稳定，但是真的不能开太快。该刹不住...
# Name: 90, dtype: object
# content_id                                          y3Oa1dcwCjlBsRPM
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            老款2.5 接近过210 还发过帖子： http://club.autohome.com.c...
# Name: 94, dtype: object
# content_id            6ALsOa4BdUbFfGr7
# subject                             动力
# sentiment_value                      0
# sentiment_word                     NaN
# content            这种速度也就郊区，高速不得笑死
# Name: 95, dtype: object
# content_id                                          MSn1hW8XCsGTkpxY
# subject                                                           配置
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            不是这个理解。原厂嗽叭是简单电容分频两分频音响系统，下面的是中低音嗽叭，仪表盘上的是高音嗽叭...
# Name: 101, dtype: object
# content_id         AC9siSxTEzyKrlaZ
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content              我也是一样的，这车异响太多了
# Name: 102, dtype: object
# content_id                                          14dQnL9lxMYeksH3
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            CRV？   新CRV配置高哦！楼主可以选择，我只关注了两天，剎不住啊剎不住，新车出来刹车有...
# Name: 112, dtype: object
# content_id                      HAVTYESJNfjlZ9iM
# subject                                       价格
# sentiment_value                                0
# sentiment_word                               NaN
# content            庞大再不降价八万，斯巴鲁在国内连一万量也卖不出去了
# Name: 117, dtype: object
# content_id                               o9iwO8ChDBUTJ7YI
# subject                                                内饰
# sentiment_value                                         0
# sentiment_word                                        NaN
# content            斯巴鲁报这么多问题出来 一下用劣质材料 一下用劣质质检员 才买一年可以退货不
# Name: 130, dtype: object
# content_id                                          xDOnv0fUogsFlkuC
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            说实话森林人确实好开！但是漆面外饰件装配、內饰装配这些细节如果能更好一点就完美了，毕竟30万...
# Name: 145, dtype: object
# content_id                                          nhAC4mEYRazX9dJL
# subject                                                           内饰
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            我当年也纠结过这个问题，论坛的老司机们跟我说买森林人的不会买CRV，反过来也一样。两个车我都...
# Name: 148, dtype: object
# content_id                                          Mj9ZO61VWTefml7z
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            我的也是12款2.0自豪，才跑了四万多公里，一胎扎了钉子频频慢撒气，一胎侧壁被破山石划伤，但...
# Name: 149, dtype: object
# content_id                cdV1254iqHpAawt7
# subject                                 动力
# sentiment_value                          0
# sentiment_word                         NaN
# content            你说的硬币声是不是加速时才有，像有东西在排气管
# Name: 150, dtype: object
# content_id                                          dRtVLIX4F60YvMbG
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            好像降到一个转速点就不响了 不需要到降到1500转好像 温度高 冷车启动高转速时间就没那么长...
# Name: 151, dtype: object
# content_id           s3U4wYnirNfeQ7o0
# subject                            动力
# sentiment_value                     0
# sentiment_word                    NaN
# content            这个还要结合，你的两次平均速度再分析
# Name: 153, dtype: object
# content_id                   j5dIzG0CvbFxlQgf
# subject                                    动力
# sentiment_value                             0
# sentiment_word                            NaN
# content            看得出换新轮胎好车很稳还是叫的很响亮，值得我们入手。
# Name: 156, dtype: object
# content_id                                          JlWDb4BCsTiN2Ie3
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            解释的不错，童年车，比你多开一万。我的加速硬币声只有在上坡且速度较慢时才有。机油灯6万只亮过...
# Name: 162, dtype: object
# content_id                                          1WCAISQtuEdTZ7G5
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            直接去4S店，让师傅涂点润滑油就好了，如果还是有异响，就让他们给你换一个。我之前就是这样的情...
# Name: 171, dtype: object
# content_id          KH853hdTJX2nWM71
# subject                           油耗
# sentiment_value                    0
# sentiment_word                   NaN
# content            因为混动是趋势，省油环保。
# Name: 172, dtype: object
# content_id                                          QqmEuP4l6sMTXASx
# subject                                                           油耗
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            开始加95，后来加92，感觉还省油了。跑高速在2000转到3000转没有特别大差异，再高没仔...
# Name: 181, dtype: object
# content_id              qtW1wiyejr4zF3Hu
# subject                               动力
# sentiment_value                        0
# sentiment_word                       NaN
# content            反正机油消耗写在说明书里面 纠结就不要买了
# Name: 183, dtype: object
# content_id                              j5dpvDJ80YWPSew3
# subject                                              安全性
# sentiment_value                                        0
# sentiment_word                                       NaN
# content            呃……我好久研究一下 ，之前也感觉是缺油，但刹车片和盘子不可能涩
# Name: 187, dtype: object
# content_id               8oeBjF7TwlPyLvcY
# subject                                动力
# sentiment_value                         0
# sentiment_word                        NaN
# content            总之除了森林人，其他车都比森林人舒适
# Name: 202, dtype: object
# content_id                                       sdAoJBha65SUxfWM
# subject                                                        动力
# sentiment_value                                                 0
# sentiment_word                                                NaN
# content            不过，我们的路况是在太差，在平整的柏油路一点异响也没有，可是在全部路况中占比实在太少
# Name: 208, dtype: object
# content_id                            uPCDeFYmpcfRz1tQ
# subject                                             动力
# sentiment_value                                      0
# sentiment_word                                     NaN
# content            左右也改了？是单纯的转向闪还是可以雷达监视左右后侧的盲区车辆？
# Name: 218, dtype: object
# content_id                                    6x4Is30vB1laSHoN
# subject                                                     动力
# sentiment_value                                              0
# sentiment_word                                             NaN
# content            人家买大众奥迪宝马保时捷的人可没这个顾虑 我老妹的烧机油途观她依然爱不释手啊。
# Name: 223, dtype: object
# content_id                                          ZAx5w2LSbkGdRMFQ
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            接线很容易，有原车插口，只是倒车影像哪里需要破点线，也不难。就是安装机头调位置有点难度，我试...
# Name: 224, dtype: object
# content_id          Z1kNWAOM9rYol0Ve
# subject                          舒适性
# sentiment_value                    0
# sentiment_word                   NaN
# content            SUV后排舒适性肯定没轿车商务车好
# Name: 225, dtype: object
# content_id                                          7duqegOxLs2Vo8XW
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            想后排舒适就顶配奇骏吧，我就2.0后程超车费劲，那些说2.0也能跑180的滚粗，我也跑过18...
# Name: 228, dtype: object
# content_id                           HWDQF5VOam2NR6rX
# subject                                            动力
# sentiment_value                                     0
# sentiment_word                                    NaN
# content            我也有这种感觉，不及拉力蓝深，但比以前的石英珠光蓝要好看一些
# Name: 238, dtype: object
# content_id                                          6oPvUG1VLyzSKxOM
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            q5只坐过没开过，但比较下来Q5除了牌子响亮，好多还真比不上森林人。空间比森林人小，后排中间...
# Name: 245, dtype: object
# content_id                                          YUG1zybnqjSDmZkJ
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            crv全世界销量都很好，满足了，空间大，故障率低、维护成本低、最新一代四驱系统有加强，（但雨...
# Name: 246, dtype: object
# content_id                                          USrqtIMjsYzeRi4W
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            群里朋友自己回来换导航，换音响，微视车说起欧蓝德和森林人比，欧兰德回去也不用换这换那吧，现在...
# Name: 247, dtype: object
# content_id                                          fwr9qOUYsxJK0ACm
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            群里朋友自己回来换导航，换音响，微视车说起欧蓝德和森林人比，欧兰德回去也不用换这换那吧，现在...
# Name: 248, dtype: object
# content_id                                          Ht7R0SnZMEV1eD6Q
# subject                                                           配置
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            选中2.0而没有买其他配置的原因很多，回过头来，即使今天让我重新选择，我还是会选这个配置，觉...
# Name: 249, dtype: object
# content_id                          5uj6bGWhXVE2aceA
# subject                                           配置
# sentiment_value                                    0
# sentiment_word                                   NaN
# content            途观l配置是硬伤，智享不智能，1.8的连天窗都没有，搞笑了
# Name: 250, dtype: object
# content_id                                          CmpW4Xv207JquMt1
# subject                                                           内饰
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            楼主好！我也订了和你一样的特装版颜色内饰相同。怎么合同上写2016款2.5特装，而不是201...
# Name: 262, dtype: object
# content_id                                          yNG3vwVFWsjkRIMg
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            常用S模式对车有什么损害吗？这应该是动力问题吧，120后稍微一点上坡这速度都提不上来，车子都...
# Name: 285, dtype: object
# content_id                                      ZAPEkuB72jnC45lO
# subject                                                       动力
# sentiment_value                                                0
# sentiment_word                                               NaN
# content            动力有储备有必要，想拿出时可以拿出来。借用车友的话讲就是：如同家里的存款，要办事时拿出来。
# Name: 289, dtype: object
# content_id                        HkaSb1yPMxmniAOl
# subject                                         动力
# sentiment_value                                  0
# sentiment_word                                 NaN
# content            我的车跑了5万多公里了，换掉的4S店机油跑了4000多
# Name: 305, dtype: object
# content_id         C2izVwpOYvM9JjDt
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content               13款 195油门踩到底了
# Name: 308, dtype: object
# content_id           HEORumQAIFNMzDd5
# subject                            动力
# sentiment_value                     0
# sentiment_word                    NaN
# content            油太次了 至少95号喷油嘴洗一下试试
# Name: 310, dtype: object
# content_id                       7RWHqS9pfuaFsxM3
# subject                                        动力
# sentiment_value                                 0
# sentiment_word                                NaN
# content            看来2.0真不省什么油，我这刚保养完，95#10个多
# Name: 312, dtype: object
# content_id          co5nyPfVM90BZkDA
# subject                           动力
# sentiment_value                    0
# sentiment_word                   NaN
# content            不是，是发动机里面传出来的
# Name: 325, dtype: object
# content_id         flA3kPNCHaVpheZo
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content             我这感觉整个发动机都大
# Name: 330, dtype: object
# content_id         otQSEuPxej9lZnRI
# subject                         舒适性
# sentiment_value                   0
# sentiment_word                  NaN
# content              高速达到100噪音简直不能忍
# Name: 333, dtype: object
# content_id                         nO5xei9AWYfENbR4
# subject                                          动力
# sentiment_value                                   0
# sentiment_word                                  NaN
# content            高速上方向重，安全性高了很多。而且高速也不必经常打方向啊。
# Name: 334, dtype: object
# content_id              tPHVDaFl6JZX3QOT
# subject                               动力
# sentiment_value                        0
# sentiment_word                       NaN
# content            后排车顶棚上的安全带没有收好，卡扣打击顶棚
# Name: 337, dtype: object
# content_id                         l4GZ17PmtNV925Ti
# subject                                          动力
# sentiment_value                                   0
# sentiment_word                                  NaN
# content            固特异，用了两年了，没变形也没异味，京东搞活动最低时300都不到
# Name: 338, dtype: object
# content_id            bnJs8fFTetghcwOu
# subject                             动力
# sentiment_value                      0
# sentiment_word                     NaN
# content            后座几乎没有坐过人，没发现有质量问题。
# Name: 341, dtype: object
# content_id                                          khucIwyDv2Jir5LF
# subject                                                          安全性
# sentiment_value                                                   -1
# sentiment_word                                                   NaN
# content            这次召回的是高田气囊，针对的是2010-2012三年里销售的车，等着3年左右后召回下一批吧（...
# Name: 346, dtype: object
# content_id                                   3jSw0GWRJQ9BXoyt
# subject                                                    动力
# sentiment_value                                             0
# sentiment_word                                            NaN
# content            开了四年森林人，车就不坏，常用件都有，异响就是前风挡和门边，30以内的车没有比他好的
# Name: 347, dtype: object
# content_id                              0gTQCnKUoP9zv5mS
# subject                                               动力
# sentiment_value                                        0
# sentiment_word                                       NaN
# content            是的，可以在需要急加速的时候直接拨降档拨片手动降一档，试一次就知道多爽了。
# Name: 351, dtype: object
# content_id                                          cVlv8HZPjB6m4y75
# subject                                                           空间
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            听老婆的吧。老婆满意，生活才能和谐。两个观点供您参考：1.一分钱一分货2.空间多大是个大呢？...
# Name: 356, dtype: object
# content_id                                          4WOkTuMarEPw5fo7
# subject                                                           操控
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            你两个体验都是正确的，确实如此。车子开熟悉后，回正慢可以适应， 初段窜感觉也可以“消失”，反...
# Name: 357, dtype: object
# content_id                                          BtKIWmdH0Zlk6jNX
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            这个我之前就粗略的算算了一下，以国内四儿子的数量和所需更换气囊的车的数量来看，最快需要2年半...
# Name: 367, dtype: object
# content_id              oWMCgrBjRVFU0mKN
# subject                               空间
# sentiment_value                        0
# sentiment_word                       NaN
# content            cx_5后拍太挤了，空间不行啊……
# Name: 375, dtype: object
# content_id                      NvQXnEqaGgiZcRzh
# subject                                       油耗
# sentiment_value                                0
# sentiment_word                               NaN
# content            你牛啊，这个油耗真心低了，向你学习，传授一下经验哈
# Name: 380, dtype: object
# content_id               zQ9gsJmFyPX64YMA
# subject                                动力
# sentiment_value                         0
# sentiment_word                        NaN
# content            喔。那就行！ 2.5的动力怎么样啊？
# Name: 388, dtype: object
# content_id                   aR76ShpmzdBZiFt9
# subject                                    动力
# sentiment_value                             0
# sentiment_word                            NaN
# content            非常不错，真干净。我是车内干净，发动机仓很少打开过。
# Name: 391, dtype: object
# content_id                             XdaQmi2cAYqHENIx
# subject                                              油耗
# sentiment_value                                       0
# sentiment_word                                      NaN
# content            居然还有2.0的，油耗不低呀。哈哈。
# Name: 407, dtype: object
# content_id         zDwITtMRVu10sqey
# subject                          油耗
# sentiment_value                   0
# sentiment_word                  NaN
# content                有图有真相，看我的油耗：
# Name: 411, dtype: object
# content_id                      FolwpA0yfQLrZEiH
# subject                                       动力
# sentiment_value                                0
# sentiment_word                               NaN
# content            我也是下地库转弯然后过减速带加速了一下就亮灯了。很给力说明
# Name: 421, dtype: object
# content_id         FZmN0vrUKYuVsDtl
# subject                          油耗
# sentiment_value                   0
# sentiment_word                  NaN
# content                4AT吧？油耗高很正常啊
# Name: 445, dtype: object
# content_id                                          YzigLBmP9naDrOkd
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            rav42019款，合资车安全性有进口的森林人好吗？是全时四驱吗？也比不了森林人！我也在等明...
# Name: 457, dtype: object
# content_id                                          nmldu0FiyIZS9Tj3
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            其实，国内的车就那么些，安全方面还是斯巴鲁一直领先，宝马奔驰就是面子货，我看安全还是斯巴鲁吧...
# Name: 472, dtype: object
# content_id                 FXbmRq815WQnuSeO
# subject                                 舒适性
# sentiment_value                           0
# sentiment_word                          NaN
# content            换了中缸声音就不好听了。斯巴鲁好让人心烦
# Name: 503, dtype: object
# content_id                      JuzNxctnG7QbFKso
# subject                                       动力
# sentiment_value                                0
# sentiment_word                               NaN
# content            前三年 每年大约折价10%   还得赔上保险啥的  不合算
# Name: 505, dtype: object
# content_id                               9IGP8J5XtxWnjBlo
# subject                                                动力
# sentiment_value                                         0
# sentiment_word                                        NaN
# content            请问你换的固特异哪款 我也是18寸 我只要耐用性 舒不舒适完全无所谓
# Name: 507, dtype: object
# content_id         KYyblSApEOBWR0eL
# subject                          外观
# sentiment_value                   0
# sentiment_word                  NaN
# content               换这个避震，车身降低了吧？
# Name: 510, dtype: object
# content_id             bj6H0Og3DuUkYyim
# subject                              动力
# sentiment_value                       0
# sentiment_word                      NaN
# content            很苦恼，别的车就不这样，内循环闻不到味道
# Name: 512, dtype: object
# content_id               09hwsk7P5cvaVKXg
# subject                                动力
# sentiment_value                         0
# sentiment_word                        NaN
# content            同月同款，你的车开内循环能闻到车外的异味吗？
# Name: 513, dtype: object
# content_id                                 6yzHFPa2VT09plQj
# subject                                                  动力
# sentiment_value                                           0
# sentiment_word                                          NaN
# content            不需要深度越野 长马据说厚道点，还没有集中反映气味难闻且几年不散的问题
# Name: 525, dtype: object
# content_id                                          9v7qXWnwuIgKDBER
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            国内测加的是92号汽油，这车发动机应该是加95以上才发挥性能，国内经销商擅自降低标号为了降低...
# Name: 530, dtype: object
# content_id                                          MR0mcoHQrWXFqJAU
# subject                                                           价格
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            确实，2.0T落地都要36，37了，对这个价位的车来说，五万不是个小数目，36万说不定会咬牙...
# Name: 533, dtype: object
# content_id                               XVWc7EHDPM3BNhqi
# subject                                                动力
# sentiment_value                                         0
# sentiment_word                                        NaN
# content            打着车 然后下车围着车转一圈看看轮胎然后上车挂档怠速走3分钟 最好的热车办法
# Name: 538, dtype: object
# content_id             pXrRtj4S6EHLeuGJ
# subject                              动力
# sentiment_value                       0
# sentiment_word                      NaN
# content            麻烦问下，当时给你最低价是14整吗
# Name: 539, dtype: object
# content_id         9ldhWyQnDV3Bpr4J
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content             那就是车头、车尾高度不一致了。
# Name: 543, dtype: object
# content_id                               IdusAw5VFOpLztJ4
# subject                                                动力
# sentiment_value                                         0
# sentiment_word                                        NaN
# content            买这车不图面子……同价位的话除去BBA不谈，atsl、es、q50l都挺好的
# Name: 547, dtype: object
# content_id                                          EDjrVy06wW1QKsCn
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            82年的苦逼孩子。15年眼看着要破产了心一横脚一顿，换个新车吧，别钱没了新车也没得开了。于是...
# Name: 549, dtype: object
# content_id                                          qprZFwPWEnxV7mUQ
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            举升起来跑？跑起来不是4个轮子转的吗？为什么要挂空挡？好像不挂空挡你手转其中一个后轮胎，另一...
# Name: 554, dtype: object
# content_id         CYXkDtqioJyxbGHZ
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content                 我的车身体强健不需要装
# Name: 555, dtype: object
# content_id                                       gCVavlsY0mF25dzR
# subject                                                        价格
# sentiment_value                                                 0
# sentiment_word                                                NaN
# content            这个标注是原厂进口的原液，估计能比国内分装的好点，求个心理安慰，关键是活动时候价钱不贵
# Name: 559, dtype: object
# content_id                                          ZXJDu2QoKyFcantL
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            瞎不瞎也请注意用词礼貌，傲虎几次试驾，觉得坐姿矮了，森林人坐姿高一些。不太建议傲虎，30~4...
# Name: 562, dtype: object
# content_id                                          WmHgCXdOIslED5NQ
# subject                                                           价格
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            不过你这车型我还没有看。问一下，你这没加装前，车子带有自动折叠吗？是那种按按钮的。不是停车就...
# Name: 570, dtype: object
# content_id                                          2vSQnRuZdGO1MFUi
# subject                                                           价格
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            简单咨询了一下，好像可以修复，就是价格很贵，鲨鱼pi报价的1500！另外都说斯巴鲁的漆不容易...
# Name: 582, dtype: object
# content_id                                          Qykdt2N3oGAhrgOb
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            森林人，全系车不会让你失望！你只管选配置、颜色、样式，动力所有的款式都够用！但有一点，2.0...
# Name: 587, dtype: object
# content_id         DV9qcNmIg8O1vFHY
# subject                          价格
# sentiment_value                   0
# sentiment_word                  NaN
# content            同是杭州的，问价格、有无加热条？
# Name: 588, dtype: object
# content_id                             SNZAupTeyE8f3DOa
# subject                                              内饰
# sentiment_value                                       0
# sentiment_word                                      NaN
# content            看你的需求吧。看重机械性能还是森林人。要追求舒适静音跟内饰档次还是昂科威
# Name: 591, dtype: object
# content_id                                          aWVobSZ95j2gydMQ
# subject                                                           价格
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            喜欢哪个样子选哪个。能喜欢森林人的朋友应该不会喜欢昂科威……喜欢森林人的朋友也不会考虑性价比...
# Name: 592, dtype: object
# content_id         cXPlC8xS9NBoZmvI
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content            空调管结冰了，调高点温度就可以了
# Name: 593, dtype: object
# content_id                                        92GLtM6NPu0CQlbq
# subject                                                         价格
# sentiment_value                                                  0
# sentiment_word                                                 NaN
# content            耐心些，小火炖肉才入味。我对贵了1万3的鹰眼无感(当然指导价贵个3~5千可以考虑)。
# Name: 595, dtype: object
# content_id            t6nfBVjDOw9vxmqr
# subject                             动力
# sentiment_value                      0
# sentiment_word                     NaN
# content            爽了吧，爽了就得付出代价，越野都得付出
# Name: 606, dtype: object
# content_id                                       H6rOgMiWeovFyYQD
# subject                                                        动力
# sentiment_value                                                 0
# sentiment_word                                                NaN
# content            我的是16款的 前几天轮胎扎了 拆完 看见里面有传感器 不知道14款 有没有 你查查
# Name: 611, dtype: object
# content_id         M2CRIPTD9b5Gcmds
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content               后排上面有个拉绳，自由调节
# Name: 617, dtype: object
# content_id                          W67mPuqewJ9aMc5b
# subject                                           动力
# sentiment_value                                    0
# sentiment_word                                   NaN
# content            另外只要是轮胎，谈进口，除了百路驰，一切都是浮云，国产没那么不济，
# Name: 620, dtype: object
# content_id                                       h8s3jBtw1NgiF6DI
# subject                                                        动力
# sentiment_value                                                 0
# sentiment_word                                                NaN
# content            前几日，听朋友讲，森林人风噪挺大的。觉得有必要了解得更仔细一点。风噪大确实蛮烦心的。
# Name: 621, dtype: object
# content_id                                          nmVxt4Tyv9CJW7ag
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            冷却液也会有一定的损耗，质保期内可以去4S店免费添加，冷却液必须添加同品牌同颜色的，千万不能...
# Name: 622, dtype: object
# content_id             1aYrZnCMKBoX3s4E
# subject                              动力
# sentiment_value                       0
# sentiment_word                      NaN
# content            哪家店，有2.5现车吗？颜色全吗？
# Name: 623, dtype: object
# content_id         lMSvUoJmbs5aOAr4
# subject                          配置
# sentiment_value                   0
# sentiment_word                  NaN
# content               其实中控什么也没显示我觉着
# Name: 625, dtype: object
# content_id                                    8tWqrNif2d1vn3yc
# subject                                                     动力
# sentiment_value                                              0
# sentiment_word                                             NaN
# content            能换还是换吧，梁变形了即便再怎么矫正防撞能力也没以前好了，而且当二手车卖也容易被砍价。
# Name: 628, dtype: object
# content_id         LzMP3x6NiRIhn1J4
# subject                          配置
# sentiment_value                   0
# sentiment_word                  NaN
# content             这也是18款我最喜欢的一个配置
# Name: 637, dtype: object
# content_id                   UbCTsEBa7D4loFLf
# subject                                    动力
# sentiment_value                             0
# sentiment_word                            NaN
# content            自然吸气的，只要不是发动机调教的很过分的都可以加92
# Name: 642, dtype: object
# content_id                                          UuaVhwncR36Aoqkd
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            据说新款隔音效果和车身稳定性xv新平台提高不少，森林人应该也一样，等三月份看看吧！再做选择。...
# Name: 644, dtype: object
# content_id         oAMV9ZCFlh5IizHD
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content             牛，2.5的170以后加速无力
# Name: 649, dtype: object
# content_id                        cKxH2Pd8M3JQD7ja
# subject                                         动力
# sentiment_value                                  0
# sentiment_word                                 NaN
# content            除了老外的那种直线加速赛，一般来说，真的是只有肉人，没有肉车。
# Name: 650, dtype: object
# content_id                                          ypgtWM4Ks3ZR2BdN
# subject                                                           内饰
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            同事买过一辆哈弗忘了是h几，当时也说等手里小森开报废了就换个哈弗玩玩，但后来实际坐了下就发现...
# Name: 655, dtype: object
# content_id                                          RCEkxf7X04bpOIwa
# subject                                                           内饰
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            premium性价比挺高的，如果对真皮座椅没需求的话。新平台出来的车真不建议买前两年的，谁知...
# Name: 659, dtype: object
# content_id         4NjVBL3t7FWqgPJX
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content                 小森要起飞了，快加速~
# Name: 664, dtype: object
# content_id                                         zalAOVtiG1Upe8Jk
# subject                                                          动力
# sentiment_value                                                   0
# sentiment_word                                                  NaN
# content            哈哈哈，有点以前打出租老夏利似的，不过车子开的爽，这些问题我能忍，我后备箱也哒哒哒的响，无所谓了
# Name: 678, dtype: object
# content_id                                          jlJM5YCSrXygxOpD
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            我的水泵去年就换了，气囊更换真北路安吉4S店说要4天的工时才能提车，嫌时间太长一直也没去换。...
# Name: 687, dtype: object
# content_id         LdSU9FJKYkja2pwn
# subject                          内饰
# sentiment_value                   0
# sentiment_word                  NaN
# content             可以用，功放放在前排座椅下面。
# Name: 702, dtype: object
# content_id                               hTmRLDS3H610WEGJ
# subject                                                油耗
# sentiment_value                                         0
# sentiment_word                                        NaN
# content            动力不足吧。我感觉2.5的森跑40-80简直太省油了。高速巡航就力不从心了。
# Name: 704, dtype: object
# content_id             dEQ2H6yVaAh7P5j8
# subject                              动力
# sentiment_value                       0
# sentiment_word                      NaN
# content            车漆可以打蜡镀晶，塑料件，那就是给你划的
# Name: 714, dtype: object
# content_id         XKjTBw5OP89DQLvF
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content                他是说小森的安全性有保障
# Name: 719, dtype: object
# content_id             7ADnOoqHVgKSbLuR
# subject                             舒适性
# sentiment_value                       0
# sentiment_word                      NaN
# content            你欧蓝德空调还好用么？需要我找点资料么？
# Name: 730, dtype: object
# content_id                                          bEf1ZICFYTW97Lr6
# subject                                                           空间
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            二十万哪是说存就存的。需要大空间车是拉货家用都能用的。现在君威太小了拉不了货。不然也不用着急...
# Name: 741, dtype: object
# content_id                uziQ92KcdPaOLAjw
# subject                                 外观
# sentiment_value                          0
# sentiment_word                         NaN
# content            贴近其他车的车身，大不了，我开后备箱出来，哼哼
# Name: 750, dtype: object
# content_id                   sgIYzSvnFhjBVPmN
# subject                                    动力
# sentiment_value                             0
# sentiment_word                            NaN
# content            海蜡，在海上运输保护发动机舱不被腐蚀的，可以清洗掉。
# Name: 761, dtype: object
# content_id                              ilVBrAke3EZMUyPt
# subject                                               动力
# sentiment_value                                        0
# sentiment_word                                       NaN
# content            同平台理论上四驱肯定比两驱费油，但是带来的驾驶感受和安全性，还是值那点油钱
# Name: 764, dtype: object
# content_id                                          aU5RcOCxXFNZ3tvJ
# subject                                                           操控
# sentiment_value                                                    1
# sentiment_word                                                   NaN
# content            我也在纠结，上次开了一下朋友的汉兰达，隔音，避震确实比森林人好，可以车太大，晃晃悠悠太笨了，...
# Name: 776, dtype: object
# content_id                                    zlWsZHG3KjfiUSDb
# subject                                                     动力
# sentiment_value                                              0
# sentiment_word                                             NaN
# content            规范技术下，没啥问题。放心管，不是啥大事！6月初，我也去换。目前发动机回火儿声太大了！
# Name: 777, dtype: object
# content_id                                          lC9WBmsbinDwXrPe
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            装过一根祖国货前顶吧，街道使用偶尔激烈驾驶，没下过赛道。 并没觉得会提升日常驾驶的操控性，反...
# Name: 786, dtype: object
# content_id                          2UBZ7gjF0de9SRWc
# subject                                           价格
# sentiment_value                                    0
# sentiment_word                                   NaN
# content            这个不好说，特价车相对来说估计买的人要多点的，毕竟价格是一个优势的
# Name: 794, dtype: object
# content_id                                          EXSrYLdzcQvjyT74
# subject                                                           油耗
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            1、N档间隙性微抖动每辆车都有。2、前几箱油油耗较高(特别第一箱)，没多久就会降下来了。3、...
# Name: 807, dtype: object
# content_id                                          m9clDQRHJEe7BVjd
# subject                                                           油耗
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            我07款2.0森已23万公里了，跑遍中国，近期还去了西藏甘南，从来没有出过故障，正常在4s保...
# Name: 808, dtype: object
# content_id                                          SW2KCuFyexEhYBVN
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            你好，这个汽车机油的使用一般情况下建议根据发动机上的要求使用最好，嘉实多，壳牌，美孚用的比较...
# Name: 821, dtype: object
# content_id                                          8pJX65eRkD7rd9cW
# subject                                                           动力
# sentiment_value                                                    0
# ...
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            2.5i 的，说明书建议4.8升，并提示下限到上限差额是1升。实际加到上限约5.2升，但是为...
# Name: 2386, dtype: object
# content_id                                          YbZsXMk3PvaVQnLK
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            我也同意。自由光就是样子。唉 空间森林人好一点，看楼主喜欢啥了吧。我刚买森林人，我也纠结过市...
# Name: 2391, dtype: object
# content_id         Ijf1P4FEWUprbgZl
# subject                          空间
# sentiment_value                   0
# sentiment_word                  NaN
# content             现在考虑傲虎了 ，想空间大点.
# Name: 2392, dtype: object
# content_id                      MR3lsLjIOEXeU2AD
# subject                                       动力
# sentiment_value                                0
# sentiment_word                               NaN
# content            罗锅上山坡----前（钱）紧，就买了低配2.5的了。
# Name: 2394, dtype: object
# content_id             0jTdQIPg6ZaLp57O
# subject                              动力
# sentiment_value                       0
# sentiment_word                      NaN
# content            只有我一个觉得尾灯像煮熟的螃蟹吗？???
# Name: 2396, dtype: object
# content_id          OQVWijN4lSh0FTey
# subject                          安全性
# sentiment_value                    0
# sentiment_word                   NaN
# content            用翼豹wrx的刹车可以过吗
# Name: 2398, dtype: object
# content_id                                          95yan1o6CpQ2A0Ew
# subject                                                          安全性
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            好东西！后摆臂换了吗！我才二万七，跟楼主比还差避震、轮毂、刹车（我感觉楼主的车应该动过了），...
# Name: 2402, dtype: object
# content_id                                          9gO4pMXdBi6xD0lW
# subject                                                          安全性
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            换了cusco可调式下摆臂，图中全是泥，看不出来。刹车还没动，ecu也不敢随便乱刷，怕出问题...
# Name: 2403, dtype: object
# content_id                          ZwYtW93KxgOFi8D2
# subject                                           价格
# sentiment_value                                    0
# sentiment_word                                   NaN
# content            好车，就是没有什么性价比，但我喜欢！两个人，2.5排量，经常跑这样
# Name: 2407, dtype: object
# content_id                  n7YxMp8c9Va2Nfse
# subject                                   配置
# sentiment_value                            0
# sentiment_word                           NaN
# content            轴承的问题和胎压没有按照厂家标准有关系吗？
# Name: 2409, dtype: object
# content_id         3AsFYcJ4OrW8wT7l
# subject                          配置
# sentiment_value                   0
# sentiment_word                  NaN
# content              我一年也开不了几次导航
# Name: 2411, dtype: object
# content_id           U3NevhxIRQaXnyLq
# subject                            配置
# sentiment_value                     0
# sentiment_word                    NaN
# content            导航我觉得太恶心了，其他目前感觉还好
# Name: 2413, dtype: object
# content_id                                          af8n9cRIS4Vq0jmH
# subject                                                           配置
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            我开沃尔沃，想再买辆小的SUV。XV大小合适，顶配ES安全配置和沃尔沃相当了，就是质感差点。...
# Name: 2417, dtype: object
# content_id                                          x9GXPl40AZ5TNiBh
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            电调座椅还有电。 我一直加92#。 偶尔92#排长队就加95#。 我活动范围内没看到98#的...
# Name: 2419, dtype: object
# content_id                       zs3gC6PE4kfNb9Wt
# subject                                        动力
# sentiment_value                                 0
# sentiment_word                                NaN
# content            之前看图，我还犹豫，看了实车，毫不犹豫的决定等SGP了
# Name: 2420, dtype: object
# content_id                                          aB6ythMmUQL4TneC
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            没啥纠结的肯定森林人，性能出众。耐用性什么的都要比Jeep强太多......特别是Eyesi...
# Name: 2432, dtype: object
# content_id                  U58QDMeHWXkfGESg
# subject                                   动力
# sentiment_value                            0
# sentiment_word                           NaN
# content            谁敢这么吹？它的四驱确实强大，不过很多细节有待提高
# Name: 2434, dtype: object
# content_id              xapJi6lVUC0oH9Py
# subject                               配置
# sentiment_value                        0
# sentiment_word                       NaN
# content            怎么得出双摄像头比单眼雷达硬件成本更低的？
# Name: 2435, dtype: object
# content_id         4cNTIxAwjOkSB8Vv
# subject                          内饰
# sentiment_value                   0
# sentiment_word                  NaN
# content                 搜??座椅！你查下看看
# Name: 2446, dtype: object
# content_id                           TiGkVHdRmPgMpb6s
# subject                                            动力
# sentiment_value                                     0
# sentiment_word                                    NaN
# content            不严重就不要搞了，发动机装配工厂是在冷库进行的，4S不具备条件和能力
# Name: 2447, dtype: object
# content_id                              yvEOU7I2Z9pbMtNz
# subject                                               动力
# sentiment_value                                        0
# sentiment_word                                       NaN
# content            就是ABS传感器，要是没问题就是后轮在变速箱后端有一个后轮轮速传感器有问题
# Name: 2452, dtype: object
# content_id                                          3GaSHdJUs4wDYfkR
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            发动机舱前面有两个可以旋转的黑色胶钉，专门顶引擎盖的！如果觉得引擎盖两边缝隙不平均或者松动，...
# Name: 2453, dtype: object
# content_id                                          WAFiDKqCfuP9xG7a
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            嗯嗯，不知道4s消除丢失钥匙的码需要多少钱，下次有机会去4s如果价格合理就消掉，先配一把钥匙...
# Name: 2454, dtype: object
# content_id                                          8qg3OP1AtB5Evz9a
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            雪地驾驶不能猛做动作，例如加减速、拐弯、变道都要轻柔，提前预判，小心前后左右的车辆。没事最好...
# Name: 2462, dtype: object
# content_id                                          5GPVFrmzW2pqw6xf
# subject                                                           操控
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            途观就一轿车底盘，3年后快散架天窗开启还吱吱响。还好卖的早，神车真心好出手，接盘侠多到数不清...
# Name: 2466, dtype: object
# content_id         cIn9fLxBgXV3451Y
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content             我还没搞完，想把它放进中控里面
# Name: 2468, dtype: object
# content_id           Fie0kyu1854nQpzA
# subject                            配置
# sentiment_value                     0
# sentiment_word                    NaN
# content            刚刚装好，就是中控下面那个取电口接的
# Name: 2475, dtype: object
# content_id                      6ru4D9eIzQ1iPkxv
# subject                                       配置
# sentiment_value                                0
# sentiment_word                               NaN
# content            朋友你的车a柱和中控台衔接的地方是松松的吗，用手指可以按动
# Name: 2483, dtype: object
# content_id         A4vmUYQOlCB5p0Mf
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content                2.0改双排会影响动力！
# Name: 2485, dtype: object
# content_id                          cADZp9bExndsOuWC
# subject                                           配置
# sentiment_value                                    0
# sentiment_word                                   NaN
# content            多余的那些配置如果你觉得对你来说值，那就就买新款。否则老款更实惠。
# Name: 2487, dtype: object
# content_id                          QjFJXPzDYsV1IRWO
# subject                                           动力
# sentiment_value                                    0
# sentiment_word                                   NaN
# content            北方一个小城市，离辽宁和内蒙比较近，冬天有雪，选择个全时四驱心安！
# Name: 2488, dtype: object
# content_id                7FzGhLUQufMglaAn
# subject                                 动力
# sentiment_value                          0
# sentiment_word                         NaN
# content            你是2.0的还是2.5的，两个动力感觉能差多少
# Name: 2505, dtype: object
# content_id         9hv6gmwl0XbRKArI
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content             森林人主打不是音乐是风噪，哈哈
# Name: 2510, dtype: object
# content_id           dkBrQ8FaUsD50qJ7
# subject                            价格
# sentiment_value                     0
# sentiment_word                    NaN
# content            价格贵 质量一般 保值率低 谨慎购买
# Name: 2516, dtype: object
# content_id                                          vDUH86p9mfyQP5cA
# subject                                                          安全性
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            我是陕西的，也是森林人，只要不超过70，没事，切忌猛打方向，踩刹车，要是搭防滑链，4条都搭肯...
# Name: 2524, dtype: object
# content_id         0m3DxdfAIcgnE4kM
# subject                          内饰
# sentiment_value                   0
# sentiment_word                  NaN
# content             汽车之家搜，挺多的，怎么调座椅
# Name: 2525, dtype: object
# content_id                                0euRkBO8AwisjYTJ
# subject                                                 动力
# sentiment_value                                          0
# sentiment_word                                         NaN
# content            我也再等等新平台的，看有没有后排出风口。。再没有，打算入手新款自由光了。。。。
# Name: 2527, dtype: object
# content_id                                          6sCNZQ0854b9k2ep
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            应该是，车高风噪大，开到180也是花了不少时间的。反而小的排量轿车更容易上180。反正这车治...
# Name: 2534, dtype: object
# content_id                                          7HjuWDZzSykeEOIQ
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            斯巴鲁通病，而且每次亮的原因都不一样，可能是三元催化器，可能是氧传感器，也可能是刹车片磨完了...
# Name: 2536, dtype: object
# content_id                           y7ziHVFaYs3vAS5C
# subject                                           安全性
# sentiment_value                                     0
# sentiment_word                                    NaN
# content            很多的是人和车的磨合，还有刹车片需要磨合。车？不过4000转就行了。
# Name: 2541, dtype: object
# content_id                              oKTmraqO2ltuZ6N0
# subject                                               动力
# sentiment_value                                        0
# sentiment_word                                       NaN
# content            网上有个视频评测森、欧、指，结论说2.4指强些，那个2.4发动机现在很出名
# Name: 2552, dtype: object
# content_id                                        pcK875yafZ0DvE9S
# subject                                                         内饰
# sentiment_value                                                  0
# sentiment_word                                                 NaN
# content            刚换了刹车油，自带材料，工时费80，也是专修店。收费确实跟维修点规模、维修技术水平有一定联系.
# Name: 2553, dtype: object
# content_id         6nb4X8DrhGIysL9R
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content                 八错！说实话中控有点丑
# Name: 2554, dtype: object
# content_id                                  nYqDJsS4CEVwAu8x
# subject                                                   动力
# sentiment_value                                            0
# sentiment_word                                           NaN
# content            老实说斯巴鲁不能越野，城市SUV都不能越野。不是大梁或者内嵌大梁，你车身会变形的。
# Name: 2555, dtype: object
# content_id                                          swWXCztEAlxLfkOI
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            着车30秒后开车走就可以，车子一动，转速就下降了；等水温灯不亮了，就可以加速跑。冬天还是建议...
# Name: 2558, dtype: object
# content_id         G5WVJdhNEr71HyBI
# subject                          动力
# sentiment_value                   0
# sentiment_word                  NaN
# content               大哥，发动机有靠谱的卖家吗
# Name: 2560, dtype: object
# content_id                                  ytm3xPrzZ4OuXIH1
# subject                                                   动力
# sentiment_value                                            0
# sentiment_word                                           NaN
# content            我以前是两台森一09，2．0跑了30W左右换的拆车机器，动力，质量非常好，去年卖了
# Name: 2561, dtype: object
# content_id         hY9A7rn2wlmEF0uo
# subject                          操控
# sentiment_value                   0
# sentiment_word                  NaN
# content            应该没事，底盘加轮胎能吧震动消化
# Name: 2563, dtype: object
# content_id               0EkBRAYPsfOTt4z3
# subject                                动力
# sentiment_value                         0
# sentiment_word                        NaN
# content            你试试Q5，X5X6，GLC的后排.....
# Name: 2569, dtype: object
# content_id                                          4N70AwcexTqDCoJr
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            朋友现在开的斯巴鲁哪款车，还是正准备入手？我是看了xv感觉哪都挺好的，可是总是觉得空间小了，...
# Name: 2580, dtype: object
# content_id                      Zl8IfcmpNrLVAPS4
# subject                                       动力
# sentiment_value                                0
# sentiment_word                               NaN
# content            你说的这些都不是事儿买斯巴鲁的人不会在乎，重要的是全时四驱
# Name: 2583, dtype: object
# content_id                                          5XznxhYNAGF7WKJD
# subject                                                           动力
# sentiment_value                                                    0
# sentiment_word                                                   NaN
# content            上车千万别开暖风，全部关闭，温度调到最低。走个6，7分钟蓝灯没了再开暖风，走走停停，D档刹车...
# Name: 2586, dtype: object
# content_id                 3qVmrKu1wxJb0X6I
# subject                                  动力
# sentiment_value                           0
# sentiment_word                          NaN
# content            估计楼主之前开过奔驰，所以觉得森林人刹车差点意思
# Name: 2589, dtype: object
# content_id                      trsL1COIpBSWXMex
# subject                                       外观
# sentiment_value                                0
# sentiment_word                               NaN
# content            总觉得棕色太商务，不过配银色车身倒是别有一番味道！恭喜??
# Name: 2591, dtype: object
# content_id                            VYJEH3N0ZkGt5Xvy
# subject                                             配置
# sentiment_value                                      0
# sentiment_word                                     NaN
# content            哈哈，终于看到有人开始厌烦前置雷达的声音了，这个亲，那个声音来自哪里？
# Name: 2618, dtype: object
# 556

# %%
len(set(content_ids))
# Out:
# 2364

# %%
new_result = {'content_id':content_ids, 'subject': subjects, 'sentiment_value': sentiment_values, 'sentiment_word': sentiment_words}

# %%
pd.DataFrame(new_result).to_csv('new_final_result.csv', index = False, encoding = 'utf-8')

# %%
pd.DataFrame(new_result)
# Out:
#             content_id subject  sentiment_value sentiment_word
# 0     XuPwKCnA2fqNh5vm      价格                0
# 1     2jNbDn85goX3IuPE      价格                0
# 2     hLgEADQ8sUnvGFK9      价格                0
# 3     nZmM7LQsfr03wUaz      价格                0
# 4     cudSKGTyMLbIt8k3      价格                0
# 5     pwd8MnrthDqLZafe      动力                0
# 6     Kh0ayJjuTrzwPAs1      价格                0
# 7     U5RMQtopwFzDVxHm      动力                0
# 8     YZovRtEAyQJgTi1I      价格                0
# 9     BeSIAUzoTWH9muYl      配置                0
# 10    SXYTBWg6FxuboMnd      配置                0
# 11    RDgTmzW9xBfY6pGv      配置                0
# 12    8cMwzsxkL4XtuDG1      配置                0
# 13    MOUrvjDsIJpbw6dQ      配置                0
# 14    t01PVoDSd9Lsy5HN      配置                0
# 15    icMQmPJA9Sv0KGTw      动力                0
# 16    VQkjM1657sIroCf3      动力                0
# 17    1rGSYnOx9Fb2ULQX      动力                0
# 18    SgNFp8ixQX1HA64y      动力                0
# 19    qIUiOxGdb0M4PQky      油耗                0
# 20    sO6Ac1mThYBKyl4M      动力                0
# 21    6GMYQa0Ag4o9nsZ2      油耗                0
# 22    6Ewe2kxO5msAg0yU      动力                0
# 23    PMeBcRxizIaNmAC7      油耗                0
# 24    9x4gvon6TfN0KtqY      油耗                0
# 25    Er3x8Ks6mpQqeZO0      动力                0
# 26    fYtbApDWqzGmKX8F     舒适性                0
# 27    f5UhrHg6Zztl7VWj      动力                0
# 28    YUWFxTOoZCkNzKcu     舒适性                0
# 29    hNVSLDr06cMsgwfI      内饰               -1
# ...                ...     ...              ...            ...
# 2486  PE5gLlduiYGTzqsn      动力                0
# 2487  trsL1COIpBSWXMex      动力                0
# 2488  WgtvsofC74wOIYVb      动力                0
# 2489  H8jYWQ5gMADxtmuh     舒适性                0
# 2490  ouMTnWL81gZemPi9     安全性               -1
# 2491  7pDJV8ab4NjH3r5e     舒适性                0
# 2492  hGPD9vBZgR6zNV4S      动力                0
# 2493  2jJXvw58LHgT3RBD      动力                0
# 2494  OCkifpF73WQYjoNI      内饰                0
# 2495  XrQJUSeIVhBib86Z      配置                0
# 2496  MF2yRZwkDtmozdPS      内饰                0
# 2497  Yu0EUZt54G8fiHOW      外观                0
# 2498  yLhg5NmjCWat4YFV      操控                0
# 2499  0GtHsUD3ikzZoX5q      油耗                0
# 2500  S3dNtUixLg2uVkWD      动力                0
# 2501  xJ1wWtb9TsYkKO5X     舒适性                0
# 2502  lr0sCcFamRVfPHn5      油耗                0
# 2503  H6y17JaXzxADtqer      操控                0
# 2504  DJES3mRatNG7AMwz      配置                0
# 2505  GdPUZvlCm438WtS5      油耗                0
# 2506  m1rOC6jMweNH2Q9J      价格                0
# 2507  vP56NeZdJA8jtXmF      配置                0
# 2508  fQnMrWegYBvTh2Ic      动力                0
# 2509  xSTt0OV9nYkb6NEa      动力                0
# 2510  BfWd1cJDFQLNn3gG     安全性                0
# 2511  IoKEnR3JdXu0gG4h      动力                0
# 2512  4p5xbNDUMLAwvzrY      动力                0
# 2513  VYJEH3N0ZkGt5Xvy      动力                0
# 2514  iSp7q8d4eW9honmI      动力                0
# 2515  WLHp3PYJ9FvOGXE2      动力                0
#
# [2516 rows x 4 columns]
