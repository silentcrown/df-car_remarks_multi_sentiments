# %%
import pandas as pd
import numpy as np
import torchvision as tv
import jieba
from gensim import models
from gensim.models import Word2Vec
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
import torch
show = ToPILImage() # 可以把Tensor转成Image，方便可视化
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../../../data/df_sen_sub/train.csv')
data
# Out:
#             content_id                                            content  \
# 0     vUXizsqexyZVRdFH           因为森林人即将换代，这套系统没必要装在一款即将换代的车型上，因为肯定会影响价格。
# 1     4QroPd9hNfnCHVt7      四驱价格貌似挺高的，高的可以看齐XC60了，看实车前脸有点违和感。不过大众的车应该不会差。
# 2     QmqJ2AvM5GplaRyz  斯柯达要说质量，似乎比大众要好一点，价格也低一些，用料完全一样。我听说过野帝，但没听说过你说...
# 3     KMT1gFJiU4NWrVDn           这玩意都是给有钱任性又不懂车的土豪用的，这价格换一次我妹夫EP020可以换三锅了
# 4     nVIlGd5yMmc37t1o                            17价格忒高，估计也就是14-15左右。
# 5     TVciHBPL5XmUxMEd  我开始就是荣放2.5  森林人2.5二选一    荣放主要是底盘质感不行   太硬  其次是...
# 6     4lb9TsO5rjqUy1Bu                   唉，这货的价格死硬死硬的，低配版优惠1万据说已经罕有了。
# 7     z98xV7MphZIF4EvO                      价格的话只能说一般般吧，太仓前段时间定的比你便宜！
# 8     hoWrMnGTUvdsK3Dm                                听过，价格太贵，但一直念念不忘
# 9     r1WHgbI0ZKqMdELy                                      恭喜恭喜，这个优惠不错哦！
# 10    JSQUo6kblXYvtc2h                                     优惠幅度不小了，北京优惠八千
# 11    7kCF590PjAYqzEL6                         优惠可以了！购进吧！买了不会后悔的！时间可鉴！
# 12    EXBiRczhIu3paJWb                                        现在 什么价 优惠多少
# 13    nQ0bIZtzj6P1Esgd                                 优惠一万一 送贴膜装甲脚垫 铁西庞大
# 14    JvXIqLT8cGDuPEWe                             我也大连的，最近也考虑入手森林人，优惠太小了
# 15    NXyGEbt0AZ5rHJ3e                                  山东威海全系这才优惠3000，MD
# 16    kN0LghcimajxWwH8                                    下手了，豪导特供，优惠1.6万
# 17    vVoKucJy5pO0jSk2                                 优惠了8000，什么都不送。
# 18    iBFJMqHtTRD5Qo6S                          兄弟2.5豪导特供优惠1.6万可以下手吗？
# 19    G8Yr51elsVaXFUZC                          恭喜，优惠多少，我准备明天去提，2.5特装优惠两万
# 20    10WF8Q53pVfOryvA  什么车款，多少优惠啊？康桥我只能谈到优惠1.5其他还送什么没问，试驾了一次看了两次2.0时尚...
# 21    VrRd1HcoMNAkvhJy                                   优惠1 ，就送行程记录
# 22    1BYpO9FsgkmWLNQu  平常心吧，我本来想买傲虎，优惠不大，钱不够，改提森林人，6月提尊贵优惠1.4w，到了9月做活...
# 23    9EFImNb0ywhHBlcR                                 哈哈，25.48。优惠够给力
# 24    2aNFSuYeZo7B1b9R  兄弟，我也云南的，你的优惠也挺大的，现在哪里来的全系3万啊。。。现傲虎全系无优惠，森林人才八...
# 25    4EK1Nu7X2DTzomRS                  来湖北，我上月订的2.0蓝色时尚，优惠1万3送6次保养，本月底提车
# 26    TWPEyNaI5mFgYupn                            什么都没有，就是现金优惠和给了点小东西
# 27    96A5VQfBgPWUYkul                什么都没有，就是现金优惠和给了点小东西，你最好先问问看有没有车
# 28    JXlEzBcKGpI8stdr                             原来最低也就优惠15000至16000
# 29    P5A3evWb9jUyHMB2                                   我们这里，优惠2000，我呵呵了
# ...                ...                                                ...
# 9917  NtDO9KM2TQJYp8rC                                  风噪大 音响差驾驶什么的，秒杀其他
# 9918  lsMktgZyBDUfbowu               安全大于一切，出远门前一定要检查车子，主要有全车油水，轮胎，刹车系统等。
# 9919  hwzJjbCV26pLscxk  发动机直接就不一样了 FA20是斯巴鲁的招牌发动机 给WRX用要是烧的厉害那帮暴力驾驶的估计...
# 9920  6FMslAfukBpR82Po                            看路况，省道多平均油耗8-9，市区多11-12
# 9921  7X9tyquOCj0aw2Ql  换挡不是根据速度，而是根据你的意图。你想省油并匀速驾驶，就在转速允许的情况档位越高越好。想要...
# 9922  7X9tyquOCj0aw2Ql  换挡不是根据速度，而是根据你的意图。你想省油并匀速驾驶，就在转速允许的情况档位越高越好。想要...
# 9923  QBGuT7YNWVDsXgb8                                  同款配置黑森还要下个月中旬才能提车
# 9924  goheSWvcEPp79Lm6                                        正常，我城里跑油耗11
# 9925  pdjz83AoiWvu1lbh  森林人做工一般，配置还不如8、9万的国产车，这是事实。在老家侄儿子的五菱宏光把我的森林人给甩...
# 9926  pdjz83AoiWvu1lbh  森林人做工一般，配置还不如8、9万的国产车，这是事实。在老家侄儿子的五菱宏光把我的森林人给甩...
# 9927  K9s7OTLiCMm1dvzH             导航已经换成凯立德了，其它的功能也很差，我只是用来听收音机，导航还是手机的好
# 9928  wpHCZYOSrmske3yW                   有没有换过导航啥的，一般新车很少电路故障，行车电脑问题几率大点！
# 9929  I5NyHgsnkWvj84di  感觉稍微有点高了，油耗高低和很多方面有关，比如你个人驾驶习惯，你行驶道路拥堵状况等等，平稳驾...
# 9930  AoZJqK17aOz4UfxX                        选12款之前的。12款后都是fb发动机， 机油消耗大。
# 9931  cQlpvPRdOwUXaVkh                  跟欧蓝德的调校很相似啊，掌握规律后，堵车时跟车，可减少踩刹车的次数
# 9932  QVf8TWXrIPDwEgNU                    哈哈哈，欧兰德也能上来跟森比，那破车你开几年试试，那操控也能比
# 9933  dr1QZyaGWbI2BKxz                           14款2.0，大连，七万多公里了，平均油耗10。
# 9934  hMZEBAwkNz8Du714    森林人2.0开了两年，一直在中石化加油站加92#，没啥问题，杠杠的，夏天开空调油耗8.5左右。
# 9935  hMZEBAwkNz8Du714    森林人2.0开了两年，一直在中石化加油站加92#，没啥问题，杠杠的，夏天开空调油耗8.5左右。
# 9936  d4aM8HCr5VisWlfU        国内轮胎的品牌还是比较多的，看你要准备用什么价位的了，一般来说声音越小的价格也就高些。
# 9937  9oHZT5rXOjauPA7V                                      我的也这样，换刹车片后消失
# 9938  wlSvQOt3Kz2ekbcg                               反正我是不会去了，除非关健部位如变速箱油
# 9939  ELB0ZT5CvK9Fok4H  我感觉你的油耗稍大些，我这里山东，最冷零下18度，最高6度或者0度左右，也是16款2.0的，...
# 9940  vdDQXJEg3wSj84er                                     我的方向盘也是两边缝不一样大
# 9941  hUSkd6ptCbfxMPo8  俺必须的说，15公里以上的上下班单程行程，很少红灯，80左右的速度……对小森是极好的……所以...
# 9942  VywQTI4iLuzd1DZ3  老铁没毛病...双击666！！！是不是这样？我这理解逻辑也挑不出毛病吧！你不矫情你试试？多大...
# 9943  Ufv6VpyNaGnShzlJ           2.0时尚，四川这段时间温度最低-1，基本上下班用，现在均速18，表显油耗9.2
# 9944  S8tmC0gxyBjzvLuN                                相貌不起眼，内饰太平淡，开起来才知道好
# 9945  vpaS3ueRQi2rhAgH  一看就知道山寨的！用的肯定是中控的普通视频输入接口而已，这种无屏的记录仪淘宝也就一两百块的东...
# 9946  5R0ZoOdv8H2MNGgt  楼主还在吗，同在上海，想咨询一下家用首辆车，到底是买森林人还是力狮好？如果森林人，2.0的动...
#
#      subject  sentiment_value sentiment_word
# 0         价格                0             影响
# 1         价格               -1              高
# 2         价格                1              低
# 3         价格               -1           有钱任性
# 4         价格               -1              高
# 5         价格                1             便宜
# 6         价格               -1             死硬
# 7         价格                0             一般
# 8         价格               -1              贵
# 9         价格                1           优惠不错
# 10        价格                1         优惠幅度不小
# 11        价格                1           不会后悔
# 12        价格                0             优惠
# 13        价格                0             优惠
# 14        价格               -1           优惠太小
# 15        价格               -1            才优惠
# 16        价格                0             优惠
# 17        价格                0             优惠
# 18        价格                0             优惠
# 19        价格                0             优惠
# 20        价格                0             优惠
# 21        价格                0             优惠
# 22        价格                0             优惠
# 23        价格                0             优惠
# 24        价格               -1              才
# 25        价格                0             优惠
# 26        价格                0             优惠
# 27        价格                0             优惠
# 28        价格                0             优惠
# 29        价格               -1             呵呵
# ...      ...              ...            ...
# 9917     舒适性               -1            NaN
# 9918     安全性                1            NaN
# 9919      动力               -1            NaN
# 9920      油耗                0            NaN
# 9921      动力                0            NaN
# 9922     安全性                1            NaN
# 9923      配置                0            NaN
# 9924      油耗                0            NaN
# 9925      配置               -1            NaN
# 9926      内饰               -1            NaN
# 9927      配置                0            NaN
# 9928      配置                0            NaN
# 9929      油耗                0            NaN
# 9930      动力                0            NaN
# 9931     安全性                1            NaN
# 9932      操控               -1            NaN
# 9933      油耗                0            NaN
# 9934      油耗                0            NaN
# 9935     舒适性                1            NaN
# 9936      价格               -1            NaN
# 9937     安全性                1            NaN
# 9938      动力                0            NaN
# 9939      油耗               -1            NaN
# 9940      操控               -1            NaN
# 9941      油耗                0            NaN
# 9942      外观                1            NaN
# 9943      油耗                0            NaN
# 9944      内饰               -1            NaN
# 9945      配置               -1            NaN
# 9946      动力                0            NaN
#
# [9947 rows x 5 columns]

# %%
'''
data = pd.read_csv('../../data/df_sen_sub/train.csv')
len(data['content_id'].unique()), len(list(data['content_id']))
content_ids = data['content_id'].unique()
subjs = data['subject'].unique()
df = {}
text, subs, sentis = [], [], []
for i in range(len(content_ids)):
    if i % 100 == 0:print(i)
    dd = data[data['content_id'] == content_ids[i]]
    text.append(dd.loc[dd.index.tolist()[0], 'content'])
    temp_subs, temp_senti = [], []
    for sub in subjs:
        temp_subs.append(sub)
        if len(dd[dd['subject'] == sub]) != 0:
            temp_senti.append(str(int(dd[dd['subject'] == sub]['sentiment_value'])))
        else:
            temp_senti.append('2')
    subs.append(','.join(temp_subs))
    sentis.append(','.join(temp_senti))
df['content'] = text
df['subjects'] = subs
df['sentiments'] = sentis
df = pd.DataFrame(df)
df.to_csv('../../data/df_sen_sub/merge_train.csv', index = False)
#data = pd.read_csv('../../data/df_sen_sub/test_public.csv')
'''
# Out:
# "\ndata = pd.read_csv('../../data/df_sen_sub/train.csv')\nlen(data['content_id'].unique()), len(list(data['content_id']))\ncontent_ids = data['content_id'].unique()\nsubjs = data['subject'].unique()\ndf = {}\ntext, subs, sentis = [], [], []\nfor i in range(len(content_ids)):\n    if i % 100 == 0:print(i)\n    dd = data[data['content_id'] == content_ids[i]]\n    text.append(dd.loc[dd.index.tolist()[0], 'content'])\n    temp_subs, temp_senti = [], []\n    for sub in subjs:\n        temp_subs.append(sub)\n        if len(dd[dd['subject'] == sub]) != 0:\n            temp_senti.append(str(int(dd[dd['subject'] == sub]['sentiment_value'])))\n        else:\n            temp_senti.append('2')\n    subs.append(','.join(temp_subs))\n    sentis.append(','.join(temp_senti))\ndf['content'] = text\ndf['subjects'] = subs\ndf['sentiments'] = sentis\ndf = pd.DataFrame(df)\ndf.to_csv('../../data/df_sen_sub/merge_train.csv', index = False)\n#data = pd.read_csv('../../data/df_sen_sub/test_public.csv')\n"

# %%
data = pd.read_csv('../../../data/df_sen_sub/merge_train.csv')
data = data.fillna('')
subs = list(data['subjects'])
sentiments = list(data['sentiments'])
content = list(data['content'])
test_data = pd.read_csv('../../../data/df_sen_sub/test_public.csv')
test_data = test_data.fillna('')
test_content = list(test_data['content'])
data = pd.read_csv('../../../data/df_sen_sub/train.csv')
data = data.fillna('')
senti_words = list(data['sentiment_word'])

# %%
with open('../../../data/df_sen_sub/add_text.txt','w') as f:
    f.write('\n'.join(list(content) + list(test_content)  + list(subs) + senti_words))
# 迭代器，使用jieba将句子进行分词
stopwords = open('../stopwords.txt', 'r').read().split('\n')
class Sentences(object):# 这个类可以根据实际情况重写，我已经将所有的文章进行分句，并整合到了一个文件里面
    def __init__(self, dirname):
        self.dirname = dirname # 句子所在文件，没句句子占一行
        #jieba.load_userdict("wordBase.txt") # 加载词库

    def __iter__(self):
        #for fname in os.listdir(self.dirname):
        for line in open(self.dirname):
                line = line.replace('\n', '')
                res = []
                for word in list(jieba.cut(line)):
                    if word in stopwords:
                        continue
                    res.append(word)
                yield res#list(jieba.cut(line))

sentences = []
def train_word2vec(folder_path, size=100):
    global sentences
    sentences = Sentences(folder_path) #生成分词后的句子，是一个二维数组

    # size是词向量长度
    # worker是线程数量，建议与物理线程数量一致
    # min_count是指出现次数小于一定程度，就忽略，0表示不忽略
    #model = Word2Vec(sentences, size=size, workers=8, min_count=0)

    # 训练结束就将模型保存起来
    #model.save("../../data/df_sen_sub/add_word2vec_model")

# 生成50维度的词向量模型
train_word2vec("../../../data/df_sen_sub/add_text.txt",100)

# 测试训练好的词向量模型，使用model[keyWord]即可获取keyword这个词的词向量
model = Word2Vec.load("../../../data/df_sen_sub/add_word2vec_model")
sentences = list(sentences)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.954 seconds.
# Prefix dict has been built succesfully.

# %%
len(sentences)
# Out:
# 28890

# %%
from collections import Counter
data = pd.read_csv('../../../data/df_sen_sub/train.csv')
sub_uniq = data['subject'].unique()
data = data[pd.notnull(data['sentiment_word'])]
senti_word_set = {}
sum_ = 0
for key in sub_uniq:
    co = 0
    senti_word_set[key] = {}
    #dd = list(data[data['subject'] == key]['sentiment_word'])
    ddd = data[data['subject'] == key]
    for kk in [-1, 0, 1]:
        dd = list(ddd[ddd['sentiment_value'] == kk]['sentiment_word'])
        ss = []
        for phras in dd:
            words = list(jieba.cut(phras))
            for word in words:
                word = word.replace(' ', '')
                if word == '' or word in stopwords:continue
                ss.append(word)
                co += 1
            counter = Counter(ss)
            sort = sorted(counter.items(), key=lambda item: item[1], reverse = True)
            for mm in counter:
                if mm not in senti_word_set[key]:
                    senti_word_set[key][mm] = kk
                elif senti_word_set[key][mm] == kk:
                    continue
                else:
                    senti_word_set[key][mm] = 0
        sum_ += co
print(sum_)
senti_word_set
# Out:
# 6431
# {'价格': {'高': 0,
#   '有钱': -1,
#   '任性': -1,
#   '死硬': -1,
#   '贵': 0,
#   '优惠': 0,
#   '太小': -1,
#   '套路': -1,
#   '太贵': -1,
#   '不值': -1,
#   '高昂': -1,
#   '下不来': -1,
#   '不会': 0,
#   '便宜': 0,
#   '放弃': -1,
#   '平易近人': -1,
#   '价格': 0,
#   '老贵': -1,
#   '没有': 0,
#   '保证': -1,
#   '好多': -1,
#   '更': -1,
#   '合适': 0,
#   '那点': -1,
#   '贵太多': -1,
#   '挺高': -1,
#   '不菲': -1,
#   '一点': 0,
#   '奇高': -1,
#   '不好': -1,
#   '小贵': 0,
#   '过高': -1,
#   '售价': -1,
#   '明显': -1,
#   '高于': -1,
#   '竞品': -1,
#   '优势': -1,
#   '虚高': -1,
#   '不高': 0,
#   '性价比': 0,
#   '不算': -1,
#   '单价': -1,
#   '没': 0,
#   '降价': -1,
#   '不要': 0,
#   '想': -1,
#   '保值': -1,
#   '率': -1,
#   '大众': -1,
#   '好': 0,
#   '略贵': -1,
#   '保养': -1,
#   '不用': -1,
#   '考虑': -1,
#   '不靠': -1,
#   '谱': -1,
#   '没法': -1,
#   '咬咬牙': -1,
#   '不合算': -1,
#   '影响': 0,
#   '亲民点': 0,
#   '差不多': 0,
#   '差距': 0,
#   '知道': 0,
#   '合理': 0,
#   '就行': 0,
#   '行情': 0,
#   '价': 0,
#   '正常': 0,
#   '几百': 0,
#   '参差不齐': 0,
#   '行': 0,
#   '买': 0,
#   '价差': 0,
#   '很大': 0,
#   '低': 0,
#   '不能': 0,
#   '在意': 0,
#   '还行': 0,
#   '不错': 1,
#   '幅度': 1,
#   '不小': 1,
#   '后悔': 1,
#   '值': 1,
#   '愉快': 1,
#   '不够': 1,
#   '比较': 1,
#   '下降': 1,
#   '很多': 1,
#   '超级': 1,
#   '最好': 1,
#   '操控': 1,
#   '满意': 1,
#   '费用': 1,
#   '相当': 1,
#   '实惠': 1,
#   '再贵': 1,
#   '车': 1,
#   '欧蓝德': 1,
#   '真心': 1,
#   '秒杀': 1,
#   '对手': 1,
#   '力度': 1,
#   '良心': 1,
#   '找不出': 1,
#   '第二辆': 1},
#  '配置': {'没': -1,
#   '实用': 0,
#   '背光': -1,
#   '没有': 0,
#   '山寨': -1,
#   '不值钱': -1,
#   '贵': -1,
#   '比不上': -1,
#   '黑': -1,
#   '垃圾': -1,
#   '差': -1,
#   '卡死': -1,
#   '黑屏': -1,
#   '惨不忍睹': -1,
#   '鸡肋': -1,
#   '坑': -1,
#   '结实': -1,
#   '国内': -1,
#   '减配': -1,
#   '全景': -1,
#   '天窗': -1,
#   '可惜': -1,
#   '不行': -1,
#   '看不上眼': -1,
#   '换个': -1,
#   '正常': -1,
#   '点': -1,
#   '喜欢': 0,
#   '不高': -1,
#   '缺失': -1,
#   '遗憾': -1,
#   '低': -1,
#   '后悔': 0,
#   '不能': -1,
#   '忍': -1,
#   '咋样': -1,
#   '不太': 0,
#   '重视': -1,
#   '不选': -1,
#   '挫': -1,
#   '改款': -1,
#   '电动': -1,
#   '尾门': -1,
#   '太慢': -1,
#   '没落': -1,
#   '锁': -1,
#   '不久': -1,
#   '必要': -1,
#   '声音': -1,
#   '手机': 0,
#   '导航': 0,
#   '掉': -1,
#   '链子': -1,
#   '车载': -1,
#   '带到': -1,
#   '沟里': -1,
#   '硬伤': -1,
#   '差点': -1,
#   '优势': -1,
#   '方便': 0,
#   '太': -1,
#   '太扯': -1,
#   '值得': 0,
#   '不值': -1,
#   '配置': 0,
#   '简陋': -1,
#   '差一点': -1,
#   '很差': -1,
#   '简配': -1,
#   '厉害': -1,
#   '主': -1,
#   '坑爹': -1,
#   '吐槽': -1,
#   '有点': 0,
#   '抖': -1,
#   '丑到': -1,
#   '无力': -1,
#   '机舱': -1,
#   '里': -1,
#   '走': -1,
#   '管子': -1,
#   '不好': -1,
#   '断轴': -1,
#   '中控': -1,
#   '比较': 0,
#   '音质': -1,
#   '心里': -1,
#   '凉凉的': -1,
#   '早日': -1,
#   '完蛋': -1,
#   '不让': -1,
#   '省心': -1,
#   '区别': -1,
#   '连线': 0,
#   '简单': 0,
#   '后窗': 0,
#   '无所谓': 0,
#   '省钱': 0,
#   '不少': 0,
#   '不带': 0,
#   '是否': 0,
#   '好': 1,
#   'OK': 1,
#   '不错': 1,
#   '值': 1,
#   '一点': 1,
#   '问题': 1,
#   '高': 1,
#   '出色': 1,
#   '顶级': 1,
#   '超前': 1,
#   '买': 1,
#   '机械性能': 1,
#   '80': 1,
#   '分': 1,
#   '均衡': 1,
#   '提升': 1,
#   '厚道': 1,
#   '不差': 1,
#   '全': 1,
#   '真高': 1,
#   '满意': 1,
#   '非常': 1,
#   '合理': 1,
#   '蛮': 1,
#   '强太多': 1,
#   '合适': 1,
#   '胜出': 1,
#   '丰富': 1,
#   '够': 1,
#   '秒杀': 1,
#   '真心': 1,
#   '机械': 1,
#   '手刹': 1,
#   '四驱': 1,
#   '安全': 1,
#   '米其林': 1,
#   '3ST': 1,
#   '安静': 1,
#   '舒适': 1,
#   '坦克': 1,
#   '欧蓝德': 1,
#   '肯定': 1,
#   '压倒性': 1,
#   '说': 1,
#   '更好': 1,
#   '已成': 1,
#   '绝唱': 1,
#   '好用': 1,
#   '皮实': 1,
#   '整车': 1,
#   '扎实': 1,
#   '视野': 1,
#   '性好': 1,
#   '开着': 1,
#   '方面': 1,
#   '舒服': 1,
#   '优点': 1,
#   '缺点': 1,
#   '几乎': 1,
#   '零': 1,
#   '期待': 1,
#   'SGP': 1,
#   '新森': 1,
#   '影响': 1,
#   '新款': 1,
#   '厚重': 1,
#   '大气': 1,
#   '良心': 1},
#  '操控': {'垃圾': -1,
#   '那么回事': -1,
#   '渗油': -1,
#   '无法': 0,
#   '差': -1,
#   '开': 0,
#   '起来': -1,
#   '实在': -1,
#   '…': -1,
#   '.': -1,
#   '多余': -1,
#   '比不上': -1,
#   '颠簸': -1,
#   '完败': -1,
#   '没': 0,
#   '好': 0,
#   '承受': -1,
#   '不起': -1,
#   '不好': -1,
#   '静音': -1,
#   '抖': -1,
#   '响': -1,
#   '异响': -1,
#   '差劲': -1,
#   '刹车盘': -1,
#   '刺': -1,
#   '拉拉': -1,
#   '掉': -1,
#   '漆': -1,
#   '偏': -1,
#   '嘎嘎响': -1,
#   '脱皮': -1,
#   '底盘': 0,
#   '漏油': -1,
#   '走烂路': -1,
#   '颠': -1,
#   '磨得': -1,
#   '发亮': -1,
#   '解': -1,
#   '太': 0,
#   '味道': -1,
#   '真': -1,
#   '不小': -1,
#   '廉价': -1,
#   '欠缺': -1,
#   '废': -1,
#   '刹车': -1,
#   '通病': -1,
#   '刹': -1,
#   '不住': -1,
#   '不佳': -1,
#   '重': -1,
#   '一点': 0,
#   '很多': 0,
#   '方向': -1,
#   '飘': -1,
#   '方向盘': 0,
#   '总是': -1,
#   '不断': -1,
#   '修正': -1,
#   '车身': -1,
#   '反应': -1,
#   '迟钝': -1,
#   '软': -1,
#   '间隙': -1,
#   '低': 0,
#   '有点': 0,
#   '需要': -1,
#   '一直': -1,
#   '微调': -1,
#   '紧凑': 0,
#   '设计': -1,
#   '简练': -1,
#   '高度': -1,
#   '180mm': -1,
#   '太高': -1,
#   '过坑': -1,
#   '瞬间': -1,
#   '轿车': -1,
#   '晃动': -1,
#   '飞': -1,
#   '叉叉': -1,
#   '摆动': -1,
#   '手感': 0,
#   '危险': -1,
#   '平衡': 0,
#   '换': 0,
#   '规格': 0,
#   '没敢': 0,
#   '玩': 0,
#   '中等': 0,
#   '偏硬': 0,
#   '更': 0,
#   '硬': 0,
#   '换代': 0,
#   '慢': 0,
#   '太稳': 0,
#   '重新': 0,
#   '松散': 0,
#   '告诉': 0,
#   '抖动': 0,
#   '更高': 0,
#   '舒服': 0,
#   '调节': 0,
#   '没什么': 0,
#   '影响': 0,
#   '没有磨损': 0,
#   '不错': 0,
#   '兼顾': 0,
#   '东西': 0,
#   '最高': 0,
#   '变化': 0,
#   '烂': 0,
#   '无所谓': 0,
#   '高': 0,
#   '控制不了': 0,
#   '加热': 0,
#   '问题': 0,
#   '差不多': 0,
#   '一流': 1,
#   '追求': 1,
#   '良好': 1,
#   '第一': 1,
#   '灵活': 1,
#   '完胜': 1,
#   '好用': 1,
#   '挺棒': 1,
#   '专业': 1,
#   '漂移': 1,
#   '好感': 1,
#   '优势': 1,
#   '喜欢': 1,
#   '符合': 1,
#   '95': 1,
#   '分': 1,
#   '牛': 1,
#   '逼': 1,
#   '要求': 1,
#   '一致': 1,
#   '升级': 1,
#   '值得': 1,
#   '不飘': 1,
#   '更好': 1,
#   '满意': 1,
#   '厉害': 1,
#   '灵巧': 1,
#   '强': 1,
#   '韧性': 1,
#   '很稳': 1,
#   '很准': 1,
#   '好点': 1,
#   '操控': 1,
#   '感': 1,
#   '安全': 1,
#   '优点': 1,
#   '轻松': 1,
#   '忍住': 1,
#   '没改': 1,
#   '舒适感': 1,
#   '真心': 1,
#   '犹如': 1,
#   '宝马': 1,
#   '比较': 1,
#   '优': 1,
#   '确实': 1,
#   '很棒': 1,
#   '自信': 1,
#   '操控性': 1,
#   '相当': 1,
#   '一个': 1,
#   '档次': 1,
#   '看点': 1,
#   '费劲': 1,
#   '没得说': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '提高': 1,
#   '性能': 1,
#   '说': 1,
#   '坐姿': 1,
#   '驾驶': 1,
#   '质感': 1,
#   '蛮': 1,
#   '给力': 1,
#   '安心': 1,
#   '质量': 1,
#   '完美': 1,
#   '肯定': 1,
#   '随性': 1,
#   '稳': 1,
#   '破百': 1,
#   '胜出': 1,
#   '最好': 1,
#   '无敌': 1,
#   '闻名': 1,
#   '可靠': 1,
#   '超过': 1,
#   '非常': 1,
#   '略胜一筹': 1,
#   '距离': 1,
#   '短': 1,
#   '灵': 1,
#   '轻': 1,
#   '操纵': 1,
#   '好开': 1,
#   '比新森强': 1,
#   '没见': 1,
#   '跑': 1,
#   '14': 1,
#   '万': 1,
#   '机器': 1,
#   '基本': 1,
#   '着迷': 1,
#   '纠结': 1,
#   '后悔': 1,
#   '解释': 1,
#   '挺稳': 1},
#  '舒适性': {'坑': -1,
#   '异响': -1,
#   '噪音': 0,
#   '颠': -1,
#   '问题': 0,
#   '打不开': -1,
#   '乱响': -1,
#   '卡顿': -1,
#   '质量': -1,
#   '很差': -1,
#   '腰疼': -1,
#   '抖': -1,
#   '舒服': 0,
#   '气门': -1,
#   '声音': 0,
#   '震': -1,
#   '响': -1,
#   '隔音': -1,
#   '不好': -1,
#   '忽悠': -1,
#   '容易': -1,
#   '晕车': -1,
#   '就别': -1,
#   '想': -1,
#   '开着': -1,
#   '累': -1,
#   '唯一': -1,
#   '不足': -1,
#   '风噪大': -1,
#   '差多': -1,
#   '很大': -1,
#   '舒适': 0,
#   '颠簸': -1,
#   '有点': 0,
#   '影响': -1,
#   '味': -1,
#   '较大': -1,
#   '偏': -1,
#   '不行': -1,
#   '较差': -1,
#   '受不了': -1,
#   '特别': -1,
#   '空调': 0,
#   '咋样': -1,
#   '烦透了': -1,
#   '耳朵': -1,
#   '音响': -1,
#   '太': 0,
#   '差': -1,
#   '变': 0,
#   '滴水': 0,
#   '现象': -1,
#   '确实': -1,
#   '不会': -1,
#   '制冷': 0,
#   '速度': -1,
#   '快': 0,
#   '开': 0,
#   '没劲': -1,
#   '差一点': -1,
#   '依旧': -1,
#   '抖抖': -1,
#   '不少': -1,
#   '难受': -1,
#   '支持': -1,
#   '发出声音': -1,
#   '很烦': -1,
#   '风噪': -1,
#   '最大': -1,
#   '比较': -1,
#   '俩': -1,
#   '车': -1,
#   '不算': 0,
#   '太好': -1,
#   '原胎': -1,
#   '严实': -1,
#   '出': -1,
#   '偏低': -1,
#   '硬': -1,
#   '毛病': -1,
#   '滋滋': -1,
#   '声': -1,
#   '土腥味': -1,
#   '抖动': -1,
#   '摩擦音': -1,
#   '气味': -1,
#   '呛': -1,
#   '格叽格': -1,
#   '叽响': -1,
#   '座椅': 0,
#   '臭': -1,
#   '视野': 0,
#   '森': -1,
#   '金属': -1,
#   '撞击': -1,
#   '响声': -1,
#   '敲击': -1,
#   '真心': -1,
#   '点': 0,
#   '发动机': -1,
#   '效果': 0,
#   '内部': -1,
#   '味道': -1,
#   '胎噪件': -1,
#   '15': -1,
#   '万': -1,
#   '听': -1,
#   '心烦': -1,
#   '后排': -1,
#   '太硬': -1,
#   '颈椎': -1,
#   '有点累': -1,
#   'X1': -1,
#   '可怜': -1,
#   '更': -1,
#   '吵': -1,
#   '扯淡': -1,
#   '静音': 0,
#   '原厂': 0,
#   '冻得': 0,
#   '正常': 0,
#   '以前': 0,
#   '小点': 0,
#   '保养': 0,
#   '忽略不计': 0,
#   '忽略': 0,
#   '掩盖': 0,
#   '有所': 0,
#   '下降': 0,
#   '冷': 0,
#   '不给力': 0,
#   '冰箱': 0,
#   '变化': 0,
#   '没': 0,
#   '舒适性': 0,
#   '还行': 0,
#   '不介意': 0,
#   '好': 1,
#   '牛': 1,
#   '逼': 1,
#   '空间': 1,
#   '看中': 1,
#   '记忆': 1,
#   '提升': 1,
#   '强': 1,
#   '感觉': 1,
#   '不错': 1,
#   '恒温': 1,
#   '满意': 1,
#   '分区': 1,
#   '减少': 1,
#   '提高': 1,
#   '很多': 1,
#   '低': 1,
#   '好听': 1,
#   '好用': 1,
#   '好点': 1,
#   '蛮': 1,
#   '给力': 1,
#   '没有': 1,
#   '高': 1,
#   '厉害': 1,
#   '非常': 1,
#   '风力': 1,
#   '强劲': 1,
#   '坐姿': 1,
#   '视线': 1,
#   '更好': 1,
#   '说': 1,
#   '性好': 1,
#   '超级': 1,
#   '调': 1,
#   '秒杀': 1,
#   'SUV': 1,
#   '乘客': 1,
#   '安静': 1},
#  '油耗': {'省油': 0,
#   '略': -1,
#   '高': 0,
#   '公平': -1,
#   '全': -1,
#   '行业': -1,
#   '造假': -1,
#   '真': -1,
#   '喜欢': -1,
#   '费油': 0,
#   '偏': -1,
#   '完败': -1,
#   '升高': -1,
#   '上升': -1,
#   '增加': 0,
#   '油耗': 0,
#   '会': -1,
#   '顶不住': -1,
#   '太高': -1,
#   '哗哗': -1,
#   '以前': -1,
#   '可能': -1,
#   '低': 0,
#   '点': -1,
#   '高点': 0,
#   '颇': -1,
#   '很多': -1,
#   '特大': -1,
#   '贼': -1,
#   '不好': -1,
#   '蹭': -1,
#   '上涨': -1,
#   '性价比': -1,
#   '控制': -1,
#   '一点': -1,
#   '1.8': -1,
#   'T': -1,
#   '不低': -1,
#   '确实': 0,
#   '爱': -1,
#   '滴': -1,
#   '不敢恭维': -1,
#   '不着': -1,
#   '调': -1,
#   '不见得': -1,
#   '省': 0,
#   '没': 0,
#   '感觉': 0,
#   '差不多': 0,
#   '市区': 0,
#   '左右': 0,
#   '正常': 0,
#   '必要': 0,
#   '做': 0,
#   '区别': 0,
#   '没说的': 0,
#   '关心': 0,
#   '稍微': 0,
#   '只能': 0,
#   '说': 0,
#   '行': 1,
#   '满意': 1,
#   '知足': 1,
#   '不高': 1,
#   '好': 1,
#   '毛病': 1,
#   '没有': 1,
#   '现象': 1,
#   '平顺': 1,
#   '自然': 1,
#   '给力': 1,
#   '额外': 1,
#   '惊喜': 1,
#   '问题': 1,
#   '不错': 1,
#   '下降': 1,
#   '不会': 1,
#   '一个': 1,
#   '稳定': 1,
#   '变化': 1,
#   '废油': 1,
#   '效果': 1,
#   '相当': 1,
#   '棒': 1,
#   '非常': 1,
#   '耐用': 1,
#   '值得': 1,
#   '拥有': 1,
#   '胜出': 1,
#   '够': 1,
#   '牛': 1,
#   '2.0': 1,
#   '森': 1,
#   '真心': 1,
#   '低油耗': 1,
#   '5.9': 1,
#   '驾驶': 1,
#   '体验': 1,
#   '超级': 1,
#   '不少': 1,
#   '水平': 1,
#   '已经': 1,
#   '挺': 1,
#   '一定': 1},
#  '动力': {'反应': 0,
#   '慢': -1,
#   '熄火': -1,
#   '肉': 0,
#   '不佳': -1,
#   '烧': 0,
#   '机油': 0,
#   '郁闷': -1,
#   '坑': -1,
#   '爆震': -1,
#   '怕': 0,
#   '失望': -1,
#   '没': 0,
#   '太吵': -1,
#   '担心': 0,
#   '通病': -1,
#   '偶尔': -1,
#   '顿挫': -1,
#   '有点': 0,
#   '受不了': -1,
#   '不够': 0,
#   '异响': -1,
#   '问题': 0,
#   '差点': -1,
#   '意思': -1,
#   '质量': -1,
#   '不行': -1,
#   '一个': -1,
#   '缸体': -1,
#   '工作': -1,
#   '严重': -1,
#   '抖动': -1,
#   '不好': -1,
#   '差': 0,
#   '车重': -1,
#   '不选': -1,
#   '代价': -1,
#   '偏弱': -1,
#   '过时': -1,
#   '轻微': -1,
#   '渗油': -1,
#   '完善': -1,
#   '变弱': -1,
#   '不了': -1,
#   '下降': 0,
#   '一点': 0,
#   '一点点': 0,
#   '鸡肋': 0,
#   '故障': -1,
#   '弱': -1,
#   '没有': 0,
#   '以前': 0,
#   '灵敏': 0,
#   '温度': 0,
#   '高': 0,
#   '漏油': -1,
#   '设计': -1,
#   '缺陷': -1,
#   '消耗': -1,
#   '生锈': -1,
#   '涉水': -1,
#   '锁死': -1,
#   '查不出': -1,
#   '哗啦声': -1,
#   '败笔': -1,
#   '转速': -1,
#   '低': 0,
#   '负担': -1,
#   '轰': -1,
#   '轰响': -1,
#   '飙车': -1,
#   '差劲': -1,
#   '牛车': -1,
#   '变闷': -1,
#   '动力': 0,
#   '降低': -1,
#   '压力': -1,
#   '重新': -1,
#   '打胶': -1,
#   '加速': 0,
#   '缓慢': -1,
#   '太弱': -1,
#   '跟不上': -1,
#   '冒烟': -1,
#   '点': 0,
#   '缝隙': -1,
#   '里': -1,
#   '油泥': -1,
#   '搞': -1,
#   '好': 0,
#   '到哪去': -1,
#   '明显': 0,
#   '发动机': 0,
#   '噪声': -1,
#   '变速箱': -1,
#   '存在': -1,
#   '不足': 0,
#   '噪音': 0,
#   '没力': -1,
#   '异味': -1,
#   '一直': -1,
#   '弊病': -1,
#   '段': -1,
#   '别提': -1,
#   '急': -1,
#   '嘶哑': -1,
#   '减少': -1,
#   '逊色': -1,
#   '降': -1,
#   '之前': -1,
#   '硬伤': -1,
#   '很差': -1,
#   '捉急': -1,
#   '差些': -1,
#   '太': 0,
#   '太行': -1,
#   '风险': -1,
#   '很大': -1,
#   '1.6': -1,
#   'T': -1,
#   '四缸': -1,
#   '四驱': 0,
#   '超个': -1,
#   '车': -1,
#   '感觉': 0,
#   '费劲': -1,
#   '擅长': -1,
#   '不好受': -1,
#   '老坏': -1,
#   '肯定': -1,
#   '指望': -1,
#   '偏磨': -1,
#   '没什么': -1,
#   '亮点': -1,
#   '不会': 0,
#   '很快': -1,
#   '连速腾': -1,
#   '起步': -1,
#   '赶不上': -1,
#   '爬坡': -1,
#   '爬': -1,
#   '上去': -1,
#   '大众': -1,
#   '调教': -1,
#   '维修': -1,
#   '起来': -1,
#   '麻烦': -1,
#   '高性能': -1,
#   '烧漏': -1,
#   '落后': -1,
#   '真的': 0,
#   '实在': -1,
#   '太老': -1,
#   '远': -1,
#   '牛': 0,
#   'b': -1,
#   '不到': -1,
#   '心理': -1,
#   '没底': -1,
#   '垃圾': -1,
#   '运气': 0,
#   '纠结': 0,
#   '好像': 0,
#   '够用': 0,
#   '不烧': 0,
#   '驾驶': 0,
#   '足够': 0,
#   '一般般': 0,
#   '换油': 0,
#   '偏': 0,
#   '伤': 0,
#   '蓄电池': 0,
#   '重心': 0,
#   '避免': 0,
#   '没关系': 0,
#   '难点': 0,
#   '不敢': 0,
#   '通红': 0,
#   '都行': 0,
#   '爆缸': 0,
#   '正常': 0,
#   '声音': 0,
#   '变小': 0,
#   '不说': 0,
#   '没觉': 0,
#   '没事': 0,
#   '影响': 0,
#   '散热': 0,
#   '不解': 0,
#   '忽略': 0,
#   '行': 0,
#   '区别': 0,
#   '差不多': 0,
#   '有所': 0,
#   '护板': 0,
#   '破碎': 0,
#   '做到': 0,
#   '最好': 0,
#   '布局': 0,
#   '限制': 0,
#   '觉得': 0,
#   '适当': 0,
#   '保养': 0,
#   '低沉': 0,
#   '疯狂': 0,
#   '没法': 0,
#   '磨损': 0,
#   '差别': 0,
#   '提速': 0,
#   '水平': 0,
#   '对置': 0,
#   '横向': 0,
#   '占用': 0,
#   '空间': 0,
#   '充足': 1,
#   '舒服': 1,
#   '很少': 1,
#   '耐用': 1,
#   '少': 1,
#   '足': 1,
#   '超车': 1,
#   '满意': 1,
#   '轻松': 1,
#   '不错': 1,
#   '用不完': 1,
#   '劲': 1,
#   '给力': 1,
#   '非常': 1,
#   '够': 1,
#   '杠杠': 1,
#   '开着': 1,
#   '爽': 1,
#   '很多': 1,
#   '完全': 1,
#   '不能': 1,
#   '比拟': 1,
#   '不差': 1,
#   '快': 1,
#   '改观': 1,
#   '不少': 1,
#   '好点': 1,
#   '95': 1,
#   '分': 1,
#   '排量': 1,
#   '提高': 1,
#   '升级': 1,
#   '提升': 1,
#   '强': 1,
#   '全时': 1,
#   '加强': 1,
#   '敏捷': 1,
#   '随叫随到': 1,
#   '好太多': 1,
#   '高原': 1,
#   '小霸王': 1,
#   '信心': 1,
#   '满满': 1,
#   '情况': 1,
#   '很爽': 1,
#   '损耗': 1,
#   '省心': 1,
#   '漏': 1,
#   '均衡': 1,
#   '轻盈': 1,
#   '舒适': 1,
#   '王': 1,
#   '优': 1,
#   '更好': 1,
#   '堪比': 1,
#   '跑车': 1,
#   '相当': 1,
#   '轻轻松松': 1,
#   '优势': 1,
#   '干净': 1,
#   '甩': 1,
#   'n': 1,
#   '条街': 1,
#   '专家': 1,
#   '已经': 1,
#   '猛': 1,
#   '拔尖': 1,
#   '追不上': 1,
#   '喜欢': 1,
#   '强些': 1,
#   '强劲': 1,
#   '更足': 1,
#   '性能': 1,
#   '效果': 1,
#   '质感': 1,
#   '很小': 1,
#   '好车': 1,
#   '太好了': 1,
#   '车挺': 1,
#   '破百': 1,
#   '秒杀': 1,
#   '胜出': 1,
#   '无敌': 1,
#   '出色': 1,
#   '可靠': 1,
#   '没得说': 1,
#   '超过': 1,
#   '更高': 1,
#   '稳定': 1,
#   '新': 1,
#   '坦克': 1,
#   '欧蓝德': 1,
#   '开启': 1,
#   '汽车': 1,
#   '新篇章': 1,
#   '轻': 1,
#   '强多': 1,
#   '响应': 1,
#   '旅行': 1,
#   '更强': 1,
#   '老牛': 1,
#   '逼': 1,
#   '最大': 1,
#   '卖点': 1,
#   '原来': 1,
#   '稳': 1,
#   '没见': 1,
#   '跑': 1,
#   '14': 1,
#   '万': 1,
#   '机器': 1,
#   '直列': 1,
#   '诱惑': 1,
#   '中控台': 1,
#   '确实': 1,
#   '着迷': 1,
#   '扯淡': 1,
#   '后悔': 1,
#   '太给力': 1,
#   '算': 1,
#   '输': 1},
#  '内饰': {'普通': 0,
#   '松垮': -1,
#   '旧': -1,
#   '差': -1,
#   '改改': 0,
#   '一点点': -1,
#   '细致': -1,
#   '挫': -1,
#   '破破烂烂': -1,
#   '有点': -1,
#   '糙': -1,
#   '影响': -1,
#   '驾驶': -1,
#   '全': -1,
#   '塑料': -1,
#   '简陋': -1,
#   '改': -1,
#   '不够': -1,
#   '完败': -1,
#   '太': 0,
#   '水': -1,
#   '过时': -1,
#   '出毛病': -1,
#   '脱皮': -1,
#   '粗糙': -1,
#   '现款': -1,
#   '一个': 0,
#   '档次': 0,
#   '内饰': 0,
#   '老气': -1,
#   '低档': -1,
#   '伤感情': -1,
#   '异味': -1,
#   '没用': -1,
#   '不满': -1,
#   '+': -1,
#   'E': -1,
#   'E11': -1,
#   ':': -1,
#   'E742': -1,
#   '缺点': -1,
#   '硬伤': -1,
#   '差一点': -1,
#   '令人发指': -1,
#   '粗': -1,
#   '不能': -1,
#   '接受': -1,
#   '整': -1,
#   '渣': -1,
#   '没戏': -1,
#   '难受': -1,
#   '单调': -1,
#   '豪华': 0,
#   '硬': -1,
#   '凸': -1,
#   '太过': -1,
#   '简单': 0,
#   '粗糟': -1,
#   '吐': -1,
#   '寒酸': -1,
#   '十万块': -1,
#   '国产车': -1,
#   '扯淡': -1,
#   '吐槽': -1,
#   '掉': -1,
#   '没得': -1,
#   '不敢恭维': -1,
#   '惨不忍睹': -1,
#   '非常': -1,
#   '落后': -1,
#   '一股': -1,
#   '丰田': -1,
#   '味': -1,
#   '后排': -1,
#   '座椅': -1,
#   '格叽格': -1,
#   '叽响': -1,
#   '臭味': -1,
#   '廉价': -1,
#   '感': -1,
#   'L0W': -1,
#   '磕碜': -1,
#   '点': -1,
#   '较差': -1,
#   '感觉': -1,
#   '多丑': -1,
#   '科技': 0,
#   '一如既往': -1,
#   '做工': 0,
#   '设计': 0,
#   '土土': -1,
#   '居然': -1,
#   '舒坦': -1,
#   '还好': 0,
#   '感冒': 0,
#   '面包车': 0,
#   '60': 0,
#   '分': 0,
#   '大致相同': 0,
#   '用处': 0,
#   '不提': 0,
#   '心知肚明': 0,
#   '要求': 0,
#   '不高': 0,
#   '特别': 0,
#   '舒服': 0,
#   '贼': 0,
#   '嚣张': 0,
#   '齐全': 0,
#   '就行': 0,
#   '不在乎': 0,
#   '不错': 1,
#   '好': 1,
#   '坐': 1,
#   '进去': 1,
#   '放松': 1,
#   '保值': 1,
#   '耐用': 1,
#   '喜欢': 1,
#   '认可度': 1,
#   '高': 1,
#   '皮实': 1,
#   '提升': 1,
#   '好看': 1,
#   '符合': 1,
#   '一致': 1,
#   '车': 1,
#   '手感': 1,
#   '爆炸': 1,
#   '不逊于': 1,
#   '大改': 1,
#   '强': 1,
#   '没': 1,
#   '说': 1,
#   '品质': 1,
#   '记忆': 1,
#   '绝对值': 1,
#   '感强': 1,
#   '中上游': 1,
#   '绝对': 1,
#   '口味': 1,
#   '保持': 1,
#   '用料': 1,
#   '简洁': 1,
#   '干练': 1,
#   '炫酷': 1,
#   '高出': 1,
#   '带': 1,
#   '喜感': 1,
#   '好点': 1,
#   '更好': 1,
#   '不少': 1,
#   '漂亮': 1,
#   '细': 1,
#   '骚': 1,
#   '很多': 1,
#   '高大': 1,
#   '秒杀': 1,
#   '胜出': 1,
#   '帅': 1,
#   '新': 1,
#   '简约': 1,
#   '比较': 1,
#   '真的': 1,
#   '感高': 1,
#   '森林': 1,
#   '人强': 1,
#   '偏硬': 1,
#   '造型': 1,
#   '吊打': 1},
#  '安全性': {'软': -1,
#   '强': 0,
#   '差劲': -1,
#   '耐磨': -1,
#   '刹': -1,
#   '不住': -1,
#   '少': -1,
#   '气囊': -1,
#   '心寒': -1,
#   '刹车': 0,
#   '行程': -1,
#   '距离': -1,
#   '长': -1,
#   '不给力': -1,
#   '问题': 0,
#   '醉': -1,
#   '恼人': -1,
#   '能比': -1,
#   '不行': -1,
#   '急刹车': -1,
#   '差点': -1,
#   '追尾': -1,
#   '无奈': -1,
#   '急': 0,
#   '加速': 0,
#   '耐用': 1,
#   '不错': 1,
#   '要求': 1,
#   '一致': 1,
#   '安全': 1,
#   '第一': 1,
#   '高': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '好': 1,
#   '超好': 1,
#   '适合': 1,
#   '效果': 1,
#   '皮实': 1,
#   '更': 1,
#   '扎实': 1,
#   '喜欢': 1,
#   '机械': 1,
#   '手刹': 1,
#   '卤素灯': 1,
#   '明显': 1,
#   '穿透力': 1,
#   '更强': 1,
#   '安全感': 1,
#   '极高': 1,
#   '硬': 1,
#   '脚感': 1,
#   '非常': 1,
#   '细腻': 1,
#   '微操': 1,
#   '完': 1,
#   '线性': 1,
#   '踩': 1,
#   '随有': 1,
#   '挺': 1,
#   '避震': 1,
#   '觉得': 1,
#   '够': 1,
#   '算': 1,
#   '输': 1},
#  '空间': {'硬伤': -1,
#   '真': -1,
#   '喜欢': 0,
#   '排挤': -1,
#   '不行': -1,
#   '钻进去': -1,
#   '奢望': -1,
#   '真的': -1,
#   '空间': 0,
#   '不敢恭维': -1,
#   '后排': -1,
#   '点': -1,
#   '舒服': 0,
#   '满意': 0,
#   '一点': -1,
#   '·': -1,
#   '没有': -1,
#   '没': 0,
#   '宽敞': 0,
#   '差': -1,
#   '有点': 0,
#   '显小': -1,
#   '异响': -1,
#   '太小': -1,
#   '完败': -1,
#   '抓狂': -1,
#   '轴距': 0,
#   '严重': -1,
#   '不符': -1,
#   '不在意': 0,
#   '感冒': 0,
#   '差别': 0,
#   '不差': 0,
#   '横向': 0,
#   '比森好': 0,
#   '纵向': 0,
#   '森': 0,
#   '较大': 0,
#   '好些': 1,
#   '满足': 1,
#   '不错': 1,
#   '坐': 1,
#   '进去': 1,
#   '放松': 1,
#   '出色': 1,
#   '杀手锏': 1,
#   '车体': 1,
#   '高': 1,
#   '均衡': 1,
#   '差不多': 1,
#   '好': 1,
#   '实用': 1,
#   '方面': 1,
#   '保障': 1,
#   '动力': 1,
#   '非常': 1,
#   '够用': 1,
#   '不小': 1,
#   '容量': 1,
#   '宽大': 1,
#   '舒适': 1,
#   '特大': 1,
#   '变': 1,
#   '甩': 1,
#   '三条': 1,
#   '街': 1,
#   '相当': 1,
#   '优势': 1,
#   '挺大': 1,
#   '更': 1,
#   '方便': 1,
#   '杠杠': 1,
#   '挺': 1,
#   '行': 1,
#   '很漂亮': 1,
#   '加长': 1,
#   '森林': 1,
#   '高点': 1,
#   '胜出': 1,
#   '很多': 1,
#   '理想': 1,
#   '后备箱': 1,
#   '更大': 1,
#   '说': 1,
#   '/': 1,
#   '后座': 1,
#   '宽': 1,
#   '坐姿': 1,
#   '好点': 1,
#   '太': 1,
#   '诱惑': 1,
#   '中控台': 1,
#   '车': 1,
#   '蛮大': 1,
#   '更好': 1},
#  '外观': {'差点': -1,
#   '硬': -1,
#   '变色': -1,
#   '丑': -1,
#   '薄': -1,
#   '好看': 0,
#   '屁股': -1,
#   '喜欢': 0,
#   '颜值': 0,
#   '差': -1,
#   '难看': -1,
#   '中庸': -1,
#   '接受度': -1,
#   '不高': -1,
#   '老气': -1,
#   '挫': -1,
#   '取消': -1,
#   '掰': -1,
#   '不动': -1,
#   '纠结': 0,
#   '硬伤': -1,
#   '很多': -1,
#   '倾斜': -1,
#   '里外': -1,
#   '摇晃': -1,
#   '平庸': -1,
#   '越丑': -1,
#   '符合': -1,
#   '协调': 0,
#   '真': 0,
#   '好': 0,
#   '外观': 0,
#   '没有': -1,
#   '丝毫': -1,
#   '质感': -1,
#   '奇丑无比': -1,
#   '太小': -1,
#   '气': -1,
#   '太丑': -1,
#   '挫样': -1,
#   '接受': -1,
#   '不了': -1,
#   '廉价': -1,
#   '软': -1,
#   '不敢恭维': -1,
#   '有点': -1,
#   '土': -1,
#   '现款': -1,
#   '无力': -1,
#   '吐槽': -1,
#   '觉得': 0,
#   '19': -1,
#   '款': -1,
#   '老款': -1,
#   '新潮': -1,
#   '拼凑': -1,
#   '杀马特': -1,
#   '尾灯': -1,
#   '好丑': -1,
#   '史上': -1,
#   '车漆': -1,
#   '平淡无奇': -1,
#   '无比': -1,
#   '毁': -1,
#   '日系车': -1,
#   '漆软': -1,
#   '真软': -1,
#   '前脸': 0,
#   '无爱': -1,
#   '镀铬': -1,
#   '太': -1,
#   '尴尬': -1,
#   '漆面': -1,
#   '太薄': -1,
#   '不像': -1,
#   '换代': -1,
#   '应有': -1,
#   '水平': -1,
#   '多丑': -1,
#   '不怎么': -1,
#   '中网': -1,
#   '低级': -1,
#   '下限': -1,
#   '在意': 0,
#   '普通': 0,
#   '凶狠': 0,
#   '前': 0,
#   '脸': 0,
#   '高配': 0,
#   '不在意': 0,
#   '无所谓': 0,
#   '性价比': 1,
#   '逼格': 1,
#   '高': 1,
#   '特别': 1,
#   '迷恋': 1,
#   '认可度': 1,
#   '尊贵': 1,
#   '挺': 1,
#   '炫': 1,
#   '要求': 1,
#   '一致': 1,
#   '时尚': 1,
#   '大改': 1,
#   '大气': 1,
#   '生猛': 1,
#   '作用': 1,
#   '降低': 1,
#   '高度': 1,
#   '口味': 1,
#   '看中': 1,
#   '不错': 1,
#   '视野': 1,
#   '底盘': 1,
#   '厉害': 1,
#   '漂亮': 1,
#   '合眼': 1,
#   '缘': 1,
#   '外形': 1,
#   '一个': 1,
#   '档次': 1,
#   '隐隐': 1,
#   '豪华车': 1,
#   '感觉': 1,
#   '真心': 1,
#   '赞': 1,
#   '车': 1,
#   '一次': 1,
#   '没修过': 1,
#   '秀气': 1,
#   '秒杀': 1,
#   '厚': 1,
#   '强化': 1,
#   '硬朗': 1,
#   '确实': 1,
#   '点': 1,
#   '颜色': 1,
#   '光线': 1,
#   '看着': 1,
#   '舒服': 1,
#   '耐看': 1,
#   '中规中矩': 1,
#   '至少': 1,
#   '新款': 1,
#   '低调': 1,
#   '这种': 1,
#   '设计': 1,
#   '精致': 1,
#   '更好': 1,
#   '森': 1,
#   '保持': 1,
#   '偏硬': 1,
#   '造型': 1,
#   '吊打': 1,
#   '面子': 1,
#   '个人': 1,
#   '比较': 1,
#   '帅气': 1,
#   '社会': 1,
#   '前网': 1,
#   '辨识': 1,
#   '度': 1,
#   '厚重': 1,
#   '真的': 1}}

# %%
x_vecs = []
x_test_vecs = []  
ind = 0
word2ind = {}
pretrained = []
senti_sen = []
senti_test_sen = []
for i in range(len(test_content) + len(content)):
    if i < len(content):
        temp = []
        t_s = []
        for j in range(len(sentences[i])):
            if sentences[i][j] not in word2ind:
                pretrained.append(model[sentences[i][j]])
                word2ind[sentences[i][j]] = ind
                ind += 1
            t_s.append(sentences[i][j])
            temp.append(model[sentences[i][j]])
        while len(temp) < 50:
            temp.append([0.0] * 100)
        if len(temp) > 50:
            temp = temp[:50]
        x_vecs.append(temp)
        senti_sen.append(t_s[:50])
    else:
        temp = []
        t_s = []
        for j in range(len(sentences[i])):
            if sentences[i][j] not in word2ind:
                pretrained.append(model[sentences[i][j]])
                word2ind[sentences[i][j]] = ind
                ind += 1
            t_s.append(sentences[i][j])
            temp.append(model[sentences[i][j]])
        while len(temp) < 50:
            temp.append([0.0] * 100)
        if len(temp) > 50:
            temp = temp[:50]
        x_test_vecs.append(temp)
        senti_test_sen.append(t_s[:50])     
x_vecs = np.array(x_vecs)
x_test_vecs = np.array(x_test_vecs)
print(x_vecs.shape, x_test_vecs.shape)
# Out:
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:18: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:30: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# (8290, 50, 100) (2364, 50, 100)

# %%
x_sent_vecs = {}
x_test_sent_vecs = {}
for key in senti_word_set:
    x_sent_vecs[key] = []
    x_test_sent_vecs[key] = []
    for i in range(len(content) + len(test_content)):
        if i < len(content):
            t_sent = []
            for j in range(len(sentences[i])):
                if sentences[i][j] in senti_word_set[key]:
                    t_sent.append(senti_word_set[key][sentences[i][j]])
                else:
                    t_sent.append(0) 
            while len(t_sent) < 50:
                t_sent.append(0)
            if len(t_sent) > 50:
                t_sent = t_sent[:50]
            x_sent_vecs[key].append(t_sent)
        else:
            t_sent = []
            for j in range(len(sentences[i])):
                if sentences[i][j] in senti_word_set[key]:
                    t_sent.append(senti_word_set[key][sentences[i][j]])
                else:
                    t_sent.append(0) 
            while len(t_sent) < 50:
                t_sent.append(0)
            if len(t_sent) > 50:
                t_sent = t_sent[:50]
            x_test_sent_vecs[key].append(t_sent)

# %%
#va, content_vecs, y
pretrained.append([0.0] * 100)
word2ind['null'] = 17387
ind2word = {}
for key in word2ind:
    ind2word[word2ind[key]] = key
map_ = ['-1', '0', '1', '2']
sub_set = {}
for i in range(len(subs)):
    subjs = subs[i].split(',')
    sentis = sentiments[i].split(',')
    for j in range(len(subjs)):
        if subjs[j] not in sub_set:
            sub_set[subjs[j]] = []
        if sentis[j] == '2':
            sub_set[subjs[j]].append(0)
        else:
            sub_set[subjs[j]].append(1)
        #sub_set[subjs[j]].append(map_.index(sentis[j]))

# %%
pretrained = np.array(pretrained)
han_x = []
for i in range(len(senti_sen)):
    temp = []
    for j in range(len(senti_sen[i])):
        temp.append(word2ind[senti_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x.append(temp)
han_x = np.array(han_x)

han_x_test = []
for i in range(len(senti_test_sen)):
    temp = []
    for j in range(len(senti_test_sen[i])):
        temp.append(word2ind[senti_test_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x_test.append(temp)
han_x = np.array(han_x)
han_x_test = np.array(han_x_test)

# %%
data = pd.read_csv('../../../data/df_sen_sub/merge_train.csv')
set_ind = []
for i in range(len(data)):
    senti = int(str(data.loc[i,'sentiments']).split(',')[0]) #0:价格
    if senti != 2:
        set_ind.append(i)

# %%
x_vecs = []
x_test_vecs = []  
ind = 0
senti_sen = []
senti_test_sen = []
for i in range(len(content)):
    if i not in set_ind:
        continue
    temp = []
    t_s = []
    for j in range(len(sentences[i])):
        if sentences[i][j] not in word2ind:
            ind += 1
        t_s.append(sentences[i][j])
        temp.append(model[sentences[i][j]])
    while len(temp) < 50:
        temp.append([0.0] * 100)
    if len(temp) > 50:
        temp = temp[:50]
    x_vecs.append(temp)
    senti_sen.append(t_s[:50])
x_vecs = np.array(x_vecs)
# Out:
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
x_sent_vecs = {}
for key in senti_word_set:
    x_sent_vecs[key] = []
    for i in range(len(content)):
        if i not in set_ind:
            continue
        t_sent = []
        for j in range(len(sentences[i])):
            if sentences[i][j] in senti_word_set[key]:
                t_sent.append(senti_word_set[key][sentences[i][j]])
            else:
                t_sent.append(0) 
        while len(t_sent) < 50:
            t_sent.append(0)
        if len(t_sent) > 50:
            t_sent = t_sent[:50]
        x_sent_vecs[key].append(t_sent)

# %%
map_ = ['-1', '0', '1']
sub_set = {}
for i in range(len(subs)):
    if i not in set_ind:
        continue
    subjs = subs[i].split(',')
    sentis = sentiments[i].split(',')
    for j in range(len(subjs)):
        if subjs[j] != '价格':continue
        if subjs[j] not in sub_set:
            sub_set[subjs[j]] = []
        sub_set[subjs[j]].append(map_.index(sentis[j]))

# %%
han_x = []
print(len(senti_sen))
for i in range(len(senti_sen)):
    temp = []
    for j in range(len(senti_sen[i])):
        temp.append(word2ind[senti_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x.append(temp)
han_x = np.array(han_x)
print(han_x.shape)
# Out:
# 1273
# (1273, 50)

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import torch.nn as nn
import torch.nn.functional as F

# %%
X_train, X_test, y_train, y_test = train_test_split(han_x,sub_set['价格'], test_size=0.2, random_state=7)

# %%
real_text = []
for i in range(len(X_test)):
    temp = []
    for j in range(len(X_test[i])):
        temp.append(ind2word[X_test[i][j]])
    real_text.append(''.join(temp))

# %%
embeddings = nn.Embedding(len(pretrained), 100)
pretrained_weight = np.array(pretrained)
embeddings.weight.data.copy_(torch.from_numpy(pretrained_weight))
han_x = embeddings(torch.from_numpy(han_x))

# %%
han_x = han_x.detach().numpy()
han_x.shape
# Out:
# (1273, 50, 100)

# %%
han_x = han_x.reshape(han_x.shape[0], -1)
han_x.shape
# Out:
# (1273, 5000)

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(han_x,sub_set['价格'], test_size=0.2, random_state=seed)

# %%
clf = XGBClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 78.04%

# %%
from sklearn.externals import joblib #jbolib模块

#保存Model(注:save文件夹要预先建立，否则会报错)
joblib.dump(clf, '价格.pkl')
# Out:
# ['价格.pkl']

# %%
res = predictions
ll = y_test
'''
for zz in range(len(res)):
    set_ = {'价格合适','便宜','实在','价格便','价格不贵','价格不高','价格不多','价钱不贵','价钱不高','价钱不多','良心','性价比高'}
    for k in set_:
        if k in real_text[zz]:
            res[zz] = 2
            #print(real_text[zz].split('null')[0], res[zz], ll[zz])
            break
    set_ = {'小贵','更贵','价格不合适','价格贵','价钱贵','价格高','价钱高','价钱多','不值','不合适','性价比低','性价比不高'}
    for k in set_:
        if k in real_text[zz]:
            res[zz] = 0
            #print(real_text[zz].split('null')[0], res[zz], ll[zz])
            break
'''
correct, total = 0, 0
for h in range(len(res)):
    total += 1
    if res[h] == ll[h]:
        correct += 1
    else:
        print(real_text[h].split('null')[0], res[h] - 1, ll[h] - 1)

print('after change result of accuracy is : %d %%' % (100 * correct / total))
# Out:
# 傲虎纠结森林人和傲虎最终傲虎家里傲虎开几年森林感觉好最后新购车纠结傲虎森林价格有点尴尬……eyesight 0 -1
# 喜欢难取舍价格高年限长难取舍 0 -1
# 国内轮胎品牌比较准备价位一般来说声音越价格高些 0 -1
# 傲虎内饰好看高科技感觉强于森林森林操控舒服傲虎贵点手头资金当初纠结傲虎森林傲虎内饰吸引傲虎行李架实在丑陋逼外貌协会选了小森小森便宜 0 -1
# 额价钱高算了提途观上海优惠完裸车13万 0 -1
# 小森已经老婆抢走准备弄台马三备用代步小巧漂亮便宜担心内饰污染装配工艺国产钢材强度合资真的实惠 0 1
# 没保值率低二手车价格挺高 0 -1
# 渠道想价格太高经济渠道私信聊聊 0 -1
# 森林机械性能crv强crv配置性价比森林人好买车需要crv新车估计加价提车免不了前期上市新crv性价比不高 1 -1
# 楼主你好了解一辆二手车价格低以后维修新车维修价格 0 -1
# 一直好看性价比不高贵 0 -1
# 现在改通风价格太高买一个通风座垫不错蓝爽300 0 -1
# 原厂压根没有玩意森是岛国原产原装进口过来存在简配美版森没有功能儿子改装唯一好处破线影响整车质保会开具加装设备发票这点不用担心缺点价格贵出保后改装价格低破线存在质保 0 -1
# 起码超车利索价格不减下来想转crv 0 -1
# 操控犹如宝马价格更便宜 0 1
# 飞歌款运行内存好像1G价格千多个人意见别买 0 -1
# 离得太远其实价格 秋季换胎打算换G012 0 1
# 1213森12卖可能少13价格可能楼主合适慢慢碰推荐12森硬件配置一点没降13内饰好很多车配置低很多 0 -1
# 参考之前驰鹏价格估计不会便宜 0 -1
# 想市区操控三十万绝对不会选森林不值价市区好四驱系统干什么空间要求不太高选Q3⃣️GLA2.0T途L强哥们不要密念价位纯进口没想象好 0 -1
# 今天去试车车是好车价格坚挺知道价格买 0 -1
# 楼主我订价格差不多可惜有没有算一下上路价里面好像4S店黑四千多牌费刚刚交订金 0 -1
# 认证年买个车平心而论斯巴鲁开过最好车很多人不买是因为懂斯巴鲁真正懂稍微贵点入手卖车商肯定价格低会说这车不行保有量少不好卖这是车商伎俩 0 1
# 没说原车导航楼主4s店加装歌乐导航查查价格品质已经良心说歌乐出导航孤落寡闻 0 1
# 买马上过年价格会涨回去 0 1
# 25万厉害的哥佩服 0 -1
# 近期刚绍兴斯巴鲁4S保养回来维修处个人低头玩手机一付爱理不理样子配件价格保养价格奇高下去害车 0 -1
# 提车时仔细检查一下价格再磨一磨七月初买四月生产觉得进口车三个月算是比较合理七个月略长车况OK价格便宜问题 0 1
# 优惠力度 0 1
# 选喜欢森林性价比不算高毕竟一纯进口关税贵 0 -1
# 价格抢钱买彭斯PUP跟着玩意便宜太 0 -1
# 恭喜恭喜优惠不错 0 1
# 喜欢19款森林想想可能放弃.小众.保养麻烦贵.后续配件难找.外观太丑尺寸特别宽度不足.售价明显高于竞品.凤毛麟角倒闭4s店.可能烧机油发动机 0 -1
# 保养价格做买机油滤清器材料找修理店做大概4s一半多点空气滤清器空调滤清器买换便宜几十搞定 0 1
# 一是产量单价高二是费油存量太少150毫升三机舱里走管子不好走 0 -1
# 肯定北方价格南方便宜一万多样子 0 1
# 一定可能本来发动机会磨损机油好一点全合成磨损EJ维俢换活塞环非常成熟价格贵换个修理包20万公里 0 1
# 前几天车友群里装说不错我装大包围不到一年鼓起来贴合不紧说压进去贴合应该会好价格貌似贵说好像1700左右 0 -1
# 好好价格太贵 0 -1
# 恭喜楼主说实话这辆车不合算2018款低配2017特装款没有区别价格高买真的2018款2.5排量 0 -1
# 看到有点贵（路边小店4s便宜点）知道活活好正常下次事先问清楚价格比较好 0 -1
# 美丰磐石盘金麒麟片实惠好用 0 1
# 13款2.5我换马牌cccuhp操控湿滑好静音不错关键便宜830一条 0 1
# 打算买一台2.5现在纠结三点16款即将面临换代同样担心烧机油车子今后开时间长易损配件价格高不太好转手 0 -1
# K5轮毂屌丝气质目前车内饰空间坐进去放松没有2T太贵太贵太贵 0 -1
# 配件价格高很多人爱森不敢买之前论坛说配件天价灯挡风玻璃贵基本等级合资车价格三倍 1 -1
# 价格贵1314款2.5容易烧机油 0 -1
# 便宜价格真心不错最好找个懂帮看看会更好 0 1
# 山东威海全系优惠3000MD 0 -1
# 15价格精品车况值 0 1
# 没有了解清楚直接手反正买心里挺热火这车总感觉价格不好谈 0 -1
# 希望绕道欧蓝德便宜四驱无敌质量杠杠滴 0 1
# 要说款车子当中配置性价比最高这款车子中乞丐版配置够用价格最低. 0 1
# 提价优惠降价不要想 0 -1
# 汽配汽修专门汽车钥匙地方估计要收400左右同行收成本价格算起来便宜很多 0 1
# 安全性操控森林性价比奇骏…毕竟便宜很多… 0 1
# after change result of accuracy is : 78 %
