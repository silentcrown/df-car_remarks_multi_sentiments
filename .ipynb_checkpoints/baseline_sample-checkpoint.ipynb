# %%
import pandas as pd
import numpy as np
import torchvision as tv
import jieba
from gensim import models
from gensim.models import Word2Vec
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
import torch
show = ToPILImage() # 可以把Tensor转成Image，方便可视化
from sklearn.model_selection import train_test_split

# %%
'''
data = pd.read_csv('../../data/df_sen_sub/train.csv')
len(data['content_id'].unique()), len(list(data['content_id']))
content_ids = data['content_id'].unique()
subjs = data['subject'].unique()
df = {}
text, subs, sentis = [], [], []
for i in range(len(content_ids)):
    if i % 100 == 0:print(i)
    dd = data[data['content_id'] == content_ids[i]]
    text.append(dd.loc[dd.index.tolist()[0], 'content'])
    temp_subs, temp_senti = [], []
    for sub in subjs:
        temp_subs.append(sub)
        if len(dd[dd['subject'] == sub]) != 0:
            temp_senti.append(str(int(dd[dd['subject'] == sub]['sentiment_value'])))
        else:
            temp_senti.append('2')
    subs.append(','.join(temp_subs))
    sentis.append(','.join(temp_senti))
df['content'] = text
df['subjects'] = subs
df['sentiments'] = sentis
df = pd.DataFrame(df)
df.to_csv('../../data/df_sen_sub/merge_train.csv', index = False)
#data = pd.read_csv('../../data/df_sen_sub/test_public.csv')
'''
# Out:
# "\ndata = pd.read_csv('../../data/df_sen_sub/train.csv')\nlen(data['content_id'].unique()), len(list(data['content_id']))\ncontent_ids = data['content_id'].unique()\nsubjs = data['subject'].unique()\ndf = {}\ntext, subs, sentis = [], [], []\nfor i in range(len(content_ids)):\n    if i % 100 == 0:print(i)\n    dd = data[data['content_id'] == content_ids[i]]\n    text.append(dd.loc[dd.index.tolist()[0], 'content'])\n    temp_subs, temp_senti = [], []\n    for sub in subjs:\n        temp_subs.append(sub)\n        if len(dd[dd['subject'] == sub]) != 0:\n            temp_senti.append(str(int(dd[dd['subject'] == sub]['sentiment_value'])))\n        else:\n            temp_senti.append('2')\n    subs.append(','.join(temp_subs))\n    sentis.append(','.join(temp_senti))\ndf['content'] = text\ndf['subjects'] = subs\ndf['sentiments'] = sentis\ndf = pd.DataFrame(df)\ndf.to_csv('../../data/df_sen_sub/merge_train.csv', index = False)\n#data = pd.read_csv('../../data/df_sen_sub/test_public.csv')\n"

# %%
data = pd.read_csv('../../data/df_sen_sub/merge_train.csv')
data = data.fillna('')
subs = list(data['subjects'])
sentiments = list(data['sentiments'])
content = list(data['content'])
test_data = pd.read_csv('../../data/df_sen_sub/test_public.csv')
test_data = test_data.fillna('')
test_content = list(test_data['content'])

# %%
with open('../../data/df_sen_sub/add_text.txt','w') as f:
    f.write('\n'.join(list(content) + list(test_content)  + list(subs)))
# 迭代器，使用jieba将句子进行分词
class Sentences(object):# 这个类可以根据实际情况重写，我已经将所有的文章进行分句，并整合到了一个文件里面
    def __init__(self, dirname):
        self.dirname = dirname # 句子所在文件，没句句子占一行
        #jieba.load_userdict("wordBase.txt") # 加载词库

    def __iter__(self):
        #for fname in os.listdir(self.dirname):
        for line in open(self.dirname):
                line = line.replace('\n', '')
                yield list(jieba.cut(line))

sentences = []
def train_word2vec(folder_path, size=100):
    global sentences
    sentences = Sentences(folder_path) #生成分词后的句子，是一个二维数组

    # size是词向量长度
    # worker是线程数量，建议与物理线程数量一致
    # min_count是指出现次数小于一定程度，就忽略，0表示不忽略
    #model = Word2Vec(sentences, size=size, workers=8, min_count=0)

    # 训练结束就将模型保存起来
    #model.save("../../data/df_sen_sub/add_word2vec_model")

# 生成50维度的词向量模型
train_word2vec("../../data/df_sen_sub/add_text.txt",100)

# 测试训练好的词向量模型，使用model[keyWord]即可获取keyword这个词的词向量
model = Word2Vec.load("../../data/df_sen_sub/add_word2vec_model")
sentences = list(sentences)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.011 seconds.
# Prefix dict has been built succesfully.

# %%
x_vecs = []
x_test_vecs = []  
ind = 0
word2ind = {}
pretrained = []
senti_sen = []
senti_test_sen = []
for i in range(len(sentences) - len(content)):
    if i < len(content):
        temp = []
        t_s = []
        for j in range(len(sentences[i])):
            if sentences[i][j] not in word2ind:
                pretrained.append(model[sentences[i][j]])
                word2ind[sentences[i][j]] = ind
                ind += 1
            t_s.append(sentences[i][j])
            temp.append(model[sentences[i][j]])
        while len(temp) < 50:
            temp.append([0.0] * 100)
        if len(temp) > 50:
            temp = temp[:50]
        x_vecs.append(temp)
        senti_sen.append(t_s[:50])
    else:
        temp = []
        t_s = []
        for j in range(len(sentences[i])):
            if sentences[i][j] not in word2ind:
                pretrained.append(model[sentences[i][j]])
                word2ind[sentences[i][j]] = ind
                ind += 1
            t_s.append(sentences[i][j])
            temp.append(model[sentences[i][j]])
        while len(temp) < 50:
            temp.append([0.0] * 100)
        if len(temp) > 50:
            temp = temp[:50]
        x_test_vecs.append(temp)
        senti_test_sen.append(t_s[:50])     
x_vecs = np.array(x_vecs)
x_test_vecs = np.array(x_test_vecs)
print(x_vecs.shape, x_test_vecs.shape)
# Out:
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:18: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:30: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# (8290, 50, 100) (2364, 50, 100)

# %%
#va, content_vecs, y
pretrained.append([0.0] * 100)
word2ind['null'] = 17387
map_ = ['-1', '0', '1', '2']
sub_set = {}
for i in range(len(subs)):
    subjs = subs[i].split(',')
    sentis = sentiments[i].split(',')
    for j in range(len(subjs)):
        if subjs[j] not in sub_set:
            sub_set[subjs[j]] = []
        sub_set[subjs[j]].append(map_.index(sentis[j]))

# %%
pretrained = np.array(pretrained)
han_x = []
for i in range(len(senti_sen)):
    temp = []
    for j in range(len(senti_sen[i])):
        temp.append(word2ind[senti_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x.append(temp)
han_x = np.array(han_x)

han_x_test = []
for i in range(len(senti_test_sen)):
    temp = []
    for j in range(len(senti_test_sen[i])):
        temp.append(word2ind[senti_test_sen[i][j]])
    while len(temp) < 50:
        temp.append(17387)

    temp = temp[:50]

    han_x_test.append(temp)
han_x = np.array(han_x)
han_x_test = np.array(han_x_test)

# %%
'''
class Net(nn.Module):
    def __init__(self, pretrained, vocab_size):
        super(Net, self).__init__()
        self.bilstm = nn.LSTM(input_size = 100, hidden_size = 100, bidirectional = True) 
        #self.fc1   = nn.Linear(3750, 50) 
        #self.fc2   = nn.Linear(200, 50)
        #self.fc3   = nn.Linear(200, 50)
        #self.fc4   = nn.Linear(100, 3)
        self.fctest   = nn.Linear(200, 3)
        self.embeddings = nn.Embedding(vocab_size, 100)
        pretrained_weight = np.array(pretrained)
        self.embeddings.weight.data.copy_(torch.from_numpy(pretrained_weight))
        
    def forward(self, x, aspects): 
        x = self.embeddings(x)#batch,50,100
        #va = self.embeddings(aspects[0])
        #t_va = va.unsqueeze(0).expand(x.shape[0], x.shape[1], 100)
        output, (hn, cn) =  self.bilstm(x.float())#batch,50,200
        H, hN = output, output[:,-1,:]
        #con = torch.cat((t_va, H), 2)
        #t1 = F.max_pool2d(F.relu(con), (1, 4))
        #con = t1.view(x.size()[0], -1)
        #con = F.relu(self.fc1(con))
        #alpha = con.unsqueeze(1)
        #rr = torch.matmul(alpha,H).squeeze(1)
        #yy = torch.cat((F.relu(self.fc2(rr)), F.relu(self.fc3(hN))), 1)
        #x = self.fc4(yy)
        x  = self.fctest(hN)
        return x
    

net = Net(pretrained, len(pretrained))
print(net)
from torch import optim
criterion = nn.CrossEntropyLoss() # 交叉熵损失函数
optimizer = optim.SGD(net.parameters(), lr=0.005, momentum=0.9)
'''
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self, pretrained, vocab_size):
        super(Net, self).__init__()
        #self.rnn1 = nn.RNN(100, 100) 
        self.bilstm = nn.LSTM(input_size = 100, hidden_size = 100, bidirectional = True)
        #self.fc1   = nn.Linear(1250, 120) 
        self.fch = nn.Linear(200, 100)
        self.fcv = nn.Linear(100, 100)
        self.fcw = nn.Linear(200, 1)
        self.fcwp = nn.Linear(200,50)
        self.fcwh = nn.Linear(200,50)
        self.fc1   = nn.Linear(3750, 120) 
        self.fc2   = nn.Linear(120, 50)
        self.fc3   = nn.Linear(50, 4)
        self.embeddings = nn.Embedding(vocab_size, 100)
        pretrained_weight = np.array(pretrained)
        self.embeddings.weight.data.copy_(torch.from_numpy(pretrained_weight))
        
    def forward(self, x, aspects): 
        x = self.embeddings(x) #[4,50,100]
        batch_size = x.shape[0]
        N = x.shape[1]
        output, (hn, cn) =  self.bilstm(x.float())  #[4,50,200]
        hN = output[:,-1,:]
        va = self.embeddings(aspects[0]) #[1, 100]
        t_va = torch.matmul(torch.ones((x.shape[0],50, 1)), va)#[4, 50, 100]
        t_va = t_va.reshape((-1, 100)) #[4*50, 100]
        x = output.reshape((-1, 200)) #[4*50, 200]
        x = torch.tanh(torch.cat((self.fch(x), self.fcv(t_va)), 1))
        M = x.reshape((batch_size, N, -1)) #[4, 50, 200]
        alpha = F.softmax(self.fcw(M)).reshape((batch_size, 1, -1))#[4,50]
        rr = torch.matmul(alpha, output).reshape((batch_size, -1)) #[4, 200]
        final = torch.tanh(self.fcwh(hN) + self.fcwp(rr))
        x = self.fc3(final)   
        return x,alpha

# %%
from collections import Counter
ii = 0
import time
for key in sub_set:
    if ii == 10:
        break
    ii += 1
    #if key not in ['外观','空间']: continue
    net = Net(pretrained, len(pretrained))
    cur_max_acc = 0.0
    print(net)
    from torch import optim
    criterion = nn.CrossEntropyLoss() # 交叉熵损失函数
    optimizer = optim.Adagrad(net.parameters(), lr=0.01)#, momentum=0.9)
    train_x, test_x, train_y, test_y = train_test_split(han_x, sub_set[key], test_size=0.01, random_state=42)
    trainset = [(train_x[i], train_y[i]) for i in range(len(train_x))]
    testset = [(test_x[i], test_y[i]) for i in range(len(test_x))]
    for epoch in range(20):  
        counter = Counter(sub_set[key])
        sum_ = 0
        weight_map = {}
        for kkk in counter:
            sum_ += counter[kkk]
        for kkk in counter:
            weight_map[kkk] = sum_ /  counter[kkk]

        weights = [weight_map[ll] for xx, ll in trainset]

        from torch.utils.data.sampler import  WeightedRandomSampler
        sampler = WeightedRandomSampler(weights,\
                                        num_samples=counter[0] + counter[1] + counter[2],\
                                        replacement=True)

        trainloader = torch.utils.data.DataLoader(
                            trainset, 
                            batch_size=4,
                            #shuffle=True, 
                            sampler = sampler,
                            num_workers=2)
        testloader = torch.utils.data.DataLoader(
                            testset, 
                            batch_size=4,
                            shuffle=False, 
                            num_workers=2)
        torch.set_num_threads(8)
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):

            # 输入数据
            inputs, labels = data
            # 梯度清零
            optimizer.zero_grad()
            # forward + backward 
            va = [[word2ind[key]]]
            va = torch.from_numpy(np.array(va))
            outputs = net(inputs, va)
            loss = criterion(outputs, labels)
            loss.backward()   

            # 更新参数 
            optimizer.step()

            # 打印log信息
            # loss 是一个scalar,需要使用loss.item()来获取数值，不能使用loss[0]
            running_loss += loss.item()
            if i % 200 == 199: # 每200个batch打印一下训练状态
                print('[%d, %5d] loss: %.3f' \
                      % (epoch+1, i+1, running_loss / 200))
                running_loss = 0.0
                
        with torch.no_grad():
            correct, total = 0, 0
            for data in testloader:
                images, labels = data
                va = [[word2ind[key]]]
                va = torch.from_numpy(np.array(va))
                outputs = net(images,va)
                _, predicted = torch.max(outputs, 1)
                #import ipdb;ipdb.set_trace()
                #res = res + [map_[int(predicted[i])] for i in range(len(predicted))]
                total += labels.size(0)
                correct += (predicted == labels).sum()
            if cur_max_acc < float(100 * correct / total):
                print('-------------cur max is ::::----------'+str(float(100 * correct / total)))
                cur_max_acc = float(100 * correct / total)
                torch.save(net, 'result+++/net' + key + '.pkl')  # 保存整个网络
            print('result of epoch ' + str(epoch) + 'accuracy is : %d %%' % (100 * correct / total))

    print('key' + key)
    #net2 = torch.load('net.pkl')
    #prediction = net2(x)
    print('Finished Training')
# Out:
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:73: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# [1,   200] loss: 1.421
# -------------cur max is ::::----------14.0
# result of epoch 0accuracy is : 14 %
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# [2,   200] loss: 1.300
# -------------cur max is ::::----------74.0
# result of epoch 1accuracy is : 74 %
# [3,   200] loss: 1.058
# -------------cur max is ::::----------77.0
# result of epoch 2accuracy is : 77 %
# [4,   200] loss: 0.980
# -------------cur max is ::::----------93.0
# result of epoch 3accuracy is : 93 %
# [5,   200] loss: 0.862
# result of epoch 4accuracy is : 85 %
# [6,   200] loss: 0.779
# result of epoch 5accuracy is : 81 %
# [7,   200] loss: 0.736
# result of epoch 6accuracy is : 86 %
# [8,   200] loss: 0.611
# result of epoch 7accuracy is : 86 %
# [9,   200] loss: 0.501
# result of epoch 8accuracy is : 89 %
# [10,   200] loss: 0.383
# result of epoch 9accuracy is : 90 %
# [11,   200] loss: 0.327
# result of epoch 10accuracy is : 90 %
# [12,   200] loss: 0.277
# result of epoch 11accuracy is : 89 %
# [13,   200] loss: 0.277
# result of epoch 12accuracy is : 89 %
# [14,   200] loss: 0.179
# result of epoch 13accuracy is : 90 %
# [15,   200] loss: 0.189
# result of epoch 14accuracy is : 91 %
# [16,   200] loss: 0.165
# result of epoch 15accuracy is : 87 %
# [17,   200] loss: 0.163
# result of epoch 16accuracy is : 90 %
# [18,   200] loss: 0.133
# result of epoch 17accuracy is : 74 %
# [19,   200] loss: 0.125
# result of epoch 18accuracy is : 90 %
# [20,   200] loss: 0.103
# result of epoch 19accuracy is : 90 %
# key价格
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# [1,   200] loss: 1.415
# -------------cur max is ::::----------18.0
# result of epoch 0accuracy is : 18 %
# [2,   200] loss: 1.388
# result of epoch 1accuracy is : 3 %
# [3,   200] loss: 1.323
# result of epoch 2accuracy is : 12 %
# [4,   200] loss: 1.207
# -------------cur max is ::::----------65.0
# result of epoch 3accuracy is : 65 %
# [5,   200] loss: 1.069
# -------------cur max is ::::----------72.0
# result of epoch 4accuracy is : 72 %
# [6,   200] loss: 0.969
# -------------cur max is ::::----------90.0
# result of epoch 5accuracy is : 90 %
# [7,   200] loss: 0.874
# result of epoch 6accuracy is : 84 %
# [8,   200] loss: 0.845
# result of epoch 7accuracy is : 89 %
# [9,   200] loss: 0.726
# result of epoch 8accuracy is : 87 %
# [10,   200] loss: 0.641
# result of epoch 9accuracy is : 90 %
# [11,   200] loss: 0.576
# -------------cur max is ::::----------91.0
# result of epoch 10accuracy is : 91 %
# [12,   200] loss: 0.506
# -------------cur max is ::::----------92.0
# result of epoch 11accuracy is : 92 %
# [13,   200] loss: 0.451
# result of epoch 12accuracy is : 91 %
# [14,   200] loss: 0.402
# result of epoch 13accuracy is : 92 %
# [15,   200] loss: 0.339
# result of epoch 14accuracy is : 92 %
# [16,   200] loss: 0.291
# result of epoch 15accuracy is : 92 %
# [17,   200] loss: 0.247
# result of epoch 16accuracy is : 92 %
# [18,   200] loss: 0.222
# result of epoch 17accuracy is : 91 %
# [19,   200] loss: 0.205
# result of epoch 18accuracy is : 77 %
# [20,   200] loss: 0.197
# -------------cur max is ::::----------93.0
# result of epoch 19accuracy is : 93 %
# key配置
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# [1,   200] loss: 1.373
# -------------cur max is ::::----------56.0
# result of epoch 0accuracy is : 56 %
# [2,   200] loss: 1.260
# -------------cur max is ::::----------69.0
# result of epoch 1accuracy is : 69 %
# [3,   200] loss: 1.179
# -------------cur max is ::::----------72.0
# result of epoch 2accuracy is : 72 %
# [4,   200] loss: 1.114
# result of epoch 3accuracy is : 72 %
# [5,   200] loss: 0.976
# -------------cur max is ::::----------78.0
# result of epoch 4accuracy is : 78 %
# [6,   200] loss: 0.949
# result of epoch 5accuracy is : 78 %
# [7,   200] loss: 0.901
# -------------cur max is ::::----------81.0
# result of epoch 6accuracy is : 81 %
# [8,   200] loss: 0.812
# -------------cur max is ::::----------84.0
# result of epoch 7accuracy is : 84 %
# [9,   200] loss: 0.755
# result of epoch 8accuracy is : 84 %
# [10,   200] loss: 0.568
# result of epoch 9accuracy is : 79 %
# [11,   200] loss: 0.518
# result of epoch 10accuracy is : 81 %
# [12,   200] loss: 0.437
# result of epoch 11accuracy is : 80 %
# [13,   200] loss: 0.359
# result of epoch 12accuracy is : 81 %
# [14,   200] loss: 0.318
# result of epoch 13accuracy is : 80 %
# [15,   200] loss: 0.261
# result of epoch 14accuracy is : 81 %
# [16,   200] loss: 0.223
# result of epoch 15accuracy is : 83 %
# [17,   200] loss: 0.208
# result of epoch 16accuracy is : 79 %
# [18,   200] loss: 0.211
# result of epoch 17accuracy is : 83 %
# [19,   200] loss: 0.186
# result of epoch 18accuracy is : 84 %
# [20,   200] loss: 0.196
# -------------cur max is ::::----------85.0
# result of epoch 19accuracy is : 85 %
# key操控
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# [1,   200] loss: 1.407
# -------------cur max is ::::----------7.0
# result of epoch 0accuracy is : 7 %
# [2,   200] loss: 1.332
# -------------cur max is ::::----------37.0
# result of epoch 1accuracy is : 37 %
# [3,   200] loss: 1.261
# result of epoch 2accuracy is : 20 %
# [4,   200] loss: 1.222
# -------------cur max is ::::----------56.0
# result of epoch 3accuracy is : 56 %
# [5,   200] loss: 1.072
# result of epoch 4accuracy is : 43 %
# [6,   200] loss: 0.895
# result of epoch 5accuracy is : 53 %
# [7,   200] loss: 0.767
# -------------cur max is ::::----------79.0
# result of epoch 6accuracy is : 79 %
# [8,   200] loss: 0.666
# result of epoch 7accuracy is : 67 %
# [9,   200] loss: 0.627
# -------------cur max is ::::----------80.0
# result of epoch 8accuracy is : 80 %
# [10,   200] loss: 0.560
# result of epoch 9accuracy is : 77 %
# [11,   200] loss: 0.517
# -------------cur max is ::::----------85.0
# result of epoch 10accuracy is : 85 %
# [12,   200] loss: 0.436
# result of epoch 11accuracy is : 80 %
# [13,   200] loss: 0.384
# result of epoch 12accuracy is : 85 %
# [14,   200] loss: 0.332
# result of epoch 13accuracy is : 78 %
# [15,   200] loss: 0.291
# result of epoch 14accuracy is : 79 %
# [16,   200] loss: 0.281
# -------------cur max is ::::----------87.0
# result of epoch 15accuracy is : 87 %
# [17,   200] loss: 0.271
# result of epoch 16accuracy is : 81 %
# [18,   200] loss: 0.231
# result of epoch 17accuracy is : 87 %
# [19,   200] loss: 0.212
# result of epoch 18accuracy is : 87 %
# [20,   200] loss: 0.163
# result of epoch 19accuracy is : 87 %
# key舒适性
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# [1,   200] loss: 1.381
# -------------cur max is ::::----------91.0
# result of epoch 0accuracy is : 91 %
# [2,   200] loss: 1.064
# result of epoch 1accuracy is : 85 %
# [3,   200] loss: 0.981
# result of epoch 2accuracy is : 77 %
# [4,   200] loss: 0.943
# result of epoch 3accuracy is : 90 %
# [5,   200] loss: 0.768
# -------------cur max is ::::----------92.0
# result of epoch 4accuracy is : 92 %
# [6,   200] loss: 0.742
# result of epoch 5accuracy is : 90 %
# [7,   200] loss: 0.625
# result of epoch 6accuracy is : 92 %
# [8,   200] loss: 0.523
# result of epoch 7accuracy is : 90 %
# [9,   200] loss: 0.456
# -------------cur max is ::::----------95.0
# result of epoch 8accuracy is : 95 %
# [10,   200] loss: 0.380
# -------------cur max is ::::----------97.0
# result of epoch 9accuracy is : 97 %
# [11,   200] loss: 0.293
# result of epoch 10accuracy is : 93 %
# [12,   200] loss: 0.281
# result of epoch 11accuracy is : 95 %
# [13,   200] loss: 0.215
# -------------cur max is ::::----------98.0
# result of epoch 12accuracy is : 98 %
# [14,   200] loss: 0.207
# result of epoch 13accuracy is : 98 %
# [15,   200] loss: 0.173
# result of epoch 14accuracy is : 98 %
# [16,   200] loss: 0.166
# -------------cur max is ::::----------100.0
# result of epoch 15accuracy is : 100 %
# [17,   200] loss: 0.162
# result of epoch 16accuracy is : 96 %
# [18,   200] loss: 0.126
# result of epoch 17accuracy is : 98 %
# [19,   200] loss: 0.139
# result of epoch 18accuracy is : 98 %
# [20,   200] loss: 0.148
# result of epoch 19accuracy is : 98 %
# key油耗
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# [1,   200] loss: 1.404
# [1,   400] loss: 1.266
# [1,   600] loss: 1.198
# -------------cur max is ::::----------74.0
# result of epoch 0accuracy is : 74 %
# [2,   200] loss: 1.131
# [2,   400] loss: 1.094
# [2,   600] loss: 1.001
# result of epoch 1accuracy is : 66 %
# [3,   200] loss: 0.994
# [3,   400] loss: 0.944
# [3,   600] loss: 0.949
# -------------cur max is ::::----------79.0
# result of epoch 2accuracy is : 79 %
# [4,   200] loss: 0.903
# [4,   400] loss: 0.918
# [4,   600] loss: 0.845
# result of epoch 3accuracy is : 74 %
# [5,   200] loss: 0.781
# [5,   400] loss: 0.777
# [5,   600] loss: 0.743
# result of epoch 4accuracy is : 73 %
# [6,   200] loss: 0.605
# [6,   400] loss: 0.649
# [6,   600] loss: 0.574
# result of epoch 5accuracy is : 78 %
# [7,   200] loss: 0.533
# [7,   400] loss: 0.588
# [7,   600] loss: 0.472
# result of epoch 6accuracy is : 79 %
# [8,   200] loss: 0.442
# [8,   400] loss: 0.404
# [8,   600] loss: 0.390
# -------------cur max is ::::----------80.0
# result of epoch 7accuracy is : 80 %
# [9,   200] loss: 0.335
# [9,   400] loss: 0.330
# [9,   600] loss: 0.351
# result of epoch 8accuracy is : 77 %
# [10,   200] loss: 0.327
# [10,   400] loss: 0.319
# [10,   600] loss: 0.274
# result of epoch 9accuracy is : 77 %
# [11,   200] loss: 0.322
# [11,   400] loss: 0.244
# [11,   600] loss: 0.262
# result of epoch 10accuracy is : 77 %
# [12,   200] loss: 0.240
# [12,   400] loss: 0.262
# [12,   600] loss: 0.251
# result of epoch 11accuracy is : 78 %
# [13,   200] loss: 0.244
# [13,   400] loss: 0.221
# [13,   600] loss: 0.246
# result of epoch 12accuracy is : 77 %
# [14,   200] loss: 0.196
# [14,   400] loss: 0.155
# [14,   600] loss: 0.203
# result of epoch 13accuracy is : 78 %
# [15,   200] loss: 0.187
# [15,   400] loss: 0.136
# [15,   600] loss: 0.179
# result of epoch 14accuracy is : 79 %
# [16,   200] loss: 0.152
# [16,   400] loss: 0.225
# [16,   600] loss: 0.194
# result of epoch 15accuracy is : 74 %
# [17,   200] loss: 0.198
# [17,   400] loss: 0.163
# [17,   600] loss: 0.127
# result of epoch 16accuracy is : 74 %
# [18,   200] loss: 0.165
# [18,   400] loss: 0.137
# [18,   600] loss: 0.138
# result of epoch 17accuracy is : 74 %
# [19,   200] loss: 0.132
# [19,   400] loss: 0.145
# [19,   600] loss: 0.164
# result of epoch 18accuracy is : 77 %
# [20,   200] loss: 0.122
# [20,   400] loss: 0.139
# [20,   600] loss: 0.111
# result of epoch 19accuracy is : 75 %
# key动力
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# -------------cur max is ::::----------2.0
# result of epoch 0accuracy is : 2 %
# -------------cur max is ::::----------91.0
# result of epoch 1accuracy is : 91 %
# result of epoch 2accuracy is : 71 %
# result of epoch 3accuracy is : 78 %
# result of epoch 4accuracy is : 90 %
# result of epoch 5accuracy is : 89 %
# -------------cur max is ::::----------93.0
# result of epoch 6accuracy is : 93 %
# -------------cur max is ::::----------95.0
# result of epoch 7accuracy is : 95 %
# -------------cur max is ::::----------97.0
# result of epoch 8accuracy is : 97 %
# result of epoch 9accuracy is : 97 %
# result of epoch 10accuracy is : 93 %
# result of epoch 11accuracy is : 96 %
# -------------cur max is ::::----------98.0
# result of epoch 12accuracy is : 98 %
# result of epoch 13accuracy is : 92 %
# result of epoch 14accuracy is : 95 %
# result of epoch 15accuracy is : 95 %
# result of epoch 16accuracy is : 93 %
# result of epoch 17accuracy is : 95 %
# result of epoch 18accuracy is : 98 %
# result of epoch 19accuracy is : 95 %
# key内饰
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# -------------cur max is ::::----------3.0
# result of epoch 0accuracy is : 3 %
# -------------cur max is ::::----------39.0
# result of epoch 1accuracy is : 39 %
# -------------cur max is ::::----------63.0
# result of epoch 2accuracy is : 63 %
# -------------cur max is ::::----------67.0
# result of epoch 3accuracy is : 67 %
# result of epoch 4accuracy is : 45 %
# -------------cur max is ::::----------80.0
# result of epoch 5accuracy is : 80 %
# result of epoch 6accuracy is : 48 %
# result of epoch 7accuracy is : 43 %
# -------------cur max is ::::----------87.0
# result of epoch 8accuracy is : 87 %
# result of epoch 9accuracy is : 80 %
# result of epoch 10accuracy is : 72 %
# -------------cur max is ::::----------91.0
# result of epoch 11accuracy is : 91 %
# result of epoch 12accuracy is : 91 %
# result of epoch 13accuracy is : 67 %
# result of epoch 14accuracy is : 91 %
# result of epoch 15accuracy is : 89 %
# result of epoch 16accuracy is : 91 %
# result of epoch 17accuracy is : 91 %
# -------------cur max is ::::----------92.0
# result of epoch 18accuracy is : 92 %
# -------------cur max is ::::----------93.0
# result of epoch 19accuracy is : 93 %
# key安全性
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# -------------cur max is ::::----------61.0
# result of epoch 0accuracy is : 61 %
# -------------cur max is ::::----------62.0
# result of epoch 1accuracy is : 62 %
# -------------cur max is ::::----------67.0
# result of epoch 2accuracy is : 67 %
# -------------cur max is ::::----------78.0
# result of epoch 3accuracy is : 78 %
# -------------cur max is ::::----------93.0
# result of epoch 4accuracy is : 93 %
# result of epoch 5accuracy is : 79 %
# result of epoch 6accuracy is : 89 %
# result of epoch 7accuracy is : 91 %
# result of epoch 8accuracy is : 90 %
# result of epoch 9accuracy is : 89 %
# result of epoch 10accuracy is : 90 %
# result of epoch 11accuracy is : 93 %
# result of epoch 12accuracy is : 93 %
# result of epoch 13accuracy is : 92 %
# result of epoch 14accuracy is : 90 %
# result of epoch 15accuracy is : 92 %
# result of epoch 16accuracy is : 92 %
# result of epoch 17accuracy is : 75 %
# result of epoch 18accuracy is : 85 %
# -------------cur max is ::::----------95.0
# result of epoch 19accuracy is : 95 %
# key空间
# Finished Training
# Net(
#   (bilstm): LSTM(100, 100, bidirectional=True)
#   (fch): Linear(in_features=200, out_features=100, bias=True)
#   (fcv): Linear(in_features=100, out_features=100, bias=True)
#   (fcw): Linear(in_features=200, out_features=1, bias=True)
#   (fcwp): Linear(in_features=200, out_features=50, bias=True)
#   (fcwh): Linear(in_features=200, out_features=50, bias=True)
#   (fc1): Linear(in_features=3750, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=4, bias=True)
#   (embeddings): Embedding(19791, 100)
# )
# -------------cur max is ::::----------6.0
# result of epoch 0accuracy is : 6 %
# -------------cur max is ::::----------74.0
# result of epoch 1accuracy is : 74 %
# result of epoch 2accuracy is : 61 %
# result of epoch 3accuracy is : 40 %
# result of epoch 4accuracy is : 69 %
# result of epoch 5accuracy is : 60 %
# -------------cur max is ::::----------77.0
# result of epoch 6accuracy is : 77 %
# result of epoch 7accuracy is : 54 %
# result of epoch 8accuracy is : 60 %
# result of epoch 9accuracy is : 60 %
# result of epoch 10accuracy is : 72 %
# -------------cur max is ::::----------79.0
# result of epoch 11accuracy is : 79 %
# result of epoch 12accuracy is : 75 %
# result of epoch 13accuracy is : 69 %
# result of epoch 14accuracy is : 74 %
# result of epoch 15accuracy is : 73 %
# -------------cur max is ::::----------83.0
# result of epoch 16accuracy is : 83 %
# result of epoch 17accuracy is : 74 %
# -------------cur max is ::::----------87.0
# result of epoch 18accuracy is : 87 %
# result of epoch 19accuracy is : 80 %
# key外观
# Finished Training

# %%
import torch.nn as nn
import torch.nn.functional as F
result_set = {}
testset = han_x_test
testloader = torch.utils.data.DataLoader(
                    testset, 
                    batch_size=4,
                    shuffle=False, 
                    num_workers=2)
for key in sub_set:
    print(key)
    res = []
    with torch.no_grad():
        correct, total = 0, 0
        for data in testloader:
            images = data
            va = [[word2ind[key]]]
            va = torch.from_numpy(np.array(va))
            net = torch.load('result+++/net' + key + '.pkl')
            outputs = net(images,va)
            _, predicted = torch.max(outputs, 1)
            res = res + [map_[int(predicted[i])] for i in range(len(predicted))]
    result_set[key] = res
# Out:
# 价格
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:73: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 配置
# 操控
# 舒适性
# 油耗
# 动力
# 内饰
# 安全性
# 空间
# 外观

# %%
data = pd.read_csv('../../data/df_sen_sub/train.csv')
uni_sub = data['subject'].unique()
for key in uni_sub:
    print(key + str(len(data[data['subject'] == key])))
    ttt = data[data['subject'] == key]
    print(len(ttt[ttt['sentiment_value'] == 0]))
    print(len(ttt[ttt['sentiment_value'] == -1]))
    print(len(ttt[ttt['sentiment_value'] == 1]))
# Out:
# 价格1273
# 1014
# 145
# 114
# 配置853
# 579
# 154
# 120
# 操控1036
# 606
# 124
# 306
# 舒适性931
# 564
# 256
# 111
# 油耗1082
# 793
# 138
# 151
# 动力2732
# 1970
# 378
# 384
# 内饰536
# 271
# 150
# 115
# 安全性573
# 380
# 93
# 100
# 空间442
# 221
# 67
# 154
# 外观489
# 263
# 111
# 115

# %%
real_pred = {}
content_ids = []
subjects = []
sentiment_values = []
sentiment_words = []
contents = []
#content_id,subject,sentiment_value,sentiment_word
for i in range(len(test_data)):
    content_id = test_data.loc[i, 'content_id']
    flag = 0
    for key in result_set:
        if result_set[key][i] != '2':
            flag = 1
            content_ids.append(str(content_id))
            subjects.append(key)
            sentiment_values.append(int(result_set[key][i]))
            sentiment_words.append("")
            contents.append(str(test_data.loc[i, 'content']))
    if flag == 0:
        content_ids.append(str(content_id))
        subjects.append('动力')
        sentiment_values.append(0)
        sentiment_words.append("")   
        contents.append(str(test_data.loc[i, 'content']))
real_pred = {"content_id":content_ids, "subject":subjects, "sentiment_value":sentiment_values, "sentiment_word":sentiment_words}
real_df = pd.DataFrame(real_pred)
real_df.to_csv('result+++/final_result++.csv', encoding = "utf-8", index = False)

# %%
len(real_df), len(test_data)
# Out:
# (3333, 2364)

# %%
real_pred['content'] = contents

dtt = pd.DataFrame(real_pred)
dtt.to_csv('result+++/see_final_result++.csv', encoding = "utf-8", index = False)

# %%
len(dtt[dtt['sentiment_value'] == -1])
# Out:
# 550

# %%
dt = pd.read_csv('result++/see_final_result++.csv')
dt[dtt['sentiment_value'] == -1]
# Out:
# /home/works/dl-tools/anaconda2/envs/yxvenv/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
#             content_id subject  sentiment_value  sentiment_word  \
# 14    t01PVoDSd9Lsy5HN      配置                0             NaN
# 16    VQkjM1657sIroCf3      动力                0             NaN
# 17    1rGSYnOx9Fb2ULQX      配置                0             NaN
# 27    fYtbApDWqzGmKX8F     舒适性                0             NaN
# 28    fYtbApDWqzGmKX8F      动力                0             NaN
# 32    aV6A5z8pJRkKIC9r      内饰                0             NaN
# 36    6p8glZ2iewsInqK4     安全性                0             NaN
# 38    l94kJgMBpYoODyzQ     安全性                0             NaN
# 41    jhmIcH6LTxkGVE19     安全性                0             NaN
# 44    Q4lp0HBNfTD2xYAv      操控                0             NaN
# 45    M3Hqx1Un8ygzFTtl      动力                1             NaN
# 54    oKdBRimU38Gjc9PJ      动力                0             NaN
# 55    zsADXh4cYeUjEKSP      动力                0             NaN
# 57    hszDKcUSek9dyP5o      动力                0             NaN
# 61    5b2XhIBYPOCfMzcu      动力                0             NaN
# 69    OKVCfRJ8X9BwxaTv      动力                0             NaN
# 70    tcPLeKdDrkYG1394      动力                0             NaN
# 71    siYq5vrJBQzkuZPy      动力                0             NaN
# 74    8P6E32xNmKAebnOs      动力                0             NaN
# 75    j2vcEXIrmkH9qs1J      动力                0             NaN
# 80    v6iprjTLdctoJW3b      动力                0             NaN
# 83    Aml1h4xUJt5u6bQ9      动力                0             NaN
# 89    p0FUwsNPYQKl1HSg     安全性                0             NaN
# 104   5rBkYEyl1IU0TVhC     舒适性                0             NaN
# 115   NAC6vpWtqaTQYXD8     舒适性                0             NaN
# 118   42VhMRSsCcn85kEd      动力                0             NaN
# 123   Mglj9pKWkY7Isixm      价格                0             NaN
# 130   g27EQ5F4bMjSp9qc      价格                0             NaN
# 131   o9iwO8ChDBUTJ7YI      动力                0             NaN
# 132   o9iwO8ChDBUTJ7YI      内饰                0             NaN
# ...                ...     ...              ...             ...
# 2471  8qg3OP1AtB5Evz9a      动力                0             NaN
# 2474  4vedD3ThESw9KJxN      动力                0             NaN
# 2483  7mGsIBJAHFZ0tCz4      外观                0             NaN
# 2485  mpAEy9iwRn631sKS      动力                0             NaN
# 2487  ODEdFk6L4psH9l28      油耗                0             NaN
# 2488  5kyiUJ0LTNMVFZfq      油耗                0             NaN
# 2489  3sHOQd5VmCz6npUY      油耗                0             NaN
# 2493  4Ist9FJBkGATqYjO      价格                0             NaN
# 2497  QjFJXPzDYsV1IRWO      操控                0             NaN
# 2498  Ni0TWvFVRU8XdmtO      操控                0             NaN
# 2506  8CZDFqhGmY3HwVz0      空间                0             NaN
# 2507  41nm2EQI9BXljaDk      内饰                0             NaN
# 2508  6DWMVcopvEKwU4PJ     舒适性                0             NaN
# 2509  0gKMWbXrF2qyRTEk      操控                0             NaN
# 2510  ZfLWb4GQDRhgyvow      价格                0             NaN
# 2528  8jgDfxBpO45FWl1m      价格                0             NaN
# 2534  0m3DxdfAIcgnE4kM      动力                0             NaN
# 2540  RKZmPl1Ny5dDC42o      外观                0             NaN
# 2541  athS4JK0ClzGrYb8      配置                0             NaN
# 2543  nkNvR74fauUP9oSg      油耗                0             NaN
# 2544  7HjuWDZzSykeEOIQ      动力                0             NaN
# 2554  CqSyRtsONd1iG5BJ      油耗                0             NaN
# 2568  G5WVJdhNEr71HyBI      动力                0             NaN
# 2576  Ct5pUOgmiTQ7o3fL      油耗                0             NaN
# 2579  1qT9KYyC8el7Om4M     舒适性                0             NaN
# 2582  sNc3FPI4ZnrUgS8G      内饰                0             NaN
# 2587  j2bY7lqSH3PawNn5      价格                0             NaN
# 2588  4N70AwcexTqDCoJr      空间                0             NaN
# 2615  H6y17JaXzxADtqer      操控                0             NaN
# 2621  xSTt0OV9nYkb6NEa      动力                0             NaN
#
#                                                 content
# 14       黑屏经常发生啊和手机蓝牙，连接后电话打进来根本听不到对方在说什么，想指往导航功能就会让你上火
# 16    60肯定是不行的。 原车轮胎的直径=215*0.65*2 15*25.4（一英寸=25.4毫...
# 17                                      那你们换的什么中控呀？
# 27    坐标深圳！我开26℃都觉得凉…动力嘛真不好说每个人感受和需求不一样…车子坐4人开了空调我倒觉...
# 28    坐标深圳！我开26℃都觉得凉…动力嘛真不好说每个人感受和需求不一样…车子坐4人开了空调我倒觉...
# 32    棕色内饰挺好看，主要是新颖，经常有人问：森林人内饰还有棕色的呢？是新款吧？比以前的好看......
# 36    毫无根据的说法，森林人哪溥如纸的铁皮我也是醉了，虽然说铁皮厚和安全不划等号，但森林人哪个也太...
# 38                            我这有套力狮GT的全套刹车给你换上比你原装的要好，
# 41    科学的方法，修理厂有一种测试笔，打开刹车油壶，插入测试笔，如果灯光报警就该换了。因为刹车油是...
# 44                      从技术上来说，比亚迪的电动四驱是真正意义上的全时四驱。
# 45    我有一个朋友是玩越野的，一直不待见城市SUV的四驱性能，直到有一次一辆森林人跟着他们一起出去...
# 54                             16款还没有开出7万多公里数，估计没有人烧机油。
# 55                          任何车都有机油消耗问题，其实烧机油最多的是神车。
# 57                 我的１５款2.5精英公里数2万，机油5ｗ30，8000公里一换油，没烧。
# 61    广东倒是不担心配件问题，大把拆车件，只要车架好，发动机变速箱总成都可以搞到，大不了换，也就四...
# 69                              同意，机械手刹看着不高大上，但是就是好用
# 70                  欧蓝德超值，森林人基本没啥性价比，买森的基本就是喜欢你就不考虑性价比。
# 71                          车身结构强度较差异响此起彼伏，当它不存在吧。迟早还会响
# 74                                     比我低，我跑市区在11.6左右。
# 75                    那要是还想有一点越野能力呢？虽然森林人能玩的也是轻度越野。
# 80       这是驾驶模式 i 是默认经济模式，S 是运动超车模式，只有在多功能方向盘 右手边位置有设置~
# 83    2.0的千万别买，肉的不行。除非你只是当作非常普通的交通工具使用，代步没问题。但要开起来舒畅...
# 89                               力狮GT的刹车换上，就好了，我有一套你要吗，
# 104                           还好现在异响都是底盘上方，如果是底盘下方就不爽了。
# 115   那些纠结内饰啦，空调出风口的我还能理解。一个你开车时候根本看不到也感觉不到的排气管，这么在意...
# 118                       动力不错，但左后臂渗油，以12.88。出手。不知是否吃机油
# 123             你这个916WS导航买的不便宜吧！现在的9016S便宜得多，打算多少出？
# 130                    2年前江苏盐城4S店就是优惠现金2万以上啊?为什么不可能？
# 131              斯巴鲁报这么多问题出来 一下用劣质材料 一下用劣质质检员 才买一年可以退货不
# 132              斯巴鲁报这么多问题出来 一下用劣质材料 一下用劣质质检员 才买一年可以退货不
# ...                                                 ...
# 2471  雪地驾驶不能猛做动作，例如加减速、拐弯、变道都要轻柔，提前预判，小心前后左右的车辆。没事最好...
# 2474           你好，这个要看具体是什么发动机了，一般来说2.5L的车型的话机油在5.6L左右的
# 2483                                     20跟25在外观上终于一致了
# 2485          1、好像没有。忘了中控上的小屏是否有数字速度表这功能了。2、自动启停不能默认关闭。
# 2487  超过100 油耗飙升 一般城里快速路 50-80 是很省 本车均速25 表显8不到一点点 均...
# 2488  13款2.5，目前52000KM，平均油耗11.4， 高速最高跑出13.8.那些跑出个位数油...
# 2489           如果均速能达到35 表显平均油耗6-7是可能的比如我下班单程 路况好的话 6.8
# 2493  保养不贵了解清楚再说，至于维修费用不容易坏还考虑这个做什么 ，配件价格还可以就是等件时间长到是真的
# 2497                  北方一个小城市，离辽宁和内蒙比较近，冬天有雪，选择个全时四驱心安！
# 2498                                  底盘升起来看看，是不是传动轴那儿？
# 2506     对空间现在想想真有点需求。空间和四驱，这二点。。。蛮重要的还是预算的问题，呵呵。。。所以纠结
# 2507                                  座椅下面是低音炮，现在车型都取消了
# 2508                                       没有。夏天后排舒适性差点
# 2509                           用久了就会这样，可以调，听说很简单，在底盘下面拧
# 2510                       配件需要等，维修费用高。用买二手车的价格买个新的更好用。
# 2528                                   看的我心潮澎湃，翻到价格立马拜拜
# 2534                                    汽车之家搜，挺多的，怎么调座椅
# 2540                                  就这一堆外观件注定了不是森林人的范
# 2541                        所以买18款的还是豪华的最实在，那点配置区别不值1万。
# 2543  我目前快速路加市区综合油耗10个，纯市区就不好说了，估计不会低于15个，高速100至120公...
# 2544  斯巴鲁通病，而且每次亮的原因都不一样，可能是三元催化器，可能是氧传感器，也可能是刹车片磨完了...
# 2554                                     咱的老森4at 油耗都偏大点
# 2568                                      大哥，发动机有靠谱的卖家吗
# 2576   我说东，你说西，我说越野攀爬能力，你驴吹不对马嘴说些没用的，你怎么不说因为你纸糊车轻，油耗还低！
# 2579                                     有空调出风口的那块金属条吗？
# 2582                                     有时候我觉得是内饰松散。。。
# 2587                                        小保养6684儿子价格
# 2588  朋友现在开的斯巴鲁哪款车，还是正准备入手？我是看了xv感觉哪都挺好的，可是总是觉得空间小了，...
# 2615          有呀，哈哈。雪地里，方向盘打死，加油的话，确实抖。不过是后轮抖，但是前当的雪咋办？
# 2621  12款2.5xs  4at， 目前行驶10万公里。  这个车除了机油消耗大点， 能拉货， 能...
#
# [444 rows x 5 columns]

# %%
c = 0
change_ind = []
change_sents = []
for i in range(len(dt)):
    c_id = str(dt.loc[i, 'content_id'])
    sub = str(dt.loc[i, 'subject'])
    lin = dtt[dtt['content_id'] == c_id]
    line = lin[lin['subject'] == sub]
    if len(line) == 0:
        continue
    if str(dt.loc[i, 'sentiment_value']) == str(int(line['sentiment_value'])):
        continue
    if str(dt.loc[i, 'sentiment_value']) != '0':
        continue
    print(dt.loc[i, 'content'], sub, str(dt.loc[i, 'sentiment_value']), str(int(line['sentiment_value'])))
    change_ind.append(i)
    change_sents.append(int(line['sentiment_value']))
    c += 1
print(c)
# Out:
# 谁还用车载导航呀！用手机导航吧及时性好！而且到港后装的机头不行，在意的话建议去换一个机头顺便改一下音响。森林人及斯巴鲁全系除了2015豪华悦享版是哈卡的音响和日本原装的机头，（我买的此款 ）其他的机头和音响都不行 配置 0 -1
# 森林人导航确实垃圾。再好的车再好的导航都没有手机导航好用，我提车后只用了二个多月的车载导航就一直用手机导航。 配置 0 -1
# 导航现在都用手机的，音箱没有说的那么差，就是低音差点，人声其实还可以。 配置 0 -1
# 接孩子应该就在城区，这油耗正常的。 油耗 0 1
# 俩车排量都不行，1.5t昂科威动力不行，比2.0t还费油，你图什么？     动力 0 -1
# 我13款2.5的2w公里就用30了 。 也没见什么不妥，就是油耗高一点而已。     油耗 0 -1
# 坐标深圳！我开26℃都觉得凉…动力嘛真不好说每个人感受和需求不一样…车子坐4人开了空调我倒觉得动力没怎么减弱 舒适性 0 1
# 坐标深圳！我开26℃都觉得凉…动力嘛真不好说每个人感受和需求不一样…车子坐4人开了空调我倒觉得动力没怎么减弱 动力 0 1
# 除开这四点 森林人还有很多缺点 比如内饰做工廉价感十足 高速上了120噪音大 CVT牺牲驾驶乐趣 后排没有出风口 没有标配四门一键升窗 棒棒糖钥匙等等 不过都不重要 喜欢就好 内饰 0 -1
# 除开这四点 森林人还有很多缺点 比如内饰做工廉价感十足 高速上了120噪音大 CVT牺牲驾驶乐趣 后排没有出风口 没有标配四门一键升窗 棒棒糖钥匙等等 不过都不重要 喜欢就好 空间 0 1
# 毫无根据的说法，森林人哪溥如纸的铁皮我也是醉了，虽然说铁皮厚和安全不划等号，但森林人哪个也太没质感了    安全性 0 -1
# 我这有套力狮GT的全套刹车给你换上比你原装的要好， 安全性 0 1
# 我的是在低速或停下来慢慢踩刹车和松刹车就会响，其他情况下不会响。 森林人的刹车就是这么破，供参考。 安全性 0 -1
# 刹车片是刹车片，刹车盘是刹车盘，二哥零件额设计寿命完全不一样，刹车盘的使用寿命远比刹车片来的长很多，看看保养手册，别被4s那帮人给骗了。 安全性 0 -1
# 烧已换中缸，行驶230kg，机油温度达到103到106是还是爆震……正在交涉 动力 0 -1
# 2.0 13款 7万开始烧机油    动力 0 -1
# 16款还没有开出7万多公里数，估计没有人烧机油。 动力 0 -1
# 我的１５款2.5精英公里数2万，机油5ｗ30，8000公里一换油，没烧。 动力 0 -1
# 大多数车友几乎都烧机油，事实决定一切     动力 0 -1
# 反正我三年7万多公里。发动机杠杠的 一直级护     动力 0 1
# 额 20的森就是没故障码也是加速无力。。。 动力 0 -1
# 有一定速度后再踩到2000转是很平稳很舒服，我是等红灯起步的时候，从静止开始脚一重就瞬间两千多转了，真的头有点翘起来的，当然不是直线加速那种夸张的抬头，是有这种车头上抬的趋势     动力 0 1
# 个人喜欢银色，耐看，典雅。颜色还是要坚持第一印象吧楼主，跟着感觉走。 外观 0 -1
# 力狮GT的刹车换上，就好了，我有一套你要吗， 安全性 0 1
# 全程100公里，四个成人加行李少量，国道限速六十占了总路程四分之一，正常路况非下坡，最低单程油耗到了4.8，16款2.5排量，我还以为表坏了 油耗 0 1
# 不知道你车辆的导航是原厂大屏导航还是后来加装的大屏导航。原厂的话去4S店找他们保修，加装的话，找加装的店修理。 配置 0 -1
# 不是这个理解。原厂嗽叭是简单电容分频两分频音响系统，下面的是中低音嗽叭，仪表盘上的是高音嗽叭。因为这个高音嗽叭口径稍大一点，所以分频点取得稍低一点。不是说中音与高音合在一起，也就是说没有什么中高音同轴之说。     外观 0 -1
# 噪音方面我感觉还行，比我以前的轩逸不大，内饰味道很小，进口车品质还是不错的 舒适性 0 -1
# 2.0动力就够用，别上2.5，性价比太低了，乞丐版性价比最高，自己换个氙气大灯，完美！ 动力 0 1
# 你好，这个价格还是不错的，公里数也是正常，买回来以后注意汽车的保养就可以了，一般都是更换全车油水，检查一下车况！然后按正常使用就可以了 价格 0 -1
# CRV？   新CRV配置高哦！楼主可以选择，我只关注了两天，剎不住啊剎不住，新车出来刹车有问题就不看了。其实楼主还可以选择CX-5和荣放RAV4、奇峻 安全性 0 -1
# 谈价格，是要有点技巧的，可以，提前，做点功课，销售员，每天见得人多了，各种各样的人，所以，他们很会套路。 价格 0 -1
# 怎么都说斯巴鲁不好看了，我怎么看着不错啊 外观 0 -1
# 动力不错，但左后臂渗油，以12.88。出手。不知是否吃机油 动力 0 1
# 我没有原车导航，你问错人了吧？我一直都是用CD鸡     配置 0 -1
# 我是2.0，9295都加过，好感觉油耗上有区别，反而感觉2.5省油，2.0小马拉大车      油耗 0 -1
# 你这个916WS导航买的不便宜吧！现在的9016S便宜得多，打算多少出？    价格 0 -1
# 是有些费油，最近全国的燃油都比较有水分。同样的路同样的加油站，几乎相同的路况，油耗现在增加好多了 油耗 0 -1
# 怪不得，车整的体质量感觉还没有我原来的锋范好，不是这里响就是哪里响 舒适性 0 -1
# 斯巴鲁2014款之后就不是高田气囊 。   丰田刹不住是脚垫卡住  。   你三菱爸爸刹车失灵是真的坏了却还嘴硬  。   我不愿意被日本人干死但是也不愿意被无良国产干死，感觉你好像很愿意被干死？  。   而且你爸爸三菱不是日本鬼子？你好好笑哦~你个马甲连灵魂都没有只能卖智商价格还低一吨几毛钱     安全性 0 -1
# 2015款 2.0特装版车主，这车就不是让你在动力方面会很爽的车，有点后悔没买奥迪A4，但市区开够用，很实用的空间，过年回家俨然当面包开 动力 0 1
# 我还是挺喜欢12款的外观，有点像放小版的GLK，座椅还有灰色顶面和那些塑料感真的想换掉。2.5的排量加自然吸气真的是爽，除了内饰各方面都喜欢     内饰 0 -1
# 感觉还行吧，23万公里了，间隙大了，还有点烧机油，所以我才让机油稠一点，     动力 0 -1
# 这个可能只是一厢情愿的美好愿望而已吧，你没看到国内各种外观仿的车卖得多好？在之家这个论坛里面为数不少的rhy***受雇于各汽车商公关团队忙于各种黑，人家专注的不是内在      外观 0 -1
# 这个价格贵吗？相对合资车比较，应该差不差不多吧。不能喝BBA比。    价格 0 -1
# 除了座椅侧面开裂外 一切都正常 开着很好 内饰 0 -1
# 这颜色和银色都比较好看 外观 0 -1
# 只要空间要求没那么大，那肯定xv 空间 0 1
# 解释的不错，童年车，比你多开一万。我的加速硬币声只有在上坡且速度较慢时才有。机油灯6万只亮过一次，是因为高温天，其它问题都没有。总体还是一部好车。就盼着下雪哈哈     动力 0 1
# 在价格相差不大的情况下，能选新款的选新款，毕竟很多小功能方面的提升，还有18款的国4，16款的是国3（国4），看到时候车管所承认哪个标准 价格 0 1
# 不要烦了，2.0的够用，要动力感觉好的话当然2.5的啦 动力 0 1
# 用全合成机油，没有必要5000公里换机油，7-8000公里没问题。 动力 0 -1
# 觉着不错！森林人是我的第四辆车！除了内饰看着一般外其他都不错！我也是试驾了所有同类别车后决定的！要操控…你懂的！     内饰 0 -1
# 中控导航是建伍的话帮我订一个吧，你拆出来看，发现是国产机，并不是建伍。 配置 0 -1
# 2.0T卖的少是因为那个价格可以买更高一个级别的车了。30多万选择太多了，一般不会选斯巴鲁了。 价格 0 -1
# FB烧机油概率很大 尤其11 12的车     动力 0 -1
# SUV后排舒适性肯定没轿车商务车好 空间 0 1
# 商务车四驱不行，走烂路底盘不行，油耗比SUV只高不低。还有我实在不感冒MPV    操控 0 -1
# 我有过02年的老奥迪a6 2.4排量 v6发动机 高速6.5 森林人高速平均9个油 市区12以上 负责人的说，四驱suv肯定比两驱轿车费油。 而且我觉得全时四驱比分时四驱也费油，所以森林人油耗略高，我接受，喜欢。     动力 0 1
# 的确如此。那时候的森林人，简单粗暴，操控不错，就是舒适性相对现在的而言，的确有些无法形容……     操控 0 1
# 听4s的人说，冬季发动机喷油量会增加，油耗会上升，是这样么？     油耗 0 -1
# 15款以后斯巴鲁改良了活塞环，以前为活塞环张力下降，就目前来看还没有再反映机油消耗大的 动力 0 -1
# 新款配置高，老款优惠大，看你喜欢配置还是价格 价格 0 -1
# 中控倒没有异响，主要是后备箱异响多 舒适性 0 -1
# q5只坐过没开过，但比较下来Q5除了牌子响亮，好多还真比不上森林人。空间比森林人小，后排中间拱起那么高，根本没法坐人。避震也不如森林人，路感太强烈。操控性不敢说，因为没开过。     空间 0 1
# crv全世界销量都很好，满足了，空间大，故障率低、维护成本低、最新一代四驱系统有加强，（但雨雪、湿滑路面一样不行）。国外的车辆主要贵在维修、保养（人工费很高）。     空间 0 1
# 群里朋友自己回来换导航，换音响，微视车说起欧蓝德和森林人比，欧兰德回去也不用换这换那吧，现在竞争这么激烈，身为进口车，性能可以，也反映烧机油，内饰都说十多万的内饰，有一些配置就20万左右都是标配，在森林人身上就难有，呵呵你继续捧，还有朋友你瞧不起什么长安，你不一定应该说是一定，没有长安老板有钱。     动力 0 -1
# 群里朋友自己回来换导航，换音响，微视车说起欧蓝德和森林人比，欧兰德回去也不用换这换那吧，现在竞争这么激烈，身为进口车，性能可以，也反映烧机油，内饰都说十多万的内饰，有一些配置就20万左右都是标配，在森林人身上就难有，呵呵你继续捧，还有朋友你瞧不起什么长安，你不一定应该说是一定，没有长安老板有钱。     内饰 0 -1
# 群里朋友自己回来换导航，换音响，微视车说起欧蓝德和森林人比，欧兰德回去也不用换这换那吧，现在竞争这么激烈，身为进口车，性能可以，也反映烧机油，内饰都说十多万的内饰，有一些配置就21万左右都是标配，在森林人身上就难有，呵呵你继续捧，还有朋友你瞧不起什么长安，你不一定应该说是一定，没有长安老板有钱。 动力 0 -1
# 选中2.0而没有买其他配置的原因很多，回过头来，即使今天让我重新选择，我还是会选这个配置，觉得性价比更高一点。另外，你说的高配，并不包含灯光系统，2.5排量以上的森林人用的是LED灯，厂家和改装厂吹嘘LED是高端灯光，个人觉得，这完全是忽悠老百姓，LED发光原理决定了它不适用汽车照明。     配置 0 -1
# 途观l配置是硬伤，智享不智能，1.8的连天窗都没有，搞笑了     配置 0 -1
# 有眼光！入门版配置很入门！动力也强劲！     动力 0 1
# 你说的这几个配置，国产suv十来万的都有配吧，森林人配置真不咋样     配置 0 -1
# 森林人油耗都不高，很经济，。只是我觉得2.0L配置够用了，节约下来的银子够开2年的汽油钱了。      油耗 0 1
# 2.0与2.5，最主要看楼主的预算以及对配置的需求。 配置 0 1
# 自己开森林人，开过同事的傲虎，这俩车取向完全不一样。森林人偏运动，运动型操控性好于傲虎，内饰做工隔音差于傲虎，适合外出比较多，比较多off road的情况傲虎偏家居，舒适性稳定性好于森林人，适合主要城市用，偶尔off road的情况具体选哪个车就看楼主到底要什么了。另外有条件的话，建议直接上2.0T，我现在就觉得2.5动力不够了。 舒适性 0 1
# 自己开森林人，开过同事的傲虎，这俩车取向完全不一样。森林人偏运动，运动型操控性好于傲虎，内饰做工隔音差于傲虎，适合外出比较多，比较多off road的情况傲虎偏家居，舒适性稳定性好于森林人，适合主要城市用，偶尔off road的情况具体选哪个车就看楼主到底要什么了。另外有条件的话，建议直接上2.0T，我现在就觉得2.5动力不够了。 内饰 0 1
# 我看傲虎论坛里有换远光LED的，是leda 02型号的。价格比PIAA便宜，我准备在日本买，这样品质能保证是真的 价格 0 1
# 去看下探界者吧，侧面和发现神行很像，北美销量前五的suv，销量排在斯巴鲁众多suv的前面，国产后价格又不贵，发动机参数完爆森林人和傲虎，还配6at和9at，上汽通用造，不说很好但也不至于很差吧，除了四驱应该没什么地方比森林人差的 价格 0 1
# 没开过荣放，这级别同排量动力，刹车不会有太大差异，底盘滤震都说森林人好。 操控 0 1
# 没开过荣放，这级别同排量动力，刹车不会有太大差异，底盘滤震都说森林人好。 动力 0 -1
# 20T动力确实美好，不过都是CVT我觉得2.5足够了，省下了5万干啥不好……    动力 0 1
# 足够了，如果追求动力就2.0T吧，多5万大0.5没必要，并且老款2.5还烧机油，新的还不知道     动力 0 -1
# 斯巴鲁机油混动，大途观不烧机油，理解不了森的油耗低     油耗 0 1
# 新款顶配也有鹰眼吧，个人感觉没啥用，司机自己才是最好的安全系统；2.5扩缸没有的事，这个发动机是2004年发布；导航啥的都无所谓，开车开的是主要部件，现在买个其他品牌的也就大几百；保养机油可以选原厂的 配置 0 -1
# 你是16款吗，我车刚跑13800，帕烧机油，所以不用四儿子的，自己换的安锁签名     动力 0 1
# 一般最高140，一是怕被拍，二是感觉噪音太大了，不大敢踩了 舒适性 0 -1
# 高速达到100噪音简直不能忍 舒适性 0 -1
# 后排车顶棚上的安全带没有收好，卡扣打击顶棚 空间 0 -1
# 我觉得内饰提升 空间变大是王道 内饰 0 1
# 这次召回的是高田气囊，针对的是2010-2012三年里销售的车，等着3年左右后召回下一批吧（如果后几年的车也用高田气囊的话） 安全性 0 -1
# 斯巴鲁最著名的三灯齐亮，，你还加多一个气囊灯，先查一下故障码，看是什么故障先。 安全性 0 -1
# 120时速开着音响基本上没啥烦人的噪音了。     舒适性 0 -1
# 那CRV吧，质量稳定，空间足够，价格又不贵，二手也好出，长三角地区治安不错，不用过多考虑本田车容易被盗的问题。城市里用CRV真心是很好的选择。    价格 0 1
# 那CRV吧，质量稳定，空间足够，价格又不贵，二手也好出，长三角地区治安不错，不用过多考虑本田车容易被盗的问题。城市里用CRV真心是很好的选择。    空间 0 1
# 虽然森林人在同价位SUV中不输其他同级对手，但是跟上面这几个车比，无论从哪方面比都是自取其辱，除了操控可能比普拉多好点外，其他方面随便一台都秒杀森林人。一分钱一分货啊    操控 0 1
# 捷达也比2700动力好，2700百公里13秒，但是搓板路跑的起来，轿车，SUV颠死了，不敢开快了。     动力 0 1
# 非常不错，真干净。我是车内干净，发动机仓很少打开过。 动力 0 -1
# 主要对发动机好点，想开10多年，用好点油没错的，价格和4s差不多     价格 0 1
# 基础版价格对比，美国是森林人便宜，德国、英国、法国都是CRV便宜，德、法作为欧盟邻国居然差价这么多，法国基础版折合人民币24万6了，跟天朝一样坑，难道税费差异很大? 价格 0 1
# 市区完全够用，高速上120以后再加速就上不去了。高原有点缺动力。日常足够了！ 动力 0 -1
# EA888发动机，烧无止境！如果是真车主，呵呵打个记号。 动力 0 -1
# 我也觉得还可以。手上最好的耳机是铁三角im02。也不算木耳了。小森的隔音不算太好。音响能听个响就可以了。毕竟买它都是为了操控 舒适性 0 -1
# 昨天试驾了探界者，操控不错，悬架也是运动偏硬，1.5 t的新车价格和新款二手森林人还便宜些。还是情怀啊！ 价格 0 1
# 昨天试驾了探界者，操控不错，悬架也是运动偏硬，1.5 t的新车价格和新款二手森林人还便宜些。还是情怀啊！ 操控 0 1
# 按照楼主这逻辑 要是换个布加迪的中网 还能整出千万级豪车的感觉呗 ？  。   前脸和后杠 跟车身比例不对~ 就那种大头娃娃的感觉~   。   日本设计师要是看到改成这样 哭死得了~~~ 外观 0 -1
# 这未必，被撞的一方就取决于被动安全了，斯巴鲁相比同级别的车属于安全的，但被一些自重比他更大，离地更高，有大梁的非同级别车就不能参照碰撞测试的成绩了，只是我觉得为了相对安全舍弃掉更多的选择性和性价比有些划不来     外观 0 -1
# 加油啊，收拾好了感受一下动力     动力 0 1
# 傲虎好一些，适合旅行出去玩，舒适度，油耗，后期使用成本低。正常保养的话，费用也不多不到六百块钱！傲虎有轿车舒适度和越野车底盘 操控 0 1
# 傲虎好一些，适合旅行出去玩，舒适度，油耗，后期使用成本低。正常保养的话，费用也不多不到六百块钱！傲虎有轿车舒适度和越野车底盘 油耗 0 1
# 如果你脚脚都大油门的，这油耗有点低了，，可以很温柔地开，看下油耗。 油耗 0 1
# 你想说的导航是原车的还是加装的吧？这个你直接咨询经销商就行了啊，个人觉得手机导航方便好用 配置 0 -1
# 开过沃尔沃的suv但不是四驱，在一个大陡坡上起步，路面有点沙土，起步打滑，而且没有陡坡助停功能，起步会溜，陡坡起步没有安全感，2.5t的又有啥用，不能给我安全感，还是小森适合我可以陪我野。 动力 0 1
# 我也听说真不让进口2.5升的版本，我想问一下，我想购买新森林人运动版，这个版本是多大排量的？其他的都完美，不知道有没有全景影像系统，我觉得这个配置将来会标配。    配置 0 -1
# 牛逼牛逼，小弟佩服，这个油耗是我高速定速巡航120的油耗！你在大上海开出这个油耗，还是个2.5的车！真心厉害！ 油耗 0 -1
# 原厂隔音不咋滴，后排没有出风口，原厂音响非常渣，油耗那是很令人满意的。    油耗 0 -1
# 原厂隔音不咋滴，后排没有出风口，原厂音响非常渣，油耗那是很令人满意的。    空间 0 1
# 也就SGP底盘吸引我要不买2018款了犹豫还在想沃尔沃XC60都是安全著称 操控 0 1
# 因为价格虚高，配件贵，保养贵，没有豪华感，国内又是重视外观不重视内在，所以保值低 价格 0 -1
# 因为价格虚高，配件贵，保养贵，没有豪华感，国内又是重视外观不重视内在，所以保值低 外观 0 -1
# 2.0加小电机动力和节油都是要比2.5好的吧 动力 0 1
# 光有2.0排量确实欠考虑。你走量不反对，但是也要给大家选择吧。一辆空有操控没有动力的车只能算半残。 操控 0 1
# 挺保值啊，别卖给贩子，遇上合适的人，二手市场森林人价格都挺高，我看过 价格 0 -1
# 过六十就有明显的胎噪和风噪了 空调出风声音也不小隔音最好的方法就是音乐开大点 要不就开慢点 舒适性 0 -1
# 同月同款，你的车开内循环能闻到车外的异味吗？ 舒适性 0 -1
# 其实现代车型的安全性能远没有我们看到几颗星什么的差异那么大，整体安全性能的趋势是统一的。     安全性 0 1
# 操控不好，圈速成绩是怎么跑出来的？     操控 0 -1
# 那就是车头、车尾高度不一致了。 外观 0 -1
# 要性能车得上XT啊 换代明年初亮相要买估计最早也要明年夏天了 动力 0 1
# 指南者扭矩你比小都上去了，你扭矩和功率都比它大怎么歇菜了，同样森林人也是CVT就上去了，相同扭矩的发动机，这就说明三菱的CVT吃不住低速大扭矩     动力 0 -1
# 烧机油不感确定，不过还是建议2.5的，2.0开着确实感觉动力不怎么样，其实也差不多少 动力 0 -1
# 看到不可控，不过说实话——白车的颜色也是有色差的，白色久了泛黄，黑色久了亚光，肯定都有色差；汽车厂的喷漆都是多头的电镀喷涂，一般的店里是达不到那个效果的，即使是有色号也不行。    外观 0 -1
# 变速箱学习你的驾驶习惯，很早就开始升档，这时候你多踩油门，变速箱只能降档。起步瞬时油耗99.9都不稀奇。 油耗 0 -1
# 我当时看也是这三款 大汉吃细粮 冠道后备箱小油箱小 综合起来还是买的小森     空间 0 -1
# 斯巴鲁不仅颜值越来越高，而且配置越来越高 配置 0 1
# 这车不适合跑市区 ，跑长途你绝对杠杠滴，可靠性，油耗那都没得说 油耗 0 -1
# 我准备把原厂CD换回去！一般的DVD导航音质不好 配置 0 -1
# 简单咨询了一下，好像可以修复，就是价格很贵，鲨鱼pi报价的1500！另外都说斯巴鲁的漆不容易吸，因为吸盘上去就可能破坏漆面，倒也不是日本车漆软偷工减料，可能是太讲究环保用的料不一样。总之1500好贵了。。。    价格 0 -1
# 请问楼主 这车烧机油吗 看很多车友反映烧机油呢 动力 0 -1
# 森林人，全系车不会让你失望！你只管选配置、颜色、样式，动力所有的款式都够用！但有一点，2.0的更省油！ 动力 0 1
# 价格也会提高，反正我今天提车，侧方视频应该可以加原装了。 价格 0 -1
# FB25烧机油的概率是EA888的零头     动力 0 -1
# 价格正常，在广州那么多拆车件，有点小问题修起来也不贵。楼上说的发动机，变速箱，涡轮都是好的就没事。 价格 0 -1
# 相对来说2.5的烧机油机率比较大。可以考虑2.0L或者2.0T 动力 0 -1
# q3我也去试驾过，试了前驱的，空间比森小，视野不及森，动力1.5t的还算不错。不过价格去到24万多的裸车，而且是国产的，味道有点难接受。bba的国产车品牌溢价太多了。个人感觉。     价格 0 1
# 这个东西就是受制于成本，森原厂的定位不高。本田以前的车门也不咋的，冠道那价格上去了你看它就完全不一样。钱给到了不仅材料连制造方法也完全不一样。 价格 0 -1
# 山东价格很死，新款优惠力度很小，老款性价比高，可能2w 价格 0 -1
# 2.5的好，油耗不高的 油耗 0 1
# 别买1.4的吉普，动力不够。要是很喜欢就买2.4的指南者或自由光，但是2.4的烧机油。我两个同事去年初同时买的自由光2.4专业版，一个烧一个不烧，烧机油的差不多2000公里1升。这概率真是拼人品，吓得我都不敢买了。 动力 0 -1
# 后备箱网是自己买的。你说的大的常亮，是指导航中控吗？    配置 0 -1
# 后备箱网是自己买的。你说的大的常亮，是指导航中控吗？    空间 0 1
# 这也是18款我最喜欢的一个配置 配置 0 1
# 我的就是10款森林人2.5动力够用了，超车很轻松，没有烧机油，目前10万公里 动力 0 -1
# 16款2.5大年初一两人，从都江堰龙池走了一段山路，然后都汶高速，成灌高速，绕城高速再经成绵高速进城回家，时速100至120，不急加速，表显5.9 动力 0 1
# cvt的代价就是加速不给力 动力 0 -1
# 牛，2.5的170以后加速无力 动力 0 1
# 除了老外的那种直线加速赛，一般来说，真的是只有肉人，没有肉车。 动力 0 1
# 价格贵，配件也贵，保险也贵，这个就是斯巴鲁的缺点，别的没毛病！ 价格 0 -1
# 国外配置不能一概而论，国外这个概念太大了，日本原版的我就不会查（不懂日文），还有欧洲版，配置我也还没查呢。单就卖的最畅销的北美市场，可以这么说。 配置 0 -1
# 建议不要买，我2017款2.0豪华版，1万公里发动机异响皮带脱落，更换皮带后异响有所缓解，但现在1.5万公里换机油后异响又来了，还有就是2.0跑高速很肉，建议要买森还是2.5或2.0T 舒适性 0 -1
# 只要舍得地板油，动力够你爬山坡，噪音什么的，见仁见智，低速可以，高速，风噪会比较明显，胎噪就，唉，，，，做隔音吧，轮拱，叶子板，这俩个地方做了会好很多 舒适性 0 -1
# 可以考虑一下仕联达隐藏式行车记录仪，价格不贵，性价比高。安装后看不到接线。我就是装的这个品牌的。淘宝有旗舰店，可以咨询一下。 价格 0 -1
# 哈哈哈，有点以前打出租老夏利似的，不过车子开的爽，这些问题我能忍，我后备箱也哒哒哒的响，无所谓了 舒适性 0 -1
# 增加车重，油耗增加。我原来想加3个厚的不锈钢板，考虑没梁，加装甲没意义。没大梁是硬伤，不敢豁车。 油耗 0 -1
# 已经重新下载多次，一样问题，郁闷！已经买了一个安卓山寨导航，到货用用看怎么样。 配置 0 -1
# 我真心求教，傲虎比森林人强在哪？尺寸空间吗？还是配置 配置 0 1
# 车漆可以打蜡镀晶，塑料件，那就是给你划的 外观 0 -1
# 感觉如果庞大真心想清库存的话，斯巴鲁的车还是好卖的，很多人不买斯巴鲁就是价格原因而已 价格 0 -1
# 保时捷就是水平对置发动机，有额外加强操控，和降低共振作用 动力 0 1
# 不讨论省不省油，伤不伤车啥的，半个小时脚一直踩在刹车上，脚不会发抖吗 安全性 0 1
# 6年7.5万公里飘过。。。不过你的油耗怎么那么低 油耗 0 1
# 这说明RAV4后轮有动力的时候不多，你的后轮一直有动力肯定甩泥啊 动力 0 -1
# 水平对置发动机全时四驱整车进口三十万落地你去找 动力 0 1
# 飞度吊就吊在它后排座椅的设计太实用了 内饰 0 -1
# 14款2，5车主，这车操控性好，视野开阔，后视镜视野同样开阔，四驱雨雪不打滑，油耗不高，140迈内加速快！不好的地方内饰寒酸！隔音差一些！过减速带之类颠的厉害！…… 油耗 0 1
# 14款2，5车主，这车操控性好，视野开阔，后视镜视野同样开阔，四驱雨雪不打滑，油耗不高，140迈内加速快！不好的地方内饰寒酸！隔音差一些！过减速带之类颠的厉害！…… 内饰 0 -1
# 好车，性能车才烧机油啊 动力 0 1
# 我的很稳定，平均油耗11上下，感觉还可以 油耗 0 1
# 嗯，是的。还得买18款啊，我就弄个2.0i的就行我们这没有豪华导航，只有时尚导航，豪华的4S从来也不进货，攒钱吧，25万。。。 配置 0 -1
# 那个东西成本很高的，新款没有算是偷工减料了。森本来就主打操控，平衡是卖点，省掉确实不应该。你看看淘宝上老森和新森够避震的价格，差很多。 价格 0 -1
# 海蜡，在海上运输保护发动机舱不被腐蚀的，可以清洗掉。 动力 0 1
# 森林人油门初段调教偏灵敏，刚开始需要适应一下，所以就造成了动力充足的假象。我的是18款2.0，平时在市区开开的话动力储备还凑合，但是一上高速，超个车费死劲了。我家还有一辆手动1.8老福克斯，高速超车刚刚的。 动力 0 1
# 低速声音确实安静，但是动力确实差，高转速时发动机声音嘶哑不圆润，用了不到1000km果断放丢。不最求速度的可以考虑，哦，对了，省油 舒适性 0 -1
# 09-12森是4AT，顿挫，和油耗是硬伤！顿挫习惯了就好，油耗综合10点几！ 油耗 0 -1
# 我换的是G012，胎噪个人感觉比原厂胎好，声音发闷，没有原厂胎嘈杂，油耗变化不大，高速100到120跑，7.3个油左右。走烂路感觉太好了，感觉车子对路面的过滤都好了，信心满满啊。诺记当时也考虑过，现在觉得自己的选择是正确的。 舒适性 0 -1
# 我换的是G012，胎噪个人感觉比原厂胎好，声音发闷，没有原厂胎嘈杂，油耗变化不大，高速100到120跑，7.3个油左右。走烂路感觉太好了，感觉车子对路面的过滤都好了，信心满满啊。诺记当时也考虑过，现在觉得自己的选择是正确的。 油耗 0 -1
# 18年1月入手2018款2.0森林人，目前综合油耗8.0，最低综合油耗达到过6.8，动力没特殊需求够用，最高速度拉到过209Km/h 油耗 0 1
# 据说取消2.0的了，放心2.5是中美特供，不会取消的，我反倒希望全面取消2.5的，换装2.0T，否则买同级别国产2.0T（途观，科迪亚克，昂科威，探界者，翼虎）的面前，动力完全处于劣势。     动力 0 1
# 据说取消2.0的了，放心2.5是中美特供，不会取消的，我反倒希望全面取消2.5的，换装2.0T，否则买同级别国产2.0T（途观，科迪亚克，昂科威，探界者，翼虎）的面前，动力完全处于劣势。     外观 0 -1
# 森林人就是标准的A级SUV，傲虎属于B级跨界旅行车；傲虎在空间、静音、舒适、行驶质感方面要强于森林人；越野性能方面森林人应该略有优势，毕竟轴距短。 空间 0 1
# 是个四个轱辘带发动机的车都能进藏    动力 0 1
# 我也迷上了，公路操控和越野兼顾，又有安全性和空间。 空间 0 1
# 其它不知道，不敢乱说，不过高速130油耗才九个，我轿车都得11个， 油耗 0 1
# 品牌小众，内饰用料差，这两点都与大多国人的要求不符，维修费用高（虽说一般不坏）。 内饰 0 -1
# 外观还好，做工差，精度差，时间长了，咯吱嘎吱响 内饰 0 -1
# 请楼主去宝马3系论坛看看，有多少买了大叫后悔的。。。动力足 颜值好 可*** 操控爽 保值高，简直无敌了，啊哈    动力 0 1
# 森林人驾驶有乐趣，可以带你去更多地方，安全性也好，但品牌力不足。三系操控性好，品牌力强***高，但不如suv更实用，坐五个人的时候还是森林人更舒服。途观是神车…对，神车！ 空间 0 1
# 改原车一键启动键一直都可以啊，只是价格都不便宜，就怕出现电脑故障。 价格 0 -1
# 2.5常年显示8.8，小熊油耗显示9.2。 油耗 0 1
# 哈哈，现在导航的地图都有提示啊，而且可以更新 配置 0 1
# 我有买来装，负责任的告诉你，绝对值得买。实际装上去比原车美观好看还耐磨耐刮，不会原车那样几年后到处是划痕。而且这东西你装上去压根不用考虑取下来，不锈钢越用越光亮。 外观 0 -1
# 对空间没有要求的话就果断选择xv，车小操控好，好停车。 操控 0 1
# 楼主一般多少公里换机油 动力 0 1
# 这胎换了之后油耗有增加吗？还有就是刹车距离怎样？高速胎噪怎样？    油耗 0 -1
# 论性能，NX200根森林人没法比！雷克萨斯的侧重点不是在性能上，而是在舒适与豪华上！如果比内饰比做工用料森林人应该完败！但是比机械比性能，NX200不是对手 内饰 0 1
# 全球化采购的后果 日本本土的价格贵 成本高 低成本的泰国货 虽然降低成本 但声誉也一起降低了     价格 0 -1
# 性价比高，轮圈大一寸，带装逼换档拨片，前脸好看，这些功能1W是搞不到的，没追求还是买豪华吧，当然，再没追求建议买其它车！望采纳     外观 0 -1
# 途观L我去试驾过，内饰豪华感比森强，后排空间比森多出四指。但有两点不满意，被放弃。一是那个天窗顶棚就是一层薄纱，试驾的时候正好是烈日当头，感觉很晒，遮光性一点都不好。二是全系标配韩泰轮胎，大众标榜自己高安全车身，却不配双好鞋，通常一般人都注意不到。 内饰 0 -1
# 森林人操控肯定比昂科威强多了，四驱能力也强很多。只是内饰和隔音比不上昂科威。 内饰 0 -1
# 是不是换成这种原厂导航，喇叭??不用换，音质就可以提高很多？ 配置 0 -1
# U盘是不是该换一个？我的U盘一直都在听歌，重来没有出现你说的情况，导航也是从来都正常的 配置 0 -1
# 如果单纯比较动力，底盘等机械性能的话，选森林人2.0XT应该不比GLC差。其他就不用比较了，森完败。 动力 0 1
# 靠，2.5的傲虎烧机油，森林人设计缺陷，空调坏，我x，我是不是不该考虑斯巴鲁了，话说我的马六7年了，什么都没修过啊 动力 0 -1
# 换过530油耗明显增加，又换回了020，一直用的摩特 油耗 0 -1
# 不过和神丁聊改车，买的改件都是精品，要提升操控就操控，提升动力， 操控 0 1
# 森就是好开，小众，能接受就买。考虑配置性价比，还是算了。 配置 0 1
# 大家都说导航是最不能忍的，还不如不加 配置 0 -1
# 其实我也纠结这两款，为了装b，忍受12秒的加速，花多5万块，最后感觉还是新crv好点。 动力 0 1
# ECU刷完以后动力会永久下降，我问过4S，但是可以解决爆震 动力 0 -1
# 这个价格不错，其他地区的车友可以参考一下 价格 0 -1
# 我是16款新车跑了3800了，冷车启动也有这噪音卡拉卡拉响几下。至今无解，汽油一直95以上。 舒适性 0 -1
# 嗯，2.5我也试驾了，油门初段很有力的，其实给我的感觉不像加速十秒的车，零到一百主观也就八秒，车上四个人，动力应该够用了，还有噪音异响有车黑说的那么多吗？ 舒适性 0 -1
# 保养价格一般，维修价格比同级别贵很多。 价格 0 -1
# 感觉配件价格一般，稍微贵一点。但也比奥迪便宜。而且只要不乱改，没碰撞，一般也坏不了。再说，还有保保险公司呢 价格 0 1
# 我不知十几个油耗是咋开的。。。。。 油耗 0 -1
# 上周去了趟果园，回家一看车身两侧全是树枝划的划痕，不过洗车抛一下就好了。小坑这些也有，估计是路上飞溅的小石子弄的。 外观 0 -1
# 发动，踩刹车，挂档，松手刹，松刹车，车就走了。驻车时踩刹车至车停，挂P档，拉手刹，就可以了。注意别加速或刹车过猛。其他没什么的，几天你就可以做到人车合一了。 安全性 0 -1
# 120噪音真心没有你说的大。你可以试试。我反正安了没感觉。油耗倒是有所上升。跑高速高0.5-1之间吧。 油耗 0 -1
# 是不是就是价格es和日间行车灯？ 外观内饰变吗/ 内饰 0 -1
# 可迪亚克就算了吧，试驾过操控一般，内饰也很一般。森林人如果上新款，特别是加鹰眼的话，价格只高不低 价格 0 -1
# 可迪亚克就算了吧，试驾过操控一般，内饰也很一般。森林人如果上新款，特别是加鹰眼的话，价格只高不低 内饰 0 -1
# 车子不就是要看配置吗?再好的品牌每款配置都不同 配置 0 -1
# 副厂大灯质量太差 配置也差 配置 0 -1
# 感觉此车的动力不错，在同等车辆中算是不错的了吧 动力 0 1
# 明白 40W内加速最快的SUV是什么车 除了唐 动力 0 1
# 机械性能，操控性，安全性都没办法吐槽，所以只能吐槽内饰了，不过说老实话 13款之后的内饰并不差 操控 0 1
# 棕色好看。 要不抛个硬币吧。 外观 0 -1
# 这个车需要提配置啊？说明你对森不了解啊 配置 0 -1
# 我2.0市区为主，油耗10.5，这年代了，首选当然2.5 油耗 0 1
# 18款2.5现在4200公里，油耗北京环路上下班8.8，故障还没遇到过，总之各方面我是超预期的满意(都没试驾过)，不过媳妇嫌车大不爱开，上月又买了个小车给她 。。 油耗 0 1
# 嗯就是！可能油耗也高哟     油耗 0 -1
# 我是17年6月提的2.5豪华特装，目前开了1万1千多公里，平均油耗7.7升/百公里 油耗 0 1
# 我准备等到新款rav4双擎和换代后的卡罗拉双擎上市后里面选择一个再换车，现款的汉兰达虽然保值率高，但油耗以及油品需求都不低，而且还要加价，应对2020年我朝普及乙醇油，我感觉汉兰达用不长久，不适合自己对下一辆车经济性的诉求，新一代rav4和卡罗拉双擎取决那时候两新车的完成度（质量可靠度当先、功能性次之）     油耗 0 1
# 我2.5自吸刚做完六万公里大保养，更换机油机滤，空气滤芯，汽油滤芯，火花塞，清洗节气门，发动机燃烧室，更换刹车油。我自己另外更换了转向助力油。用时三小时。变速箱油和差速器油每4万公里更换。 动力 0 -1
# 楼主，烧机油是概率事件，斯巴鲁和大众都一个样，看你的运气了。根据4S店的说法，16款以后的森林人烧机油情况有所改善。车漆是真薄，不是反话，日系车的通病，如果介意这个，斯巴鲁的车可以一票否决。 动力 0 -1
# 抛开越野不谈这个前提下，傲虎舒适性真心强于森林人，但森林人天窗比傲虎大，头部空间优于傲虎。 舒适性 0 1
# 外观内饰我看是能完胜了，这代RAV4肯定卖的不错。    内饰 0 1
# 经典之所以是经典就如经典音乐一样值得时间的检验，这和老不老没关系。牧马人常年保持一贯的设计风格，不是固执，而是文化自信使然。日系车整体外观的垮掉绝非偶然。森林人本身是有自己的文化和设计语言的。可惜的是或许流于世俗，或是寡于内心，完全洗剪吹了～一代名车彻底消失，街上跑的就是奇骏，面包，老款汉兰达加莫名妖娆尾灯的混合体。（轮毂丑的我已无力吐槽）算了，开着四代，好歹还有些影子吧～～～～ 外观 0 -1
# 买车时我关注过2.5和2.0的区别。斯巴鲁的海外特供2.5排量并非缸体的纵深容量增加而是缸径的扩大。当时我也不懂但就是担心所以没选2.5。现在感觉烧机油原因多少和活塞环配合有关。     动力 0 -1
# 我之前选车，感觉其他日系SUV要是全时四驱加上这些辅助件齐全，排量1.3—1.5之间的比森林人便宜，但是2.0以上排量的和森林人的价格差不多了，有的还略高一些，这有个同级别比较，才能看出性价比的关系，而且操控没有森林人好。     价格 0 1
# 论坛看了那么久，有看到森林人15款回复自己烧机油的（15傲虎带油冷的有过发帖烧机油的）还没一个正儿八经发帖说自己15款森林人烧机油的，lz实现了零的突破，我这完全没有挖苦lz的意思，静待16款以后烧机油的帖子，lz可能你会被人问到是否添加了外面买的假机油，像lz这样经常高速的还是绕开斯巴鲁的车为好 动力 0 -1
# 那还好，基本中小故障都没怎么遇到过，烧机油，渗漏，是斯巴鲁最大的两个痛点，是否索赔成功后修理的呢？     动力 0 -1
# 这款车形容一下就是，10万元档次的内饰和隔音，20万元档次的外观，50万档次的操控 内饰 0 -1
# 我也换了8850，谁用谁知道！什么车窗后备箱异响，完全忽视！ 舒适性 0 -1
# 内循环，应该也不是完全密闭的，可能会有缝隙，渗透进来。无异味客气进入，不会发觉，有异味就会被发觉 舒适性 0 -1
# 差速器换挡。。。速度高了改变前后轮动力分配 动力 0 -1
# 价格给你便宜了，新车还加了价你一来一回不少钱。 价格 0 -1
# 16款里边，2.5豪华是最实用的。 自动感应灯，转向灯，雨刷，方向盘，主驾驶记忆，前排座椅 后排座椅加热。 值得购买 eye-sight我是没赶上，更值得推荐 内饰 0 1
# 经常坐满，要家用空间大，就汉兰达。经常自己开，要点乐趣就森林人。5008可以pass了。 空间 0 1
# 还有，人家红外激光雷达价格随便都是毫米波雷达的几十倍，结果你还说什么几乎忽略不计！看样子你家的毫米波雷达都是清朝祖传下来的，都卖成古董价了…… 配置 0 -1
# 功率扭矩肯定有增加，但是牺牲稳定性增加油耗也是没啥必要了…… 油耗 0 -1
# 只有2.5的试驾车型，当时试驾的2.5的动力真的不错，一直踩一直有的动力 动力 0 -1
# 豪华导航版带eyesight系统（鹰眼） 配置 0 -1
# 486性能车，油耗其次。近来3000公里没什么急事，加速不那么急，所以油耗低一点。 油耗 0 1
# 现在的车动力都过剩，2.5够你玩了，而个人感觉是绰绰有余，那些说动力不足的以前是不是都是开超跑啊。 动力 0 -1
# 要我选肯定森林人，X1除了品牌和外观真没啥了。 外观 0 -1
# 楼主估计也就值个七八万，因为这车后期的保养费用确实太高了，而且油耗也没有什么优势，大家买这个车就不如买个省油耐用一点的丰田车了 油耗 0 -1
# 得先把方向盘气囊拆下来，有一颗才镙丝才能拧下来。 安全性 0 -1
# 不用管它，时间长自己就好了，森森有自我修复功能。我的后备箱异响，找不到哪里响，响了半年自己好了 舒适性 0 -1
# 花200元换掉中控上的二个高音喇叭，包你满意。 配置 0 -1
# 楼主你好！车辆的品牌、外观、颜色和内饰的选择，本身就是一件仁者见仁智者见智的事情，只要你喜欢，就是最好的选择。 内饰 0 1
# 森林人外观内饰都不如刚出的杠5吧，保值率的低下导致买二手车不错，水平对置发动机的后续维护也和你要的省钱省心背道而驰。逼格方面只要不上到bba，哪来的逼格？ 内饰 0 -1
# 我的和你不太一样，缓慢的过减速带，车身起伏太大右前底盘就会异响，但是快速过减速带和烂路就不会响。 舒适性 0 -1
# 保养不贵，操控不错在suv里，你可以试驾，但是空间没有汉兰达大，没有他气派大气，斯巴鲁是低调的车。装逼勿选，优势就是四驱安全一点 操控 0 1
# 可以直接把中控屏换成建武的917就OK了 哈哈 配置 0 -1
# 好车，配置升级让人羡慕啊，尤其是有很多实用配置升级。 配置 0 1
# 北京石景山古城的那个店，丰台有一个也这个价格！置换还有4千补贴。车友们你们的车现在启动声音大吗？ 价格 0 -1
# 12款，只做了气囊召回，没说水泵也召回啊？ 安全性 0 -1
# 看台版森林人扶手箱里有两个USB接口和一个AUX接口、咱这那个位置只有一个塑料盖板。估计中控导航不一样所致。嫌USB少、以后可以买个12V电源转USB插头。 配置 0 -1
# 森林人的座椅一定要调高一点  脚才能很好的踩死刹车  那样就不累了 安全性 0 1
# 肯定疼，森林人坐垫很短，腿的一半是架空着踩油门和刹车，久了肯定酸，森林人所谓的空间大，是建立在坐垫短的基础上 空间 0 1
# 20大几万的车，保养和同价格的车基本上差不多，不贵。 价格 0 -1
# 换了肯定不烧，以后还是烧，还有拆了发动机车贬值加异响。 动力 0 -1
# 进藏要上高海拔可以考虑2.5 高原自吸动力要打折扣 反正XT肯定够用 动力 0 1
# 森林人刹车软是针对越野及湿滑路面的一种调教，要硬的话不是做不出来 安全性 0 1
# 我现在1.5手动那个动力随叫随到，真的爽！ 动力 0 1
# 卧槽比16款配置高太多了 配置 0 -1
# 您好用什么发动机保护剂好一些啊 谢谢 动力 0 1
# 斯巴鲁这配置和价格确实不是很合算 价格 0 -1
# 卖肯定没问题，只是价格问题 价格 0 -1
# 80-100定速巡航 油耗是比较低的 油耗 0 1
# 就是不踩刹车，车自己会溜，需要刹车的 安全性 0 -1
# 配置够用就好，2.5日常使用足够了，我也是同款。 配置 0 -1
# 外观比马自达好看太多了.........马自达那些车只能看一眼....之后再看有点LOW 外观 0 -1
# 很多人都说 特别是操控几乎完美 动力要是配上T的话 简直就是神车了 动力 0 1
# 就算要换变速箱也不用这么麻烦吧 动力 0 -1
# 喜欢suv.但傲虎配置好 配置 0 -1
# 我的2.04AT！近期油耗13.6！上下班单边5公里。没办法长期短途行驶 油耗 0 -1
# 嗯嗯，深有同感。我就是看好纯进口车的品质还有他的全时四驱和主动安全系统才决定买小森 操控 0 1
# 我觉得，变速箱机械手刹不用改（我觉得挺实用的），内饰档次和质感加强质感，后排空调出口必须有。 内饰 0 1
# 680你还觉得便宜？只能说这些年国行机油价格太离谱了，让你觉得机油是很高大上的东西。去美国亚马逊看下机油价格能吓尿你 价格 0 -1
# 美国买的原装导航也是一坨屎 配置 0 -1
# 动力在100公里内都很好，加速线性。100以上提速稍一慢点，但对我够用了。城里开很灵活，异响什么暂没有，行驶稳定性好，特别是开弯道很稳当！. 动力 0 1
# 斯巴鲁的车在同级别中配置是算比较寒酸的 其实斯巴鲁是比较有性格的车企 不用华丽的配置来吸引消费者 而是安安心心造车固执的坚持全系水平对置加全时四驱这么固执的车企确实很少了 配置 0 -1
# 我这个是才出来的2016款2.5的豪华特装，只比顶配少了尾翼，价格便宜很多，配置也齐全。    配置 0 -1
# 换老的cd是最妥的，国内导航后换的dvd导航都不怎么样 配置 0 -1
# 垃圾导航加上拉圾服务，无语 配置 0 -1
# 换了两个后轮，是米其林轮胎，静音效果很好。不知道前面两个换了后是否静音更好。 舒适性 0 1
# 嗯，对的。堵车油耗高，别的都可以     油耗 0 -1
# 我刚刚入手2.5尊贵很满意，开着舒服，油耗很省，跟我1.6马3差不多。 油耗 0 1
# 其实视野好也是安全的很重要很重要的一环！ 安全性 0 1
# 说得太对，我是准车主，观察留意很久。相对现在质量问题比较多，国内减配主动安全系统，迟迟不敢下手。    安全性 0 1
# 盘子太小，鲍鱼太弱，还掉粉，森林人的刹车真的太烂 安全性 0 -1
# 按时间段上次2012年换代，这一代2017就该换代了，最晚2018年，这一代森林人最给斯巴鲁丢人，油管腐蚀、CVT热保护、烧机油    动力 0 -1
# 我可没你这么无聊。烧机油反正我的一直就没烧过。可能买到假的了      动力 0 1
# 森林人空间、视野、大天窗、四驱，后排这些cx5都比不了的，还有纯进口品质，你看下美国最好品质紧凑SUV，森林人几乎年年上榜。 空间 0 1
# 建议选择白色！我上一辆车是银色，开着银色车时我就想再买就买辆白色车，所以我又买了白色的森林人。白色耐脏，银色也耐脏，白色比银色大气些，涵盖的大部分车友的年龄段，而且白色比其他颜色醒目，安全性高。我买白色的现在一点不后悔。    外观 0 -1
# 主要你的车保养正常 不烧机油 这油耗是正常的 我的se 360的有也就开360公里这车有油耗就是大 没办法 谁让你喜欢 油耗 0 -1
# 首先换车退款可以商量，不给商量就走法律渠道维权。让他修复后这个终身保养可以考虑，但是要签协议列免费保养项目清单，让斯巴鲁盖章相关责任人签字认可。或者给便宜点钱提车，价格3W起。 价格 0 1
# 我首保前综合7.9，首保后到8.2.现在综合8.1，区别不大，这个车耗油在高速120以后，山路不省油，冷车也耗油，我最省油的时候是在热车走城市环路6点几，最低到过4.4，路况良好暴力驾驶也就7点几……     油耗 0 1
# 壳牌0W20，效果和价格都很好。     价格 0 -1
# 是的，经典的二代无框森林人！如果是二代森你这个价格还是很合理的！    价格 0 -1
# 没有关系，09款的车，夏天用92，现在用95，二者动力有别。 动力 0 -1
# 市内开没任何问题，上高速，八十以后加速慢点，深踩点油门呗，没感觉和2.5的差多少 动力 0 1
# 粘度高，会不会油耗变高？等你换后感受。我还有两个月才换     油耗 0 -1
# 我缓停就没有异响，估计是盘子和片子之间间隙问题     舒适性 0 -1
# 烧机油可能和平时不关心有很大关系。但是网上查查美国市场烧机油现象也蛮多的。我朋友16款2.5尊贵还没出现这个问题。水平对置可能确实比较烧机油，大众的不是也烧么……我觉得很正常。看了那么些论坛，2.5排量的6万公里之后烧机油问题相对多些，2.0的好像真的很少 动力 0 -1
# 烧机油的话还是卖了比较好，烧的也太早了。我三年9万多数高速7000一保养。只能说RP好……     动力 0 -1
# 客观的说，能增加低扭，进藏，或者经常爬山有用，但是对应这个价格，还是缺少性价比。毕竟这东西不便宜。    价格 0 1
# 海拔3500以上有影响，加速缓慢，特别是上坡时，转速上升，动力则跟不上，明显动力不足了！平原则没问题。 动力 0 -1
# 这个价格的紧凑型SUV舒适性都差不多，森林人硬归硬，我也没觉得比CRV不舒服。当然，跟中型SUV比肯定还有点差距，我家还有个新汉兰达，乘坐舒适性相比就确实是两个档次了。 价格 0 -1
# 只要车戴蓝牙和手机连接上了，手机里的导航就可以通过车里的音响播放了，但是没有图像。 配置 0 -1
# 看来用5-30的还是不少哈！我的车6万公里了，从4万多开始用5-30的机油，除了油耗高了一些没见其它毛病。还是坚持用5-30吧 油耗 0 1
# 真要是倾向森林人的话，比较一下奇骏就可以出手了，至于途观L完全不是一个类型的 注意一点：森林人的CVT纯鸡肋，配置低 配置 0 -1
# 买你能买得起的最高配置！ 配置 0 -1
# 不去了，都一样，我又选了几天车倒是发现了，之所以卖森因为不是豪品牌，不是喜欢的车标，仅仅是因为情怀和25以内没有bba可选，也不是喜欢的内饰。光有内在是打动不了我的，我知道了自己喜欢的！够了，买个思域或者福克斯代步，去挣钱了，以后换bba！     内饰 0 -1
# 主要看外观漆面及内饰，希望不是展车 内饰 0 -1
# 亲戚家crv，也不错，内饰比森林人强，视野森痛快，底盘森高的多。 操控 0 1
# 我去年买的森林人 之前我也看好了 昂科威 实在是太喜欢它的内饰了 但是因为爆出分体式插销脱轴隐患 所以就买了森林人 森林人2.0油门调教的很灵敏 120以下提速都很快 完全够用 内饰 0 -1
# 公路四驱差别都不大，这俩车价格差很多，看自己收入买，都不是能越野的车不要纠结四驱哪个更好！ 价格 0 -1
# 动力有没有要求？保养的话肯定汉兰达便宜实惠 动力 0 1
# 看你有犹豫就2.5不会后悔 外观能改动力改不了 动力 0 1
# 我的和你一样。我现在跑了10万多了，之前用的0-20，气门室盖渗油，现在自己换了壳牌5-30 H6，现在基本不渗油了，5000公里缺不到0.8L机油。 动力 0 -1
# 你还开的不够，颠簸路你是遇到太少了，就是那种城市里被卡车压的到处是坑洼的路面，真的不敢开快，否则叽里嘎啦的都是声音，底盘传来的震动就是松散，同样途观我开过就没这个样子     操控 0 -1
# 2.2舒适性好，2.5有点硬了。 舒适性 0 -1
# 时速大概60-70 烂路感觉不出来，反而一般水泥路面就会出现，自从发觉有了异响之后，感觉自己都幻听了，不过问题不算大，主要自己懒     舒适性 0 -1
# 我对异响已经免疫了，真的。 舒适性 0 -1
# 请问LZ16款气囊有没有问题呀？还是分批召回？ 安全性 0 -1
# 车子后半部异响太多了，麻木了不想管了，找个安静的比较烂的路以非常慢的速度，各种杂音。。。感觉森林人车身刚度真不咋滴 舒适性 0 -1
# 垃圾导航、主机。15款特装2.0 配置 0 -1
# 换大屏导航有用吗？还不如一个手机更新又快。 配置 0 -1
# 13款2.5尊贵有爆震， 就是加速地盘刺拉拉或者嘎拉卡拉声音。 没管他。使劲操 动力 0 -1
# 这车除了底盘，发动机，其他确实挺LOW的。。 操控 0 1
# 对动力要求高2.5也不够 动力 0 -1
# 保养不贵，维修贵进口车都是一样的，不过楼主如果想省心又便宜，我建议去买SUV销量前五的车型（品牌不限），如果想享受有一定的驾驶乐趣有一定的通过性，选这个车不会后悔。顺便说一下合资里面四驱的价格也都不便宜的。 价格 0 1
# 你开多了就知道了，初段还行，后段加速后步行了。    动力 0 -1
# 补充一点，我买之前也试过指南者，试驾一次就放弃了，没劲，工艺不如森林人，你看各评测的都不如森林人，四驱价格也不便宜，估计买指南者的也是抱着对JEEP的情节。 价格 0 1
# 阿特兹这样的轿车，空间不如森林人    空间 0 1
# 我也是新提车4个月 好坏跟你分享下 ：1导航很山寨 2怠速抖动（不抖不是森林人） 3真皮座椅包裹性很好 很舒服（没透气，时间长屁股难受） 4 内饰 0 -1
# 我也13款、爆震厉害。4S前几天电话说。升级电脑。以前的升级电脑会影响动力。8月份马上就出新的升级程序，对动力没影响。可以解决爆震 动力 0 -1
# 这是我出去玩的照片，给你一些参考，比铺地上的强多了，隔潮，睡得爽，唯一的问题就是拆装费劲，还有价格略贵 价格 0 -1
# 是啊，动力搭配对四驱性能也很关键     动力 0 -1
# 想花钱？看我的：把你那个庞大山寨导航扔了，上某宝收一个原厂的印象换上，买一个卡仕达的云景2S车内后视镜，连电子狗、行车记录仪都省了。    配置 0 -1
# 我觉得上2.5不后悔。有能力上2.0t。动力永远都不要觉得够用就好 动力 0 1
# 不可否认7儿子的配件都是进口的，所以贵啊，不是一般的贵，想买斯巴鲁，还是先去4儿子看看配件的价格吧，一般的收入不高，果断放弃，如果你爱折腾无所谓，他们对比的车竟然是宝马X3。一般很多配件比如三元 氧传感器 方向机 角度传感器等等一个月才有配件，让你急着用车的时候想死的心都有。 价格 0 -1
# 能选2.5的尽量买2.5的 2.0动力市区也够用了 2.5多了中控彩屏 配置 0 1
# 好便宜啊，这个价格只能上一间酷似狗啊    价格 0 -1
# 等你开个2.3年，就会发现车子的动力不像原来这么足了 动力 0 1
# 这个在网上卖，有很多的，只要相互匹配的车型的话，只要价格买高一点，应该质量不会差到哪里去。 价格 0 -1
# 没有2.5L车型，销量将少一半，轻度越野无动力，要四驱有何用 动力 0 1
# 我问了江门中运，回复在日规版基础上适当调整配置。没有明确回复动力配置。估计动力会和日本一样。     配置 0 -1
# 我问了江门中运，回复在日规版基础上适当调整配置。没有明确回复动力配置。估计动力会和日本一样。     动力 0 -1
# 沃尔沃已经不是以前的喔喔了 是以安全著称的，综合性能方面个人觉得斯巴鲁好一些。从来没见来喔喔去越野旅行的 动力 0 1
# 我加了，打算去掉，作为外观党，感觉不协调 外观 0 -1
# 动力目前还算满意 当然谁不想追求更燥呢……     动力 0 1
# 很多喜欢动力强的只是更喜欢推背感和大脚油门超车的快感罢了。追求虐人的爽快～你2.0拉到160下高速上不要减速也可以玩的很嗨。你的言论不能苟同     动力 0 1
# 新款取消2.5的了，如果只想2.0就还是等吧，但我觉得2.5会好一点。等快换代时价格应该会好点。     价格 0 -1
# 这个价格是真心便宜啊！比我谈下来的价格便宜了将近2万哦！     价格 0 1
# 看空间需求！森空间肯定比XV好 空间 0 -1
# 看到新XV外观小改，更有层次感了，不如等上市看一下 外观 0 -1
# 米其林轮胎不错，基本是静音，舒适，安全的代名词，噪音控制一直是米其林引以为豪的优势，而且比其他轮胎在制动距离方面有优势，所以也是安全性高的一个体现，因为柔软的质地，吸震减震方面也是非常不错的，几乎涵盖了除了耐用性之外的其他特点了。 舒适性 0 1
# 其实我一直很不理解为啥很多人都把斯巴鲁的内饰说的如此不堪……其实我觉得真的还OK啊！     内饰 0 -1
# 做做工作，配件不便宜。保养没多贵。     价格 0 -1
# 森林人等红灯怠速不显示油耗？我等红灯的时候尤其是刚动车行驶距离不长的是，短距离油耗蹭蹭的往上涨，路况稍好开一小段距离油耗就下来了，森林人可不像某些怠速不计入油耗的恶心车企     油耗 0 -1
# 用油箱指针格评油耗，也只有你们了，关键看油浮子准确不 油耗 0 -1
# 大哥首保是免费的 你还能指望啥吧 如果不是怕质保时间发动机出问题 我首保就换其他机油了 动力 0 -1
# 使用carplay以后必须用手机上的地图导航吗？手机后装的高德地图之类的导航能用吗？    配置 0 -1
# 你这个油耗算正常的，新款FB发动机 cvt，论坛里是很多人开到7-8个油的平均市区油耗，不管你信不信，多个CVT能省四五个油，我是不信！毕竟2.5的四驱车，又不是混动！ 油耗 0 1
# 好像是 你在质保期内反映过油温过高或者烧机油问题就还会免费解决    动力 0 -1
# 均速20以下，每少一个速度，油耗变化有时候会很大，越低的时候差距越大，看了几个朋友的均速及油耗得出的结论，有时候差一个速度就是很堵和一般堵的区别了     油耗 0 -1
# 我也想入，就想问问11/12的烧机油不，求高速，是所有都烧还是部分少 动力 0 -1
# 途观还比森林人越野性能好点，这是我今年听到最大的笑话 动力 0 1
# 经鉴定，是正品 刹车片的声音，我的也有，听说是无解，只能换。16款森林人，现在25000了，刹车还是有声音。。。 舒适性 0 -1
# 我车5月26日满4年，现在9万多公里今天刚换了后轮轴承发动机烧机油有爆震，由于已过保无法索赔，5万多时换左右下悬臂索赔了的，说实话森林人质量真不咱地。 动力 0 -1
# 18寸轮毂、LED大灯、大灯随动转向、液晶仪表盘、中控小彩屏 以上都是全系标配？这有点扯淡啊 配置 0 1
# 我是装的歌乐，不过出去导航都是用手机，方便升级快 配置 0 1
# 斯巴鲁的操控确实不错，十一可以开着我斯巴鲁游玩了，走起来 操控 0 1
# 昂科威最大的问题是后排头部空间和500升都不到后备箱。     空间 0 -1
# 斯巴鲁四驱是针对公路的，紧急并线驾驶极限比rav4高，内饰做工稍差……我是2.0的，4万公里暂时不烧机油。楼主要是喜欢驾驶的话买森林人，rav4适合那种代步对驾驶感要求不高的。 内饰 0 1
# 应该是老款森林人拆下来的，几乎全新，主要不带导航，导航是鸡肋，还不如手机，关键尺寸和16款完美匹配，日本原产     配置 0 -1
# CDX、森林人 价格差不多。一个是合资车一个是进口车。所以我觉得还是森林人 价格 0 -1
# 不错 在郊区有斯巴鲁小货车 不知道是不是水平发动机 动力 0 1
# 烧机油是普遍现象，看个人理解了，有些车主认为是一个设计缺陷，我觉得还好，没机械方面的问题，这个车就是ok的。 不一定安索消耗就小。 换机油品牌对消耗程度基本没影响。多留意机油标尺添加机油即可     动力 0 -1
# 要看个人还是车行，跑八万买过来要做大大保健，价格有点高15以下可以出手。 价格 0 -1
# 18配置太好了，真的很实用，我觉得就差无钥匙进入和启动了，够了 配置 0 -1
# 可以的，直接利用原车中控当作显示屏，切换动作来自倒车、转向、双闪三种信号。     配置 0 -1
# 18森还是这个破导航！ 配置 0 -1
# 当初就是选择es而没有选择2.0t，现在觉得2.5动力不是很足够，不过es真好用 动力 0 1
# 刹车盘应该不用换，换耐磨士的陶瓷刹车片就很好了，一千左右前后片。 安全性 0 -1
# 森林人是主打车型买xv还不如买价格同等轿车选择余地大的多 价格 0 -1
# 新森刚出来说不定价格更恶心，建议汉兰达，其实高配冠道挺好的，也值得考虑。 价格 0 1
# 看你在科雷傲论坛咨询过科雷傲次顶配，哈哈，我在森林人论坛发过后悔没提森林人，我的科雷傲是次顶配，你的森林人是我想要的配置，真巧，一年啦，我的科雷傲开着还行，你的森林人应该比科雷傲更好吧 配置 0 -1
# 受教。如果能有一款底盘兼顾韧性、整、路感、灵活、舒适就好了 操控 0 1
# 我初期选斯巴鲁的主要原因还是安全性，驾驶感受是之后才成粉的～内饰虽然人人说丑，但环保无毒也是很赞的一点。其他的么……反正还好我买的森林人没毛病 内饰 0 -1
# 凯美瑞合资不是挺好么？别小看国产车，广汽丰田的品控是众多品牌中数一数二的，在全世界的丰田工厂里都是名列前茅的。我巴不得斯巴鲁国产呢，避开关税，价格最少也能下滑20%，多好。 价格 0 -1
# 掌握方法很方便拆装，两勾两卡。装的时候先勾后卡，拆的时候先拗开下面两卡位再往上一顶就出来某宝搜森林人后视镜片价格80那家好像在卖（但我没在他那里买） 价格 0 -1
# 斯巴鲁特殊，找个懂行的看看吧……价格很不错 价格 0 1
# 其实参照levorg的外观打造，保留大鼻子，一定是爆款啊。。真搞不懂SUBARU。。。 外观 0 -1
# 95的最适合，目前六万了，没有爆震问题，加过几次92明显出现爆震和加速不顺畅 动力 0 -1
# 看了这个外观，很庆幸没继续等买了18款的 外观 0 -1
# 让速不让道，踩刹车就可以的事情。 安全性 0 -1
# 假新闻，太假了，怎么会刹车和定速巡航两个独立的系统同时失灵，刹车系统有绝对的优先权。 安全性 0 1
# 很多尾灯轮毂菊花音响中控屏隔音 配置 0 -1
# x1太小了，男人开确实不太适合，后排空间也比森小很多，有孩子以后会觉得后排空间还是很有用的，x3可以考虑 空间 0 -1
# 之所以考虑再入斯巴鲁，主要考虑省油、操控好、跑烂路耐操。不太看重舒适性，噪音问题……森林人应该不会比BRZ更令人困扰的吧？ 操控 0 1
# 之所以考虑再入斯巴鲁，主要考虑省油、操控好、跑烂路耐操。不太看重舒适性，噪音问题……森林人应该不会比BRZ更令人困扰的吧？ 舒适性 0 1
# 好像新发动机力气大了点 动力 0 1
# 跨度有点大吧！翻了一倍的价格。经济实用家庭用，新凯美瑞。商务出行且需要面子，奔驰E。低调性价比高，沃尔沃S90。 价格 0 1
# 我的森也是换G012，个人感觉胎躁还好，油耗变化不大（原来最担心的）。但是走烂路感觉好太多了。     油耗 0 -1
# 18款森林人配置不低，我一开始也是想买xv顶配，对比之后现在已经交了森林人的定金。森林人的空间确实不是xv能比的。 空间 0 1
# 傲虎舒适性更好，森林人通过性和操控更好。所以看你更看重哪一点？还是去试驾，坐进去感受一下再选择吧。 操控 0 1
# 要是2.5不烧机油，绝对2.5，2.0加速不是很给力，油耗并不会比2.5低 油耗 0 1
# 怎么说呢。。应该是感觉差不多。。因为电动机相应更快其实也是动力的表现    动力 0 -1
# 动力够用，某东自营买一个汽油添加剂就ok 动力 0 1
# 价格还是很合适的，赶快入手吧 价格 0 -1
# 都写的很清楚了，森傲维修，自己开修理厂的，当然可以开的久啊，坏了自己修，成本可以低不少，保养品的货源也可以搞到价格最低的的真品，所以懂车才能买斯巴鲁，等买给了下家车主手上试试 价格 0 1
# 奇骏是纯工具代步车，森林人是买来享受操控乐趣的。两个车都能满足越野需求 操控 0 1
# GT是伟大的旅行的缩写，动力操控长途旅行各方面吊打森林人，非要找缺点的话，森林人短些刨泥坑好点吧，对比傲虎还行，作为紧凑型suv森林人对比的是道奇酷威 操控 0 1
# 我就觉得远不如现款好看，仅外观上来说。内在比如强度平台的技术之类肯定还是进步的。    外观 0 1
# 没问题，去年2.0的川进青出。没有任何问题，只是高海拔动力减弱。 动力 0 1
# 森林人就应该方正一点有气势，可以多学习路虎设计，外观这块实在是太弱了。19新款比原来都差了不少，日本人不知道怎么了这么多年工业设计反而都往下走了。中国的国产车反而设计上在蹭蹭地往上走。 外观 0 -1
# 讲真，我也不知道2.5为啥不进入中国。可能销量占比太少吧，毕竟森林人还是2.0买的多，而且消费税率也悬殊一些。上2.0混动价格方面竞争性会更强一些。    价格 0 -1
# 是的，好像普遍烧机油的是2.4的，别的型号应该还可以的，但是2.0的动力偏弱，买2.4的真要看脸，我自认运气不行，所以不能赌 ，如果森没有符合要求的，那就只能看自由光2.0T的了，不过个人还是喜欢自吸的车子，好纠结，还是希望斯巴鲁能给力点吧    动力 0 -1
# 现在关税也降了，我觉得还有下探空间，要清库存上新款了     空间 0 1
# 是fb的发动机，没感觉烧机油现在，主要在市区开的多，基本不跑高速，一年就6000公里足够了。。。     动力 0 -1
# 动力强劲油耗低无异味异响过湾平稳爬雪地牛叉！我是2、0L 油耗 0 1
# FB25烧机油漏机油都很正常啊 动力 0 -1
# 天窗开关位置也响，听声音是里面响，用手顶住就不响了，怎么办 舒适性 0 -1
# 2.5吧，超车啥的都利索，别2.0买了又纠结开的又不舒服，这东西，油耗又没有相差多夸张，动力储备一定要充足，平时虽说用不了，关键时刻也许能救命的 动力 0 1
# 森林人发动机特殊，一定要用好的全合成（顶级）油，侧重发动机润滑保护，不要考虑微乎其微那么点燃油经济性。    动力 0 -1
# 重点检查刹车片，清洗卡钳 安全性 0 1
# 那些论坛里晒2.5油耗7左右，并且纯市区的，我是非常佩服！我只知道连1.5自动小两厢车市区开空调油耗都要9 油耗 0 -1
# STI空调泵有点异响很正常，通病，我换了3个泵才换到一个很好的声音不算大的泵。。。    舒适性 0 -1
# 这车噪音大，烧机油，内饰普通，退了不后悔，真的，我也后悔买这车了 舒适性 0 -1
# 奇骏太软了，像坐在沙发里面开车一样。途观方向盘又太硬，典型的大众范，油门和刹车都是硬 安全性 0 1
# 前后杠是塑料，车身是金属，他们的底色是有区别的，所以喷漆就会有区别，只是白色更明显一点，不要在意这些细节。如帮助到您，请点击回复下方的采纳，谢谢！ 外观 0 -1
# 还不如买豪华版吧，獠牙版就是前脸变化大，豪华版好像保留了前脸样子     外观 0 -1
# 比加速是找虐。不过森综合起来比迈腾更实用，自己喜欢就好 动力 0 1
# 用钥匙解锁直接恢复记忆座椅这个细节功能确实很人性化、 内饰 0 -1
# 应该是没踩刹车启动车子，然后挂空挡     安全性 0 -1
# 两车同档次同级别，关键还是外观取向。本人就很不习惯CRV变态的臀部。 外观 0 -1
# 是新款，但是我感觉白车搞个黑色的有点不伦不类，没现款协调好看。 外观 0 -1
# 刹车总泵顶装后，刹车感觉怎么样？ 安全性 0 -1
# 2.0在3000米以上加速无力，2.5在4000米以上加速无力。剩下自己考虑 动力 0 -1
# 就这车而言，95确实比92更好用，也更能延长发动机的寿命。 动力 0 1
# 了解，就是感觉不太喜欢cvt的加速感 动力 0 1
# 快了应该七八月，配置增加不少。但听其它贴听说森林人年底有小改款不知真假！ 配置 0 -1
# 刹车开关或者刹车灯泡问题。。 安全性 0 -1
# ，以前关注过奇骏，外观不喜欢，没有试驾过，有人说森林人外观不好看，我自己到是觉的挺好看的，比较硬朗。 外观 0 1
# 最根本的问题是方向盘是歪的 操控 0 -1
# 说实话旗舰店4L500出头就是没有性价比了，更别说平时标价，纯粹是宰客，所以要买除非有更低的价格。 价格 0 1
# 没用原车的，用的原来导航的。 配置 0 -1
# 另外这款中控是电容屏吗？ 配置 0 -1
# 发动机没那么脆弱，看见有人直接高压水枪重新发动机舱 动力 0 -1
# 自然吸气的绝对动力肯定没发跟涡轮增压比啊，但是平顺顺滑而且油耗低。 油耗 0 1
# 自然吸气的绝对动力肯定没发跟涡轮增压比啊，但是平顺顺滑而且油耗低。 动力 0 1
# 因为水平，重心得到很好的控制，车身稳定，发动机震动还是有的 动力 0 1
# 要是这么比，肯定选时尚，差一万，外观漂亮多了，獠牙，尾翼，18寸轮圈，自动头灯。档把区也不一样，时尚的好看 外观 0 -1
# 没来过2.5不知道2.5的油耗。2.0T跑国道一般就是六个多油，跑高速一般不超120的话也就是七个油，一箱油跑七百公里没问题 油耗 0 -1
# 其他不做评价，但一直觉得指南者的外观，是这个级别里最漂亮的，没有之一 外观 0 1
# 新车时就上限多一厘米，我觉得只要加速不肉应该就没问题 动力 0 -1
# 破话车身的平衡性，让驾驶员无法判断车身极限的到来， 外观 0 -1
# 还有运动踏板，车身镀络装饰条。 外观 0 -1
# 车载导航没意思，我都用手机导航的。 配置 0 -1
# 这价格不错了，我是春节前在西安提的2.5同款，优惠三千，啥也没送。 价格 0 -1
# 水平发动机，润滑难度本身就高，机油换早些应该会降低点磨损，我这样理解，所以5000换的 动力 0 -1
# 导航我觉得太恶心了，其他目前感觉还好 配置 0 -1
# 感觉有点烧机油，去4s测了一下没故障码，但修理工说这个款都烧机油     动力 0 -1
# 出门自驾游还是森林人有优势，一是开长途空间大不容易疲劳，二是半拉子越野车（承载式车身经常能不自量力的跟霸道比划比划）能对付困难路面。当然了，上下班用ｘｖ就行了。 空间 0 1
# 出门自驾游还是森林人有优势，一是开长途空间大不容易疲劳，二是半拉子越野车（承载式车身经常能不自量力的跟霸道比划比划）能对付困难路面。当然了，上下班用ｘｖ就行了。 外观 0 -1
# 帕杰罗块头太大，油耗有点高，噪音略大。此车最大的优点，霸气，好看！ 油耗 0 -1
# 低速80以下噪音完全可以接受，超过80就比较严重，主要是风噪和胎噪，高速120的时候车内听广播都费劲 舒适性 0 -1
# 机械手刹是安全的最后一道防线，机械的可以控制刹车力度，电子的能吗？机械的能漂移，电子的能吗？ 安全性 0 1
# 不要太在意那自动刹车，我试傲虎时，用自鹰眼自动跟车，脚没在刹车上总觉的不爽。但一踩又自动关闭，可以说，我要做的动作比以前没这系统的还要多。 安全性 0 1
# 配置有提升，三大件没变。 配置 0 -1
# 车身设计有一定的韧性，加强件增加的是车身的刚性。 外观 0 -1
# 保养不贵，零件的价格现在相对很合理，对比进口大众要便宜。 价格 0 -1
# 除了前灯，外观上没区别！增加了些有用的配置，算是有些改动吧。生产商有改进的想法就行，一成不变跟不上时代 外观 0 -1
# 搜刹车开关，论坛里已经有大把问题了，这毛病必须召回了， 安全性 0 -1
# 中控导航里面的线头会有异响 配置 0 -1
# 我还没搞完，想把它放进中控里面 配置 0 -1
# 进口品质又如何，内饰垃圾，还异响 内饰 0 -1
# 13款2.5，目前52000KM，平均油耗11.4， 高速最高跑出13.8.那些跑出个位数油耗的基本是瞬间油耗，要不就是省油大师 油耗 0 -1
# 八楼说得对，森的内饰板基本是卡扣，卡得也不紧，松垮垮的，恼火球得很。 内饰 0 -1
# 保养不贵了解清楚再说，至于维修费用不容易坏还考虑这个做什么 ，配件价格还可以就是等件时间长到是真的 价格 0 -1
# 正常，这国产的垃圾导航，趁早换了吧 配置 0 -1
# 多余的那些配置如果你觉得对你来说值，那就就买新款。否则老款更实惠。 配置 0 1
# 是FB发动机吗？听说换了FB发动机之后的第一批烧机油比较严重 动力 0 -1
# 配件需要等，维修费用高。用买二手车的价格买个新的更好用。 价格 0 -1
# 车子其实也不能完全看动力，各有所爱！ 动力 0 -1
# 这批发动机漏油严重，抬发动机6000起步价 动力 0 -1
# 森林人主打不是音乐是风噪，哈哈 动力 0 1
# 我知到换水泵没听说换气囊 安全性 0 -1
# 就这一堆外观件注定了不是森林人的范 外观 0 -1
# 所以买18款的还是豪华的最实在，那点配置区别不值1万。 配置 0 -1
# 冷车转速高是其一，这车发动机声音的确大是其二！ 动力 0 1
# 咱的老森4at 油耗都偏大点 油耗 0 -1
# 哎，不只是油耗，顿挫感也是杠杠的， 油耗 0 -1
# 冬天机油粘度增加，阻力增加，还有热车时间长，都会增加油耗，在不开空调的情况下，会比平时高0.4-1个左右，我春秋能开7.6个，目前8个油了。 油耗 0 -1
# 八错！说实话中控有点丑 配置 0 -1
# 应该是水平对置的发动机，只有保时捷和斯巴鲁 动力 0 1
# 我以前是两台森一09，2．0跑了30W左右换的拆车机器，动力，质量非常好，去年卖了 动力 0 1
# 动力的话倒不是很介意，主要是城市里开，偶尔出去浪一下就好 动力 0 1
# 这个价格很诱惑，具体看车况给价格 价格 0 -1
# 考虑了一下我还是决定丰田，斯巴鲁的价格还是高了一些（相比日本），保养也贵，而且在我这个城市没有四儿子店也不方便 价格 0 -1
# 老爷子10款的森林人换了15款的傲虎，严格来说傲虎就不算suv，就是一个跨界旅行车，因为乘坐空间有点矮，但是比森林人舒服， 空间 0 1
# 总觉得棕色太商务，不过配银色车身倒是别有一番味道！恭喜?? 外观 0 -1
# 听说米其林的胎噪音低，我也正在考虑 舒适性 0 1
# 是的，看动力选择和设计取向了，希望森林人还是那个森林人。 动力 0 1
# 外观不要改太多，硬派些 外观 0 -1
# 对一分钱一分货。换位思考人车好好的可能特便宜卖你吗。二手车最忌讳贪便宜。正经车商的车都是有一个市场定价的。低于市场价格肯定有问题。 价格 0 -1
# 531

# %%
d = pd.read_csv('result++/final_result++.csv')
d.loc[change_ind, 'sentiment_value'] = change_sents
d.to_csv('result+++/merge_final_result++.csv', index = False)
dt.loc[change_ind, 'sentiment_value'] = change_sents
dt.to_csv('result+++/see_merge_final_result++.csv', index = False)

# %%
dt[dt['sentiment_value'] == 1]
# Out:
#             content_id subject  sentiment_value  sentiment_word  \
# 20    qIUiOxGdb0M4PQky      油耗                1             NaN
# 27    fYtbApDWqzGmKX8F     舒适性                1             NaN
# 28    fYtbApDWqzGmKX8F      动力                1             NaN
# 31    hNVSLDr06cMsgwfI      空间                1             NaN
# 33    aV6A5z8pJRkKIC9r      外观                1             NaN
# 38    l94kJgMBpYoODyzQ     安全性                1             NaN
# 45    M3Hqx1Un8ygzFTtl      动力                1             NaN
# 60    EKI7PjFs81Lc52uS      动力                1             NaN
# 65    qvD82LNTpMdsAXIe      动力                1             NaN
# 66    sKPpYiV2bXWEjTLc      空间                1             NaN
# 89    p0FUwsNPYQKl1HSg     安全性                1             NaN
# 94    Q6aR7udCFz4U5jrI      油耗                1             NaN
# 107   x6mbO2rHfU3hTej4      内饰                1             NaN
# 108   8Hdtp2WE6nMf93YP      动力                1             NaN
# 118   42VhMRSsCcn85kEd      动力                1             NaN
# 137   9firBmw7PNz0XQyE      动力                1             NaN
# 139   bJ5L9HBuvqgPm3O2      外观                1             NaN
# 141   HkGilbeypwMczdoQ      外观                1             NaN
# 160   N9CZ1kQdnrxPaqRs      空间                1             NaN
# 161   zXPLFe5Sqvc06RuG      空间                1             NaN
# 162   zXPLFe5Sqvc06RuG      外观                1             NaN
# 164   JlWDb4BCsTiN2Ie3      动力                1             NaN
# 166   O7j9h8MaymUvVAtT      价格                1             NaN
# 172   N0MLJFXRIE3wVl9d      动力                1             NaN
# 209   qopu4EsiAz9KU7MC      空间                1             NaN
# 224   Z1kNWAOM9rYol0Ve      空间                1             NaN
# 228   Krp3Gzk2aNhHJ6R7      动力                1             NaN
# 230   axPES1MA7I8BlcvO      操控                1             NaN
# 243   tpl0FmwfHdM13qZK      操控                1             NaN
# 244   6oPvUG1VLyzSKxOM      空间                1             NaN
# ...                ...     ...              ...             ...
# 2285  4vHOx2oj7cmynaG1      动力                1             NaN
# 2288  dysLaH7rFpxUNwTG      操控                1             NaN
# 2289  dysLaH7rFpxUNwTG      空间                1             NaN
# 2296  jE6k7BXpZLNWl1hQ      外观                1             NaN
# 2302  dloSVE124GTviNPL      价格                1             NaN
# 2328  Z1quzevkUXF9JplK      油耗                1             NaN
# 2329  Z1quzevkUXF9JplK      动力                1             NaN
# 2333  WsSnOLBp2wqvmxoy      动力                1             NaN
# 2346  blzhHtvQLcxIyfod      外观                1             NaN
# 2398  YbZsXMk3PvaVQnLK      空间                1             NaN
# 2404  4thTeMKoNiIgx65W      外观                1             NaN
# 2406  sMi23mko0HIQtY8g     安全性                1             NaN
# 2425  af8n9cRIS4Vq0jmH      空间                1             NaN
# 2427  JRAFg3bDo1C67q9h      空间                1             NaN
# 2431  3qravlupfdIAMznx      空间                1             NaN
# 2440  3m7VUknLa6Ff5rPc     安全性                1             NaN
# 2441  LaPs4F8Q9q0Wewp5     安全性                1             NaN
# 2442  aB6ythMmUQL4TneC      动力                1             NaN
# 2496  cADZp9bExndsOuWC      配置                1             NaN
# 2518  9hv6gmwl0XbRKArI      动力                1             NaN
# 2545  6nulXChYs8biaKg7      操控                1             NaN
# 2546  6nulXChYs8biaKg7      内饰                1             NaN
# 2548  FVOZ4U9adMc6gnRb      动力                1             NaN
# 2564  itm5q6I1z8vf7ZMD      动力                1             NaN
# 2569  ytm3xPrzZ4OuXIH1      动力                1             NaN
# 2575  YT5pdexbmOQwG7hR      动力                1             NaN
# 2597  vPCDf2OemEGh4jzl      空间                1             NaN
# 2601  H8jYWQ5gMADxtmuh     舒适性                1             NaN
# 2604  hGPD9vBZgR6zNV4S      动力                1             NaN
# 2624  4p5xbNDUMLAwvzrY      动力                1             NaN
#
#                                                 content
# 20                                    接孩子应该就在城区，这油耗正常的。
# 27    坐标深圳！我开26℃都觉得凉…动力嘛真不好说每个人感受和需求不一样…车子坐4人开了空调我倒觉...
# 28    坐标深圳！我开26℃都觉得凉…动力嘛真不好说每个人感受和需求不一样…车子坐4人开了空调我倒觉...
# 31    除开这四点 森林人还有很多缺点 比如内饰做工廉价感十足 高速上了120噪音大 CVT牺牲驾驶...
# 33    棕色内饰挺好看，主要是新颖，经常有人问：森林人内饰还有棕色的呢？是新款吧？比以前的好看......
# 38                            我这有套力狮GT的全套刹车给你换上比你原装的要好，
# 45    我有一个朋友是玩越野的，一直不待见城市SUV的四驱性能，直到有一次一辆森林人跟着他们一起出去...
# 60                           反正我三年7万多公里。发动机杠杠的 一直级护
# 65    有一定速度后再踩到2000转是很平稳很舒服，我是等红灯起步的时候，从静止开始脚一重就瞬间两千...
# 66                                   q3呗。森林人倒是比q3空间大多了。
# 89                               力狮GT的刹车换上，就好了，我有一套你要吗，
# 94    全程100公里，四个成人加行李少量，国道限速六十占了总路程四分之一，正常路况非下坡，最低单程...
# 107               噪音方面我感觉还行，比我以前的轩逸不大，内饰味道很小，进口车品质还是不错的
# 108         2.0动力就够用，别上2.5，性价比太低了，乞丐版性价比最高，自己换个氙气大灯，完美！
# 118                       动力不错，但左后臂渗油，以12.88。出手。不知是否吃机油
# 137   2015款 2.0特装版车主，这车就不是让你在动力方面会很爽的车，有点后悔没买奥迪A4，但市...
# 139                                     觉得这个蓝比石英珠光蓝好看多了
# 141   我还是挺喜欢12款的外观，有点像放小版的GLK，座椅还有灰色顶面和那些塑料感真的想换掉。2....
# 160                                    只要空间要求没那么大，那肯定xv
# 161   我个人觉得不是空间问题。只是更喜欢森林人外观。xv不太喜欢。但是价钱上面很是喜欢……我对空间...
# 162   我个人觉得不是空间问题。只是更喜欢森林人外观。xv不太喜欢。但是价钱上面很是喜欢……我对空间...
# 164   解释的不错，童年车，比你多开一万。我的加速硬币声只有在上坡且速度较慢时才有。机油灯6万只亮过...
# 166   在价格相差不大的情况下，能选新款的选新款，毕竟很多小功能方面的提升，还有18款的国4，16款...
# 172                         不要烦了，2.0的够用，要动力感觉好的话当然2.5的啦
# 209                             对后排空间要求不高一定是新款XV，新平台不一样
# 224                                   SUV后排舒适性肯定没轿车商务车好
# 228   我有过02年的老奥迪a6 2.4排量 v6发动机 高速6.5 森林人高速平均9个油 市区12...
# 230   的确如此。那时候的森林人，简单粗暴，操控不错，就是舒适性相对现在的而言，的确有些无法形容……...
# 243   家里有进口老指2.4和森林人2.5的表示这两款各有味道。而国产新指在4s看过就是自由侠plu...
# 244   q5只坐过没开过，但比较下来Q5除了牌子响亮，好多还真比不上森林人。空间比森林人小，后排中间...
# ...                                                 ...
# 2285                                 了解，就是感觉不太喜欢cvt的加速感
# 2288  一个人开森林人，全家使用后排经常坐人就途观。森林人对路面反馈太积极，一个人开是爽了，后面坐车...
# 2289  一个人开森林人，全家使用后排经常坐人就途观。森林人对路面反馈太积极，一个人开是爽了，后面坐车...
# 2296  ，以前关注过奇骏，外观不喜欢，没有试驾过，有人说森林人外观不好看，我自己到是觉的挺好看的，比...
# 2302  说实话旗舰店4L500出头就是没有性价比了，更别说平时标价，纯粹是宰客，所以要买除非有更低的价格。
# 2328                  自然吸气的绝对动力肯定没发跟涡轮增压比啊，但是平顺顺滑而且油耗低。
# 2329                  自然吸气的绝对动力肯定没发跟涡轮增压比啊，但是平顺顺滑而且油耗低。
# 2333                      因为水平，重心得到很好的控制，车身稳定，发动机震动还是有的
# 2346                 其他不做评价，但一直觉得指南者的外观，是这个级别里最漂亮的，没有之一
# 2398  我也同意。自由光就是样子。唉 空间森林人好一点，看楼主喜欢啥了吧。我刚买森林人，我也纠结过市...
# 2404  主要是森的性能取向用途这些，感觉更适合原来的尾灯风格。其实可以多学习一下路虎，平直的线条用好...
# 2406  效果肯定是AP好啊。WRX刹车只能说够用，要刹车好用那还是STI刹车好用点，AP刹车向德系一...
# 2425  我开沃尔沃，想再买辆小的SUV。XV大小合适，顶配ES安全配置和沃尔沃相当了，就是质感差点。...
# 2427                      后排空调出风口、后排USB接口、盲区提醒、人脸识别疲劳提醒
# 2431  出门自驾游还是森林人有优势，一是开长途空间大不容易疲劳，二是半拉子越野车（承载式车身经常能不...
# 2440     机械手刹是安全的最后一道防线，机械的可以控制刹车力度，电子的能吗？机械的能漂移，电子的能吗？
# 2441  不要太在意那自动刹车，我试傲虎时，用自鹰眼自动跟车，脚没在刹车上总觉的不爽。但一踩又自动关闭...
# 2442  没啥纠结的肯定森林人，性能出众。耐用性什么的都要比Jeep强太多......特别是Eyesi...
# 2496                  多余的那些配置如果你觉得对你来说值，那就就买新款。否则老款更实惠。
# 2518                                    森林人主打不是音乐是风噪，哈哈
# 2545         在公路操控还是马自达略胜半筹但是差别不大，然而到了烂路上就不一样了。森林人胜在全面。
# 2546         在公路操控还是马自达略胜半筹但是差别不大，然而到了烂路上就不一样了。森林人胜在全面。
# 2548                            冷车转速高是其一，这车发动机声音的确大是其二！
# 2564                              应该是水平对置的发动机，只有保时捷和斯巴鲁
# 2569          我以前是两台森一09，2．0跑了30W左右换的拆车机器，动力，质量非常好，去年卖了
# 2575                       动力的话倒不是很介意，主要是城市里开，偶尔出去浪一下就好
# 2597  老爷子10款的森林人换了15款的傲虎，严格来说傲虎就不算suv，就是一个跨界旅行车，因为乘坐...
# 2601                                  听说米其林的胎噪音低，我也正在考虑
# 2604                       是的，看动力选择和设计取向了，希望森林人还是那个森林人。
# 2624  全时四驱仅比一般SUV车强一点，肯定干不过Q5，XC60，连A4也干不过。水平对置仅体现在低...
#
# [297 rows x 5 columns]
