# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../../data/df_sen_sub/train.csv')
data = data[pd.notnull(data['sentiment_word'])]

# %%
data
# Out:
#             content_id                                            content  \
# 0     vUXizsqexyZVRdFH           因为森林人即将换代，这套系统没必要装在一款即将换代的车型上，因为肯定会影响价格。
# 1     4QroPd9hNfnCHVt7      四驱价格貌似挺高的，高的可以看齐XC60了，看实车前脸有点违和感。不过大众的车应该不会差。
# 2     QmqJ2AvM5GplaRyz  斯柯达要说质量，似乎比大众要好一点，价格也低一些，用料完全一样。我听说过野帝，但没听说过你说...
# 3     KMT1gFJiU4NWrVDn           这玩意都是给有钱任性又不懂车的土豪用的，这价格换一次我妹夫EP020可以换三锅了
# 4     nVIlGd5yMmc37t1o                            17价格忒高，估计也就是14-15左右。
# 5     TVciHBPL5XmUxMEd  我开始就是荣放2.5  森林人2.5二选一    荣放主要是底盘质感不行   太硬  其次是...
# 6     4lb9TsO5rjqUy1Bu                   唉，这货的价格死硬死硬的，低配版优惠1万据说已经罕有了。
# 7     z98xV7MphZIF4EvO                      价格的话只能说一般般吧，太仓前段时间定的比你便宜！
# 8     hoWrMnGTUvdsK3Dm                                听过，价格太贵，但一直念念不忘
# 9     r1WHgbI0ZKqMdELy                                      恭喜恭喜，这个优惠不错哦！
# 10    JSQUo6kblXYvtc2h                                     优惠幅度不小了，北京优惠八千
# 11    7kCF590PjAYqzEL6                         优惠可以了！购进吧！买了不会后悔的！时间可鉴！
# ...

# %%
result = pd.read_csv('result++/see_final_result++.csv')
new_result = pd.read_csv('result++/final_result++.csv')
test = result[result['subject'] == '价格']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '很良心 价格好 实惠 便宜些 优惠幅度不小  费用不高 合适 优惠不错 性价比高 合理 优惠小 找不出第二辆 便宜很多 价格很合适了 价格不错 比较低的 还便宜 真心便宜，秒杀对手    不会后悔 这个价格也超级优惠 再贵的车也没有欧蓝德好 优惠力度还是可以的'.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '售价明显高于竞品 只优惠 挺高 价格过高 价格不合适 不合适 虚高 略贵 降价还是不要想了 高了好多 高昂 咬咬牙的 有钱任性 贵一点 才优惠 不值 没啥优惠 奇高 价格贵 单价高 不用考虑了 价格太贵 不会便宜 价格较高 保值率还是大众好一些 不靠谱 保养价格贵 太贵了 价格高 贵太多 小贵 还不如 也贵 套路 价格老贵了 不菲 性价比不算很高 不合算 下不来 不平易近人 不便宜 给个更便宜的价格 优惠太小'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 113 套路 谈价格，是要有点技巧的，可以，提前，做点功课，销售员，每天见得人多了，各种各样的人，所以，他们很会套路。
# 123 不便宜 你这个916WS导航买的不便宜吧！现在的9016S便宜得多，打算多少出？
# 148 价格贵 这个价格贵吗？相对合资车比较，应该差不差不多吧。不能喝BBA比。
# 361 价格贵 价格贵，进口车直接带来的问题就是这个。
# 414 便宜些 昨天试驾了探界者，操控不错，悬架也是运动偏硬，1.5 t的新车价格和新款二手森林人还便宜些。还是情怀啊！
# 417 合适 09-12款都合适，价格800元物流到付
# 421 合适 我也是买的09年的，建议楼主车况好价格合适可以买
# 460 价格好 比南京价格好多了，南京全款时尚落地25.5
# 492 虚高 因为价格虚高，配件贵，保养贵，没有豪华感，国内又是重视外观不重视内在，所以保值低
# 497 合适 挺保值啊，别卖给贩子，遇上合适的人，二手市场森林人价格都挺高，我看过
# 513 合适 就是壳牌和鹏斯配方都是一样的东西都是一样的 想试试壳牌020就试试pup 020就可以了 六七十块钱一瓶 价格合适
# 615 性价比高 山东价格很死，新款优惠力度很小，老款性价比高，可能2w
# 648 价格贵 价格贵，配件也贵，保险也贵，这个就是斯巴鲁的缺点，别的没毛病！
# 674 性价比高 可以考虑一下仕联达隐藏式行车记录仪，价格不贵，性价比高。安装后看不到接线。我就是装的这个品牌的。淘宝有旗舰店，可以咨询一下。
# 795 价格好 佛山几个汽配城都有斯巴鲁专修的。价格还平宜。上我车气缸盖也有一点点漏。问了要吊发动机。价格好像六佰多。
# 846 不便宜 改原车一键启动键一直都可以啊，只是价格都不便宜，就怕出现电脑故障。
# 863 也贵 这价格看不懂，前后桥油980？是指前差后差油吗？这也贵得太离谱了；四滤，机油滤、空气滤、空调滤，还有一个是哪个？怎么算也要不到900吧？你应该是看了外面的两根皮带，正时皮带要拆开正时盖才能看到？其实，正时皮带根本看不出什么问题的，到十万就必须换了，见过几台车没及时换正时套件导致顶缸的，好吓人。
# ...

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '配置']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '四驱好能安全一点  米其林3ST，安静，舒适 整车也比较扎实 视野和通过性好 合适 坦克也没有欧蓝德好 买它的机械性能  配置高 喜欢他的机械手刹 一点问题都没有 只有优点，缺点几乎为零 开着各方面都舒服 压倒性的说欧蓝德更好 丰富 对新森的影响 其他配置真心喜欢 好的不是一点 实用 顶级  机械上还是很皮实的 肯定四驱欧蓝德好     强太多 均衡 提升'.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '机舱里走管子不好走 音质不行 中控差  没有全景天窗很可惜 换个正常点 黑屏 电动尾门太慢 背光  断轴  配置比较低 山寨 不久 没落锁 简配太厉害 挫 主导航垃圾 结实 有声音 有点抖 丑到无力吐槽 车载导航带到沟里 掉了链子 中控山寨 缺失遗憾 硬伤 卡死 有手机导航 手机导航 配置简陋 不是大改款 坑爹 国内减配 垃圾导航'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 10 手机导航 谁还用车载导航呀！用手机导航吧及时性好！而且到港后装的机头不行，在意的话建议去换一个机头顺便改一下音响。森林人及斯巴鲁全系除了2015豪华悦享版是哈卡的音响和日本原装的机头，（我买的此款 ）其他的机头和音响都不行
# 11 垃圾导航 你好，我也是受够了16款的垃圾导航。这个美版主机哪里可以买到？安装后可以完美使用吗，有什么问题？求告知，感激不尽！
# 12 有手机导航 森林人导航确实垃圾。再好的车再好的导航都没有手机导航好用，我提车后只用了二个多月的车载导航就一直用手机导航。
# 14 黑屏 黑屏经常发生啊和手机蓝牙，连接后电话打进来根本听不到对方在说什么，想指往导航功能就会让你上火
# 120 手机导航 目前一般就是用手机导航。车载导航是次要，最多是辅助功能，主要是将来坏了的话，没有倒车影像了。
# 250 硬伤 途观l配置是硬伤，智享不智能，1.8的连天窗都没有，搞笑了
# 458 手机导航 你想说的导航是原车的还是加装的吧？这个你直接咨询经销商就行了啊，个人觉得手机导航方便好用
# 658 手机导航 对啊！我也觉得用手机导航就可以了，所以想把它换成有蓝牙和AUX的Cd机就好，马云家有泰版的森林人CD机，听说效果不错，不知道可不可以完美对插不用破线安装啊！谢谢啦
# 699 山寨 已经重新下载多次，一样问题，郁闷！已经买了一个安卓山寨导航，到货用用看怎么样。
# 872 手机导航 手机导航比车载的还要详细
# 1313 实用 好车，配置升级让人羡慕啊，尤其是有很多实用配置升级。
# 1352 配置高 卧槽比16款配置高太多了
# 1431 垃圾导航 垃圾导航加上拉圾服务，无语
# 1575 手机导航 直接手机导航，又方便又快捷。
# 1679 垃圾导航 垃圾导航、主机。15款特装2.0
# 1742 山寨 你不知道斯巴鲁的导航全部是山寨的吗？
# 1746 山寨 想花钱？看我的：把你那个庞大山寨导航扔了，上某宝收一个原厂的印象换上，买一个卡仕达的云景2S车内后视镜，连电子狗、行车记录仪都省了。
# 1931 实用 18配置太好了，真的很实用，我觉得就差无钥匙进入和启动了，够了
# 2357 手机导航 车载导航没意思，我都用手机导航的。
# 2449 提升 配置有提升，三大件没变。
# 2495 垃圾导航 正常，这国产的垃圾导航，趁早换了吧
# ...

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '舒适性']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '视野好 风力强劲 视野超级好，调好座椅秒杀一切SUV 乘客舒适 坐姿高视线更好 舒服 视野和通过性好  空间舒适没的说 舒服安静 安静 空间坐姿都好点 制冷快 空间大 空间舒适 看中座椅记忆 强 分区空调 噪音减少  静音舒适 恒温 制冷效果好 空调很牛逼'.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '抖动 乱响 噪音烦透了 耳朵不好了 很烦 隔音不好 噪音 个隔音，胎噪件15万的车都不如。听着心烦 特别抖 座椅有点臭 声音很大 格叽格叽响 噪音变大 内部味道较大  后排太硬。 原胎声音我是受不了 土腥味 偏低 有异响 颠  金属撞击响声特别大 抖抖 各种响 大 不会小 硬 滴水现象 比较差 大些 坑 不舒服 异响多 差一点 空调问题 扯淡 异响比较多 音响太差 不严实  声音大  气门声音大     视野不如森 风噪真心大 俩车隔音都不算太好 X1的座椅小的可怜 空调不制冷 风噪最大 发动机噪音确实大 风噪是大了点 唯一不足 噪音偏大 出问题 不严实 有问题打不开 比不过 滋滋声 卡顿 空调不咋样 有噪音 速度快噪音大 不舒服、异响 噪音依旧 不是很舒适 噪音大 有金属敲击的声音 隔音太差 气味呛人 差多了 忽悠 容易晕车 就别想了 不咋地 隔音还不如森 更吵 开着累 差 有点影响 异响 腰疼 毛病多 摩擦音 开空调没劲 发出声音 风噪大 味特别大  隔音效果一般 质量很差 颠簸 有味 颈椎有点累 较差 隔音差 噪音较大'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 104 异响 还好现在异响都是底盘上方，如果是底盘下方就不爽了。
# 106 噪音 噪音方面我感觉还行，比我以前的轩逸不大，内饰味道很小，进口车品质还是不错的
# 128 颠簸 同款 每次窗户开着只要颠簸 就会有共振的响声 左右两边都是这样
# 156 静音舒适 每种轮胎各有千秋吧，看你注重什么方面。像固特异静音舒适、耐用、干湿地、操控性能都是蛮不错的。
# 241 有异响 中控倒没有异响，主要是后备箱异响多
# 259 隔音差 自己开森林人，开过同事的傲虎，这俩车取向完全不一样。森林人偏运动，运动型操控性好于傲虎，内饰做工隔音差于傲虎，适合外出比较多，比较多off road的情况傲虎偏家居，舒适性稳定性好于森林人，适合主要城市用，偶尔off road的情况具体选哪个车就看楼主到底要什么了。另外有条件的话，建议直接上2.0T，我现在就觉得2.5动力不够了。
# 307 噪音 别用长城了，我第一桶长城用起来不错，谁知第二桶大变样，加上后行使顿挫，噪音很大，完全是劣质机油的表现，都是天猫旗舰店买的，也不知是什么原因。气得我半死，用了5天，赶快换掉了。  如果不是假机油，那只能说长城机油品质不稳定，质量差异大，有不合格产品出厂。 我收回以前对长城机油的夸奖
# 333 噪音 一般最高140，一是怕被拍，二是感觉噪音太大了，不大敢踩了
# 334 噪音 高速达到100噪音简直不能忍
# 344 舒服 我感觉森的自动空调很好用，调好温度，直接风凉旋钮调整到auto就可以了，我一般调整到24度，其他都是auto，这时候温度，雾气都会没有，很舒服（同在上海，最近下雨很不爽）
# 369 噪音 120时速开着音响基本上没啥烦人的噪音了。
# 641 噪音 据说新款隔音效果和车身稳定性xv新平台提高不少，森林人应该也一样，等三月份看看吧！再做选择。不差这几个月，也不知道现款跑高速怎样，噪音异响明显吗？试驾车都不让上高速，城区试不出来的
# 663 异响 建议不要买，我2017款2.0豪华版，1万公里发动机异响皮带脱落，更换皮带后异响有所缓解，但现在1.5万公里换机油后异响又来了，还有就是2.0跑高速很肉，建议要买森还是2.5或2.0T
# ...

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '操控']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '好性能 没见过跑14万还有那么好的机器 距离短 就要这么开 操控好 升级 性能好 上了一个档次 操控很满意 随性 不费劲 优势 牛 看点是操控 更好更灵活  轻松 挺稳的 操控性不错 不飘 强 专业 好点 底盘比新森强一些 驾驶质感强 犹如宝马一般 也不错 好用 灵活 非常好 有点性能 舒服 高 甩三条街 自信多了 相当好 操控很棒 没得说 胜出 闻名 稳 追求 好很多 操控性好很多 操控真心不错 破百 漂移 优 操纵好，底盘高 舒适感强  操控也好 比较灵 操控不错 较好 很韧性  方向盘比较轻 操控感 好开'.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in ' 差劲 底盘漏油  抖 飘 味道真不小 废刹车 底盘不是很紧凑 异响 车身的反应较迟钝。 刹车怎么这么软呢   嘎嘎响 脱皮 离地间隙低 响  需要一直微调 走烂路很颠 有点抖 渗油 方向好飘，方向盘总是要不断修正方向 方向盘飘 差很多 偏了 高度只有180mm 刹车盘 飞叉叉 颠簸 承受不起 磨得发亮 静音不好  摆动 设计要是再简练一些就好了 很危险 就是底盘太高了，过坑瞬间比轿车晃动大     刹不住 开起来实在是…. 欠缺 多余的 手感差'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 72 好用 防爆胎又硬又重，好用吗
# 84 漂移 稳定 可靠 还能玩漂移
# 103 异响 还好现在异响都是底盘上方，如果是底盘下方就不爽了。
# 149 操控好 我当年也纠结过这个问题，论坛的老司机们跟我说买森林人的不会买CRV，反过来也一样。两个车我都去看了，森林人驾驶视野宽阔，操控好，原因就不说了，不知道的没必要考虑斯巴鲁了，内饰差点意思。CRV刚好相反。综上，我上周提了18款森林人，手打这么多字，不客气。
# 200 操控好 操控的话是森好些还是翼虎好些？斯巴鲁太少了，翼虎经常开都说森操控好 我想知道多大区别呀
# 230 操控不错 的确如此。那时候的森林人，简单粗暴，操控不错，就是舒适性相对现在的而言，的确有些无法形容……
# 378 好点 虽然森林人在同价位SUV中不输其他同级对手，但是跟上面这几个车比，无论从哪方面比都是自取其辱，除了操控可能比普拉多好点外，其他方面随便一台都秒杀森林人。一分钱一分货啊
# 397 好用 就是调节音量不好用了，可以用方向盘的功能键，
# 415 操控不错 昨天试驾了探界者，操控不错，悬架也是运动偏硬，1.5 t的新车价格和新款二手森林人还便宜些。还是情怀啊！
# 457 操控感 12款森林人，现在越开越喜欢，特别是他的操控感。平时只需正常保养即可。
# 511 操控感 你的要求，是配置高？还是排量大？又或是操控感好？
# 731 操控好 而且经常比森林人强不是非常正常吗，人家硬派越野。你让他跟森林人比比操控好不好啊
# 909 操控好 对空间没有要求的话就果断选择xv，车小操控好，好停车。
# 1069 性能好 森林人性能好，车好看，又省钱，当然是适合于我们这一些初创业者。
# 1210 操控好 我就需要操控好点，价格便宜，烂路也能走的即可.120转弯
# 1234 手感差 对方向盘套尤其抵触，不仅样子难看，土得掉渣，而且手感差，握感太粗，不利于操控安全
# 1306 异响 我的和你不太一样，缓慢的过减速带，车身起伏太大右前底盘就会异响，但是快速过减速带和烂路就不会响。
# 1309 多余的 这个真不好形容，阻尼感是有，过减速带啥的底盘感觉也很整，没有多余的跳动，不会有那种坐轿子一样的感觉
# ...

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '油耗']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '2.0森市区油耗真心不错， 省油不少   省油的 挺省油的 非常满意 很低 油耗高一个 油耗也不高 没有任何油耗现象 油耗下降 低 确实省 油耗真心棒 耐用 最低油耗5.9驾驶体验超级棒 油耗水平已经很满意  省油 不高  油耗没那么高 也不高 油耗低 油耗好 油耗低一些 这油耗牛啊 不一定费油'.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '不省油 爱咋滴就咋滴 上升 油耗会上升 增加 很高  大 油耗有上升 油耗造假 比以前多 大些 升高 高 全行业造假 费油 油耗大 性价比低 油耗太高 不见得省 顶不住 油耗确实很高 油耗蹭蹭的往上涨 太高 油耗哗哗的 油耗不好控制 不公平 1.8T油耗不低 油耗很高 油耗增加 高一点  油耗高 偏大 油耗上升 略高 贼高 不可能低 特大 不着调 高了点 颇高 高很多 增加油耗 高点'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 23 高一点 我13款2.5的2w公里就用30了 。 也没见什么不妥，就是油耗高一点而已。
# 92 增加 这两天突然之间油耗增加了！难道是天凉了的缘故。老森2.0
# 121 省油 我是2.0，9295都加过，好感觉油耗上有区别，反而感觉2.5省油，2.0小马拉大车
# 126 增加 是有些费油，最近全国的燃油都比较有水分。同样的路同样的加油站，几乎相同的路况，油耗现在增加好多了
# 170 省油 其实原厂胎真的不错，排水性一流，还省油，现在用倍耐力P7，胎噪大，油耗大，只是因为是防爆胎，有点不爽.
# 194 高一点 想不明白你这种问题，钱宽裕的话肯定2.5啊，难道买2.5都傻子？我是2.5低配，我认为区别就在于，第一，满载下影响动力小，第二，油耗高一点，也就一个油。这点应该不难选择
# 234 上升 听4s的人说，冬季发动机喷油量会增加，油耗会上升，是这样么？
# 256 不高 森林人油耗都不高，很经济，。只是我觉得2.0L配置够用了，节约下来的银子够开2年的汽油钱了。
# 299 油耗低 说得到位，长城挺好看，不过没开过，森林人我刚开了3280公里的长途回来，还行，就是风大时有点飘，别的都很好，油耗低，基本满分了
# 300 油耗低 斯巴鲁机油混动，大途观不烧机油，理解不了森的油耗低
# 443 油耗高 4AT吧？油耗高很正常啊
# 445 增加 噪音还好，油耗增加.一点
# 573 油耗高 其实看怠速时间长短，经常怠速平均油耗高些，我今天高速跑过5.7。市区就10.4。
# 577 上升 现在用了5格油，剩余油耗里程从300上升到520，会不会有点夸张。
# 626 不高 2.5的好，油耗不高的
# 692 增加 增加车重，油耗增加。我原来想加3个厚的不锈钢板，考虑没梁，加装甲没意义。没大梁是硬伤，不敢豁车。
# 739 不高 14款2，5车主，这车操控性好，视野开阔，后视镜视野同样开阔，四驱雨雪不打滑，油耗不高，140迈内加速快！不好的地方内饰寒酸！隔音差一些！过减速带之类颠的厉害！……
# 792 费油 地盘没问题，油耗基本跟新车时一样，是比较费油，关键提速太快，你车跑多少公里了？
# ...

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '动力']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '堪比跑车 超车 没见过跑14万还有那么好的机器 追不上 动力响应更好 水平对置发动机 全时四驱是最大卖点 四驱无敌 水平对置发动机就是轻啊 发动机很新啊 强劲  加速好点 不烧机油  好动力 提速满意 杠杠的 均衡  加速轻轻松松  有所提升 坦克也没有欧蓝德好 加速不错 动力牛 动力强很多 发动机是好 动力为王 反应敏捷 好很很多 驾驶质感强 改观不少 优势明显 够 啥都好 有动力 高原小霸王 很够用 噪音很小  动力足 用不完的劲 动力更好 提速快 好的多 耐用 随叫随到 完全够用 不为别的，就为了中控台和空间 加速快 没烧 优 发动机专家 动力也够了 非常猛 将开启汽车动力的新篇章 不能比拟 比直列的要轻很多 轻盈 发动机不错  动力强多 比以前快  开着爽 动力不错 动力和空间太诱惑了！ 动力好点 水平对置发动机原来这么稳  猛 全时四驱 四驱旅行 '.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '抖动 有点降低 发动机异味 发动机一直是弊病 偏磨 动力不咋地，1.6T 四缸四驱，超个车都感觉费劲 噪音 故障 降低动力 变速箱大众调教得很差  发动机没力  轻微渗油 降低 转速低 哗啦声 慢 肉 肯定烧 发动机实在太老 差的不是一点点 高性能发动机 飙车差劲 发动机烧漏机油风险大  爆震 老坏 、发动机嘶哑 漏油 不会很快 弱 重新打胶 发动机存在问题 变弱 没动力  动力呵呵 没有以前灵敏 怕动力不够 有一个缸体不工作，严重抖动 动力不行 动力不够 机油不好 加速抖动 车重 动力不足 严重烧机油  后段不行 维修起来麻烦 噪音大 渗油 变速箱差 轰轰响  动力弱 缝隙里油泥不好搞 动机噪声大 下机油 加速缓慢 熄火 机油消耗  急加速不行  烧机油 异响 太吵  没 动力下降  急加速问题 负担大 爬坡也爬不上去 连速腾起步都赶不上 偶尔有顿挫 反应慢  牛车 跟不上变速箱落后是真的'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 22 动力不行 俩车排量都不行，1.5t昂科威动力不行，比2.0t还费油，你图什么？
# 48 下机油 是不是每2000公里测一下机油，每次消耗多少以上才能索赔换中缸？
# 49 烧机油 据说烧机油是常跑高速才会出现，偶尔一次应该不会嘛
# 50 烧机油 烧机油真不是机油问题。
# 51 机油消耗 是的，自从跑了一趟版纳，就拉开了烧机油的大幕。问4S等于白问，喊观察，只承认机油消耗，拒不承认烧机油。
# 52 爆震 烧已换中缸，行驶230kg，机油温度达到103到106是还是爆震……正在交涉
# 53 烧机油 2.0 13款 7万开始烧机油
# 54 烧机油 16款还没有开出7万多公里数，估计没有人烧机油。
# 55 机油消耗 任何车都有机油消耗问题，其实烧机油最多的是神车。
# 57 没烧 我的１５款2.5精英公里数2万，机油5ｗ30，8000公里一换油，没烧。
# 58 烧机油 大多数车友几乎都烧机油，事实决定一切
# 60 杠杠的 反正我三年7万多公里。发动机杠杠的 一直级护
# 64 故障 额 20的森就是没故障码也是加速无力。。。
# 71 异响 车身结构强度较差异响此起彼伏，当它不存在吧。迟早还会响
# 80 超车 这是驾驶模式 i 是默认经济模式，S 是运动超车模式，只有在多功能方向盘 右手边位置有设置~
# 87 全时四驱 途观加95油耗比小森高点，保养差不多，后期维修比小森便宜点，没事故基本问题都不大，小森是全时四驱，31以内唯一，全时和适时有区别，途观做工更扎实一些，如果在北方小森很有优势，不论什么路面，雨雪天气，安全系数高出很多，操控没的说，虽然途观更舒适，但各方面考虑小森没毛病。
# 88 全时四驱 途观加95油耗比小森高点，保养差不多，后期维修比小森便宜点，没事故基本问题都不大，小森是全时四驱，32以内唯一，全时和适时有区别，途观做工更扎实一些，如果在北方小森很有优势，不论什么路面，雨雪天气，安全系数高出很多，操控没的说，虽然途观更舒适，但各方面考虑小森没毛病。
# 97 烧机油 我家岳父大人的2.5烧机油严重，问题是这车是我推荐的，我岳父每次加机油，心里一定在骂我。
# 102 异响 我也是一样的，这车异响太多了
# ...

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '内饰']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '内饰豪华 保持偏硬的造型 对口味 符合 用料不错 内饰也好看 设计上也是不错 大改 骚 品质不错 简洁干练 比森林人强不少 高出一个档次 内饰也可以 做工好 好 漂亮 简约的很  豪华感强 内饰科技感高 吊打 坐进去最放松的 细 好看  带喜感  皮实耐用 好点 好了很多 可以保持 高大上 手感爆炸 没的说 帅 真的不错 内饰真的提升 内饰绝对豪华  新 好看，炫酷'.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '磕碜了点 设计感土土的 内饰全塑料 不细致 差 单调 粗糙 普通 改了也不够 脱皮  惨不忍睹 又硬又凸 座椅臭味 内饰要吐 如此的廉价的感觉 挫 令人发指 影响驾驶 不是一个档次 一股丰田味 内饰太L0W 后排座椅 格叽格叽响 内饰有廉价感 有些粗 落后 不舒坦 内饰太老气 渣 没戏 旧 硬伤 完败 过时 还不如十万块的国产车 松垮 非常一般 做工粗糙 糙 不如现款 科技感也是一如既往的差  破破烂烂的 内饰太寒酸 太差 内饰太过简单粗糟    多丑 不改改 简陋 有点糙 不如 不敢恭维  内饰简陋 不够整 全塑料 内饰低档  不豪华 太水'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 32 好看 棕色内饰挺好看，主要是新颖，经常有人问：森林人内饰还有棕色的呢？是新款吧？比以前的好看......
# 735 后排座椅 飞度吊就吊在它后排座椅的设计太实用了
# 929 完败 论性能，NX200根森林人没法比！雷克萨斯的侧重点不是在性能上，而是在舒适与豪华上！如果比内饰比做工用料森林人应该完败！但是比机械比性能，NX200不是对手
# 945 内饰豪华 途观L我去试驾过，内饰豪华感比森强，后排空间比森多出四指。但有两点不满意，被放弃。一是那个天窗顶棚就是一层薄纱，试驾的时候正好是烈日当头，感觉很晒，遮光性一点都不好。二是全系标配韩泰轮胎，大众标榜自己高安全车身，却不配双好鞋，通常一般人都注意不到。
# 1213 后排座椅 16款里边，2.5豪华是最实用的。 自动感应灯，转向灯，雨刷，方向盘，主驾驶记忆，前排座椅 后排座椅加热。 值得购买 eye-sight我是没赶上，更值得推荐
# 1305 不如 森林人外观内饰都不如刚出的杠5吧，保值率的低下导致买二手车不错，水平对置发动机的后续维护也和你要的省钱省心背道而驰。逼格方面只要不上到bba，哪来的逼格？
# 1870 后排座椅 试了几天，是后排座椅异响。副驾后面的座椅，谢谢了。还有右后窗三角的地方
# 2206 普通 这车噪音大，烧机油，内饰普通，退了不后悔，真的，我也后悔买这车了
# 2490 松垮 八楼说得对，森的内饰板基本是卡扣，卡得也不紧，松垮垮的，恼火球得很。
# 89 9
#             content_id subject  sentiment_value sentiment_word
# 32    aV6A5z8pJRkKIC9r      内饰                1             好看
# 735   KsAywUF0QmbhYG7j      内饰               -1           后排座椅
# 929   BLpnDEK2MgYWqFhR      内饰               -1             完败
# 945   OJAalMdiGVwc68Tk      内饰                1           内饰豪华
# ...

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '安全性']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in ''.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '刹车软，刹车行程距离长 刹车软 刹不住 刹不住、软 急刹车 怎么这么软'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 133 刹不住 斯巴鲁2014款之后就不是高田气囊 。   丰田刹不住是脚垫卡住  。   你三菱爸爸刹车失灵是真的坏了却还嘴硬  。   我不愿意被日本人干死但是也不愿意被无良国产干死，感觉你好像很愿意被干死？  。   而且你爸爸三菱不是日本鬼子？你好好笑哦~你个马甲连灵魂都没有只能卖智商价格还低一吨几毛钱
# 1342 刹车软 森林人刹车软是针对越野及湿滑路面的一种调教，要硬的话不是做不出来
# 1453 刹不住 森林人的刹车还是可靠的，就是刹车行程稍微长点，只要有好的驾驶习惯，不要跟车太近，养成提前制动的好习惯，要是你把刹车搞得一踩就来，一个是你自己开着不舒服，而且就怕后车刹不住撞到你车
# 1492 刹车软 森林人的出厂轮胎抓地力并不好，这的确是个问题。但是制动力矩并不小，我赛道上跑过几次，所以可以对这句话负责。而且刹车点头情况也并不严重，但是和crv比应该差一点，因为没有cvr那么公路。当然，换一套盘和皮以后会更好一些。随便一脚就能踩出防抱死的话，怎么也不能称之为刹车力矩不足吧。千万不要把长行程误解成刹车软。
# 158 4
#             content_id subject  sentiment_value sentiment_word
# 133   tka3Nq9TAR5BH7Ij     安全性               -1            刹不住
# 1342  zO3ND7P0C16gotiw     安全性               -1            刹车软
# 1453  yNW7hAIvr2E43fL0     安全性               -1            刹不住
# 1492  gS8mMHCB5P1LkEKu     安全性               -1            刹车软

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '空间']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '大了很多 空间较大  空间不小 空间很满意 车内空间蛮大 非常好 空间有点 甩三条街 大空间 杀手锏 各方面都好些 空间/后座又宽， 坐进去最放松的 空间舒适没的说 空间大动力可以 空间坐姿都好点 胜出 空间更大 还可以 很漂亮 空间大 大  宽敞 差不多 较大后备箱 不为别的，就为了中控台和空间 空间大很多 舒服的很 够用 车体高 宽大舒适 后备箱大 变大 不小 动力和空间太诱惑了！ 特大 空间也大 是大的 实用 挺好的 挺大 高点 轴距也加长了更宽敞了 容量大  舒服'.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '小了点 不大 较小 后排空间小了点 有点小 宽敞 显小 轴距和空间严重不符 后排挤 太小  小 小一点 ·没有那么大 太小了 空间不行 钻进去 只要是空间小'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 138 够用 2015款 2.0特装版车主，这车就不是让你在动力方面会很爽的车，有点后悔没买奥迪A4，但市区开够用，很实用的空间，过年回家俨然当面包开
# 245 空间大 crv全世界销量都很好，满足了，空间大，故障率低、维护成本低、最新一代四驱系统有加强，（但雨雪、湿滑路面一样不行）。国外的车辆主要贵在维修、保养（人工费很高）。
# 340 变大 我觉得内饰提升 空间变大是王道
# 373 空间不行 cx_5后拍太挤了，空间不行啊……
# 736 实用 飞度吊就吊在它后排座椅的设计太实用了
# 737 大空间 二十万哪是说存就存的。需要大空间车是拉货家用都能用的。现在君威太小了拉不了货。不然也不用着急换了。看来只能买那个奇骏了。虽然内心深爱斯巴鲁森林人
# 840 实用 森林人驾驶有乐趣，可以带你去更多地方，安全性也好，但品牌力不足。三系操控性好，品牌力强***高，但不如suv更实用，坐五个人的时候还是森林人更舒服。途观是神车…对，神车！
# 1219 空间大 经常坐满，要家用空间大，就汉兰达。经常自己开，要点乐趣就森林人。5008可以pass了。
# 1332 空间大 肯定疼，森林人坐垫很短，腿的一半是架空着踩油门和刹车，久了肯定酸，森林人所谓的空间大，是建立在坐垫短的基础上
# 1669 空间大 大哥，你确定开的是森林人吗，2.0轻松上140发动机转速也就2500左右，往上空间大的很啊，而且s模式下转速高，不适合高速开，s模式下120迈发动机3000转。你换i模式开开试试吧
# 2029 太小 x1太小了，男人开确实不太适合，后排空间也比森小很多，有孩子以后会觉得后排空间还是很有用的，x3可以考虑
# 2082 空间大 能上3系GT，就别考虑森林人了，我还准备从森林人换到3GT呢，森林人除了空间大视野好，相比较再无优点
# 2085 大空间 多4公分能感觉宽多少？关键看造型，方正的森林人内部空间宽度比同级别的不差！锐界比汉兰达尺寸都大空间却差远了
# 2382 差不多 如果后备箱不放宠物就完全不用管，弄个和破损地方大小差不多的塑料板，用502粘上就行了，这种地方平时也看不到，又不影响美观啥的
# 2399 空间大 现在考虑傲虎了 ，想空间大点.
# ...

# %%
for key in data['subject'].unique():
    print(key)
    temp = data[data['sentiment_value'] == 0]
    print('0::::')
    print(' '.join(set(temp[temp['subject'] == key]['sentiment_word'])))
    temp = data[data['sentiment_value'] == -1]
    print('-1::::')
    print(' '.join(set(temp[temp['subject'] == key]['sentiment_word'])))
    temp = data[data['sentiment_value'] == 1]
    print('1::::')
    print(' '.join(set(temp[temp['subject'] == key]['sentiment_word'])))
# Out:
# 价格
# 0::::
# 影响 一般 差距不大 贵一点 参差不齐 价格差不多 合适就买 差不多 价格不知道 没啥优惠 不要在意价格 还行吧 价格还行 还行 合理就行 正常价格 也就多几百 行情价 价差很大 低也不能要 小贵 亲民点 优惠 价格一般 哪个贵 不便宜
# -1::::
# 贵太多 有钱任性 没有优势 单价高 优惠太小 略贵 死硬 价格贵 不菲 不合算 贵一点 高 才 售价明显高于竞品 没有保证 咬咬牙的 下不来 高了好多 贵 才优惠 套路 价格过高 降价还是不要想了 挺高 呵呵 没啥优惠 不会便宜 价格太贵 保养价格贵 性价比不算很高 便宜 高昂 高了 没法比 价格较高 奇高 不好 虚高 不值 不用考虑了 贵了 也贵 价格不合适 只优惠 给个更便宜的价格 不高 价格老贵了 放弃 也就那点而已 不合适 价格高   保值率还是大众好一些 不靠谱 小贵 不平易近人 太贵了 还不如 不便宜
# 1::::
# 优惠不错 很不错 比较低的 下降 不贵 找不出第二辆 最好 高 价格好 优惠力度还是可以的  这个价格也超级优惠 相当不错 价格很合适了 优惠幅度不小 价格不错 愉快 价格不够 真心便宜，秒杀对手    操控满意 还便宜 低 便宜很多 合理 再贵的车也没有欧蓝德好 费用不高 性价比高 优惠小 不高 可以的 不会后悔 实惠 值 很良心 便宜些 便宜 不能比的 合适
# 配置
# 0::::
# 无所谓 用导航不少 都一样 是否可以 后窗 手机导航方便 省钱 一般 不带导航 没有导航 手机导航 简单 连线
# -1::::
# 不选 不行 不值钱 结实 车载导航带到沟里 没优势 配置简陋 不实用 背光 差 黑屏 不如 惨不忍睹 不喜欢 手机导航 不值得 坑爹 中控山寨 很差 比不上 丑到无力吐槽 太扯了 贵 差一点 不让人省心 有声音 不咋样 太垃圾 没有 不方便 掉了链子 没落锁 心里凉凉的 山寨 坑 卡死 中控差 不久 简配太厉害 不值 低 垃圾导航 早日完蛋 没 挫 国内减配 硬伤 吐槽 不高 不太重视 没区别 后悔 有手机导航 断轴 黑 换个正常点 不是大改款 主导航垃圾 不能忍 鸡肋 差点 有点抖 配置比较低 机舱里走管子不好走 电动尾门太慢 缺失遗憾 没必要 垃圾 看不上眼 没有全景天窗很可惜 音质不行
# 1::::
# ...

# %%
#result = pd.read_csv('result++/see_final_result++.csv')
test = result[result['subject'] == '外观']
index = test[test['sentiment_value'] == 0].index.tolist()
text = list(test[test['sentiment_value'] == 0]['content'])
flags = []
change_inds = []
change_sents = []
change_words = []
c = 0
for i in range(len(text)):
    flag = 0
    for key in '新款厚重大气 上了一个档次了，隐隐有豪华车的感觉 这么看确实大气点 秒杀 时尚 保持偏硬的造型 看着真舒服 认可度高 大 对口味 大气  前脸好看 低调 外观不错 底盘厉害 外形好看 有面子 喜欢这种前脸 漂亮 好 颜值高 很耐看 硬朗  外观真心赞 帅气~ 好看  前网辨识度很高 高度都一样 看中外观 外形至少本人觉得新款还可以  好看 颜色和光线还可以  合眼缘 个人觉得比较好看 社会社会！ 喜欢森的外形 秀气 降低 厚 逼格高 强化 前脸设计看着精致，协调了 前脸更好看  车的外形也漂亮 挺炫 尊贵 视野好'.split(' '):
        if key != '' and len(key) >= 2 and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(1)
            change_inds.append(index[i])
            change_words.append(key)
            break
    for key in '屁股很不喜欢 颜值差 车漆真软 掰不动 日系车漆软 无力吐槽 硬 难看 摇晃 平庸 取消 差 不协调 真难看 廉价 越丑 有点土 接受度不高 拼凑杀马特 不怎么好看 史上最难看 接受不了 不咋新潮 觉得19款没有老款好看 低级无下限 还是现款好看 前脸无爱 车漆薄 薄 不咋地  挫 车漆薄，软 小 不好看 差点 差很多 外观没有丝毫质感！     中庸 纠结 外观太丑 硬伤 外观奇丑无比 尾灯好丑 怎么看都不协调 老气 倾斜大 不像换代应有的水平 好难看 镀铬太多 让人尴尬 变色 平淡无奇平庸无比 丑 挫样 车漆软 中网丑 里外不一 漆面太薄 外观太小气 多丑'.split(' '):
        if flag == 0 and len(key) >= 2 and key != '' and key in text[i]:
            print(index[i], key, text[i])
            c += 1
            flag = 1
            change_sents.append(-1)
            change_inds.append(index[i])
            change_words.append(key)
            break
print(len(text),c)
new_result.loc[change_inds, 'sentiment_value'] = change_sents
new_result.loc[change_inds, 'sentiment_word'] = change_words
new_result.loc[change_inds]
# Out:
# 81 好看 运动款前脸更好看！个人认为!
# 114 好看 怎么都说斯巴鲁不好看了，我怎么看着不错啊
# 159 好看 这颜色和银色都比较好看
# 178 好看 买雷诺 新产品 样子好看还便宜
# 507 降低 换这个避震，车身降低了吧？
# 580 车漆软 简单咨询了一下，好像可以修复，就是价格很贵，鲨鱼pi报价的1500！另外都说斯巴鲁的漆不容易吸，因为吸盘上去就可能破坏漆面，倒也不是日本车漆软偷工减料，可能是太讲究环保用的料不一样。总之1500好贵了。。。
# 765 尊贵 如果家里不止你一个人开，而且还有新手，那就比较有用了，不光保护别人，还能保护车。当初4s自己配了一款外观和2.5尊贵es一模一样的（獠牙杠，黑尾翼，黑后视镜的），只是不带es，有的店有，有的没有
# 789 取消 据说取消2.0的了，放心2.5是中美特供，不会取消的，我反倒希望全面取消2.5的，换装2.0T，否则买同级别国产2.0T（途观，科迪亚克，昂科威，探界者，翼虎）的面前，动力完全处于劣势。
# 903 好看 我有买来装，负责任的告诉你，绝对值得买。实际装上去比原车美观好看还耐磨耐刮，不会原车那样几年后到处是划痕。而且这东西你装上去压根不用考虑取下来，不锈钢越用越光亮。
# 930 好看 外观没有原车的好看，这是我一直没决定换建伍的原因。最近瞄到纽曼的车PAD不错，准备入手。
# 932 好看 中网霸道，后包围奔驰，确实不好看
# 943 前脸好看 性价比高，轮圈大一寸，带装逼换档拨片，前脸好看，这些功能1W是搞不到的，没追求还是买豪华吧，当然，再没追求建议买其它车！望采纳
# 1087 好看 棕色好看。 要不抛个硬币吧。
# 1137 车漆软 车漆软，不是主要理由，算我没说！问烧机油，说明我沒彻底了解森？何解？请明示！
# 1149 无力吐槽 经典之所以是经典就如经典音乐一样值得时间的检验，这和老不老没关系。牧马人常年保持一贯的设计风格，不是固执，而是文化自信使然。日系车整体外观的垮掉绝非偶然。森林人本身是有自己的文化和设计语言的。可惜的是或许流于世俗，或是寡于内心，完全洗剪吹了～一代名车彻底消失，街上跑的就是奇骏，面包，老款汉兰达加莫名妖娆尾灯的混合体。（轮毂丑的我已无力吐槽）算了，开着四代，好歹还有些影子吧～～～～
# ...

# %%
new_result[new_result['sentiment_value'] == 1]
# Out:
#             content_id subject  sentiment_value sentiment_word
# 32    aV6A5z8pJRkKIC9r      内饰                1             好看
# 33    aV6A5z8pJRkKIC9r      外观                1            NaN
# 45    M3Hqx1Un8ygzFTtl      动力                1            NaN
# 57    hszDKcUSek9dyP5o      动力                1             没烧
# 60    EKI7PjFs81Lc52uS      动力                1            杠杠的
# 66    sKPpYiV2bXWEjTLc      空间                1            NaN
# 72    aLs9AwhZ85vgiRbx      操控                1             好用
# 80    v6iprjTLdctoJW3b      动力                1             超车
# 81    RF9YTAlbQU5CagdN      外观                1             好看
# 84    hcWAJdmC9avz7MU1      操控                1             漂移
# 87    QRw7ngTJ2A5CYBGW      动力                1           全时四驱
# 88    06vPIQBqVNe2dl3f      动力                1           全时四驱
# 107   x6mbO2rHfU3hTej4      内饰                1            NaN
# 110   HfSMToNXhrwY3mlk      动力                1             超车
# ...

# %%
new_result.to_csv('result++/final_result+++.csv', index = False)
